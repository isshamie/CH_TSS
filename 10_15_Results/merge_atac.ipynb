# %% [markdown]
# # Merge ATAC-seq bed files

# %%
tissues_with_atac = ['CHO','Brain','Liver','Lung','Kidney','Spleen','BMDMwt','BMDM1hKLA']

# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])
ref_fa = doc['ref_fa']
annotation=doc['annotation']

# %%
tss_annotation = doc['tss_annotation']

# %%
import os
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm
### notebook specific configuration ###
from os.path import basename
#mpl.style.use('ggplot')
mpl.style.use('fivethirtyeight')
from cycler import cycler
mpl.rcParams['axes.prop_cycle'] = cycler(color='bgrcmyk')

from Homer import *

print('Number of tissues: ',len(tissues))
# Out:
# ('Number of tissues: ', 15)

# %%
all_bed = []
for t in tissues_with_atac:
    all_bed = all_bed + glob.glob(os.path.join("Results/ATAC_results/",t,"*sort"))

cmd = "mergePeaks " + " ".join(all_bed) + " > Results/ATAC_results/ATAC_merge.merge"
#cmd = "bedtools merge -i " + " ".join(all_bed) + " > Results/ATAC_results/ATAC_merge.bed"
#!{cmd}
print(cmd)
# !{cmd}
# Out:
# mergePeaks Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort > Results/ATAC_results/ATAC_merge.merge
# 	Max distance to merge: direct overlap required (-d given)
# 	Merging peaks...
# 	Comparing Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total) and Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total)
# 	Comparing Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total) and Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total)
# 	Comparing Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total) and Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total)
# 	Comparing Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total) and Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total)
# 	Comparing Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total) and Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total)
# 	Comparing Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total) and Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total)
# 	Comparing Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total) and Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total)
# 	Comparing Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total) and Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total)
# 	Comparing Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total) and Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total)
# 	Comparing Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total) and Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total)
# 	Comparing Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total) and Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total)
# 	Comparing Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total) and Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total)
# 	Comparing Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total) and Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total)
# 	Comparing Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total) and Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total)
# 	Comparing Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total) and Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total)
# 	Comparing Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total) and Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total)
# 	Comparing Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total) and Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total)
# 	Comparing Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total) and Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total)
# 	Comparing Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total) and Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total)
# 	Comparing Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total) and Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total)
# 	Comparing Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total) and Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total)
# 	Comparing Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total) and Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total)
# 	Comparing Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total) and Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total)
# 	Comparing Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total) and Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total)
# 	Comparing Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total) and Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total)
# 	Comparing Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total) and Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total)
# 	Comparing Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total) and Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total)
# 	Comparing Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total) and Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total)
# 	Comparing Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total) and Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total)
# 	Comparing Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total) and Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total)
# 	Comparing Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total) and Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total)
# 	Comparing Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total) and Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total)
# 	Comparing Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total) and Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total)
# 	Comparing Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total) and Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total)
# 	Comparing Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total) and Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total)
# 	Comparing Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total) and Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total)
# 	Comparing Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total) and Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total)
# 	Comparing Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total) and Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total)
# 	Comparing Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total) and Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total)
# 	Comparing Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total) and Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total)
# 	Comparing Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total) and Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total)
# 	Comparing Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total) and Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total)
# 	Comparing Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total) and Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort (95911 total)
# 	Comparing Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total) and Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (107261 total)
# 	Comparing Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total) and Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (15864 total)
# 	Comparing Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total) and Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (38744 total)
# 	Comparing Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total) and Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (110536 total)
# 	Comparing Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total) and Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort (43561 total)
# 	Comparing Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total) and Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort (116204 total)
#
# Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort	Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort	Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort	Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort	Total	Name
# X				X			3111	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X				X		X	1458	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X				X	X		140	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X				X	X	X	261	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X						44388	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X					X	3693	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X				X		507	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X				X	X	328	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X			X			6660	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X			X		X	2310	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X			X	X		297	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X			X	X	X	636	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X	X	X				4	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X	X	X			X	15	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X	X	X		X		1	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X	X	X		X	X	14	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X	X	X	X			84	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X	X	X	X		X	515	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X	X	X	X	X		40	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X	X	X	X	X	X	5364	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 						X	47642	Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 					X		12265	Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 					X	X	2294	Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 				X			46771	Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 				X		X	3446	Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 				X	X		604	Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 				X	X	X	396	Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X		X	X				9	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X		X	X			X	12	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X		X	X		X		13	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X		X	X		X	X	19	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X		X	X	X			21	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X		X	X	X		X	29	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X		X	X	X	X		19	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X		X	X	X	X	X	86	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X	X	X				12	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X	X	X			X	17	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X	X	X		X		1	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X	X	X		X	X	14	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X	X	X	X			69	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X	X	X	X		X	188	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X	X	X	X	X		27	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X	X	X	X	X	X	560	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X	X					37	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X	X				X	34	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X	X			X		4	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X	X			X	X	8	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X	X		X			112	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X	X		X		X	304	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X	X		X	X		17	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X	X		X	X	X	212	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 		X	X				43	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 		X	X			X	25	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 		X	X		X		9	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 		X	X		X	X	26	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 		X	X	X			73	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 		X	X	X		X	54	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 		X	X	X	X		7	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 		X	X	X	X	X	51	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X		X					129	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X		X				X	47	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X		X			X		25	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X		X			X	X	20	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X		X		X			77	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X		X		X		X	51	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X		X		X	X		14	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X		X		X	X	X	32	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X	X					156	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X	X				X	43	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X	X			X		5	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X	X			X	X	8	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X		X				133	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X		X			X	231	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X		X		X		27	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X		X		X	X	142	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X	X		X			218	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X	X		X		X	144	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X	X		X	X		19	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X	X		X	X	X	59	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X		X	X			604	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X		X	X		X	2351	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X		X	X	X		186	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X		X	X	X	X	7040	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 		X					5031	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 		X				X	191	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 		X			X		82	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 		X			X	X	44	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X			X				352	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X			X			X	382	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X			X		X		72	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X			X		X	X	220	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 		X		X			779	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 		X		X		X	100	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 		X		X	X		32	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 		X		X	X	X	24	Results/ATAC_results/Liver/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X			X	X			345	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X			X	X		X	423	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X			X	X	X		73	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X			X	X	X	X	289	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X		X				553	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X		X			X	367	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X		X		X		42	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X		X		X	X	258	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X		X	X			1011	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X		X	X		X	1459	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 	X		X	X	X		172	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 	X		X	X	X	X	1680	Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X						3682	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X					X	1972	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X				X		119	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X				X	X	223	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X			X			2341	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X			X		X	2868	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X	X			X	X		274	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X	X			X	X	X	1217	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Brain/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 			X				3452	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 			X			X	1517	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 			X		X		374	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 			X		X	X	913	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 			X	X			1280	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 			X	X		X	597	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# 			X	X	X		147	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# 			X	X	X	X	358	Results/ATAC_results/Lung/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Kidney/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X							36632	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort
# X						X	6860	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort
# X					X		594	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort
# X					X	X	437	Results/ATAC_results/CHO/ATAC_ppr.naive_overlap.narrowPeak.sort|Results/ATAC_results/Spleen/ATAC_rep1-pr.naive_overlap.narrowPeak.sort|Results/ATAC_results/BMDMwt/ATAC_ppr.naive_overlap.narrowPeak.sort

# %%
merge_atac = pd.read_csv("Results/ATAC_results/ATAC_merge.merge",sep="\t",index_col=0)
merge_atac.sort_values(["chr","start","end","strand"],inplace=True)
merge_atac["strand"] = "."
merge_atac["Stat"] = merge_atac["Stat"].astype(int)
merge_atac["ID"] = merge_atac.index
merge_atac = merge_atac[["chr","start","end","ID","Stat","strand"]]

merge_atac.to_csv("Results/ATAC_results/ATAC_merge.bed",index=None,header=None,sep="\t")
merge_atac.head(100)
# Out:
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                        chr   start     end  \
# #name (cmd = mergePeaks Results/ATAC_results/CH...
# Merged-picr_0-10230-1                               picr_0   10156   10305
# Merged-picr_0-20899-9                               picr_0   20400   21233
# Merged-picr_0-44585-10                              picr_0   44038   44930
# Merged-picr_0-60409-1                               picr_0   60244   60575
# Merged-picr_0-69155-1                               picr_0   69031   69279
# Merged-picr_0-71827-2                               picr_0   71688   71969
# Merged-picr_0-72670-4                               picr_0   72332   72969
# Merged-picr_0-78130-11                              picr_0   77806   78482
# Merged-picr_0-78787-6                               picr_0   78561   79312
# Merged-picr_0-83968-5                               picr_0   83583   84372
# Merged-picr_0-87605-1                               picr_0   87525   87686
# Merged-picr_0-89514-2                               picr_0   89263   89791
# Merged-picr_0-91095-1                               picr_0   90958   91233
# Merged-picr_0-92722-4                               picr_0   92464   92922
# Merged-picr_0-96538-1                               picr_0   96412   96664
# Merged-picr_0-97019-1                               picr_0   96900   97139
# Merged-picr_0-98839-8                               picr_0   98439   99173
# Merged-picr_0-109187-1                              picr_0  109113  109262
# Merged-picr_0-109710-1                              picr_0  109612  109809
# Merged-picr_0-113089-1                              picr_0  113012  113167
# Merged-picr_0-120764-3                              picr_0  120327  121236
# Merged-picr_0-124133-3                              picr_0  123959  124254
# Merged-picr_0-132648-5                              picr_0  132363  132809
# Merged-picr_0-136606-7                              picr_0  136350  136889
# Merged-picr_0-140815-1                              picr_0  140568  141062
# Merged-picr_0-142110-2                              picr_0  141861  142294
# Merged-picr_0-145508-1                              picr_0  145354  145662
# Merged-picr_0-146684-1                              picr_0  146476  146893
# Merged-picr_0-147886-7                              picr_0  147451  148245
# Merged-picr_0-148764-3                              picr_0  148512  149077
# ...                                                    ...     ...     ...
# Merged-picr_0-347590-6                              picr_0  347248  347967
# Merged-picr_0-348901-2                              picr_0  348749  349065
# Merged-picr_0-355636-4                              picr_0  355233  355951
# Merged-picr_0-361519-1                              picr_0  361409  361629
# Merged-picr_0-363361-1                              picr_0  363223  363499
# Merged-picr_0-363706-1                              picr_0  363602  363811
# Merged-picr_0-364389-7                              picr_0  364003  364610
# Merged-picr_0-368508-1                              picr_0  368352  368665
# Merged-picr_0-369753-1                              picr_0  369623  369884
# Merged-picr_0-370743-1                              picr_0  370626  370860
# Merged-picr_0-375715-2                              picr_0  375561  375856
# Merged-picr_0-377485-1                              picr_0  377313  377658
# Merged-picr_0-382729-4                              picr_0  382479  382933
# Merged-picr_0-383547-1                              picr_0  383364  383731
# Merged-picr_0-386096-1                              picr_0  385946  386246
# Merged-picr_0-387169-1                              picr_0  386957  387381
# Merged-picr_0-388522-1                              picr_0  388251  388794
# Merged-picr_0-390091-1                              picr_0  389987  390196
# Merged-picr_0-396862-1                              picr_0  396776  396949
# Merged-picr_0-398860-9                              picr_0  398460  399172
# Merged-picr_0-399611-1                              picr_0  399493  399729
# Merged-picr_0-405332-1                              picr_0  405216  405449
# Merged-picr_0-407752-1                              picr_0  407566  407939
# Merged-picr_0-410341-1                              picr_0  410214  410468
# Merged-picr_0-411089-5                              picr_0  410816  411402
# Merged-picr_0-412992-4                              picr_0  412868  413105
# Merged-picr_0-418616-3                              picr_0  418184  418973
# Merged-picr_0-429315-2                              picr_0  429139  429492
# Merged-picr_0-432721-1                              picr_0  432509  432934
# Merged-picr_0-440991-6                              picr_0  440719  441213
#
#                                                                         ID  \
# #name (cmd = mergePeaks Results/ATAC_results/CH...
# Merged-picr_0-10230-1                                Merged-picr_0-10230-1
# Merged-picr_0-20899-9                                Merged-picr_0-20899-9
# Merged-picr_0-44585-10                              Merged-picr_0-44585-10
# Merged-picr_0-60409-1                                Merged-picr_0-60409-1
# Merged-picr_0-69155-1                                Merged-picr_0-69155-1
# Merged-picr_0-71827-2                                Merged-picr_0-71827-2
# Merged-picr_0-72670-4                                Merged-picr_0-72670-4
# Merged-picr_0-78130-11                              Merged-picr_0-78130-11
# Merged-picr_0-78787-6                                Merged-picr_0-78787-6
# Merged-picr_0-83968-5                                Merged-picr_0-83968-5
# Merged-picr_0-87605-1                                Merged-picr_0-87605-1
# Merged-picr_0-89514-2                                Merged-picr_0-89514-2
# Merged-picr_0-91095-1                                Merged-picr_0-91095-1
# Merged-picr_0-92722-4                                Merged-picr_0-92722-4
# Merged-picr_0-96538-1                                Merged-picr_0-96538-1
# Merged-picr_0-97019-1                                Merged-picr_0-97019-1
# Merged-picr_0-98839-8                                Merged-picr_0-98839-8
# Merged-picr_0-109187-1                              Merged-picr_0-109187-1
# Merged-picr_0-109710-1                              Merged-picr_0-109710-1
# Merged-picr_0-113089-1                              Merged-picr_0-113089-1
# Merged-picr_0-120764-3                              Merged-picr_0-120764-3
# Merged-picr_0-124133-3                              Merged-picr_0-124133-3
# Merged-picr_0-132648-5                              Merged-picr_0-132648-5
# Merged-picr_0-136606-7                              Merged-picr_0-136606-7
# Merged-picr_0-140815-1                              Merged-picr_0-140815-1
# Merged-picr_0-142110-2                              Merged-picr_0-142110-2
# Merged-picr_0-145508-1                              Merged-picr_0-145508-1
# Merged-picr_0-146684-1                              Merged-picr_0-146684-1
# Merged-picr_0-147886-7                              Merged-picr_0-147886-7
# Merged-picr_0-148764-3                              Merged-picr_0-148764-3
# ...                                                                    ...
# Merged-picr_0-347590-6                              Merged-picr_0-347590-6
# Merged-picr_0-348901-2                              Merged-picr_0-348901-2
# Merged-picr_0-355636-4                              Merged-picr_0-355636-4
# Merged-picr_0-361519-1                              Merged-picr_0-361519-1
# Merged-picr_0-363361-1                              Merged-picr_0-363361-1
# Merged-picr_0-363706-1                              Merged-picr_0-363706-1
# Merged-picr_0-364389-7                              Merged-picr_0-364389-7
# Merged-picr_0-368508-1                              Merged-picr_0-368508-1
# Merged-picr_0-369753-1                              Merged-picr_0-369753-1
# Merged-picr_0-370743-1                              Merged-picr_0-370743-1
# Merged-picr_0-375715-2                              Merged-picr_0-375715-2
# Merged-picr_0-377485-1                              Merged-picr_0-377485-1
# Merged-picr_0-382729-4                              Merged-picr_0-382729-4
# Merged-picr_0-383547-1                              Merged-picr_0-383547-1
# Merged-picr_0-386096-1                              Merged-picr_0-386096-1
# Merged-picr_0-387169-1                              Merged-picr_0-387169-1
# Merged-picr_0-388522-1                              Merged-picr_0-388522-1
# Merged-picr_0-390091-1                              Merged-picr_0-390091-1
# Merged-picr_0-396862-1                              Merged-picr_0-396862-1
# Merged-picr_0-398860-9                              Merged-picr_0-398860-9
# Merged-picr_0-399611-1                              Merged-picr_0-399611-1
# Merged-picr_0-405332-1                              Merged-picr_0-405332-1
# Merged-picr_0-407752-1                              Merged-picr_0-407752-1
# Merged-picr_0-410341-1                              Merged-picr_0-410341-1
# Merged-picr_0-411089-5                              Merged-picr_0-411089-5
# Merged-picr_0-412992-4                              Merged-picr_0-412992-4
# Merged-picr_0-418616-3                              Merged-picr_0-418616-3
# Merged-picr_0-429315-2                              Merged-picr_0-429315-2
# Merged-picr_0-432721-1                              Merged-picr_0-432721-1
# Merged-picr_0-440991-6                              Merged-picr_0-440991-6
#
#                                                     Stat strand
# #name (cmd = mergePeaks Results/ATAC_results/CH...
# Merged-picr_0-10230-1                                  0      .
# Merged-picr_0-20899-9                                  0      .
# Merged-picr_0-44585-10                                 0      .
# Merged-picr_0-60409-1                                  0      .
# Merged-picr_0-69155-1                                  0      .
# Merged-picr_0-71827-2                                  0      .
# Merged-picr_0-72670-4                                  0      .
# Merged-picr_0-78130-11                                 0      .
# Merged-picr_0-78787-6                                  0      .
# Merged-picr_0-83968-5                                  0      .
# Merged-picr_0-87605-1                                  0      .
# Merged-picr_0-89514-2                                  0      .
# Merged-picr_0-91095-1                                  0      .
# Merged-picr_0-92722-4                                  0      .
# Merged-picr_0-96538-1                                  0      .
# Merged-picr_0-97019-1                                  0      .
# Merged-picr_0-98839-8                                  0      .
# Merged-picr_0-109187-1                                 0      .
# Merged-picr_0-109710-1                                 0      .
# Merged-picr_0-113089-1                                 0      .
# Merged-picr_0-120764-3                                 0      .
# Merged-picr_0-124133-3                                 0      .
# Merged-picr_0-132648-5                                 0      .
# Merged-picr_0-136606-7                                 0      .
# Merged-picr_0-140815-1                                 0      .
# Merged-picr_0-142110-2                                 0      .
# Merged-picr_0-145508-1                                 0      .
# Merged-picr_0-146684-1                                 0      .
# Merged-picr_0-147886-7                                 0      .
# Merged-picr_0-148764-3                                 0      .
# ...                                                  ...    ...
# Merged-picr_0-347590-6                                 0      .
# Merged-picr_0-348901-2                                 0      .
# Merged-picr_0-355636-4                                 0      .
# Merged-picr_0-361519-1                                 0      .
# Merged-picr_0-363361-1                                 0      .
# Merged-picr_0-363706-1                                 0      .
# Merged-picr_0-364389-7                                 0      .
# Merged-picr_0-368508-1                                 0      .
# Merged-picr_0-369753-1                                 0      .
# Merged-picr_0-370743-1                                 0      .
# Merged-picr_0-375715-2                                 0      .
# Merged-picr_0-377485-1                                 0      .
# Merged-picr_0-382729-4                                 0      .
# Merged-picr_0-383547-1                                 0      .
# Merged-picr_0-386096-1                                 0      .
# Merged-picr_0-387169-1                                 0      .
# Merged-picr_0-388522-1                                 0      .
# Merged-picr_0-390091-1                                 0      .
# Merged-picr_0-396862-1                                 0      .
# Merged-picr_0-398860-9                                 0      .
# Merged-picr_0-399611-1                                 0      .
# Merged-picr_0-405332-1                                 0      .
# Merged-picr_0-407752-1                                 0      .
# Merged-picr_0-410341-1                                 0      .
# Merged-picr_0-411089-5                                 0      .
# Merged-picr_0-412992-4                                 0      .
# Merged-picr_0-418616-3                                 0      .
# Merged-picr_0-429315-2                                 0      .
# Merged-picr_0-432721-1                                 0      .
# Merged-picr_0-440991-6                                 0      .
#
# [100 rows x 6 columns]
