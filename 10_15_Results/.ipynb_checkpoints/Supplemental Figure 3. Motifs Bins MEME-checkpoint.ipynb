# %% [markdown]
# # 1. Environment Setup

# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])
ref_fa = doc['ref_fa']
anno_gff=doc['annotation']
mRNA_peak_file = doc["mRNA_peak_file"]

tss_annotation = doc['tss_annotation']

import os
os.chdir
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm
import time

from os.path import basename
##mpl.use('Agg')
#mpl.style.use('ggplot')
#mpl.style.use('fivethirtyeight')
from Homer import *

print('Number of tissues: ',len(tissues))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ('Number of tissues: ', 15)

# %%
from create_output import *

# %%
sys.path.append("/home/isshamie/software/homebrew/parallel_functions/")
import parallel_functions as pf

# %%
import motif_analysis

# %%
motif_folder = doc['motif_folder']
motifs_of_interest = map(lambda x: os.path.basename(x).split('.')[0],glob.glob(motif_folder + '/*motif'))
motifs_of_interest
# Out:
# ['scl',
#  'cdx2',
#  'fli',
#  'pu1',
#  'elf3',
#  'klf10',
#  'sp5',
#  'oct2',
#  'ebna1',
#  'phox2a',
#  'hinfp',
#  'bcl6',
#  'smad4',
#  'pknox1',
#  'gata3',
#  'myf5',
#  'staf',
#  'pbx2',
#  'tbet',
#  'znf528',
#  'pax7-longest',
#  'spdef',
#  'tra',
#  'klf14',
#  'nrf',
#  'p53-myc',
#  'gata3',
#  'sp2',
#  'foxa1',
#  'hif2a',
#  'vdr',
#  'znf264',
#  'gabp',
#  'tead',
#  'irf1',
#  'sf1',
#  'znf136',
#  'p65',
#  'klf6',
#  'stat6',
#  'tcf7l2',
#  'zscan22',
#  'six4',
#  'gfi1b',
#  'foxl2',
#  'tr4',
#  'gata3',
#  'mef2d',
#  'grhl2',
#  'ptf1a',
#  'znf322',
#  'lxre',
#  'ar-half',
#  'npas',
#  'fosl2',
#  'arnt',
#  'gata3',
#  'lhx2',
#  'nfat-ap1',
#  'ets-runx',
#  'erg',
#  'meis1',
#  'tbx20',
#  'znf675',
#  'hoxd12',
#  'nfatc1',
#  'rfx2',
#  'znf415',
#  'hnf1b',
#  'e2f6',
#  'usf2',
#  'foxo3',
#  'pit1-long',
#  'ews-fli1',
#  'oct',
#  'ehf',
#  'are-fox',
#  'pax3-fkhr',
#  'jun-cre',
#  'sox3',
#  'limb',
#  'runx1m',
#  'tfe3',
#  'stat1',
#  'couptf2',
#  'heb',
#  'zfp809',
#  'nfy',
#  'gata2',
#  'p53',
#  'zfp281',
#  'brn2',
#  'jun-ap1',
#  'elf1',
#  'rxr',
#  'atf7',
#  'zic3',
#  'foxa2',
#  'pax5',
#  'pax7-long',
#  'znf416',
#  'boris',
#  'isre',
#  'reverb',
#  'cebp-cebp',
#  'hoxb13',
#  'dmrt1',
#  'zbtb12',
#  'pax8',
#  'max',
#  'hnf6',
#  'rfx6',
#  'nrf2',
#  'bapx1',
#  'pbx1',
#  'e47',
#  'zkscan1',
#  'tata',
#  'znf519',
#  'tcf4',
#  'dmc1',
#  'znf16',
#  'lrh1',
#  'pparg',
#  'cebp-ap1',
#  'bzip-irf',
#  'dr5',
#  'srebp1a',
#  'egr2',
#  'jund',
#  'dux4',
#  'six2',
#  'cmyc',
#  'chr',
#  'sp1',
#  'lef1',
#  'mef2a',
#  'oct-oct',
#  'gre-raw',
#  'bach1',
#  'ets-ebox',
#  'gre',
#  'znf263',
#  'hoxd10',
#  'irf3',
#  'bhlhe40',
#  'znf669',
#  'klf9',
#  'oct4-sox17',
#  'mafk',
#  'ets',
#  'tcfcp2l1',
#  'rbpj1-ebox',
#  'pbx3',
#  'gfy',
#  'pit1',
#  'mef2b',
#  'nf1',
#  'tbx21',
#  'gata3',
#  'pax5-short',
#  'tcf12',
#  'elk4',
#  'nanog',
#  'runx1',
#  'etv2',
#  'klf3',
#  'sox17',
#  'znf711',
#  'hsf',
#  'foxk2',
#  'erra',
#  'tgif2',
#  'nkx2',
#  'crx',
#  'ascl1',
#  'atoh1',
#  'nmyc',
#  'ap2',
#  'bmal',
#  'tgif1',
#  'ews-erg',
#  'stat3',
#  'prdm1',
#  'myba',
#  'couptf1',
#  'lhx3',
#  'oct6',
#  'etv1',
#  'smad3',
#  'nkx2',
#  'isl1',
#  'e2f1',
#  'foxa3',
#  'ets-distal',
#  'rfx5',
#  'gata4',
#  'tead4',
#  'lhx1',
#  'znf692',
#  'oct4-sox2',
#  'atf2',
#  'foxp1',
#  'tbr1',
#  'rbpj1',
#  'trb',
#  'rfx1',
#  'thrb',
#  'nf1-half',
#  'ebf-old',
#  'fra1',
#  'tlx',
#  'sox15',
#  'foxk1',
#  'hif1a',
#  'tead2',
#  'ere',
#  'irf8',
#  'pr',
#  'npas2',
#  'pu1-irf',
#  'batf',
#  'oct',
#  'atf4',
#  'hoxa13',
#  'e2f',
#  'nfe2l2',
#  'egr1',
#  'gfy-staf',
#  'gli',
#  'ap4',
#  'sox2',
#  'gfx',
#  'sox10',
#  'tead3',
#  'sox4',
#  'xbox',
#  'hif1b',
#  'znf165',
#  'nrf1',
#  'myog',
#  'snai2',
#  'zic',
#  'rorc',
#  'gata',
#  'srf',
#  'gata-scl',
#  'barx1',
#  'otx2',
#  'p63',
#  'brachyury',
#  'e2f4',
#  'rara',
#  'atf1',
#  'stat5',
#  'zbtb18',
#  'prop1',
#  'znf317',
#  'pax6',
#  'pitx1-ebox',
#  'ronin',
#  'nkx2',
#  'hand2',
#  'cux2',
#  'elk1',
#  'hoxd11',
#  'cMyc',
#  'chop',
#  'neurog2',
#  'ebf',
#  'esrrb',
#  'cebp',
#  'clock',
#  'bach2',
#  'stat4',
#  'mafa',
#  'atf3',
#  'sox9',
#  'hoxc9',
#  'twist1',
#  'pitx1',
#  'dr0',
#  'tcf3',
#  'gata6',
#  'zfp3',
#  'smad2',
#  'p73',
#  'es',
#  'ebox',
#  'foxo1',
#  'nfkb',
#  'gsc',
#  'nr5a2',
#  'nfil3',
#  'spib',
#  'e2f3',
#  'elf5',
#  'nkx6',
#  'hlf',
#  'rfx3',
#  'stat3',
#  'nfe2',
#  'runx2',
#  'mafF',
#  'tcf21',
#  'fra2',
#  'cre',
#  'myb',
#  'prdm14',
#  'e2f7',
#  'mitf',
#  'ets1',
#  'znf41',
#  'yy1',
#  'zfx',
#  'prdm9',
#  'batf3-irf8',
#  'hnf4',
#  'prdm10',
#  'irf2',
#  'nr2f6',
#  'maz',
#  'brn1',
#  'klf4',
#  'lrf',
#  'hsf1',
#  'oct-oct',
#  'irf4',
#  'eklf',
#  'klf5',
#  'hnf1',
#  't1isre',
#  'sox6',
#  'mafb',
#  'znf652',
#  'znf467',
#  'pgr',
#  'znf7',
#  'dmrt6',
#  'neurod1',
#  'hoxa9',
#  'pu1-irf8',
#  'usf1',
#  'stat6',
#  'p50',
#  'tbox-smad',
#  'pdx1',
#  'ctcf',
#  'foxm1',
#  'nf1-fox',
#  'fxr',
#  'tbx5',
#  'nur77',
#  'fox-ebox',
#  'pax7',
#  'hoxb4',
#  'junb',
#  'six1',
#  'bmyb',
#  'tcf7',
#  'hoxa2',
#  'rest',
#  'zeb1',
#  'cdx4',
#  'tead1',
#  'znf189',
#  'hoxa11',
#  'mef2c',
#  'runx',
#  'ctcf-mys',
#  'ap2gamma',
#  'hoxd13',
#  'srebp2',
#  'eomes',
#  'oct4',
#  'nkx3',
#  'foxa1',
#  'foxh1',
#  'myod',
#  'scrt1',
#  'e2a',
#  'etv4',
#  'are',
#  'ap1',
#  'znf382',
#  'rarg',
#  'zbtb33',
#  'hoxa10',
#  'mynn',
#  'mnt',
#  'olig2',
#  'foxf1']

# %% [markdown]
# ## Create directory

# %%
out_dir = "Results/Figures/SuppFigure3/"
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ## Create Fasta file for the output bed sequences

# %%
bed_file = "Results/output/TSS1.exp.bed"
out_f = os.path.join(out_dir,"TSS1.exp.fa")
cmd = "homerTools extract {bed_f} {ref_fa} -fa > {out_f}".format(bed_f=bed_file,ref_fa=ref_fa,out_f=out_f)
# !{cmd}
#Homer.extract_peak_sequences(bed_file,peak_list,genome,f_save,upstream=1000,downstream=100)
# Out:
# 	Extracting sequences from file: /data/isshamie/genome/picr_final/picr.fa
# 	Looking for peak sequences in a single file (/data/isshamie/genome/picr_final/picr.fa)
# 	Extracting 1425 sequences from picr_0
# 	Extracting 751 sequences from picr_4
# 	Extracting 541 sequences from picr_5
# 	Extracting 446 sequences from picr_12
# 	Extracting 423 sequences from picr_13
# 	Extracting 399 sequences from picr_15
# 	Extracting 211 sequences from picr_17
# 	Extracting 275 sequences from picr_18
# 	Extracting 350 sequences from picr_19
# 	Extracting 403 sequences from picr_20
# 	Extracting 249 sequences from picr_21
# 	Extracting 754 sequences from picr_22
# 	Extracting 133 sequences from picr_26
# 	Extracting 397 sequences from picr_27
# 	Extracting 209 sequences from picr_28
# 	Extracting 169 sequences from picr_31
# 	Extracting 102 sequences from picr_32
# 	Extracting 250 sequences from picr_33
# 	Extracting 658 sequences from picr_35
# 	Extracting 271 sequences from picr_36
# 	Extracting 131 sequences from picr_42
# 	Extracting 207 sequences from picr_44
# 	Extracting 152 sequences from picr_45
# 	Extracting 141 sequences from picr_46
# 	Extracting 218 sequences from picr_48
# 	Extracting 143 sequences from picr_49
# 	Extracting 278 sequences from picr_50
# 	Extracting 148 sequences from picr_51
# 	Extracting 342 sequences from picr_53
# 	Extracting 317 sequences from picr_54
# 	Extracting 266 sequences from picr_56
# 	Extracting 234 sequences from picr_57
# 	Extracting 366 sequences from picr_58
# 	Extracting 386 sequences from picr_59
# 	Extracting 56 sequences from picr_60
# 	Extracting 380 sequences from picr_61
# 	Extracting 271 sequences from picr_62
# 	Extracting 151 sequences from picr_63
# 	Extracting 108 sequences from picr_64
# 	Extracting 153 sequences from picr_65
# 	Extracting 161 sequences from picr_66
# 	Extracting 61 sequences from picr_67
# 	Extracting 66 sequences from picr_68
# 	Extracting 99 sequences from picr_69
# 	Extracting 211 sequences from picr_71
# 	Extracting 87 sequences from picr_72
# 	Extracting 162 sequences from picr_73
# 	Extracting 411 sequences from picr_74
# 	Extracting 175 sequences from picr_75
# 	Extracting 67 sequences from picr_76
# 	Extracting 67 sequences from picr_77
# 	Extracting 147 sequences from picr_79
# 	Extracting 57 sequences from picr_80
# 	Extracting 50 sequences from picr_81
# 	Extracting 76 sequences from picr_82
# 	Extracting 167 sequences from picr_83
# 	Extracting 212 sequences from picr_84
# 	Extracting 296 sequences from picr_85
# 	Extracting 60 sequences from picr_86
# 	Extracting 188 sequences from picr_87
# 	Extracting 138 sequences from picr_88
# 	Extracting 61 sequences from picr_90
# 	Extracting 67 sequences from picr_91
# 	Extracting 53 sequences from picr_92
# 	Extracting 359 sequences from picr_93
# 	Extracting 112 sequences from picr_94
# 	Extracting 77 sequences from picr_95
# 	Extracting 124 sequences from picr_96
# 	Extracting 30 sequences from picr_97
# 	Extracting 211 sequences from picr_98
# 	Extracting 21 sequences from picr_99
# 	Extracting 126 sequences from picr_100
# 	Extracting 124 sequences from picr_101
# 	Extracting 66 sequences from picr_102
# 	Extracting 27 sequences from picr_104
# 	Extracting 107 sequences from picr_105
# 	Extracting 78 sequences from picr_109
# 	Extracting 53 sequences from picr_110
# 	Extracting 102 sequences from picr_111
# 	Extracting 45 sequences from picr_112
# 	Extracting 80 sequences from picr_113
# 	Extracting 27 sequences from picr_114
# 	Extracting 86 sequences from picr_115
# 	Extracting 46 sequences from picr_116
# 	Extracting 175 sequences from picr_117
# 	Extracting 62 sequences from picr_118
# 	Extracting 266 sequences from picr_119
# 	Extracting 235 sequences from picr_120
# 	Extracting 103 sequences from picr_122
# 	Extracting 74 sequences from picr_123
# 	Extracting 66 sequences from picr_124
# 	Extracting 49 sequences from picr_125
# 	Extracting 36 sequences from picr_126
# 	Extracting 137 sequences from picr_127
# 	Extracting 35 sequences from picr_128
# 	Extracting 13 sequences from picr_129
# 	Extracting 233 sequences from picr_130
# 	Extracting 45 sequences from picr_131
# 	Extracting 258 sequences from picr_132
# 	Extracting 134 sequences from picr_133
# 	Extracting 30 sequences from picr_134
# 	Extracting 53 sequences from picr_135
# 	Extracting 129 sequences from picr_136
# 	Extracting 53 sequences from picr_137
# 	Extracting 146 sequences from picr_138
# 	Extracting 129 sequences from picr_139
# 	Extracting 34 sequences from picr_140
# 	Extracting 27 sequences from picr_141
# 	Extracting 22 sequences from picr_142
# 	Extracting 24 sequences from picr_143
# 	Extracting 35 sequences from picr_144
# 	Extracting 29 sequences from picr_145
# 	Extracting 36 sequences from picr_146
# 	Extracting 50 sequences from picr_148
# 	Extracting 25 sequences from picr_149
# 	Extracting 30 sequences from picr_151
# 	Extracting 40 sequences from picr_152
# 	Extracting 53 sequences from picr_153
# 	Extracting 149 sequences from picr_154
# 	Extracting 47 sequences from picr_155
# 	Extracting 125 sequences from picr_157
# 	Extracting 127 sequences from picr_158
# 	Extracting 23 sequences from picr_159
# 	Extracting 9 sequences from picr_160
# 	Extracting 86 sequences from picr_161
# 	Extracting 32 sequences from picr_162
# 	Extracting 30 sequences from picr_163
# 	Extracting 17 sequences from picr_164
# 	Extracting 74 sequences from picr_166
# 	Extracting 80 sequences from picr_167
# 	Extracting 17 sequences from picr_168
# 	Extracting 28 sequences from picr_169
# 	Extracting 8 sequences from picr_170
# 	Extracting 20 sequences from picr_171
# 	Extracting 18 sequences from picr_172
# 	Extracting 36 sequences from picr_173
# 	Extracting 47 sequences from picr_174
# 	Extracting 5 sequences from picr_176
# 	Extracting 1 sequences from picr_177
# 	Extracting 18 sequences from picr_178
# 	Extracting 1 sequences from picr_180
# 	Extracting 4 sequences from picr_182
# 	Extracting 32 sequences from picr_183
# 	Extracting 1 sequences from picr_184
# 	Extracting 41 sequences from picr_185
# 	Extracting 34 sequences from picr_186
# 	Extracting 17 sequences from picr_187
# 	Extracting 20 sequences from picr_188
# 	Extracting 30 sequences from picr_191
# 	Extracting 29 sequences from picr_192
# 	Extracting 7 sequences from picr_193
# 	Extracting 52 sequences from picr_195
# 	Extracting 3 sequences from picr_198
# 	Extracting 7 sequences from picr_199
# 	Extracting 28 sequences from picr_200
# 	Extracting 1 sequences from picr_201
# 	Extracting 20 sequences from picr_209
# 	Extracting 2 sequences from picr_211
# 	Extracting 1 sequences from picr_222
# 	Extracting 4 sequences from picr_231
# 	Extracting 5 sequences from picr_232
# 	Extracting 2 sequences from picr_234
# 	Extracting 12 sequences from picr_235
# 	Extracting 5 sequences from picr_244
# 	Extracting 2 sequences from picr_245
# 	Extracting 2 sequences from picr_248
# 	Extracting 1 sequences from picr_250
# 	Extracting 2 sequences from picr_251
# 	Extracting 6 sequences from picr_253
# 	Extracting 1 sequences from picr_263
# 	Extracting 5 sequences from picr_265
# 	Extracting 4 sequences from picr_268
# 	Extracting 2 sequences from picr_269
# 	Extracting 2 sequences from picr_274
# 	Extracting 2 sequences from picr_276
# 	Extracting 2 sequences from picr_279
# 	Extracting 2 sequences from picr_289
# 	Extracting 4 sequences from picr_296
# 	Extracting 5 sequences from picr_298
# 	Extracting 1 sequences from picr_303
# 	Extracting 1 sequences from picr_309
# 	Extracting 1 sequences from picr_310
# 	Extracting 10 sequences from picr_312
# 	Extracting 2 sequences from picr_316
# 	Extracting 4 sequences from picr_317
# 	Extracting 3 sequences from picr_323
# 	Extracting 2 sequences from picr_328
# 	Extracting 2 sequences from picr_329
# 	Extracting 1 sequences from picr_331
# 	Extracting 2 sequences from picr_332
# 	Extracting 2 sequences from picr_334
# 	Extracting 1 sequences from picr_341
# 	Extracting 2 sequences from picr_342
# 	Extracting 1 sequences from picr_348
# 	Extracting 1 sequences from picr_349
# 	Extracting 1 sequences from picr_353
# 	Extracting 2 sequences from picr_355
# 	Extracting 1 sequences from picr_356
# 	Extracting 2 sequences from picr_358
# 	Extracting 1 sequences from picr_361
# 	Extracting 2 sequences from picr_362
# 	Extracting 2 sequences from picr_367
# 	Extracting 2 sequences from picr_374
# 	Extracting 1 sequences from picr_375
# 	Extracting 12 sequences from picr_378
# 	Extracting 2 sequences from picr_380
# 	Extracting 4 sequences from picr_400
# 	Extracting 1 sequences from picr_412
# 	Extracting 1 sequences from picr_413
# 	Extracting 2 sequences from picr_415
# 	Extracting 1 sequences from picr_432
# 	Extracting 1 sequences from picr_433
# 	Extracting 2 sequences from picr_434
# 	Extracting 3 sequences from picr_435
# 	Extracting 3 sequences from picr_438
# 	Extracting 3 sequences from picr_456
# 	Extracting 1 sequences from picr_458
# 	Extracting 1 sequences from picr_463
# 	Extracting 2 sequences from picr_474
# 	Extracting 3 sequences from picr_477
# 	Extracting 1 sequences from picr_478
# 	Extracting 1 sequences from picr_480
# 	Extracting 1 sequences from picr_488
# 	Extracting 2 sequences from picr_492
# 	Extracting 1 sequences from picr_493
# 	Extracting 3 sequences from picr_498
# 	Extracting 1 sequences from picr_507
# 	Extracting 1 sequences from picr_509
# 	Extracting 3 sequences from picr_512
# 	Extracting 2 sequences from picr_517
# 	Extracting 4 sequences from picr_529
# 	Extracting 2 sequences from picr_534
# 	Extracting 2 sequences from picr_561
# 	Extracting 1 sequences from picr_566
# 	Extracting 8 sequences from picr_591
# 	Extracting 1 sequences from picr_603
# 	Extracting 1 sequences from picr_606
# 	Extracting 1 sequences from picr_608
# 	Extracting 1 sequences from picr_622
# 	Extracting 1 sequences from picr_653
# 	Extracting 1 sequences from picr_654
# 	Extracting 1 sequences from picr_676
# 	Extracting 1 sequences from picr_688
# 	Extracting 3 sequences from picr_709
# 	Extracting 1 sequences from picr_721
# 	Extracting 2 sequences from picr_769
# 	Extracting 3 sequences from picr_776
# 	Extracting 1 sequences from picr_778
# 	Extracting 1 sequences from picr_817
# 	Extracting 2 sequences from picr_824
# 	Extracting 1 sequences from picr_843
# 	Extracting 2 sequences from picr_853
# 	Extracting 1 sequences from picr_854
# 	Extracting 1 sequences from picr_885
# 	Extracting 2 sequences from picr_911
# 	Extracting 1 sequences from picr_954
# 	Extracting 1 sequences from picr_964
# 	Extracting 1 sequences from picr_997
# 	Extracting 1 sequences from picr_1030
# 	Extracting 1 sequences from picr_1034
# 	Extracting 2 sequences from picr_1046
# 	Extracting 1 sequences from picr_1059
# 	Extracting 1 sequences from picr_1064
# 	Extracting 1 sequences from picr_1097
# 	Extracting 2 sequences from picr_1137
# 	Extracting 2 sequences from picr_1165
# 	Extracting 1 sequences from picr_1232
# 	Extracting 1 sequences from picr_1410
# 	Extracting 1 sequences from picr_1425
# 	Extracting 1 sequences from picr_1490
# 	Extracting 1 sequences from picr_1501
# 	Extracting 2 sequences from picr_1503
# 	Extracting 1 sequences from picr_1628
# 	Extracting 3 sequences from picr_1669
# 	Extracting 1 sequences from picr_1677
# 	Extracting 5 sequences from picr_1757
# 	Extracting 239 sequences from picr_7a
# 	Extracting 810 sequences from picr_1
# 	Extracting 553 sequences from picr_10
# 	Extracting 273 sequences from picr_103
# 	Extracting 197 sequences from picr_106
# 	Extracting 26 sequences from picr_107
# 	Extracting 146 sequences from picr_108
# 	Extracting 378 sequences from picr_11
# 	Extracting 51 sequences from picr_121
# 	Extracting 307 sequences from picr_14
# 	Extracting 438 sequences from picr_16
# 	Extracting 1145 sequences from picr_2
# 	Extracting 544 sequences from picr_23
# 	Extracting 508 sequences from picr_24
# 	Extracting 115 sequences from picr_25
# 	Extracting 374 sequences from picr_29
# 	Extracting 818 sequences from picr_3
# 	Extracting 146 sequences from picr_30
# 	Extracting 218 sequences from picr_34
# 	Extracting 156 sequences from picr_37
# 	Extracting 353 sequences from picr_38
# 	Extracting 353 sequences from picr_39
# 	Extracting 2 sequences from picr_393
# 	Extracting 342 sequences from picr_40
# 	Extracting 187 sequences from picr_41
# 	Extracting 221 sequences from picr_43
# 	Extracting 289 sequences from picr_47
# 	Extracting 492 sequences from picr_52
# 	Extracting 169 sequences from picr_55
# 	Extracting 529 sequences from picr_6
# 	Extracting 361 sequences from picr_70
# 	Extracting 111 sequences from picr_78
# 	Extracting 1174 sequences from picr_8
# 	Extracting 233 sequences from picr_89
# 	Extracting 494 sequences from picr_9
# 	Extracting 144 sequences from picr_7b

# %% [markdown]
# ## Do the same for reference. Also need to create the bed file beforehand

# %%
bed_f = "Results/output/TSS1.exp.bed"
meta_f = "Results/output/TSS1.exp.meta"
save_f = os.path.join(out_dir,"TSS1.exp_refseq_centered.bed")
refseq_f = mRNA_peak_file
exp_bed_to_refseq(bed_f, meta_f, refseq_f, save_f = save_f)
out_f= os.path.join(out_dir,os.path.basename(save_f).replace(".bed",".fa"))

cmd = "homerTools extract {bed_f} {ref_fa} -fa > {out_f}".format(bed_f=save_f,ref_fa=ref_fa,out_f=out_f)
print(cmd)
# !{cmd}
# Out:
# homerTools extract Results/Figures/SuppFigure3/TSS1.exp_refseq_centered.bed /data/isshamie/genome/picr_final/picr.fa -fa > Results/Figures/SuppFigure3/TSS1.exp_refseq_centered.fa
#
# 	Extracting sequences from file: /data/isshamie/genome/picr_final/picr.fa
# 	Looking for peak sequences in a single file (/data/isshamie/genome/picr_final/picr.fa)
# 	Extracting 1425 sequences from picr_0
# 	Extracting 751 sequences from picr_4
# 	Extracting 541 sequences from picr_5
# 	Extracting 446 sequences from picr_12
# 	Extracting 423 sequences from picr_13
# 	Extracting 399 sequences from picr_15
# 	Extracting 211 sequences from picr_17
# 	Extracting 275 sequences from picr_18
# 	Extracting 350 sequences from picr_19
# 	Extracting 403 sequences from picr_20
# 	Extracting 249 sequences from picr_21
# 	Extracting 754 sequences from picr_22
# 	Extracting 133 sequences from picr_26
# 	Extracting 397 sequences from picr_27
# 	Extracting 209 sequences from picr_28
# 	Extracting 169 sequences from picr_31
# 	Extracting 102 sequences from picr_32
# 	Extracting 250 sequences from picr_33
# 	Extracting 658 sequences from picr_35
# 	Extracting 271 sequences from picr_36
# 	Extracting 131 sequences from picr_42
# 	Extracting 207 sequences from picr_44
# 	Extracting 152 sequences from picr_45
# 	Extracting 141 sequences from picr_46
# 	Extracting 218 sequences from picr_48
# 	Extracting 143 sequences from picr_49
# 	Extracting 278 sequences from picr_50
# 	Extracting 148 sequences from picr_51
# 	Extracting 342 sequences from picr_53
# 	Extracting 317 sequences from picr_54
# 	Extracting 266 sequences from picr_56
# 	Extracting 234 sequences from picr_57
# 	Extracting 366 sequences from picr_58
# 	Extracting 386 sequences from picr_59
# 	Extracting 56 sequences from picr_60
# 	Extracting 380 sequences from picr_61
# 	Extracting 271 sequences from picr_62
# 	Extracting 151 sequences from picr_63
# 	Extracting 108 sequences from picr_64
# 	Extracting 153 sequences from picr_65
# 	Extracting 161 sequences from picr_66
# 	Extracting 61 sequences from picr_67
# 	Extracting 66 sequences from picr_68
# 	Extracting 99 sequences from picr_69
# 	Extracting 211 sequences from picr_71
# 	Extracting 87 sequences from picr_72
# 	Extracting 162 sequences from picr_73
# 	Extracting 411 sequences from picr_74
# 	Extracting 175 sequences from picr_75
# 	Extracting 67 sequences from picr_76
# 	Extracting 67 sequences from picr_77
# 	Extracting 147 sequences from picr_79
# 	Extracting 57 sequences from picr_80
# 	Extracting 50 sequences from picr_81
# 	Extracting 76 sequences from picr_82
# 	Extracting 167 sequences from picr_83
# 	Extracting 212 sequences from picr_84
# 	Extracting 296 sequences from picr_85
# 	Extracting 60 sequences from picr_86
# 	Extracting 188 sequences from picr_87
# 	Extracting 138 sequences from picr_88
# 	Extracting 61 sequences from picr_90
# 	Extracting 67 sequences from picr_91
# 	Extracting 53 sequences from picr_92
# 	Extracting 359 sequences from picr_93
# 	Extracting 112 sequences from picr_94
# 	Extracting 77 sequences from picr_95
# 	Extracting 124 sequences from picr_96
# 	Extracting 30 sequences from picr_97
# 	Extracting 211 sequences from picr_98
# 	Extracting 21 sequences from picr_99
# 	Extracting 126 sequences from picr_100
# 	Extracting 124 sequences from picr_101
# 	Extracting 66 sequences from picr_102
# 	Extracting 27 sequences from picr_104
# 	Extracting 107 sequences from picr_105
# 	Extracting 78 sequences from picr_109
# 	Extracting 53 sequences from picr_110
# 	Extracting 102 sequences from picr_111
# 	Extracting 45 sequences from picr_112
# 	Extracting 80 sequences from picr_113
# 	Extracting 27 sequences from picr_114
# 	Extracting 86 sequences from picr_115
# 	Extracting 46 sequences from picr_116
# 	Extracting 175 sequences from picr_117
# 	Extracting 62 sequences from picr_118
# 	Extracting 266 sequences from picr_119
# 	Extracting 235 sequences from picr_120
# 	Extracting 103 sequences from picr_122
# 	Extracting 74 sequences from picr_123
# 	Extracting 66 sequences from picr_124
# 	Extracting 49 sequences from picr_125
# 	Extracting 36 sequences from picr_126
# 	Extracting 137 sequences from picr_127
# 	Extracting 35 sequences from picr_128
# 	Extracting 13 sequences from picr_129
# 	Extracting 233 sequences from picr_130
# 	Extracting 45 sequences from picr_131
# 	Extracting 258 sequences from picr_132
# 	Extracting 134 sequences from picr_133
# 	Extracting 30 sequences from picr_134
# 	Extracting 53 sequences from picr_135
# 	Extracting 129 sequences from picr_136
# 	Extracting 53 sequences from picr_137
# 	Extracting 146 sequences from picr_138
# 	Extracting 129 sequences from picr_139
# 	Extracting 34 sequences from picr_140
# 	Extracting 27 sequences from picr_141
# 	Extracting 22 sequences from picr_142
# 	Extracting 24 sequences from picr_143
# 	Extracting 35 sequences from picr_144
# 	Extracting 29 sequences from picr_145
# 	Extracting 36 sequences from picr_146
# 	Extracting 50 sequences from picr_148
# 	Extracting 25 sequences from picr_149
# 	Extracting 30 sequences from picr_151
# 	Extracting 40 sequences from picr_152
# 	Extracting 53 sequences from picr_153
# 	Extracting 149 sequences from picr_154
# 	Extracting 47 sequences from picr_155
# 	Extracting 125 sequences from picr_157
# 	Extracting 127 sequences from picr_158
# 	Extracting 23 sequences from picr_159
# 	Extracting 9 sequences from picr_160
# 	Extracting 86 sequences from picr_161
# 	Extracting 32 sequences from picr_162
# 	Extracting 30 sequences from picr_163
# 	Extracting 17 sequences from picr_164
# 	Extracting 74 sequences from picr_166
# 	Extracting 80 sequences from picr_167
# 	Extracting 17 sequences from picr_168
# 	Extracting 28 sequences from picr_169
# 	Extracting 8 sequences from picr_170
# 	Extracting 20 sequences from picr_171
# 	Extracting 18 sequences from picr_172
# 	Extracting 36 sequences from picr_173
# 	Extracting 47 sequences from picr_174
# 	Extracting 5 sequences from picr_176
# 	Extracting 1 sequences from picr_177
# 	Extracting 18 sequences from picr_178
# 	Extracting 1 sequences from picr_180
# 	Extracting 4 sequences from picr_182
# 	Extracting 32 sequences from picr_183
# 	Extracting 1 sequences from picr_184
# 	Extracting 41 sequences from picr_185
# 	Extracting 34 sequences from picr_186
# 	Extracting 17 sequences from picr_187
# 	Extracting 20 sequences from picr_188
# 	Extracting 30 sequences from picr_191
# 	Extracting 29 sequences from picr_192
# 	Extracting 7 sequences from picr_193
# 	Extracting 52 sequences from picr_195
# 	Extracting 3 sequences from picr_198
# 	Extracting 7 sequences from picr_199
# 	Extracting 28 sequences from picr_200
# 	Extracting 1 sequences from picr_201
# 	Extracting 20 sequences from picr_209
# 	Extracting 2 sequences from picr_211
# 	Extracting 1 sequences from picr_222
# 	Extracting 4 sequences from picr_231
# 	Extracting 5 sequences from picr_232
# 	Extracting 2 sequences from picr_234
# 	Extracting 12 sequences from picr_235
# 	Extracting 5 sequences from picr_244
# 	Extracting 2 sequences from picr_245
# 	Extracting 2 sequences from picr_248
# 	Extracting 1 sequences from picr_250
# 	Extracting 2 sequences from picr_251
# 	Extracting 6 sequences from picr_253
# 	Extracting 1 sequences from picr_263
# 	Extracting 5 sequences from picr_265
# 	Extracting 4 sequences from picr_268
# 	Extracting 2 sequences from picr_269
# 	Extracting 2 sequences from picr_274
# 	Extracting 2 sequences from picr_276
# 	Extracting 2 sequences from picr_279
# 	Extracting 2 sequences from picr_289
# 	Extracting 4 sequences from picr_296
# 	Extracting 5 sequences from picr_298
# 	Extracting 1 sequences from picr_303
# 	Extracting 1 sequences from picr_309
# 	Extracting 1 sequences from picr_310
# 	Extracting 10 sequences from picr_312
# 	Extracting 2 sequences from picr_316
# 	Extracting 4 sequences from picr_317
# 	Extracting 3 sequences from picr_323
# 	Extracting 2 sequences from picr_328
# 	Extracting 2 sequences from picr_329
# 	Extracting 1 sequences from picr_331
# 	Extracting 2 sequences from picr_332
# 	Extracting 2 sequences from picr_334
# 	Extracting 1 sequences from picr_341
# 	Extracting 2 sequences from picr_342
# 	Extracting 1 sequences from picr_348
# 	Extracting 1 sequences from picr_349
# 	Extracting 1 sequences from picr_353
# 	Extracting 2 sequences from picr_355
# 	Extracting 1 sequences from picr_356
# 	Extracting 2 sequences from picr_358
# 	Extracting 1 sequences from picr_361
# 	Extracting 2 sequences from picr_362
# 	Extracting 2 sequences from picr_367
# 	Extracting 2 sequences from picr_374
# 	Extracting 1 sequences from picr_375
# 	Extracting 12 sequences from picr_378
# 	Extracting 2 sequences from picr_380
# 	Extracting 4 sequences from picr_400
# 	Extracting 1 sequences from picr_412
# 	Extracting 1 sequences from picr_413
# 	Extracting 2 sequences from picr_415
# 	Extracting 1 sequences from picr_432
# 	Extracting 1 sequences from picr_433
# 	Extracting 2 sequences from picr_434
# 	Extracting 3 sequences from picr_435
# 	Extracting 3 sequences from picr_438
# 	Extracting 3 sequences from picr_456
# 	Extracting 1 sequences from picr_458
# 	Extracting 1 sequences from picr_463
# 	Extracting 2 sequences from picr_474
# 	Extracting 3 sequences from picr_477
# 	Extracting 1 sequences from picr_478
# 	Extracting 1 sequences from picr_480
# 	Extracting 1 sequences from picr_488
# 	Extracting 2 sequences from picr_492
# 	Extracting 1 sequences from picr_493
# 	Extracting 3 sequences from picr_498
# 	Extracting 1 sequences from picr_507
# 	Extracting 1 sequences from picr_509
# 	Extracting 3 sequences from picr_512
# 	Extracting 2 sequences from picr_517
# 	Extracting 4 sequences from picr_529
# 	Extracting 2 sequences from picr_534
# 	Extracting 2 sequences from picr_561
# 	Extracting 1 sequences from picr_566
# 	Extracting 8 sequences from picr_591
# 	Extracting 1 sequences from picr_603
# 	Extracting 1 sequences from picr_606
# 	Extracting 1 sequences from picr_608
# 	Extracting 1 sequences from picr_622
# 	Extracting 1 sequences from picr_653
# 	Extracting 1 sequences from picr_654
# 	Extracting 1 sequences from picr_676
# 	Extracting 1 sequences from picr_688
# 	Extracting 3 sequences from picr_709
# 	Extracting 1 sequences from picr_721
# 	Extracting 2 sequences from picr_769
# 	Extracting 3 sequences from picr_776
# 	Extracting 1 sequences from picr_778
# 	Extracting 1 sequences from picr_817
# 	Extracting 2 sequences from picr_824
# 	Extracting 1 sequences from picr_843
# 	Extracting 2 sequences from picr_853
# 	Extracting 1 sequences from picr_854
# 	Extracting 1 sequences from picr_885
# 	Extracting 2 sequences from picr_911
# 	Extracting 1 sequences from picr_954
# 	Extracting 1 sequences from picr_964
# 	Extracting 1 sequences from picr_997
# 	Extracting 1 sequences from picr_1030
# 	Extracting 1 sequences from picr_1034
# 	Extracting 2 sequences from picr_1046
# 	Extracting 1 sequences from picr_1059
# 	Extracting 1 sequences from picr_1064
# 	Extracting 1 sequences from picr_1097
# 	Extracting 2 sequences from picr_1137
# 	Extracting 2 sequences from picr_1165
# 	Extracting 1 sequences from picr_1232
# 	Extracting 1 sequences from picr_1410
# 	Extracting 1 sequences from picr_1425
# 	Extracting 1 sequences from picr_1490
# 	Extracting 1 sequences from picr_1501
# 	Extracting 2 sequences from picr_1503
# 	Extracting 1 sequences from picr_1628
# 	Extracting 3 sequences from picr_1669
# 	Extracting 1 sequences from picr_1677
# 	Extracting 5 sequences from picr_1757
# 	Extracting 239 sequences from picr_7a
# 	Extracting 810 sequences from picr_1
# 	Extracting 553 sequences from picr_10
# 	Extracting 273 sequences from picr_103
# 	Extracting 197 sequences from picr_106
# 	Extracting 26 sequences from picr_107
# 	Extracting 146 sequences from picr_108
# 	Extracting 378 sequences from picr_11
# 	Extracting 51 sequences from picr_121
# 	Extracting 307 sequences from picr_14
# 	Extracting 438 sequences from picr_16
# 	Extracting 1145 sequences from picr_2
# 	Extracting 544 sequences from picr_23
# 	Extracting 508 sequences from picr_24
# 	Extracting 115 sequences from picr_25
# 	Extracting 374 sequences from picr_29
# 	Extracting 818 sequences from picr_3
# 	Extracting 146 sequences from picr_30
# 	Extracting 218 sequences from picr_34
# 	Extracting 156 sequences from picr_37
# 	Extracting 353 sequences from picr_38
# 	Extracting 353 sequences from picr_39
# 	Extracting 2 sequences from picr_393
# 	Extracting 342 sequences from picr_40
# 	Extracting 187 sequences from picr_41
# 	Extracting 221 sequences from picr_43
# 	Extracting 289 sequences from picr_47
# 	Extracting 492 sequences from picr_52
# 	Extracting 169 sequences from picr_55
# 	Extracting 529 sequences from picr_6
# 	Extracting 361 sequences from picr_70
# 	Extracting 111 sequences from picr_78
# 	Extracting 1174 sequences from picr_8
# 	Extracting 233 sequences from picr_89
# 	Extracting 494 sequences from picr_9
# 	Extracting 144 sequences from picr_7b

# %%
motifs_of_interest = ['inr','tata', 'sp1', 'ctcf']
motifs_of_interest = ['inr']
fa_file = os.path.join(out_dir,"TSS1.exp.fa")
f_save = 'Results/Figures/SuppFigure3/TSS_exp_instance_nonbin'
motif_analysis.all_motifs_of_interest_instance(motifs_of_interest,fa_file,
                                    motif_folder, f_save,
                                    lowmem=False)
# Out:
# 0it [00:00, ?it/s]
# inr
# 22555it [17:59, 23.26it/s]

# %% [markdown]
# ## 3. Motif Generation

# %% [markdown]
# ### Experimental

# %%
t = time.time()
motifs_of_interest = ['inr']
fa_file = os.path.join(out_dir,"TSS1.exp.fa")

f_save = 'Results/Figures/SuppFigure3/TSS_exp_instance_bin'
motif_analysis.all_motifs_of_interest_instance(motifs_of_interest,fa_file,
                                    motif_folder, f_save,
                                    lowmem=True)
print(t - time.time())
# Out:
# inr
# ('Number of records', 35247)
# ('max length of a sequence: ', 150)
# 100%|██████████| 35247/35247 [1:16:42<00:00,  7.66it/s]
# Time taken: 4606
# -4608.65337896

# %%
t = time.time()
motifs_of_interest = ['inr']
fa_file = os.path.join(out_dir,"TSS1.exp.fa")

f_save = 'Results/Figures/SuppFigure3/TSS_exp_instance_nonbin'
motif_analysis.all_motifs_of_interest_instance(motifs_of_interest,fa_file,
                                    motif_folder, f_save,
                                    lowmem=False)
print(t - time.time())
# Out:
# 0it [00:00, ?it/s]
# inr
# 35247it [18:07, 32.41it/s]
# Time taken: 1088
# -1088.25026202

# %%
t = time.time()
motifs_of_interest = ['inr']
fa_file = os.path.join(out_dir,"TSS1.exp.fa")

f_save = 'Results/Figures/SuppFigure3/TSS_exp_instance_nonbinV2'
motif_analysis.all_motifs_of_interest_instance(motifs_of_interest,fa_file,
                                    motif_folder, f_save,
                                    lowmem=False)
print(t - time.time())
# Out:
# 4it [00:00, 39.25it/s]
# inr
# 31117it [14:54, 34.63it/s]

# %% [markdown]
# ### Refseq

# %%
t = time.time()
motifs_of_interest = ['inr']
fa_file = os.path.join(out_dir,"TSS1.exp_refseq_center.fa")

f_save = 'Results/Figures/SuppFigure3/TSS1.exp_refseq_center_instance_nonbin'
motif_analysis.all_motifs_of_interest_instance(motifs_of_interest,fa_file,
                                    motif_folder, f_save,
                                    lowmem=False)
print(time.time()-t)
# Out:
# 2729it [00:00, 27288.66it/s]
# inr
# 35247it [00:01, 25505.24it/s]
# Time taken: 1
# 1.73443293571

# %%
inr_df = pd.read_csv(f_save+"_inr_instance.tsv",sep="\t",index_col=0)
inr_df
# Out:
#                                -150   -149   -148   -147   -146   -145   -144  \
# p1@SERHL_gene_1_4_asmbl_14    False  False  False  False  False  False  False
# p1@RRP7A_gene_2_asmbl_10      False  False  False  False  False  False  False
# p1@RRP7A_gene_2_asmbl_4       False  False  False  False  False  False  False
# p1@POLDIP3_gene_3_1_asmbl_19  False  False  False  False  False  False  False
# p2@CYB5R3_gene_3_2_asmbl_20   False  False  False  False  False  False  False
# p1@CYB5R3_gene_3_2_asmbl_20   False  False  False  False  False  False  False
# p1@POLDIP3_gene_3_1_asmbl_17  False  False  False  False  False  False  False
# p2@A4GALT_gene_4_3_asmbl_30   False  False  False  False  False  False  False
# p1@A4GALT_gene_4_3_asmbl_30   False  False  False  False  False  False  False
# p1@A4GALT_gene_4_3_asmbl_24   False  False  False  False  False  False  False
# p3@ARFGAP3_gene_5_1_asmbl_33  False  False  False  False  False  False  False
# p2@ARFGAP3_gene_5_1_asmbl_33  False  False  False  False  False  False  False
# p1@ARFGAP3_gene_5_1_asmbl_33  False  False  False  False  False  False  False
# p1@ARFGAP3_gene_5_1_asmbl_31  False  False  False  False  False  False  False
# p1@PACSIN2_gene_6_asmbl_37    False  False  False  False  False  False  False
# p1@PACSIN2_gene_6_asmbl_40    False  False  False  False  False  False  False
# p1@PACSIN2_gene_6_asmbl_43    False  False  False  False  False  False  False
# p1@PACSIN2_gene_6_asmbl_39    False  False  False  False  False  False  False
# p1@TTLL1_gene_7_asmbl_49      False  False  False  False  False  False  False
# p2@BIK_gene_11_asmbl_64       False  False  False  False  False  False  False
# p3@BIK_gene_11_asmbl_64       False  False  False  False  False  False  False
# p1@BIK_gene_11_asmbl_64       False  False  False  False  False  False  False
# p1@BIK_gene_11_asmbl_63       False  False  False  False  False  False  False
# p1@TSPO_gene_9_asmbl_56       False  False  False  False  False  False  False
# p1@TSPO_gene_9_asmbl_60       False  False  False  False  False  False  False
# p2@MCAT_gene_10_asmbl_57      False  False  False  False  False  False  False
# p1@MCAT_gene_10_asmbl_57      False  False  False  False  False  False  False
# p1@TTLL12_gene_8_asmbl_59     False  False  False  False  False  False  False
# p1@TTLL12_gene_8_asmbl_52     False  False  False  False  False  False  False
# p1@SCUBE1_gene_12_asmbl_67    False  False  False  False  False  False  False
# ...                             ...    ...    ...    ...    ...    ...    ...
# p1@ATXN10_gene_38_asmbl_151   False  False  False  False  False  False  False
# p1@WNT7B_gene_39_asmbl_154    False  False  False  False  False  False  False
# p3@WNT7B_gene_39_asmbl_152    False  False  False  False  False  False  False
# p2@WNT7B_gene_39_asmbl_152    False  False  False  False  False  False  False
# p1@WNT7B_gene_39_asmbl_152    False  False  False  False  False  False  False
# p3@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p5@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p4@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p1@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p2@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p2@PPARA_gene_47_asmbl_167    False  False  False  False  False  False  False
# p1@PPARA_gene_47_asmbl_167    False  False  False  False  False  False  False
# p3@CDPF1_gene_48_asmbl_177    False  False  False  False  False  False  False
# p2@CDPF1_gene_48_asmbl_177    False  False  False  False  False  False  False
# p1@CDPF1_gene_48_asmbl_177    False  False  False  False  False  False  False
# p1@PKDREJ_gene_50_asmbl_179   False  False  False  False  False  False  False
# p1@PKDREJ_gene_49_asmbl_178   False  False  False  False  False  False  False
# p1@TTC38_gene_51_2_asmbl_181  False  False  False  False  False  False  False
# p1@TRMU_gene_52_3_asmbl_187   False  False  False  False  False  False  False
# p1@TRMU_gene_52_3_asmbl_186   False  False  False  False  False  False  False
# p3@CELSR1_gene_53_asmbl_185   False  False  False  False  False  False  False
# p2@CELSR1_gene_53_asmbl_185   False  False  False  False  False  False  False
# p1@CELSR1_gene_53_asmbl_185   False  False  False  False  False  False  False
# p2@GRAMD4_gene_54_asmbl_200   False  False  False  False  False  False  False
# p1@GRAMD4_gene_54_asmbl_200   False  False  False  False  False  False  False
# p1@GRAMD4_gene_54_asmbl_199   False  False  False  False  False  False  False
# p1@GRAMD4_gene_54_asmbl_201   False  False  False  False  False  False  False
# p1@CERK_gene_55_asmbl_206     False  False  False  False  False  False  False
# p1@CERK_gene_55_asmbl_204     False  False  False  False  False  False  False
# p2@CERK_gene_55_asmbl_204     False  False  False  False  False  False  False
#
#                                -143   -142   -141  ...      140    141    142  \
# p1@SERHL_gene_1_4_asmbl_14    False  False  False  ...    False  False  False
# p1@RRP7A_gene_2_asmbl_10      False  False  False  ...    False  False  False
# p1@RRP7A_gene_2_asmbl_4       False  False  False  ...    False  False  False
# p1@POLDIP3_gene_3_1_asmbl_19  False  False  False  ...    False  False  False
# p2@CYB5R3_gene_3_2_asmbl_20   False  False  False  ...    False  False  False
# p1@CYB5R3_gene_3_2_asmbl_20   False  False  False  ...    False  False  False
# p1@POLDIP3_gene_3_1_asmbl_17  False  False  False  ...    False  False  False
# p2@A4GALT_gene_4_3_asmbl_30   False  False  False  ...    False  False  False
# p1@A4GALT_gene_4_3_asmbl_30   False  False  False  ...    False  False  False
# p1@A4GALT_gene_4_3_asmbl_24   False  False  False  ...    False  False  False
# p3@ARFGAP3_gene_5_1_asmbl_33  False  False  False  ...    False  False  False
# p2@ARFGAP3_gene_5_1_asmbl_33  False  False  False  ...    False  False  False
# p1@ARFGAP3_gene_5_1_asmbl_33  False  False  False  ...    False  False  False
# p1@ARFGAP3_gene_5_1_asmbl_31  False  False  False  ...    False  False  False
# p1@PACSIN2_gene_6_asmbl_37    False  False  False  ...    False  False  False
# p1@PACSIN2_gene_6_asmbl_40    False  False  False  ...    False  False  False
# p1@PACSIN2_gene_6_asmbl_43    False  False  False  ...    False  False  False
# p1@PACSIN2_gene_6_asmbl_39    False  False  False  ...    False  False  False
# p1@TTLL1_gene_7_asmbl_49      False  False  False  ...    False  False  False
# p2@BIK_gene_11_asmbl_64       False  False  False  ...    False  False  False
# p3@BIK_gene_11_asmbl_64       False  False  False  ...    False  False  False
# p1@BIK_gene_11_asmbl_64       False  False  False  ...    False  False  False
# p1@BIK_gene_11_asmbl_63       False  False  False  ...    False  False  False
# p1@TSPO_gene_9_asmbl_56       False  False  False  ...    False  False  False
# p1@TSPO_gene_9_asmbl_60       False  False  False  ...    False  False  False
# p2@MCAT_gene_10_asmbl_57      False  False  False  ...    False  False  False
# p1@MCAT_gene_10_asmbl_57      False  False  False  ...    False  False  False
# p1@TTLL12_gene_8_asmbl_59     False  False  False  ...    False  False  False
# p1@TTLL12_gene_8_asmbl_52     False  False  False  ...    False  False  False
# p1@SCUBE1_gene_12_asmbl_67    False  False  False  ...    False  False  False
# ...                             ...    ...    ...  ...      ...    ...    ...
# p1@ATXN10_gene_38_asmbl_151   False  False  False  ...    False  False  False
# p1@WNT7B_gene_39_asmbl_154    False  False  False  ...    False  False  False
# p3@WNT7B_gene_39_asmbl_152    False  False  False  ...    False  False  False
# p2@WNT7B_gene_39_asmbl_152    False  False  False  ...    False  False  False
# p1@WNT7B_gene_39_asmbl_152    False  False  False  ...    False  False  False
# p3@PPARA_gene_47_asmbl_166    False  False  False  ...     True  False  False
# p5@PPARA_gene_47_asmbl_166    False  False  False  ...    False  False  False
# p4@PPARA_gene_47_asmbl_166    False  False  False  ...    False  False  False
# p1@PPARA_gene_47_asmbl_166    False  False  False  ...    False  False  False
# p2@PPARA_gene_47_asmbl_166    False  False  False  ...    False  False  False
# p2@PPARA_gene_47_asmbl_167    False  False  False  ...    False  False  False
# p1@PPARA_gene_47_asmbl_167    False  False  False  ...    False  False  False
# p3@CDPF1_gene_48_asmbl_177    False  False  False  ...    False  False  False
# p2@CDPF1_gene_48_asmbl_177    False  False  False  ...    False  False  False
# p1@CDPF1_gene_48_asmbl_177    False  False  False  ...    False  False  False
# p1@PKDREJ_gene_50_asmbl_179   False  False  False  ...    False  False  False
# p1@PKDREJ_gene_49_asmbl_178   False  False  False  ...    False  False  False
# p1@TTC38_gene_51_2_asmbl_181  False  False  False  ...    False  False  False
# p1@TRMU_gene_52_3_asmbl_187   False  False  False  ...    False  False  False
# p1@TRMU_gene_52_3_asmbl_186   False  False  False  ...    False  False  False
# p3@CELSR1_gene_53_asmbl_185   False  False  False  ...    False  False  False
# p2@CELSR1_gene_53_asmbl_185   False  False  False  ...    False  False  False
# p1@CELSR1_gene_53_asmbl_185   False  False  False  ...    False  False  False
# p2@GRAMD4_gene_54_asmbl_200   False  False  False  ...    False  False  False
# p1@GRAMD4_gene_54_asmbl_200   False  False  False  ...    False  False  False
# p1@GRAMD4_gene_54_asmbl_199   False  False  False  ...    False  False  False
# p1@GRAMD4_gene_54_asmbl_201   False  False  False  ...    False  False  False
# p1@CERK_gene_55_asmbl_206     False  False  False  ...    False  False  False
# p1@CERK_gene_55_asmbl_204     False  False  False  ...    False  False  False
# p2@CERK_gene_55_asmbl_204     False  False  False  ...    False  False  False
#
#                                 143    144    145    146    147    148    149
# p1@SERHL_gene_1_4_asmbl_14    False  False  False  False  False  False  False
# p1@RRP7A_gene_2_asmbl_10      False  False  False  False  False  False  False
# p1@RRP7A_gene_2_asmbl_4       False  False  False  False  False  False  False
# p1@POLDIP3_gene_3_1_asmbl_19  False  False  False  False  False  False  False
# p2@CYB5R3_gene_3_2_asmbl_20   False  False  False  False  False  False  False
# p1@CYB5R3_gene_3_2_asmbl_20   False  False  False  False  False  False  False
# p1@POLDIP3_gene_3_1_asmbl_17  False  False  False  False  False  False  False
# p2@A4GALT_gene_4_3_asmbl_30   False  False  False  False  False  False  False
# p1@A4GALT_gene_4_3_asmbl_30   False  False  False  False  False  False  False
# p1@A4GALT_gene_4_3_asmbl_24   False  False  False  False  False  False  False
# p3@ARFGAP3_gene_5_1_asmbl_33  False  False  False  False  False  False  False
# p2@ARFGAP3_gene_5_1_asmbl_33  False  False  False  False  False  False  False
# p1@ARFGAP3_gene_5_1_asmbl_33  False  False  False  False  False  False  False
# p1@ARFGAP3_gene_5_1_asmbl_31  False  False  False  False  False  False  False
# p1@PACSIN2_gene_6_asmbl_37    False  False  False  False  False  False  False
# p1@PACSIN2_gene_6_asmbl_40    False  False  False  False  False  False  False
# p1@PACSIN2_gene_6_asmbl_43    False  False  False  False  False  False  False
# p1@PACSIN2_gene_6_asmbl_39    False  False  False  False  False  False  False
# p1@TTLL1_gene_7_asmbl_49      False  False  False  False  False  False  False
# p2@BIK_gene_11_asmbl_64       False  False  False  False  False  False  False
# p3@BIK_gene_11_asmbl_64       False  False  False  False  False  False  False
# p1@BIK_gene_11_asmbl_64       False  False  False  False  False  False  False
# p1@BIK_gene_11_asmbl_63       False  False  False  False  False  False  False
# p1@TSPO_gene_9_asmbl_56       False  False  False  False  False  False  False
# p1@TSPO_gene_9_asmbl_60       False  False  False  False  False  False  False
# p2@MCAT_gene_10_asmbl_57      False  False  False  False  False  False  False
# p1@MCAT_gene_10_asmbl_57      False  False  False  False  False  False  False
# p1@TTLL12_gene_8_asmbl_59     False  False  False  False  False  False  False
# p1@TTLL12_gene_8_asmbl_52     False  False  False  False  False  False  False
# p1@SCUBE1_gene_12_asmbl_67    False  False  False  False  False  False  False
# ...                             ...    ...    ...    ...    ...    ...    ...
# p1@ATXN10_gene_38_asmbl_151   False  False  False  False  False  False  False
# p1@WNT7B_gene_39_asmbl_154    False  False  False  False  False  False  False
# p3@WNT7B_gene_39_asmbl_152    False  False  False  False  False  False  False
# p2@WNT7B_gene_39_asmbl_152    False  False  False  False  False  False  False
# p1@WNT7B_gene_39_asmbl_152    False  False  False  False  False  False  False
# p3@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p5@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p4@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p1@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p2@PPARA_gene_47_asmbl_166    False  False  False  False  False  False  False
# p2@PPARA_gene_47_asmbl_167    False  False  False  False  False  False  False
# p1@PPARA_gene_47_asmbl_167    False  False  False  False  False  False  False
# p3@CDPF1_gene_48_asmbl_177    False  False  False  False  False  False  False
# p2@CDPF1_gene_48_asmbl_177    False  False  False  False  False  False  False
# p1@CDPF1_gene_48_asmbl_177    False  False  False  False  False  False  False
# p1@PKDREJ_gene_50_asmbl_179   False  False  False  False  False  False  False
# p1@PKDREJ_gene_49_asmbl_178   False  False  False  False  False  False  False
# p1@TTC38_gene_51_2_asmbl_181  False  False  False  False  False  False  False
# p1@TRMU_gene_52_3_asmbl_187   False  False  False  False  False  False  False
# p1@TRMU_gene_52_3_asmbl_186   False  False  False  False  False  False  False
# p3@CELSR1_gene_53_asmbl_185   False  False  False  False  False  False  False
# p2@CELSR1_gene_53_asmbl_185   False  False  False  False  False  False  False
# p1@CELSR1_gene_53_asmbl_185   False  False  False  False  False  False  False
# p2@GRAMD4_gene_54_asmbl_200   False  False  False  False  False  False  False
# p1@GRAMD4_gene_54_asmbl_200   False  False  False  False  False  False  False
# p1@GRAMD4_gene_54_asmbl_199   False  False  False  False  False  False  False
# p1@GRAMD4_gene_54_asmbl_201   False  False  False  False  False  False  False
# p1@CERK_gene_55_asmbl_206     False  False  False  False  False  False  False
# p1@CERK_gene_55_asmbl_204     False  False  False  False  False  False  False
# p2@CERK_gene_55_asmbl_204     False  False  False  False  False  False  False
#
# [100 rows x 300 columns]

# %% [markdown]
# # 4. Plotting
