# %% [markdown]
# # Using the GCF annotation
# ## Similar to hg38 (here using mRNA.peak sequence )
# ## Going to do both nucleotide frequency and the motifs in one notebook

# %%
## Parameters specific to where your folders are and your data
parameter_file = '../parameters/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
supplemental = doc["supplemental"]
sys.path.append(doc['pipeline_path'])

import time
import os
from os.path import join, basename
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm

from os.path import basename
##mpl.use('Agg')
#mpl.style.use('ggplot')
#mpl.style.use('fivethirtyeight')
from Homer import *
import helper
import create_output
print('Number of tissues: ',len(tissues))

os.chdir(doc["results"])
# Out:
# /home/isshamie/software/anaconda2/envs/TSS/lib/python3.7/site-packages/ipykernel_launcher.py:7: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   import sys
# Number of tissues:  13

# %%
import motif_analysis

# %%
homer_path =  "/data2/resources/software/homer/v4.11_10242019/bin/"
os.environ['PATH'] = f"{homer_path}:{os.environ['PATH']}"
# !which homer
# Out:
# /data2/resources/software/homer/v4.11_10242019/bin//homer

# %% [markdown]
# ## Input

# %%
ref_fa = doc["ref_fa"]
anno_gff = doc["annotation"]
mRNA_peak_file = "genome/picr/gcf/mRNA.peak"
tss_annotation = 'genome/picr/gcf/start_site_mRNA.tsv'
seq_f = "genome/picr/gcf/mRNA_150.tss.fa"
peak_f = "genome/picr/gcf/mRNA_150.tss.bed"

# %% [markdown]
# ## Outdirs

# %%
nucleotide_out = "gcf_nucleotide"
motif_out = "gcf_motif_from_meme"

if not os.path.exists(nucleotide_out):
    os.mkdir(nucleotide_out)
    
if not os.path.exists(motif_out):
    os.mkdir(motif_out)

# %% [markdown]
# # Nucleotide Sequences of RefSeq TSS

# %%
f2 = "genome/picr/gcf/mRNA.peak"
homer_nucleotide(mRNA_peak_file,
    join(nucleotide_out,'gcf_nucfreq_nucl'),
    ref_fa,
    size=200)
# Out:
# annotatePeaks.pl genome/picr/gcf/mRNA.peak /data/isshamie/genome/hamster/ncbi_anno_103/GCF_003668045.1_CriGri-PICR/GCF_003668045.1_CriGri-PICR_genomic.fna -size 200 -hist 1 -di > gcf_nucleotide/gcf_nucfreq_nucl
# No handles with labels found to put in legend.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
f1 = "output_annotation/TSS1.exp.bed"
homer_nucleotide(f1,
    join(nucleotide_out,'eTSS_nucfreq_nucl'),
    ref_fa,
    size=200)
# Out:
# annotatePeaks.pl output_annotation/TSS1.exp.bed /data/isshamie/genome/hamster/ncbi_anno_103/GCF_003668045.1_CriGri-PICR/GCF_003668045.1_CriGri-PICR_genomic.fna -size 200 -hist 1 -di > gcf_nucleotide/eTSS_nucfreq_nucl
# No handles with labels found to put in legend.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Motifs

# %%
# ref_fa = doc["ref_fa"]
# anno_gff = doc["annotation"]
# mRNA_peak_file = "genome/picr/gcf/mRNA.peak"
# tss_annotation = 'genome/picr/gcf/start_site_mRNA.tsv'


# seq_f = "genome/picr/gcf/mRNA_150.tss.fa"
# peak_f = "genome/picr/gcf/mRNA_150.tss.bed" #"genome/hg38/mRNA_150.tss.peak"s

# %% [markdown]
# ## Motif Generation
#
# ### Using FIMO

# %%
t = time.time()
meme_motifs_dir = join(supplemental,'homer_motifs/MEME_motifs.txt')
out_dir = join(motif_out, "gcf.meme")
#meme_motifs_dir = join("fimo", 'hg38', 'MEME_motifs_short.txt')

cmd = "fimo --o {out_dir} {motif_f} {seq_f} ".format(motif_f=meme_motifs_dir,seq_f=seq_f,out_dir=out_dir)
print(cmd)
# !{cmd}
print(t - time.time())
# Out:
# fimo --o gcf_motif_from_meme/gcf.meme /data/isshamie/TSS/Analysis/supplemental/homer_motifs/MEME_motifs.txt genome/picr/gcf/mRNA_150.tss.fa
# Using motif +ap1.motif of width 10.
# Using motif -ap1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +ap2.motif of width 12.
# Using motif -ap2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.679208
# Using motif +ap2gamma.motif of width 12.
# Using motif -ap2gamma.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.6796
# Using motif +ap4.motif of width 10.
# Using motif -ap4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.907541
# Using motif +ar-half.motif of width 10.
# Using motif -ar-half.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.900189
# Using motif +are-fox.motif of width 20.
# Using motif -are-fox.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999397
# Using motif +are.motif of width 16.
# Using motif -are.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.966867
# Using motif +arnt.motif of width 10.
# Using motif -arnt.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.875179
# Using motif +ascl1.motif of width 12.
# Using motif -ascl1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.828073
# Using motif +atf1.motif of width 10.
# Using motif -atf1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +atf2.motif of width 12.
# Using motif -atf2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.9628
# Using motif +atf3.motif of width 12.
# Using motif -atf3.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +atf4.motif of width 10.
# Using motif -atf4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +atf7.motif of width 12.
# Using motif -atf7.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.945047
# Using motif +atoh1.motif of width 12.
# Using motif -atoh1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.8452
# Using motif +bach1.motif of width 15.
# Using motif -bach1.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +bach2.motif of width 10.
# Using motif -bach2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.989274
# Using motif +bapx1.motif of width 10.
# Using motif -bapx1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +barx1.motif of width 10.
# Using motif -barx1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +batf.motif of width 10.
# Using motif -batf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +batf3-irf8.motif of width 15.
# Using motif -batf3-irf8.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +bcl6.motif of width 15.
# Using motif -bcl6.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.997688
# Using motif +bhlhe40.motif of width 10.
# Using motif -bhlhe40.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.873694
# Using motif +bmal.motif of width 8.
# Using motif -bmal.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.884348
# Using motif +bmyb.motif of width 10.
# Using motif -bmyb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +boris.motif of width 20.
# Using motif -boris.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.640792
# Using motif +brachyury.motif of width 21.
# Using motif -brachyury.motif of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.924685
# Using motif +brn1.motif of width 12.
# Using motif -brn1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +brn2.motif of width 10.
# Using motif -brn2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +bzip-irf.motif of width 18.
# Using motif -bzip-irf.motif of width 18.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999698
# Using motif +cdx2.motif of width 10.
# Using motif -cdx2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cdx4.motif of width 12.
# Using motif -cdx4.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cebp-ap1.motif of width 10.
# Using motif -cebp-ap1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cebp-cebp.motif of width 20.
# Using motif -cebp-cebp.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cebp.motif of width 10.
# Using motif -cebp.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +chop.motif of width 10.
# Using motif -chop.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +chr.motif of width 10.
# Using motif -chr.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +clock.motif of width 8.
# Using motif -clock.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.878919
# Using motif +cMyc.lncap.motif of width 8.
# Using motif -cMyc.lncap.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.774175
# Using motif +cmyc.motif of width 10.
# Using motif -cmyc.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7728
# Using motif +couptf1.motif of width 12.
# Using motif -couptf1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.898614
# Using motif +couptf2.motif of width 8.
# Using motif -couptf2.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.868679
# Using motif +cre.motif of width 12.
# Using motif -cre.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.718269
# Using motif +crx.motif of width 8.
# Using motif -crx.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +ctcf-mys.motif of width 20.
# Using motif -ctcf-mys.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.986809
# Using motif +ctcf.motif of width 20.
# Using motif -ctcf.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.782261
# Using motif +cux2.motif of width 10.
# Using motif -cux2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +dmc1.motif of width 20.
# Using motif -dmc1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +dmrt1.motif of width 15.
# Using motif -dmrt1.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +dmrt6.motif of width 15.
# Using motif -dmrt6.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +dr0.motif of width 12.
# Using motif -dr0.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.921368
# Using motif +dr5.motif of width 18.
# Using motif -dr5.motif of width 18.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.818679
# Using motif +dux4.motif of width 15.
# Using motif -dux4.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +e2a.motif of width 10.
# Using motif -e2a.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.762222
# Using motif +e2f.motif of width 12.
# Using motif -e2f.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.66098
# Using motif +e2f1.motif of width 10.
# Using motif -e2f1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7358
# Using motif +e2f3.motif of width 12.
# Using motif -e2f3.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.698077
# Using motif +e2f4.motif of width 10.
# Using motif -e2f4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.66099
# Using motif +e2f6.motif of width 10.
# Using motif -e2f6.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.746078
# Using motif +e2f7.motif of width 12.
# Using motif -e2f7.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.719612
# Using motif +e47.motif of width 10.
# Using motif -e47.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.79
# Using motif +ebf-old.motif of width 12.
# Using motif -ebf-old.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.84
# Using motif +ebf.motif of width 12.
# Using motif -ebf.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.797477
# Using motif +ebna1.motif of width 20.
# Using motif -ebna1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.883704
# Using motif +ebox.motif of width 12.
# Using motif -ebox.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.751068
# Using motif +egr1.motif of width 10.
# Using motif -egr1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.819649
# Using motif +egr2.motif of width 12.
# Using motif -egr2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.778644
# Using motif +ehf.motif of width 10.
# Using motif -ehf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.989263
# Using motif +eklf.motif of width 12.
# Using motif -eklf.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.847478
# Using motif +elf1.motif of width 10.
# Using motif -elf1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.852427
# Using motif +elf3.motif of width 10.
# Using motif -elf3.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.997273
# Using motif +elf5.motif of width 10.
# Using motif -elf5.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.99868
# Using motif +elk1.motif of width 10.
# Using motif -elk1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.8642
# Using motif +elk4.motif of width 10.
# Using motif -elk4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.932
# Using motif +eomes.motif of width 10.
# Using motif -eomes.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +ere.motif of width 15.
# Using motif -ere.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.890769
# Using motif +erg.motif of width 10.
# Using motif -erg.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.949333
# Using motif +erra.motif of width 10.
# Using motif -erra.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.89248
# Using motif +es.motif of width 12.
# Using motif -es.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.908986
# Using motif +esrrb.motif of width 10.
# Using motif -esrrb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.8682
# Using motif +ets-distal.motif of width 10.
# Using motif -ets-distal.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.994667
# Using motif +ets-ebox.motif of width 12.
# Using motif -ets-ebox.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.976612
# Using motif +ets-runx.motif of width 12.
# Using motif -ets-runx.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.902222
# Using motif +ets.motif of width 10.
# Using motif -ets.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.870088
# Using motif +ets1.motif of width 10.
# Using motif -ets1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.952645
# Using motif +etv1.motif of width 10.
# Using motif -etv1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.87717
# Using motif +etv2.motif of width 12.
# Using motif -etv2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.944029
# Using motif +etv4.motif of width 10.
# Using motif -etv4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.816923
# Using motif +ews-erg.motif of width 10.
# Using motif -ews-erg.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +ews-fli1.motif of width 10.
# Using motif -ews-fli1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999497
# Using motif +fli.motif of width 10.
# Using motif -fli.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.909667
# Using motif +fosl2.motif of width 12.
# Using motif -fosl2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999594
# Using motif +fox-ebox.motif of width 17.
# Using motif -fox-ebox.motif of width 17.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxa1.lncap.motif of width 10.
# Using motif -foxa1.lncap.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxa1.mcf7.motif of width 10.
# Using motif -foxa1.mcf7.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxa2.motif of width 12.
# Using motif -foxa2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxa3.motif of width 15.
# Using motif -foxa3.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxf1.motif of width 12.
# Using motif -foxf1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxh1.motif of width 12.
# Using motif -foxh1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxk1.motif of width 10.
# Using motif -foxk1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxk2.motif of width 12.
# Using motif -foxk2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxl2.motif of width 12.
# Using motif -foxl2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxm1.motif of width 10.
# Using motif -foxm1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxo1.motif of width 8.
# Using motif -foxo1.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxo3.motif of width 8.
# Using motif -foxo3.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxp1.motif of width 12.
# Using motif -foxp1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +fra1.motif of width 12.
# Using motif -fra1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +fra2.motif of width 12.
# Using motif -fra2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +fxr.motif of width 14.
# Using motif -fxr.motif of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.817944
# Using motif +gabp.motif of width 10.
# Using motif -gabp.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.863455
# Using motif +gata-scl.motif of width 20.
# Using motif -gata-scl.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.936167
# Using motif +gata.motif of width 10.
# Using motif -gata.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata2.motif of width 10.
# Using motif -gata2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.dr4.motif of width 15.
# Using motif -gata3.dr4.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.dr8.motif of width 20.
# Using motif -gata3.dr8.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.ir3.motif of width 20.
# Using motif -gata3.ir3.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.ir4.motif of width 15.
# Using motif -gata3.ir4.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.motif of width 8.
# Using motif -gata3.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata4.motif of width 10.
# Using motif -gata4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata6.motif of width 10.
# Using motif -gata6.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gfi1b.motif of width 10.
# Using motif -gfi1b.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998995
# Using motif +gfx.motif of width 12.
# Using motif -gfx.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.8252
# Using motif +gfy-staf.motif of width 20.
# Using motif -gfy-staf.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.978281
# Using motif +gfy.motif of width 12.
# Using motif -gfy.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.908837
# Using motif +gli.motif of width 12.
# Using motif -gli.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.777714
# Using motif +gre-raw.motif of width 15.
# Using motif -gre-raw.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998265
# Using motif +gre.motif of width 16.
# Using motif -gre.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.975425
# Using motif +grhl2.motif of width 20.
# Using motif -grhl2.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gsc.motif of width 8.
# Using motif -gsc.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hand2.motif of width 15.
# Using motif -hand2.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.936232
# Using motif +heb.motif of width 10.
# Using motif -heb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.712549
# Using motif +hif1a.motif of width 8.
# Using motif -hif1a.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.853981
# Using motif +hif1b.motif of width 8.
# Using motif -hif1b.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.959649
# Using motif +hif2a.motif of width 10.
# Using motif -hif2a.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.878824
# Using motif +hinfp.motif of width 10.
# Using motif -hinfp.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.669505
# Using motif +hlf.motif of width 10.
# Using motif -hlf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hnf1.motif of width 13.
# Using motif -hnf1.motif of width 13.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hnf1b.motif of width 12.
# Using motif -hnf1b.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hnf4.motif of width 16.
# Using motif -hnf4.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.985946
# Using motif +hnf6.motif of width 10.
# Using motif -hnf6.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa10.motif of width 10.
# Using motif -hoxa10.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa11.motif of width 10.
# Using motif -hoxa11.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa13.motif of width 10.
# Using motif -hoxa13.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa2.motif of width 12.
# Using motif -hoxa2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa9.motif of width 10.
# Using motif -hoxa9.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxb13.motif of width 10.
# Using motif -hoxb13.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxb4.motif of width 12.
# Using motif -hoxb4.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxc9.motif of width 12.
# Using motif -hoxc9.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxd10.motif of width 10.
# Using motif -hoxd10.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxd11.motif of width 10.
# Using motif -hoxd11.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxd12.motif of width 12.
# Using motif -hoxd12.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxd13.motif of width 10.
# Using motif -hoxd13.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hsf.motif of width 15.
# Using motif -hsf.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hsf1.motif of width 20.
# Using motif -hsf1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.802
# Using motif +inr.motif of width 8.
# Using motif -inr.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.944277
# Using motif +irf1.motif of width 12.
# Using motif -irf1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999095
# Using motif +irf2.motif of width 12.
# Using motif -irf2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.923148
# Using motif +irf3.motif of width 12.
# Using motif -irf3.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998291
# Using motif +irf4.motif of width 10.
# Using motif -irf4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +irf8.motif of width 12.
# Using motif -irf8.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998693
# Using motif +isl1.motif of width 8.
# Using motif -isl1.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +isre.motif of width 12.
# Using motif -isre.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +jun-ap1.motif of width 12.
# Using motif -jun-ap1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +jun-cre.motif of width 12.
# Using motif -jun-cre.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +junb.motif of width 10.
# Using motif -junb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +jund.motif of width 12.
# Using motif -jund.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +klf10.motif of width 12.
# Using motif -klf10.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.806154
# Using motif +klf14.motif of width 12.
# Using motif -klf14.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.781311
# Using motif +klf3.motif of width 15.
# Using motif -klf3.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.758512
# Using motif +klf4.motif of width 10.
# Using motif -klf4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.775248
# Using motif +klf5.motif of width 10.
# Using motif -klf5.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.830175
# Using motif +klf6.motif of width 12.
# Using motif -klf6.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.751485
# Using motif +klf9.motif of width 12.
# Using motif -klf9.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.778545
# Using motif +lef1.motif of width 10.
# Using motif -lef1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +lhx1.motif of width 10.
# Using motif -lhx1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +lhx2.motif of width 8.
# Using motif -lhx2.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +lhx3.motif of width 10.
# Using motif -lhx3.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +limb.motif of width 10.
# Using motif -limb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +lrf.motif of width 10.
# Using motif -lrf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.735752
# Using motif +lrh1.motif of width 10.
# Using motif -lrh1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.939692
# Using motif +lxre.motif of width 16.
# Using motif -lxre.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998283
# Using motif +mafa.motif of width 10.
# Using motif -mafa.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.918559
# Using motif +mafb.motif of width 20.
# Using motif -mafb.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999397
# Using motif +mafF.motif of width 15.
# Using motif -mafF.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mafk.motif of width 12.
# Using motif -mafk.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.967898
# Using motif +max.motif of width 12.
# Using motif -max.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.867333
# Using motif +maz.motif of width 8.
# Using motif -maz.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.685825
# Using motif +mef2a.motif of width 10.
# Using motif -mef2a.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mef2b.motif of width 12.
# Using motif -mef2b.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mef2c.motif of width 12.
# Using motif -mef2c.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mef2d.motif of width 12.
# Using motif -mef2d.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +meis1.motif of width 10.
# Using motif -meis1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.874128
# Using motif +mitf.motif of width 10.
# Using motif -mitf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.868571
# Using motif +mnt.motif of width 10.
# Using motif -mnt.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.903107
# Using motif +myb.motif of width 8.
# Using motif -myb.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.923762
# Using motif +myba.motif of width 10.
# Using motif -myba.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.955806
# Using motif +myf5.motif of width 10.
# Using motif -myf5.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.863729
# Using motif +mynn.motif of width 15.
# Using motif -mynn.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +myod.motif of width 12.
# Using motif -myod.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.845333
# Using motif +myog.motif of width 8.
# Using motif -myog.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.857798
# Using motif +nanog.motif of width 10.
# Using motif -nanog.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +neurod1.motif of width 10.
# Using motif -neurod1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.882586
# Using motif +neurog2.motif of width 10.
# Using motif -neurog2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.922037
# Using motif +nf1-fox.motif of width 16.
# Using motif -nf1-fox.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +nf1-half.motif of width 8.
# Using motif -nf1-half.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.798416
# Using motif +nf1.motif of width 16.
# Using motif -nf1.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.832833
# Using motif +nfat-ap1.motif of width 20.
# Using motif -nfat-ap1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999296
# Using motif +nfatc1.motif of width 10.
# Using motif -nfatc1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +nfe2.motif of width 12.
# Using motif -nfe2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999196
# Using motif +nfe2l2.motif of width 15.
# Using motif -nfe2l2.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +nfil3.motif of width 15.
# Using motif -nfil3.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +nfkb.motif of width 10.
# Using motif -nfkb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999397
# Using motif +nfy.motif of width 10.
# Using motif -nfy.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.877944
# Using motif +nkx2.1.motif of width 10.
# Using motif -nkx2.1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999095
# Using motif +nkx2.2.motif of width 10.
# Using motif -nkx2.2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.961752
# Using motif +nkx2.5.motif of width 10.
# Using motif -nkx2.5.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.996566
# Using motif +nkx3.1.motif of width 10.
# Using motif -nkx3.1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999497
# Using motif +nkx6.1.motif of width 8.
# Using motif -nkx6.1.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +nmyc.motif of width 10.
# Using motif -nmyc.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7784
# Using motif +npas.motif of width 8.
# Using motif -npas.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.876364
# Using motif +npas2.motif of width 10.
# Using motif -npas2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.890943
# Using motif +nr2f6.motif of width 12.
# Using motif -nr2f6.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.838378
# Using motif +nr5a2.motif of width 10.
# Using motif -nr5a2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.917308
# Using motif +nrf.motif of width 12.
# Using motif -nrf.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.707611
# Using motif +nrf1.motif of width 12.
# Using motif -nrf1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.685149
# Using motif +nrf2.motif of width 12.
# Using motif -nrf2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.985952
# Using motif +nur77.motif of width 12.
# Using motif -nur77.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct-oct.motif of width 15.
# Using motif -oct-oct.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct-oct.short.motif of width 15.
# Using motif -oct-oct.short.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct.ir.motif of width 15.
# Using motif -oct.ir.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct.ir1.motif of width 15.
# Using motif -oct.ir1.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct2.motif of width 10.
# Using motif -oct2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct4-sox17.motif of width 15.
# Using motif -oct4-sox17.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct4-sox2.motif of width 15.
# Using motif -oct4-sox2.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct4.motif of width 10.
# Using motif -oct4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +oct6.motif of width 12.
# Using motif -oct6.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +olig2.motif of width 10.
# Using motif -olig2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.973765
# Using motif +otx2.motif of width 10.
# Using motif -otx2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +p50.motif of width 12.
# Using motif -p50.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.74297
# Using motif +p53-myc.motif of width 14.
# Using motif -p53-myc.motif of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.806733
# Using motif +p53.motif of width 20.
# Using motif -p53.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.935659
# Using motif +p63.motif of width 20.
# Using motif -p63.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.940526
# Using motif +p65.motif of width 12.
# Using motif -p65.motif of width 12.
# ...
# Estimating pi_0.
# Estimated pi_0=0.797797
# Using motif +spdef.motif of width 10.
# Using motif -spdef.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.99016
# Using motif +spib.motif of width 12.
# Using motif -spib.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.980361
# Using motif +srebp1a.motif of width 10.
# Using motif -srebp1a.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.852308
# Using motif +srebp2.motif of width 12.
# Using motif -srebp2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.805586
# Using motif +srf.motif of width 12.
# Using motif -srf.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +staf.motif of width 15.
# Using motif -staf.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.837857
# Using motif +stat1.motif of width 14.
# Using motif -stat1.motif of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +stat3.il23.motif of width 14.
# Using motif -stat3.il23.motif of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.992472
# Using motif +stat3.motif of width 10.
# Using motif -stat3.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.943119
# Using motif +stat4.motif of width 12.
# Using motif -stat4.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +stat5.motif of width 12.
# Using motif -stat5.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +stat6.2.motif of width 10.
# Using motif -stat6.2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +stat6.motif of width 12.
# Using motif -stat6.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +t1isre.motif of width 12.
# Using motif -t1isre.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tata.motif of width 12.
# Using motif -tata.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tbet.motif of width 10.
# Using motif -tbet.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tbox-smad.motif of width 12.
# Using motif -tbox-smad.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.90463
# Using motif +tbr1.motif of width 10.
# Using motif -tbr1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tbx20.motif of width 12.
# Using motif -tbx20.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.943486
# Using motif +tbx21.motif of width 10.
# Using motif -tbx21.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tbx5.motif of width 8.
# Using motif -tbx5.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.919531
# Using motif +tcf12.motif of width 10.
# Using motif -tcf12.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.797222
# Using motif +tcf21.motif of width 10.
# Using motif -tcf21.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.890827
# Using motif +tcf3.motif of width 10.
# Using motif -tcf3.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tcf4.motif of width 12.
# Using motif -tcf4.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tcf7.motif of width 12.
# Using motif -tcf7.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999799
# Using motif +tcf7l2.motif of width 10.
# Using motif -tcf7l2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tcfcp2l1.motif of width 20.
# Using motif -tcfcp2l1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.916567
# Using motif +tead.motif of width 10.
# Using motif -tead.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tead1.motif of width 10.
# Using motif -tead1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tead2.motif of width 10.
# Using motif -tead2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tead3.motif of width 10.
# Using motif -tead3.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tead4.motif of width 10.
# Using motif -tead4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.995754
# Using motif +tfe3.motif of width 12.
# Using motif -tfe3.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.917143
# Using motif +tgif1.motif of width 8.
# Using motif -tgif1.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +tgif2.motif of width 8.
# Using motif -tgif2.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999799
# Using motif +thrb.motif of width 15.
# Using motif -thrb.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.757843
# Using motif +tlx.motif of width 14.
# Using motif -tlx.motif of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.885082
# Using motif +tr4.motif of width 14.
# Using motif -tr4.motif of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.887111
# Using motif +tra.motif of width 15.
# Using motif -tra.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.861695
# Using motif +trb.motif of width 8.
# Using motif -trb.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.935263
# Using motif +twist1.motif of width 20.
# Using motif -twist1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.884912
# Using motif +usf1.motif of width 10.
# Using motif -usf1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.808738
# Using motif +usf2.motif of width 10.
# Using motif -usf2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.8662
# Using motif +vdr.motif of width 20.
# Using motif -vdr.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.905077
# Using motif +xbox.motif of width 14.
# Using motif -xbox.motif of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +yy1.motif of width 12.
# Using motif -yy1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.87578
# Using motif +zbtb12.motif of width 15.
# Using motif -zbtb12.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.876667
# Using motif +zbtb18.motif of width 10.
# Using motif -zbtb18.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.876637
# Using motif +zbtb33.motif of width 15.
# Using motif -zbtb33.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.717228
# Using motif +zeb1.motif of width 10.
# Using motif -zeb1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.872581
# Using motif +zfp281.motif of width 12.
# Using motif -zfp281.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.778113
# Using motif +zfp3.motif of width 25.
# Using motif -zfp3.motif of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.988995
# Using motif +zfp809.motif of width 15.
# Using motif -zfp809.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.729623
# Using motif +zfx.motif of width 8.
# Using motif -zfx.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7832
# Using motif +zic.motif of width 10.
# Using motif -zic.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.874643
# Using motif +zic3.motif of width 15.
# Using motif -zic3.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.749381
# Using motif +zkscan1.motif of width 15.
# Using motif -zkscan1.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.852039
# Using motif +znf136.motif of width 25.
# Using motif -znf136.motif of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +znf16.motif of width 25.
# Using motif -znf16.motif of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.837857
# Using motif +znf165.motif of width 15.
# Using motif -znf165.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7146
# Using motif +znf189.motif of width 10.
# Using motif -znf189.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.887593
# Using motif +znf263.motif of width 10.
# Using motif -znf263.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.754775
# Using motif +znf264.motif of width 12.
# Using motif -znf264.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.922692
# Using motif +znf317.motif of width 15.
# Using motif -znf317.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.985464
# Using motif +znf322.motif of width 20.
# Using motif -znf322.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.860451
# Using motif +znf382.motif of width 20.
# Using motif -znf382.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.996061
# Using motif +znf41.motif of width 25.
# Using motif -znf41.motif of width 25.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.951786
# Using motif +znf415.motif of width 12.
# Using motif -znf415.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.833269
# Using motif +znf416.motif of width 10.
# Using motif -znf416.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.948961
# Using motif +znf467.motif of width 12.
# Using motif -znf467.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.850139
# Using motif +znf519.motif of width 10.
# Using motif -znf519.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.6964
# Using motif +znf528.motif of width 15.
# Using motif -znf528.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998894
# Using motif +znf652.motif of width 15.
# Using motif -znf652.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +znf669.motif of width 15.
# Using motif -znf669.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.769444
# Using motif +znf675.motif of width 15.
# Using motif -znf675.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +znf692.motif of width 10.
# Using motif -znf692.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.671154
# Using motif +znf7.motif of width 45.
# Using motif -znf7.motif of width 45.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.86931
# Using motif +znf711.motif of width 8.
# Using motif -znf711.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.729143
# Using motif +zscan22.motif of width 20.
# Using motif -zscan22.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.866053
# -800.9301784038544

# %%
motif_f = os.path.join(out_dir, "fimo.tsv")
peaks_df_exp = read_bed_file(peak_f.replace(".peak",".bed"))
peaks_df_exp = peaks_df_exp[~(peaks_df_exp.index.duplicated())]
motifs_df_exp = pd.read_csv(motif_f,sep="\t",comment="#")
#inr = motifs_df[motifs_df["motif_id"] == "inr.motif"]
motifs_df_exp.head()
# Out:
#       motif_id  motif_alt_id   sequence_name  start  stop strand    score  \
# 0  ronin.motif           NaN  XM_027409439.1      5    24      +  30.4364
# 1  ronin.motif           NaN  XM_027409440.1      6    25      +  30.4364
# 2  ronin.motif           NaN  XM_027414975.1     20    39      +  30.4364
# 3  ronin.motif           NaN  XM_027431202.1     53    72      -  30.4364
# 4  znf16.motif           NaN  XM_027408480.1     99   123      +  33.8970
#
#         p-value   q-value           matched_sequence
# 0  1.230000e-12  0.000003       GACTACAACTCCCAGAAGGC
# 1  1.230000e-12  0.000003       GACTACAACTCCCAGAAGGC
# 2  1.230000e-12  0.000003       GACTACAACTCCCAGAAGGC
# 3  1.230000e-12  0.000003       GACTACAACTCCCAGAAGGC
# 4  1.450000e-12  0.000014  AACCTTCCATGGCTCCCTATCACCT

# %%
motifs_of_interest = ["tata.motif", "inr.motif"]
#motifs_of_interest = ["ap2.motif"]

# %%
peak_center=75
motifs_data = dict()
for m in motifs_of_interest:
    name = m.replace(".motif", "")
    curr_exp = motifs_df_exp[motifs_df_exp["motif_id"] ==  m]
    
    #curr = motifs_df.query("motif_id == 'tata.motif' ")
    num_nts = np.max(curr_exp["stop"])
    
    curr_out_neg_exp = motif_analysis.initialize_motif_df(peaks_df_exp.index,seq_len=num_nts)

    curr_out_pos_exp = motif_analysis.initialize_motif_df(peaks_df_exp.index,seq_len=num_nts)

    
    #first_seq = curr_out.columns.values[0]
    first_seq = curr_out_neg_exp.columns.values[0]
    for ind,val in (curr_exp.iterrows()):
        if val["strand"] == "-":
            curr_out_neg_exp.at[val["sequence_name"],first_seq + val["start"] - 1] = True

    for ind,val in (curr_exp.iterrows()):
        if val["strand"] == "+":
            curr_out_pos_exp.at[val["sequence_name"],first_seq + val["start"] - 1] = True
        
    N = 5
    f,ax = plt.subplots()
    
    y_exp = np.array(curr_out_pos_exp.sum()) +np.array(curr_out_neg_exp.sum())
    motifs_data[name] = pd.DataFrame({"Position":curr_out_neg_exp.columns.values, "Motif Counts Human HG38":y_exp})
    motifs_data[name].to_csv(os.path.join(out_dir, name+".csv"), index=False)
        
    ax.bar(x=range(1, len(y_exp)+1), height= y_exp, color="b", alpha=0.4)
    plt.title(name)
    
    ax.set_xlabel("Distance to TSS")
    ax.set_ylabel("Motif Frequency")
    
    ax.set_xticks(np.arange(-1*peak_center,peak_center+1, 15) + peak_center)
    ax.set_xticklabels(np.arange(-1*peak_center,peak_center+1, 15))

# %% [markdown]
# ------

# %% [markdown]
# ------

# %% [markdown]
# ------
