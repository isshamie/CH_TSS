# %%
import pickle
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
import seaborn as sns

# %%
ref_fa = '/data/isshamie/genome/picr.fa'

# %% [markdown]
# ## Read in tss experimental and all start sites and merge them. Set the actual_start to be tss experimental when there is one

# %%
# %%time
tss = pd.read_csv('Results/tss_final/tss_peakCenter_1kb_1kb.bed',sep='\t',header=None, index_col =3)
 
#Munge data for downstream processing
cols = tss.columns.values
cols = ['Chr','Start','End','Score','Strand']
tss.columns= cols

name_vals = ['gene','gene_id','transcript_id','Tissues','cs']

tmp_tss = tss.copy()
for ind in tmp_tss.index.values:
    curr = ind.split(';')
    for i,val in enumerate(curr):
        tmp_tss.set_value(ind,name_vals[i],val)

tmp_tss['Length'] = tmp_tss['End'] - tmp_tss['Start']

tss = tmp_tss
tss['actual_start'] = tss.apply(lambda x: int(np.floor(((x['Start']+x['End'])-1)/2)) 
                if x['Strand'] == '+' else int(np.ceil(((x['Start']+x['End'])-1)/2)),axis=1)

#tss['actual_start'] = tss.apply( lambda x: x['Start'] if x['Strand'] == '+' else x['End'],axis=1)

## Just in case make a copy
tss['actual_start_copy'] = tss['actual_start']

tss.head()
# Out:
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
#                                                        Chr  Start    End  \
# 3
# RRP7A;gene_2;asmbl_4;CHO;cs=1                       picr_0  45849  45999
# RRP7A;gene_2;asmbl_10;Brain,CHO,Spleen;cs=1         picr_0  44409  44566
# SERHL;gene_1_4;asmbl_14;BMDMwt,Heart,Spleen,CHO...  picr_0  20879  21067
# POLDIP3;gene_3_1;asmbl_17;BMDMwt,Heart,Spleen,C...  picr_0  98719  98916
# POLDIP3;gene_3_1;asmbl_19;BMDMwt,Heart,Spleen,C...  picr_0  78177  78416
#
#                                                          Score Strand  \
# 3
# RRP7A;gene_2;asmbl_4;CHO;cs=1                         3.040000      -
# RRP7A;gene_2;asmbl_10;Brain,CHO,Spleen;cs=1          10.105000      -
# SERHL;gene_1_4;asmbl_14;BMDMwt,Heart,Spleen,CHO...   96.550003      +
# POLDIP3;gene_3_1;asmbl_17;BMDMwt,Heart,Spleen,C...  146.399994      -
# POLDIP3;gene_3_1;asmbl_19;BMDMwt,Heart,Spleen,C...   34.799999      -
#
#                                                        gene   gene_id  \
# 3
# RRP7A;gene_2;asmbl_4;CHO;cs=1                         RRP7A    gene_2
# RRP7A;gene_2;asmbl_10;Brain,CHO,Spleen;cs=1           RRP7A    gene_2
# SERHL;gene_1_4;asmbl_14;BMDMwt,Heart,Spleen,CHO...    SERHL  gene_1_4
# POLDIP3;gene_3_1;asmbl_17;BMDMwt,Heart,Spleen,C...  POLDIP3  gene_3_1
# POLDIP3;gene_3_1;asmbl_19;BMDMwt,Heart,Spleen,C...  POLDIP3  gene_3_1
#
#                                                    transcript_id  \
# 3
# RRP7A;gene_2;asmbl_4;CHO;cs=1                            asmbl_4
# RRP7A;gene_2;asmbl_10;Brain,CHO,Spleen;cs=1             asmbl_10
# SERHL;gene_1_4;asmbl_14;BMDMwt,Heart,Spleen,CHO...      asmbl_14
# POLDIP3;gene_3_1;asmbl_17;BMDMwt,Heart,Spleen,C...      asmbl_17
# POLDIP3;gene_3_1;asmbl_19;BMDMwt,Heart,Spleen,C...      asmbl_19
#
#                                                                                               Tissues  \
# 3
# RRP7A;gene_2;asmbl_4;CHO;cs=1                                                                     CHO
# RRP7A;gene_2;asmbl_10;Brain,CHO,Spleen;cs=1                                          Brain,CHO,Spleen
# SERHL;gene_1_4;asmbl_14;BMDMwt,Heart,Spleen,CHO...  BMDMwt,Heart,Spleen,CHO,Brain,Lung,Liver,Muscl...
# POLDIP3;gene_3_1;asmbl_17;BMDMwt,Heart,Spleen,C...  BMDMwt,Heart,Spleen,CHO,Brain,Lung,Liver,Muscl...
# POLDIP3;gene_3_1;asmbl_19;BMDMwt,Heart,Spleen,C...  BMDMwt,Heart,Spleen,CHO,Brain,Lung,Liver,Muscl...
#
#                                                       cs  Length  actual_start
# 3
# RRP7A;gene_2;asmbl_4;CHO;cs=1                       cs=1     150         45923
# RRP7A;gene_2;asmbl_10;Brain,CHO,Spleen;cs=1         cs=1     157         44487
# SERHL;gene_1_4;asmbl_14;BMDMwt,Heart,Spleen,CHO...  cs=2     188         20972
# POLDIP3;gene_3_1;asmbl_17;BMDMwt,Heart,Spleen,C...  cs=1     197         98817
# POLDIP3;gene_3_1;asmbl_19;BMDMwt,Heart,Spleen,C...  cs=3     239         78296

# %%
annotation_start_site = pd.read_csv('/data/isshamie/genome/start_site_mRNA_updated_final_sort.tsv',index_col = 0,sep='\t')
annotation_start_site.head()
# Out:
#                                                        Chr  Start    End  \
# ID=asmbl_2;Parent=gene_1_2;gene_id=gene_1_2;gen...  picr_0    176  38694
# ID=asmbl_4;Parent=gene_2;gene_id=gene_2;gene=RR...  picr_0   7715  46630
# ID=asmbl_7;Parent=gene_2;gene_id=gene_2;gene=RR...  picr_0   7759  44597
# ID=asmbl_8;Parent=gene_2;gene_id=gene_2;gene=RR...  picr_0   7767  44597
# ID=asmbl_9;Parent=gene_2;gene_id=gene_2;gene=RR...  picr_0   7789  44568
#
#                                                    Strand       ID    Parent  \
# ID=asmbl_2;Parent=gene_1_2;gene_id=gene_1_2;gen...      +  asmbl_2  gene_1_2
# ID=asmbl_4;Parent=gene_2;gene_id=gene_2;gene=RR...      -  asmbl_4    gene_2
# ID=asmbl_7;Parent=gene_2;gene_id=gene_2;gene=RR...      -  asmbl_7    gene_2
# ID=asmbl_8;Parent=gene_2;gene_id=gene_2;gene=RR...      -  asmbl_8    gene_2
# ID=asmbl_9;Parent=gene_2;gene_id=gene_2;gene=RR...      -  asmbl_9    gene_2
#
#                                                      gene_id   gene  \
# ID=asmbl_2;Parent=gene_1_2;gene_id=gene_1_2;gen...  gene_1_2  SERHL
# ID=asmbl_4;Parent=gene_2;gene_id=gene_2;gene=RR...    gene_2  RRP7A
# ID=asmbl_7;Parent=gene_2;gene_id=gene_2;gene=RR...    gene_2  RRP7A
# ID=asmbl_8;Parent=gene_2;gene_id=gene_2;gene=RR...    gene_2  RRP7A
# ID=asmbl_9;Parent=gene_2;gene_id=gene_2;gene=RR...    gene_2  RRP7A
#
#                                                    transcript_id  cs  Length  \
# ID=asmbl_2;Parent=gene_1_2;gene_id=gene_1_2;gen...       asmbl_2   2   38518
# ID=asmbl_4;Parent=gene_2;gene_id=gene_2;gene=RR...       asmbl_4   1   38915
# ID=asmbl_7;Parent=gene_2;gene_id=gene_2;gene=RR...       asmbl_7   1   36838
# ID=asmbl_8;Parent=gene_2;gene_id=gene_2;gene=RR...       asmbl_8   1   36830
# ID=asmbl_9;Parent=gene_2;gene_id=gene_2;gene=RR...       asmbl_9   1   36779
#
#                                                     actual_start
# ID=asmbl_2;Parent=gene_1_2;gene_id=gene_1_2;gen...           176
# ID=asmbl_4;Parent=gene_2;gene_id=gene_2;gene=RR...         46630
# ID=asmbl_7;Parent=gene_2;gene_id=gene_2;gene=RR...         44597
# ID=asmbl_8;Parent=gene_2;gene_id=gene_2;gene=RR...         44597
# ID=asmbl_9;Parent=gene_2;gene_id=gene_2;gene=RR...         44568

# %%
annotation_start_site.shape
# Out:
# (52382, 12)

# %% [markdown]
# ### Merge the two

# %%
tss['actual_start_copy'] = tss['actual_start']

# %%
merged = pd.merge(tss,annotation_start_site,on=['transcript_id','gene','gene_id','Strand','Chr'],how='outer')#,left_on='actual_start')

## Set actual_start to be from left if its not null otherwise right
merged['actual_start'] = merged.apply(lambda x: x['actual_start_x'] if not np.isnan(x['actual_start_x']) 
                                      else x['actual_start_y'], axis=1)
print(merged.shape)

merged['Start'] = merged['Start_y']
merged['End'] = merged['End_y']

merged = merged.set_index('transcript_id')

# Sort by chr, start and end
merged = merged.sort_values(['Chr','Start','End'])
merged.head()
# Out:
# (52382, 21)
#                   Chr  Start_x    End_x       Score Strand     gene   gene_id  \
# transcript_id
# asmbl_4        picr_0  45849.0  45999.0    3.040000      -    RRP7A    gene_2
# asmbl_10       picr_0  44409.0  44566.0   10.105000      -    RRP7A    gene_2
# asmbl_14       picr_0  20879.0  21067.0   96.550003      +    SERHL  gene_1_4
# asmbl_17       picr_0  98719.0  98916.0  146.399994      -  POLDIP3  gene_3_1
# asmbl_19       picr_0  78177.0  78416.0   34.799999      -  POLDIP3  gene_3_1
#
#                                                          Tissues  cs_x  \
# transcript_id
# asmbl_4                                                      CHO  cs=1
# asmbl_10                                        Brain,CHO,Spleen  cs=1
# asmbl_14       BMDMwt,Heart,Spleen,CHO,Brain,Lung,Liver,Muscl...  cs=2
# asmbl_17       BMDMwt,Heart,Spleen,CHO,Brain,Lung,Liver,Muscl...  cs=1
# asmbl_19       BMDMwt,Heart,Spleen,CHO,Brain,Lung,Liver,Muscl...  cs=3
#
#                Length_x  ...    Start_y  End_y        ID    Parent cs_y  \
# transcript_id            ...
# asmbl_4           150.0  ...       7715  46630   asmbl_4    gene_2    1
# asmbl_10          157.0  ...       7821  44513  asmbl_10    gene_2    1
# asmbl_14          188.0  ...      20942  38694  asmbl_14  gene_1_4    2
# asmbl_17          197.0  ...      49679  98922  asmbl_17  gene_3_1    1
# asmbl_19          239.0  ...      64336  78255  asmbl_19  gene_3_1    3
#
#               Length_y  actual_start_y  actual_start  Start    End
# transcript_id
# asmbl_4          38915           46630       45923.0   7715  46630
# asmbl_10         36692           44513       44487.0   7821  44513
# asmbl_14         17752           20942       20972.0  20942  38694
# asmbl_17         49243           98922       98817.0  49679  98922
# asmbl_19         13919           78255       78296.0  64336  78255
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Load CDS and setup for later merging

# %%
# %%time 
cds = pd.read_csv('/data/isshamie/genome/CDS.gff3',sep='\t',header=None,index_col=8)
#Munge data for downstream processing
cols = cds.columns.values
cols = ['Chr','Merge','Type','Start','End','.','Strand','..']
cds.columns= cols
#Drop the unncesseary columns
cds.drop(['Merge','.','..','Type'],axis=1,inplace=True)

## Setup actual_start for cds
cds['actual_start'] = cds.apply(lambda x: int(x['Start']) if x['Strand'] == '+' else int(x['End']),axis=1)


tmp_cds = cds.copy()
for ind in tmp_cds.index.values:
    curr = ind.split(';')
    for i in curr:
        curr_split = i.split('=')
        tmp_cds.set_value(ind,curr_split[0],curr_split[1])

tmp_cds['Length'] = tmp_cds['End'] - tmp_cds['Start']

cds = tmp_cds
cds = cds.rename(columns={'protein_id':'transcript_id'})
cds.head()
# Out:
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# CPU times: user 1min 30s, sys: 4.42 s, total: 1min 35s
# Wall time: 58.4 s

# %% [markdown]
# ## Save as bed file and extract sequences

# %% [markdown]
# # Extract sequences

# %%
# %%time
bins = [-2000,2000]

alltss_f = 'Results/tss_final/tss_peakCenter_1kb_1kb_ALLGENES_FLANK_2kb.bed'

merged_bed = merged[['Chr','actual_start','Strand','gene_id','gene']]
merged_bed['transcript_id'] = merged_bed.index
merged_bed['Start']  = merged_bed['actual_start'] + bins[0]
merged_bed['Start'] = merged_bed['Start'].astype(int)
merged_bed['End'] = merged_bed['actual_start'] +  bins[1] + 1
merged_bed['End'] = merged_bed['End'].astype(int)
merged_bed['ID'] = merged_bed.apply(lambda x: x['gene'] + ';' + x['gene_id'] + ';' + x['transcript_id'],axis=1)
merged_bed['Score'] = 0
merged_bed = merged_bed[['Chr','Start','End','ID','Score','Strand']]

merged_bed.to_csv(alltss_f,header=None,index=None,sep='\t')

merged_bed
# Out:
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#                     Chr    Start      End                                  ID  \
# transcript_id
# asmbl_2          picr_0    -1824     2177              SERHL;gene_1_2;asmbl_2
# asmbl_4          picr_0    43923    47924                RRP7A;gene_2;asmbl_4
# asmbl_7          picr_0    42597    46598                RRP7A;gene_2;asmbl_7
# asmbl_8          picr_0    42597    46598                RRP7A;gene_2;asmbl_8
# asmbl_9          picr_0    42568    46569                RRP7A;gene_2;asmbl_9
# asmbl_10         picr_0    42487    46488               RRP7A;gene_2;asmbl_10
# asmbl_11         picr_0    16149    20150             SERHL;gene_1_4;asmbl_11
# asmbl_12         picr_0    18787    22788             SERHL;gene_1_4;asmbl_12
# asmbl_14         picr_0    18972    22973             SERHL;gene_1_4;asmbl_14
# asmbl_15         picr_0    20504    24505             SERHL;gene_1_4;asmbl_15
# asmbl_16         picr_0    42549    46550               RRP7A;gene_2;asmbl_16
# asmbl_17         picr_0    96817   100818           POLDIP3;gene_3_1;asmbl_17
# asmbl_18         picr_0    63510    67511           POLDIP3;gene_3_1;asmbl_18
# asmbl_19         picr_0    76296    80297           POLDIP3;gene_3_1;asmbl_19
# asmbl_20         picr_0    90199    94200            CYB5R3;gene_3_2;asmbl_20
# asmbl_21         picr_0   183875   187876            A4GALT;gene_4_1;asmbl_21
# asmbl_22         picr_0   183760   187761            A4GALT;gene_4_3;asmbl_22
# asmbl_24         picr_0   184288   188289            A4GALT;gene_4_3;asmbl_24
# asmbl_30         picr_0   183727   187728            A4GALT;gene_4_3;asmbl_30
# asmbl_27         picr_0   188544   192545            A4GALT;gene_4_3;asmbl_27
# asmbl_31         picr_0   296212   300213           ARFGAP3;gene_5_1;asmbl_31
# asmbl_33         picr_0   273669   277670           ARFGAP3;gene_5_1;asmbl_33
# asmbl_32         picr_0   296241   300242           ARFGAP3;gene_5_1;asmbl_32
# asmbl_39         picr_0   396907   400908             PACSIN2;gene_6;asmbl_39
# asmbl_41         picr_0   396870   400871             PACSIN2;gene_6;asmbl_41
# asmbl_42         picr_0   396885   400886             PACSIN2;gene_6;asmbl_42
# asmbl_43         picr_0   396822   400823             PACSIN2;gene_6;asmbl_43
# asmbl_37         picr_0   362375   366376             PACSIN2;gene_6;asmbl_37
# asmbl_44         picr_0   396907   400908             PACSIN2;gene_6;asmbl_44
# asmbl_46         picr_0   396878   400879             PACSIN2;gene_6;asmbl_46
# ...                 ...      ...      ...                                 ...
# asmbl_86715     picr_99  1659205  1663206        NOC3L;gene_30652;asmbl_86715
# asmbl_86717     picr_99  1814047  1818048        NOVA1;gene_30653;asmbl_86717
# asmbl_86718     picr_99  1814550  1818551        NOVA1;gene_30653;asmbl_86718
# asmbl_86719     picr_99  1815516  1819517        NOVA1;gene_30653;asmbl_86719
# asmbl_86720     picr_99  1816096  1820097        NOVA1;gene_30653;asmbl_86720
# asmbl_86722     picr_99  2237032  2241033         ODC1;gene_30655;asmbl_86722
# asmbl_86745     picr_99  2898175  2902176      ALG12;gene_30659_2;asmbl_86745
# asmbl_86746     picr_99  3281730  3285731       BCLAF1;gene_30660;asmbl_86746
# asmbl_86747     picr_99  3426604  3430605       STXBP6;gene_30661;asmbl_86747
# asmbl_86748     picr_99  3483279  3487280       STXBP6;gene_30661;asmbl_86748
# asmbl_86749     picr_99  3707553  3711554       LYPLA1;gene_30662;asmbl_86749
# asmbl_86750     picr_99  3778406  3782407      ERVK-10;gene_30663;asmbl_86750
# asmbl_86753     picr_99  4060714  4064715        NRCAM;gene_30665;asmbl_86753
# asmbl_86752     picr_99  4060761  4064762        NRCAM;gene_30665;asmbl_86752
# asmbl_86760     picr_99  3931613  3935614        NRCAM;gene_30665;asmbl_86760
# asmbl_86762     picr_99  3931613  3935614        NRCAM;gene_30665;asmbl_86762
# asmbl_86764     picr_99  4128605  4132606       PNPLA8;gene_30666;asmbl_86764
# asmbl_86765     picr_99  4138492  4142493       DNAJB9;gene_30667;asmbl_86765
# asmbl_86766     picr_99  4146701  4150702       DNAJB9;gene_30667;asmbl_86766
# asmbl_86767     picr_99  4147349  4151350       DNAJB9;gene_30667;asmbl_86767
# asmbl_86768     picr_99  4148222  4152223       DNAJB9;gene_30667;asmbl_86768
# asmbl_86773     picr_99  5681256  5685257     AASDHPPT;gene_30671;asmbl_86773
# asmbl_86774     picr_99  6273077  6277078          ENV;gene_30672;asmbl_86774
# asmbl_86776     picr_99  6821783  6825784        LRRN3;gene_30674;asmbl_86776
# asmbl_86777     picr_99  6822757  6826758        LRRN3;gene_30674;asmbl_86777
# asmbl_86779     picr_99  6822889  6826890        LRRN3;gene_30674;asmbl_86779
# asmbl_86784    picr_991    12644    16645     IGKV2-30;gene_30675;asmbl_86784
# asmbl_86785    picr_996    18730    22731        EFNB2;gene_30676;asmbl_86785
# asmbl_86788    picr_997    10858    14859  KV3AK_MOUSE;gene_30677;asmbl_86788
# asmbl_86789    picr_997    28011    32012  KV3A9_MOUSE;gene_30678;asmbl_86789
#
#                Score Strand
# transcript_id
# asmbl_2            0      +
# asmbl_4            0      -
# asmbl_7            0      -
# asmbl_8            0      -
# asmbl_9            0      -
# asmbl_10           0      -
# asmbl_11           0      +
# asmbl_12           0      +
# asmbl_14           0      +
# asmbl_15           0      +
# asmbl_16           0      -
# asmbl_17           0      -
# asmbl_18           0      -
# asmbl_19           0      -
# asmbl_20           0      -
# asmbl_21           0      -
# asmbl_22           0      -
# asmbl_24           0      -
# asmbl_30           0      -
# asmbl_27           0      -
# asmbl_31           0      -
# asmbl_33           0      -
# asmbl_32           0      -
# asmbl_39           0      -
# asmbl_41           0      -
# asmbl_42           0      -
# asmbl_43           0      -
# asmbl_37           0      -
# asmbl_44           0      -
# asmbl_46           0      -
# ...              ...    ...
# asmbl_86715        0      -
# asmbl_86717        0      +
# asmbl_86718        0      +
# asmbl_86719        0      +
# asmbl_86720        0      +
# asmbl_86722        0      +
# asmbl_86745        0      -
# asmbl_86746        0      -
# asmbl_86747        0      +
# asmbl_86748        0      +
# asmbl_86749        0      -
# asmbl_86750        0      -
# asmbl_86753        0      -
# asmbl_86752        0      -
# asmbl_86760        0      -
# asmbl_86762        0      -
# asmbl_86764        0      -
# asmbl_86765        0      +
# asmbl_86766        0      +
# asmbl_86767        0      +
# asmbl_86768        0      +
# asmbl_86773        0      -
# asmbl_86774        0      -
# asmbl_86776        0      +
# asmbl_86777        0      +
# asmbl_86779        0      +
# asmbl_86784        0      -
# asmbl_86785        0      +
# asmbl_86788        0      +
# asmbl_86789        0      +
#
# [52382 rows x 6 columns]

# %%
out_fa = alltss_f.replace('bed','fa')
cmd = 'homerTools extract {bed_f} {ref_fa} -fa > {out}'.format(bed_f=alltss_f,ref_fa=ref_fa,out=out_fa)
print(cmd)
# !{cmd}
# Out:
# homerTools extract Results/tss_final/tss_peakCenter_1kb_1kb_ALLGENES_FLANK_2kb.bed /data/isshamie/genome/picr.fa -fa > Results/tss_final/tss_peakCenter_1kb_1kb_ALLGENES_FLANK_2kb.fa
#
# 	Extracting sequences from file: /data/isshamie/genome/picr.fa
# 	Looking for peak sequences in a single file (/data/isshamie/genome/picr.fa)
# 	Extracting 2093 sequences from picr_0
# 	Extracting 1147 sequences from picr_1
# 	Extracting 1913 sequences from picr_2
# 	Extracting 1117 sequences from picr_3
# 	Extracting 1063 sequences from picr_4
# 	Extracting 747 sequences from picr_5
# 	Extracting 719 sequences from picr_6
# 	Extracting 1684 sequences from picr_8
# 	Extracting 654 sequences from picr_9
# 	Extracting 767 sequences from picr_10
# 	Extracting 516 sequences from picr_11
# 	Extracting 190 sequences from picr_7b
# 	Extracting 599 sequences from picr_12
# 	Extracting 584 sequences from picr_13
# 	Extracting 506 sequences from picr_14
# 	Extracting 609 sequences from picr_15
# 	Extracting 676 sequences from picr_16
# 	Extracting 285 sequences from picr_17
# 	Extracting 381 sequences from picr_18
# 	Extracting 465 sequences from picr_19
# 	Extracting 563 sequences from picr_20
# 	Extracting 375 sequences from picr_21
# 	Extracting 1124 sequences from picr_22
# 	Extracting 688 sequences from picr_23
# 	Extracting 709 sequences from picr_24
# 	Extracting 232 sequences from picr_25
# 	Extracting 269 sequences from picr_26
# 	Extracting 594 sequences from picr_27
# 	Extracting 323 sequences from picr_28
# 	Extracting 639 sequences from picr_29
# 	Extracting 230 sequences from picr_30
# 	Extracting 265 sequences from picr_31
# 	Extracting 176 sequences from picr_32
# 	Extracting 347 sequences from picr_33
# 	Extracting 315 sequences from picr_34
# 	Extracting 958 sequences from picr_35
# 	Extracting 411 sequences from picr_36
# 	Extracting 230 sequences from picr_37
# 	Extracting 466 sequences from picr_38
# 	Extracting 473 sequences from picr_39
# 	Extracting 536 sequences from picr_40
# 	Extracting 197 sequences from picr_41
# 	Extracting 189 sequences from picr_42
# 	Extracting 349 sequences from picr_43
# 	Extracting 305 sequences from picr_44
# 	Extracting 171 sequences from picr_45
# 	Extracting 178 sequences from picr_46
# 	Extracting 449 sequences from picr_47
# 	Extracting 301 sequences from picr_48
# 	Extracting 201 sequences from picr_49
# 	Extracting 412 sequences from picr_50
# 	Extracting 197 sequences from picr_51
# 	Extracting 625 sequences from picr_52
# 	Extracting 564 sequences from picr_53
# 	Extracting 486 sequences from picr_54
# 	Extracting 221 sequences from picr_55
# 	Extracting 410 sequences from picr_56
# 	Extracting 347 sequences from picr_57
# 	Extracting 556 sequences from picr_58
# 	Extracting 560 sequences from picr_59
# 	Extracting 92 sequences from picr_60
# 	Extracting 548 sequences from picr_61
# 	Extracting 405 sequences from picr_62
# 	Extracting 217 sequences from picr_63
# 	Extracting 125 sequences from picr_64
# 	Extracting 219 sequences from picr_65
# 	Extracting 259 sequences from picr_66
# 	Extracting 112 sequences from picr_67
# 	Extracting 114 sequences from picr_68
# 	Extracting 165 sequences from picr_69
# 	Extracting 521 sequences from picr_70
# 	Extracting 306 sequences from picr_71
# 	Extracting 131 sequences from picr_72
# 	Extracting 221 sequences from picr_73
# 	Extracting 588 sequences from picr_74
# 	Extracting 280 sequences from picr_75
# 	Extracting 134 sequences from picr_76
# 	Extracting 93 sequences from picr_77
# 	Extracting 347 sequences from picr_7a
# 	Extracting 117 sequences from picr_78
# 	Extracting 225 sequences from picr_79
# 	Extracting 64 sequences from picr_80
# 	Extracting 67 sequences from picr_81
# 	Extracting 126 sequences from picr_82
# 	Extracting 243 sequences from picr_83
# 	Extracting 302 sequences from picr_84
# 	Extracting 434 sequences from picr_85
# 	Extracting 100 sequences from picr_86
# 	Extracting 276 sequences from picr_87
# 	Extracting 192 sequences from picr_88
# 	Extracting 340 sequences from picr_89
# 	Extracting 94 sequences from picr_90
# 	Extracting 117 sequences from picr_91
# 	Extracting 72 sequences from picr_92
# 	Extracting 506 sequences from picr_93
# 	Extracting 136 sequences from picr_94
# 	Extracting 117 sequences from picr_95
# 	Extracting 151 sequences from picr_96
# 	Extracting 50 sequences from picr_97
# 	Extracting 241 sequences from picr_98
# 	Extracting 27 sequences from picr_99
# 	Extracting 228 sequences from picr_100
# 	Extracting 148 sequences from picr_101
# 	Extracting 116 sequences from picr_102
# 	Extracting 391 sequences from picr_103
# 	Extracting 43 sequences from picr_104
# 	Extracting 149 sequences from picr_105
# 	Extracting 267 sequences from picr_106
# 	Extracting 40 sequences from picr_107
# 	Extracting 236 sequences from picr_108
# 	Extracting 101 sequences from picr_109
# 	Extracting 80 sequences from picr_110
# 	Extracting 136 sequences from picr_111
# 	Extracting 55 sequences from picr_112
# 	Extracting 121 sequences from picr_113
# 	Extracting 41 sequences from picr_114
# 	Extracting 125 sequences from picr_115
# 	Extracting 80 sequences from picr_116
# 	Extracting 238 sequences from picr_117
# 	Extracting 76 sequences from picr_118
# 	Extracting 402 sequences from picr_119
# 	Extracting 287 sequences from picr_120
# 	Extracting 76 sequences from picr_121
# 	Extracting 129 sequences from picr_122
# 	Extracting 116 sequences from picr_123
# 	Extracting 111 sequences from picr_124
# 	Extracting 77 sequences from picr_125
# 	Extracting 64 sequences from picr_126
# 	Extracting 220 sequences from picr_127
# 	Extracting 59 sequences from picr_128
# 	Extracting 28 sequences from picr_129
# 	Extracting 417 sequences from picr_130
# 	Extracting 79 sequences from picr_131
# 	Extracting 406 sequences from picr_132
# 	Extracting 255 sequences from picr_133
# 	Extracting 58 sequences from picr_134
# 	Extracting 80 sequences from picr_135
# 	Extracting 180 sequences from picr_136
# 	Extracting 99 sequences from picr_137
# 	Extracting 201 sequences from picr_138
# 	Extracting 228 sequences from picr_139
# 	Extracting 57 sequences from picr_140
# 	Extracting 42 sequences from picr_141
# 	Extracting 35 sequences from picr_142
# 	Extracting 30 sequences from picr_143
# 	Extracting 45 sequences from picr_144
# 	Extracting 29 sequences from picr_145
# 	Extracting 66 sequences from picr_146
# 	Extracting 7 sequences from picr_147
# 	Extracting 128 sequences from picr_148
# 	Extracting 72 sequences from picr_149
# 	Extracting 3 sequences from picr_150
# 	Extracting 44 sequences from picr_151
# 	Extracting 67 sequences from picr_152
# 	Extracting 79 sequences from picr_153
# 	Extracting 185 sequences from picr_154
# 	Extracting 65 sequences from picr_155
# 	Extracting 1 sequences from picr_156
# 	Extracting 159 sequences from picr_157
# 	Extracting 187 sequences from picr_158
# 	Extracting 29 sequences from picr_159
# 	Extracting 15 sequences from picr_160
# 	Extracting 122 sequences from picr_161
# 	Extracting 52 sequences from picr_162
# 	Extracting 55 sequences from picr_163
# 	Extracting 21 sequences from picr_164
# 	Extracting 130 sequences from picr_166
# 	Extracting 148 sequences from picr_167
# 	Extracting 27 sequences from picr_168
# 	Extracting 65 sequences from picr_169
# 	Extracting 17 sequences from picr_170
# 	Extracting 31 sequences from picr_171
# 	Extracting 19 sequences from picr_172
# 	Extracting 49 sequences from picr_173
# 	Extracting 63 sequences from picr_174
# 	Extracting 3 sequences from picr_175
# 	Extracting 2 sequences from picr_176
# 	Extracting 1 sequences from picr_177
# 	Extracting 66 sequences from picr_178
# 	Extracting 2 sequences from picr_179
# 	Extracting 7 sequences from picr_180
# 	Extracting 3 sequences from picr_181
# 	Extracting 11 sequences from picr_182
# 	Extracting 48 sequences from picr_183
# 	Extracting 5 sequences from picr_184
# 	Extracting 61 sequences from picr_185
# 	Extracting 60 sequences from picr_186
# 	Extracting 38 sequences from picr_187
# 	Extracting 26 sequences from picr_188
# 	Extracting 1 sequences from picr_190
# 	Extracting 63 sequences from picr_191
# 	Extracting 50 sequences from picr_192
# 	Extracting 19 sequences from picr_193
# 	Extracting 57 sequences from picr_195
# 	Extracting 1 sequences from picr_197
# 	Extracting 7 sequences from picr_198
# 	Extracting 29 sequences from picr_199
# 	Extracting 32 sequences from picr_200
# 	Extracting 4 sequences from picr_201
# 	Extracting 2 sequences from picr_203
# 	Extracting 3 sequences from picr_204
# 	Extracting 5 sequences from picr_205
# 	Extracting 2 sequences from picr_207
# 	Extracting 1 sequences from picr_208
# 	Extracting 41 sequences from picr_209
# 	Extracting 2 sequences from picr_210
# 	Extracting 6 sequences from picr_211
# 	Extracting 5 sequences from picr_213
# 	Extracting 1 sequences from picr_216
# 	Extracting 3 sequences from picr_220
# 	Extracting 1 sequences from picr_221
# 	Extracting 6 sequences from picr_222
# 	Extracting 1 sequences from picr_223
# 	Extracting 2 sequences from picr_226
# 	Extracting 1 sequences from picr_227
# 	Extracting 1 sequences from picr_229
# 	Extracting 8 sequences from picr_231
# 	Extracting 18 sequences from picr_232
# 	Extracting 2 sequences from picr_233
# 	Extracting 2 sequences from picr_234
# 	Extracting 20 sequences from picr_235
# 	Extracting 3 sequences from picr_237
# 	Extracting 4 sequences from picr_241
# 	Extracting 2 sequences from picr_242
# 	Extracting 20 sequences from picr_244
# 	Extracting 15 sequences from picr_245
# 	Extracting 5 sequences from picr_248
# 	Extracting 2 sequences from picr_249
# 	Extracting 5 sequences from picr_250
# 	Extracting 3 sequences from picr_251
# 	Extracting 17 sequences from picr_253
# 	Extracting 1 sequences from picr_255
# 	Extracting 2 sequences from picr_256
# 	Extracting 1 sequences from picr_260
# 	Extracting 2 sequences from picr_261
# 	Extracting 6 sequences from picr_263
# 	Extracting 2 sequences from picr_264
# 	Extracting 6 sequences from picr_265
# 	Extracting 10 sequences from picr_268
# 	Extracting 4 sequences from picr_269
# 	Extracting 3 sequences from picr_271
# 	Extracting 3 sequences from picr_272
# 	Extracting 5 sequences from picr_274
# 	Extracting 2 sequences from picr_275
# 	Extracting 4 sequences from picr_276
# 	Extracting 5 sequences from picr_279
# 	Extracting 1 sequences from picr_284
# 	Extracting 1 sequences from picr_285
# 	Extracting 4 sequences from picr_289
# 	Extracting 3 sequences from picr_294
# 	Extracting 1 sequences from picr_295
# 	Extracting 6 sequences from picr_296
# 	Extracting 5 sequences from picr_298
# 	Extracting 5 sequences from picr_303
# 	Extracting 1 sequences from picr_308
# 	Extracting 5 sequences from picr_309
# 	Extracting 1 sequences from picr_310
# 	Extracting 2 sequences from picr_311
# 	Extracting 15 sequences from picr_312
# 	Extracting 1 sequences from picr_314
# 	Extracting 7 sequences from picr_316
# 	Extracting 13 sequences from picr_317
# 	Extracting 3 sequences from picr_318
# 	Extracting 1 sequences from picr_319
# 	Extracting 4 sequences from picr_321
# 	Extracting 6 sequences from picr_323
# 	Extracting 3 sequences from picr_325
# 	Extracting 11 sequences from picr_328
# 	Extracting 3 sequences from picr_329
# 	Extracting 3 sequences from picr_330
# 	Extracting 7 sequences from picr_331
# 	Extracting 6 sequences from picr_332
# 	Extracting 1 sequences from picr_333
# 	Extracting 7 sequences from picr_334
# 	Extracting 1 sequences from picr_336
# 	Extracting 1 sequences from picr_338
# 	Extracting 28 sequences from picr_341
# 	Extracting 2 sequences from picr_342
# 	Extracting 4 sequences from picr_345
# 	Extracting 1 sequences from picr_347
# 	Extracting 4 sequences from picr_348
# 	Extracting 4 sequences from picr_349
# 	Extracting 2 sequences from picr_351
# 	Extracting 6 sequences from picr_353
# 	Extracting 6 sequences from picr_355
# 	Extracting 10 sequences from picr_356
# 	Extracting 6 sequences from picr_358
# 	Extracting 5 sequences from picr_360
# 	Extracting 3 sequences from picr_361
# 	Extracting 5 sequences from picr_362
# 	Extracting 3 sequences from picr_363
# 	Extracting 1 sequences from picr_364
# 	Extracting 2 sequences from picr_365
# 	Extracting 7 sequences from picr_367
# 	Extracting 1 sequences from picr_370
# 	Extracting 1 sequences from picr_372
# 	Extracting 1 sequences from picr_374
# 	Extracting 4 sequences from picr_375
# 	Extracting 10 sequences from picr_378
# 	Extracting 6 sequences from picr_380
# 	Extracting 1 sequences from picr_383
# 	Extracting 5 sequences from picr_386
# 	Extracting 4 sequences from picr_389
# 	Extracting 2 sequences from picr_390
# 	Extracting 8 sequences from picr_391
# 	Extracting 6 sequences from picr_393
# 	Extracting 1 sequences from picr_395
# 	Extracting 1 sequences from picr_397
# 	Extracting 4 sequences from picr_400
# 	Extracting 2 sequences from picr_404
# 	Extracting 5 sequences from picr_410
# 	Extracting 3 sequences from picr_412
# 	Extracting 8 sequences from picr_413
# 	Extracting 5 sequences from picr_415
# 	Extracting 2 sequences from picr_416
# 	Extracting 1 sequences from picr_417
# 	Extracting 1 sequences from picr_425
# 	Extracting 1 sequences from picr_426
# 	Extracting 3 sequences from picr_432
# 	Extracting 9 sequences from picr_433
# 	Extracting 2 sequences from picr_434
# 	Extracting 5 sequences from picr_435
# 	Extracting 1 sequences from picr_437
# 	Extracting 6 sequences from picr_438
# 	Extracting 1 sequences from picr_440
# 	Extracting 1 sequences from picr_442
# 	Extracting 2 sequences from picr_446
# 	Extracting 1 sequences from picr_450
# 	Extracting 1 sequences from picr_452
# 	Extracting 2 sequences from picr_454
# 	Extracting 1 sequences from picr_455
# 	Extracting 4 sequences from picr_456
# 	Extracting 2 sequences from picr_457
# 	Extracting 5 sequences from picr_458
# 	Extracting 1 sequences from picr_462
# 	Extracting 10 sequences from picr_463
# 	Extracting 2 sequences from picr_472
# 	Extracting 8 sequences from picr_474
# 	Extracting 1 sequences from picr_476
# 	Extracting 3 sequences from picr_477
# 	Extracting 2 sequences from picr_478
# 	Extracting 1 sequences from picr_479
# 	Extracting 3 sequences from picr_480
# 	Extracting 1 sequences from picr_481
# 	Extracting 2 sequences from picr_485
# 	Extracting 1 sequences from picr_487
# 	Extracting 2 sequences from picr_488
# 	Extracting 2 sequences from picr_489
# 	Extracting 1 sequences from picr_491
# 	Extracting 6 sequences from picr_492
# 	Extracting 1 sequences from picr_493
# 	Extracting 1 sequences from picr_494
# 	Extracting 1 sequences from picr_495
# 	Extracting 7 sequences from picr_498
# 	Extracting 2 sequences from picr_500
# 	Extracting 1 sequences from picr_502
# 	Extracting 1 sequences from picr_504
# 	Extracting 2 sequences from picr_506
# 	Extracting 1 sequences from picr_507
# 	Extracting 3 sequences from picr_509
# 	Extracting 4 sequences from picr_512
# 	Extracting 4 sequences from picr_517
# 	Extracting 1 sequences from picr_524
# 	Extracting 3 sequences from picr_527
# 	Extracting 2 sequences from picr_529
# 	Extracting 1 sequences from picr_531
# 	Extracting 3 sequences from picr_533
# 	Extracting 1 sequences from picr_534
# 	Extracting 1 sequences from picr_538
# 	Extracting 1 sequences from picr_539
# 	Extracting 1 sequences from picr_540
# 	Extracting 1 sequences from picr_542
# 	Extracting 2 sequences from picr_546
# 	Extracting 1 sequences from picr_550
# 	Extracting 1 sequences from picr_556
# 	Extracting 1 sequences from picr_557
# 	Extracting 3 sequences from picr_559
# 	Extracting 4 sequences from picr_561
# 	Extracting 1 sequences from picr_566
# 	Extracting 1 sequences from picr_568
# 	Extracting 4 sequences from picr_570
# 	Extracting 2 sequences from picr_571
# 	Extracting 3 sequences from picr_572
# 	Extracting 1 sequences from picr_576
# 	Extracting 15 sequences from picr_579
# 	Extracting 1 sequences from picr_580
# 	Extracting 1 sequences from picr_581
# 	Extracting 1 sequences from picr_583
# 	Extracting 11 sequences from picr_591
# 	Extracting 2 sequences from picr_595
# 	Extracting 2 sequences from picr_596
# 	Extracting 1 sequences from picr_599
# 	Extracting 1 sequences from picr_601
# 	Extracting 2 sequences from picr_603
# 	Extracting 1 sequences from picr_604
# 	Extracting 2 sequences from picr_606
# 	Extracting 2 sequences from picr_608
# 	Extracting 1 sequences from picr_618
# 	Extracting 2 sequences from picr_619
# 	Extracting 1 sequences from picr_620
# 	Extracting 2 sequences from picr_622
# 	Extracting 3 sequences from picr_624
# 	Extracting 1 sequences from picr_627
# 	Extracting 2 sequences from picr_638
# 	Extracting 1 sequences from picr_641
# 	Extracting 2 sequences from picr_642
# 	Extracting 16 sequences from picr_653
# 	Extracting 1 sequences from picr_654
# 	Extracting 1 sequences from picr_655
# 	Extracting 5 sequences from picr_656
# 	Extracting 8 sequences from picr_665
# 	Extracting 2 sequences from picr_668
# 	Extracting 4 sequences from picr_673
# 	Extracting 1 sequences from picr_674
# 	Extracting 2 sequences from picr_676
# 	Extracting 1 sequences from picr_680
# 	Extracting 3 sequences from picr_684
# 	Extracting 2 sequences from picr_685
# 	Extracting 1 sequences from picr_686
# 	Extracting 2 sequences from picr_688
# 	Extracting 2 sequences from picr_690
# 	Extracting 2 sequences from picr_692
# 	Extracting 1 sequences from picr_698
# 	Extracting 11 sequences from picr_709
# 	Extracting 1 sequences from picr_715
# 	Extracting 1 sequences from picr_716
# 	Extracting 1 sequences from picr_721
# 	Extracting 4 sequences from picr_729
# 	Extracting 8 sequences from picr_731
# 	Extracting 5 sequences from picr_738
# 	Extracting 1 sequences from picr_744
# 	Extracting 1 sequences from picr_746
# 	Extracting 2 sequences from picr_761
# 	Extracting 1 sequences from picr_764
# 	Extracting 3 sequences from picr_768
# 	Extracting 3 sequences from picr_769
# 	Extracting 1 sequences from picr_772
# 	Extracting 13 sequences from picr_776
# 	Extracting 2 sequences from picr_778
# 	Extracting 1 sequences from picr_780
# 	Extracting 7 sequences from picr_788
# 	Extracting 1 sequences from picr_793
# 	Extracting 3 sequences from picr_799
# 	Extracting 1 sequences from picr_806
# 	Extracting 2 sequences from picr_817
# 	Extracting 2 sequences from picr_820
# 	Extracting 2 sequences from picr_824
# 	Extracting 1 sequences from picr_833
# 	Extracting 5 sequences from picr_843
# 	Extracting 2 sequences from picr_845
# 	Extracting 1 sequences from picr_851
# 	Extracting 4 sequences from picr_853
# 	Extracting 4 sequences from picr_854
# 	Extracting 1 sequences from picr_857
# 	Extracting 1 sequences from picr_858
# 	Extracting 2 sequences from picr_859
# 	Extracting 1 sequences from picr_862
# 	Extracting 1 sequences from picr_864
# 	Extracting 1 sequences from picr_866
# 	Extracting 1 sequences from picr_872
# 	Extracting 3 sequences from picr_875
# 	Extracting 1 sequences from picr_884
# 	Extracting 3 sequences from picr_885
# 	Extracting 6 sequences from picr_886
# 	Extracting 1 sequences from picr_889
# 	Extracting 3 sequences from picr_896
# 	Extracting 1 sequences from picr_897
# 	Extracting 1 sequences from picr_902
# 	Extracting 3 sequences from picr_905
# 	Extracting 1 sequences from picr_911
# 	Extracting 1 sequences from picr_914
# 	Extracting 1 sequences from picr_922
# 	Extracting 1 sequences from picr_928
# 	Extracting 2 sequences from picr_932
# 	Extracting 4 sequences from picr_934
# 	Extracting 2 sequences from picr_936
# 	Extracting 1 sequences from picr_938
# 	Extracting 1 sequences from picr_943
# 	Extracting 1 sequences from picr_954
# 	Extracting 1 sequences from picr_955
# 	Extracting 1 sequences from picr_956
# 	Extracting 2 sequences from picr_964
# 	Extracting 1 sequences from picr_967
# 	Extracting 2 sequences from picr_978
# 	Extracting 3 sequences from picr_980
# 	Extracting 3 sequences from picr_985
# 	Extracting 1 sequences from picr_991
# 	Extracting 1 sequences from picr_996
# 	Extracting 2 sequences from picr_997
# 	Extracting 1 sequences from picr_1009
# 	Extracting 1 sequences from picr_1010
# 	Extracting 5 sequences from picr_1018
# 	Extracting 1 sequences from picr_1019
# 	Extracting 3 sequences from picr_1021
# 	Extracting 2 sequences from picr_1022
# 	Extracting 2 sequences from picr_1029
# 	Extracting 3 sequences from picr_1030
# 	Extracting 1 sequences from picr_1034
# 	Extracting 2 sequences from picr_1046
# 	Extracting 1 sequences from picr_1059
# 	Extracting 1 sequences from picr_1064
# 	Extracting 1 sequences from picr_1065
# 	Extracting 1 sequences from picr_1067
# 	Extracting 1 sequences from picr_1069
# 	Extracting 2 sequences from picr_1074
# 	Extracting 3 sequences from picr_1078
# 	Extracting 1 sequences from picr_1079
# 	Extracting 1 sequences from picr_1085
# 	Extracting 4 sequences from picr_1093
# 	Extracting 1 sequences from picr_1096
# 	Extracting 1 sequences from picr_1097
# 	Extracting 1 sequences from picr_1100
# 	Extracting 2 sequences from picr_1108
# 	Extracting 1 sequences from picr_1122
# 	Extracting 1 sequences from picr_1125
# 	Extracting 1 sequences from picr_1127
# 	Extracting 2 sequences from picr_1135
# 	Extracting 3 sequences from picr_1137
# 	Extracting 1 sequences from picr_1140
# 	Extracting 1 sequences from picr_1142
# 	Extracting 1 sequences from picr_1149
# 	Extracting 1 sequences from picr_1154
# 	Extracting 4 sequences from picr_1165
# 	Extracting 5 sequences from picr_1173
# 	Extracting 1 sequences from picr_1174
# 	Extracting 1 sequences from picr_1181
# 	Extracting 1 sequences from picr_1194
# 	Extracting 1 sequences from picr_1200
# 	Extracting 1 sequences from picr_1202
# 	Extracting 3 sequences from picr_1209
# 	Extracting 1 sequences from picr_1216
# 	Extracting 1 sequences from picr_1223
# 	Extracting 4 sequences from picr_1232
# 	Extracting 1 sequences from picr_1233
# 	Extracting 1 sequences from picr_1241
# 	Extracting 1 sequences from picr_1251
# 	Extracting 2 sequences from picr_1258
# 	Extracting 1 sequences from picr_1262
# 	Extracting 1 sequences from picr_1270
# 	Extracting 1 sequences from picr_1282
# 	Extracting 1 sequences from picr_1288
# 	Extracting 1 sequences from picr_1289
# 	Extracting 2 sequences from picr_1298
# 	Extracting 1 sequences from picr_1300
# 	Extracting 1 sequences from picr_1302
# 	Extracting 1 sequences from picr_1303
# 	Extracting 2 sequences from picr_1312
# 	Extracting 1 sequences from picr_1314
# 	Extracting 1 sequences from picr_1322
# 	Extracting 1 sequences from picr_1333
# 	Extracting 1 sequences from picr_1338
# 	Extracting 1 sequences from picr_1340
# 	Extracting 1 sequences from picr_1356
# 	Extracting 1 sequences from picr_1366
# 	Extracting 1 sequences from picr_1371
# 	Extracting 1 sequences from picr_1374
# 	Extracting 1 sequences from picr_1386
# 	Extracting 2 sequences from picr_1389
# 	Extracting 1 sequences from picr_1392
# 	Extracting 1 sequences from picr_1401
# 	Extracting 3 sequences from picr_1410
# 	Extracting 1 sequences from picr_1412
# 	Extracting 1 sequences from picr_1416
# 	Extracting 1 sequences from picr_1417
# 	Extracting 1 sequences from picr_1420
# 	Extracting 2 sequences from picr_1425
# 	Extracting 1 sequences from picr_1434
# 	Extracting 2 sequences from picr_1455
# 	Extracting 1 sequences from picr_1456
# 	Extracting 1 sequences from picr_1458
# 	Extracting 1 sequences from picr_1471
# 	Extracting 2 sequences from picr_1490
# 	Extracting 3 sequences from picr_1497
# 	Extracting 2 sequences from picr_1501
# 	Extracting 1 sequences from picr_1503
# 	Extracting 1 sequences from picr_1530
# 	Extracting 1 sequences from picr_1532
# 	Extracting 1 sequences from picr_1557
# 	Extracting 1 sequences from picr_1573
# 	Extracting 2 sequences from picr_1583
# 	Extracting 1 sequences from picr_1590
# 	Extracting 1 sequences from picr_1598
# 	Extracting 2 sequences from picr_1608
# 	Extracting 2 sequences from picr_1628
# 	Extracting 1 sequences from picr_1631
# 	Extracting 1 sequences from picr_1637
# 	Extracting 1 sequences from picr_1645
# 	Extracting 1 sequences from picr_1647
# 	Extracting 5 sequences from picr_1669
# 	Extracting 3 sequences from picr_1677
# 	Extracting 1 sequences from picr_1678
# 	Extracting 1 sequences from picr_1700
# 	Extracting 1 sequences from picr_1725
# 	Extracting 3 sequences from picr_1757
# 	Extracting 1 sequences from picr_1759
# 	Extracting 1 sequences from picr_1763
# 	Extracting 1 sequences from picr_1767
# 	Extracting 1 sequences from picr_1789
# 	Extracting 2 sequences from picr_1794
# 	Extracting 1 sequences from picr_1795

# %% [markdown]
# ### get the center, do +/- 2kb for all, save to proper bed file

# %% [markdown]
# ## Loop through each peak and
# NOTE: Note which strand you are working with
# 1) Add sequence -2k:+2k
# 2) Determine if there is a nearby transcript id within 2k bp upstream and if it is part of the same gene_id or different. If it is the same, write where the end of it is.
# 3) Determine where the coding region of this associated gene is.
# 4) Determine if any genes downstream within 2kb (Does not matter which strand its in)
#
# Next, loop through each non-experimental transcript, pick the first isoform and extract their sequence and do the same as before .
#
# INPUT:
# 1) Annotation file: List of each mRNA, exon, and coding region
# 2) txn peak file
# 3) picr.fa genome for extracting sequences
# 4) txn_df to get transcripts that do not have a peak (May not be as necessary)

# %% [markdown]
# ## Create output dataframe tss_full

# %%
tss_full = merged[['gene_id','gene']] #merged[['transcript_id','gene_id','gene']]
#tss_full = tss_full.set_index('transcript_id')

## Add columns
tss_full['Gene Upstream Position'] = np.nan
tss_full['Coding Region Start'] = np.nan
tss_full['Gene Downstream Position'] = np.nan
tss_full['Experimental'] = 0
tss_full['ATAC'] = np.nan
# Out:
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
tss_full.head()
# Out:
#                 gene_id   gene  Gene Upstream Position  Coding Region Start  \
# transcript_id
# asmbl_2        gene_1_2  SERHL                     NaN                  NaN
# asmbl_4          gene_2  RRP7A                     NaN                  NaN
# asmbl_7          gene_2  RRP7A                     NaN                  NaN
# asmbl_8          gene_2  RRP7A                     NaN                  NaN
# asmbl_9          gene_2  RRP7A                     NaN                  NaN
#
#                Gene Downstream Position  Experimental  ATAC
# transcript_id
# asmbl_2                             NaN             0   NaN
# asmbl_4                             NaN             0   NaN
# asmbl_7                             NaN             0   NaN
# asmbl_8                             NaN             0   NaN
# asmbl_9                             NaN             0   NaN

# %%
import tqdm

# %%
# %%time
## Loop through each transcript
bin_val = 2000
for ind,val in tqdm.tqdm_notebook(merged.iterrows()):
    # First determine if experimental:
    if ~(np.isnan(merged.loc[ind,'actual_start_x'])):
        tss_full.set_value(ind,'Experimental',1)
    
    ## For each, get all transcripts of the same Chromosome
    filt = foo[foo['Chr'] == val['Chr']]

    ## Keep transcripts that are within bin_val away from the current transcript
    filt = filt[np.abs(val['actual_start'] - filt['actual_start']) < bin_val]
    
    ## Keep transcripts from a different gene_id, so no isoforms
    filt = filt[~(filt['gene_id'] == val['gene_id'])]
    
    
    if not len(filt) == 0:
#         print(val['gene'])
#         print(val['gene_id'])
#         print(filt)
        
        ## Determine nearest upstream genes distance and nearest downstream genes distance
        
        ## Multiplier is to reverse the up- and downstream genes when the transcript is on the negative strand
        if val['Strand'] == '+':
            multiplier = 1
        elif val['Strand'] == '-':
            multiplier = -1
        else:
            print('Strand info is wrong',ind)
            continue
        # For upstream, the upstream genes will have smaller start, so the value will be negative relative to the center
        up = filt[multiplier*(filt['actual_start'] - val['actual_start']) < 0]
        upstream = np.max(multiplier*(up['actual_start'] - val['actual_start']))
        # For downstream, the distance will be positive
        down = filt[multiplier*(filt['actual_start'] - val['actual_start']) > 0]
        downstream = np.min(multiplier*(down['actual_start'] - val['actual_start']))
        
        #Set values in the matrix
        tss_full.set_value(ind,'Gene Upstream Position',upstream) 
        tss_full.set_value(ind,'Gene Downstream Position',downstream)

    
    ## Get nearest CDS 
    cds_filt = cds[cds['transcript_id'] == ind]
    
    ##Assuming that cds will always be downstream of start site (by definition)
    if not len(cds_filt) == 0:
        tss_full.set_value(ind,'Coding Region Start',np.min(np.abs(val['actual_start'] - cds_filt['actual_start'])))
# Out:
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:50: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/isshamie/software/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:42: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %% [markdown]
# ### Save output

# %%
tss_full.to_csv('Results/tss_final/s_final/tss_peakCenter_1kb_1kb_ALLGENES_FLANK_2kb.META.tsv',sep='tsv')

# %%
tss_full.to_csv('Results/tss_final/tss_peakCenter_1kb_1kb_ALLGENES_FLANK_2kb.META.tsv',sep='tsv')

# %% [markdown]
# ## Plot

# %%
sns.distplot(tss_full['Gene Upstream Position'].dropna())

# %%
sns.distplot(tss_full['Gene Downstream Position'].dropna())

# %% [markdown]
# -------------------

# %% [markdown]
# -------------------

# %% [markdown]
# -------------------

# %% [markdown]
# -------------------

# %% [markdown]
# # Ignore below this.
# Misc. Scrap

# %% [markdown]
# ### First make flanking -2kb to +2kb for each peak and save

# %%
tss_experiment = 'Results/tss_final/tss_peakCenter_1kb_1kb.bed'
tss_flank_out = 'Results/tss_final/tss_peakCenter_1kb_1kb_FLANK_2kb.bed'

out_fa = 'Results/tss_final/tss_peakCenter_1kb_1kb_FLANK_2kb.fa'

# %%
def extend_bed_file(bed_f, out_f, bins=[-2000,2000]):
    df = pd.read_csv(bed_f,sep='\t',header=None)
    center = df.apply(lambda x: int(np.floor(((x[1]+x[2])-1)/2)) 
                    if x[5] == '+' else int(np.ceil(((x[1]+x[2])-1)/2)),axis=1)
    df[1] = center + bins[0]
    df[2] = center + bins[1] + 1
    df.to_csv(out_f,sep='\t',header= None,index=False)
    return

# %%
# %%time
extend_bed_file(tss_experiment,tss_flank_out,bins=[-2000,2000])
# Out:
# CPU times: user 3.14 s, sys: 40 ms, total: 3.18 s
# Wall time: 3.19 s

# %%
cmd = 'homerTools extract {bed_f} {ref_fa} -fa > {out}'.format(bed_f=tss_flank_out,ref_fa=ref_fa,out=out_fa)
# !{cmd}
# Out:
# 	Extracting sequences from file: /data/isshamie/genome/picr.fa
# 	Looking for peak sequences in a single file (/data/isshamie/genome/picr.fa)
# 	Extracting 916 sequences from picr_0
# 	Extracting 540 sequences from picr_1
# 	Extracting 744 sequences from picr_2
# 	Extracting 532 sequences from picr_3
# 	Extracting 478 sequences from picr_4
# 	Extracting 362 sequences from picr_5
# 	Extracting 346 sequences from picr_6
# 	Extracting 764 sequences from picr_8
# 	Extracting 306 sequences from picr_9
# 	Extracting 359 sequences from picr_10
# 	Extracting 249 sequences from picr_11
# 	Extracting 82 sequences from picr_7b
# 	Extracting 275 sequences from picr_12
# 	Extracting 285 sequences from picr_13
# 	Extracting 212 sequences from picr_14
# 	Extracting 285 sequences from picr_15
# 	Extracting 295 sequences from picr_16
# 	Extracting 145 sequences from picr_17
# 	Extracting 174 sequences from picr_18
# 	Extracting 229 sequences from picr_19
# 	Extracting 258 sequences from picr_20
# 	Extracting 174 sequences from picr_21
# 	Extracting 513 sequences from picr_22
# 	Extracting 343 sequences from picr_23
# 	Extracting 322 sequences from picr_24
# 	Extracting 80 sequences from picr_25
# 	Extracting 97 sequences from picr_26
# 	Extracting 251 sequences from picr_27
# 	Extracting 153 sequences from picr_28
# 	Extracting 249 sequences from picr_29
# 	Extracting 96 sequences from picr_30
# 	Extracting 121 sequences from picr_31
# 	Extracting 68 sequences from picr_32
# 	Extracting 161 sequences from picr_33
# 	Extracting 138 sequences from picr_34
# 	Extracting 464 sequences from picr_35
# 	Extracting 187 sequences from picr_36
# 	Extracting 99 sequences from picr_37
# 	Extracting 216 sequences from picr_38
# 	Extracting 225 sequences from picr_39
# 	Extracting 233 sequences from picr_40
# 	Extracting 112 sequences from picr_41
# 	Extracting 82 sequences from picr_42
# 	Extracting 163 sequences from picr_43
# 	Extracting 149 sequences from picr_44
# 	Extracting 96 sequences from picr_45
# 	Extracting 94 sequences from picr_46
# 	Extracting 189 sequences from picr_47
# 	Extracting 129 sequences from picr_48
# 	Extracting 90 sequences from picr_49
# 	Extracting 199 sequences from picr_50
# 	Extracting 101 sequences from picr_51
# 	Extracting 307 sequences from picr_52
# 	Extracting 250 sequences from picr_53
# 	Extracting 215 sequences from picr_54
# 	Extracting 105 sequences from picr_55
# 	Extracting 177 sequences from picr_56
# 	Extracting 160 sequences from picr_57
# 	Extracting 254 sequences from picr_58
# 	Extracting 239 sequences from picr_59
# 	Extracting 36 sequences from picr_60
# 	Extracting 263 sequences from picr_61
# 	Extracting 180 sequences from picr_62
# 	Extracting 92 sequences from picr_63
# 	Extracting 70 sequences from picr_64
# 	Extracting 109 sequences from picr_65
# 	Extracting 108 sequences from picr_66
# 	Extracting 48 sequences from picr_67
# 	Extracting 44 sequences from picr_68
# 	Extracting 64 sequences from picr_69
# 	Extracting 222 sequences from picr_70
# 	Extracting 131 sequences from picr_71
# 	Extracting 56 sequences from picr_72
# 	Extracting 107 sequences from picr_73
# 	Extracting 290 sequences from picr_74
# 	Extracting 121 sequences from picr_75
# 	Extracting 49 sequences from picr_76
# 	Extracting 43 sequences from picr_77
# 	Extracting 165 sequences from picr_7a
# 	Extracting 67 sequences from picr_78
# 	Extracting 95 sequences from picr_79
# 	Extracting 32 sequences from picr_80
# 	Extracting 29 sequences from picr_81
# 	Extracting 55 sequences from picr_82
# 	Extracting 119 sequences from picr_83
# 	Extracting 150 sequences from picr_84
# 	Extracting 188 sequences from picr_85
# 	Extracting 37 sequences from picr_86
# 	Extracting 122 sequences from picr_87
# 	Extracting 82 sequences from picr_88
# 	Extracting 146 sequences from picr_89
# 	Extracting 43 sequences from picr_90
# 	Extracting 49 sequences from picr_91
# 	Extracting 34 sequences from picr_92
# 	Extracting 223 sequences from picr_93
# 	Extracting 64 sequences from picr_94
# 	Extracting 48 sequences from picr_95
# 	Extracting 80 sequences from picr_96
# 	Extracting 19 sequences from picr_97
# 	Extracting 133 sequences from picr_98
# 	Extracting 12 sequences from picr_99
# 	Extracting 83 sequences from picr_100
# 	Extracting 73 sequences from picr_101
# 	Extracting 44 sequences from picr_102
# 	Extracting 172 sequences from picr_103
# 	Extracting 21 sequences from picr_104
# 	Extracting 80 sequences from picr_105
# 	Extracting 131 sequences from picr_106
# 	Extracting 20 sequences from picr_107
# 	Extracting 94 sequences from picr_108
# 	Extracting 48 sequences from picr_109
# 	Extracting 34 sequences from picr_110
# 	Extracting 64 sequences from picr_111
# 	Extracting 31 sequences from picr_112
# 	Extracting 52 sequences from picr_113
# 	Extracting 20 sequences from picr_114
# 	Extracting 58 sequences from picr_115
# 	Extracting 33 sequences from picr_116
# 	Extracting 111 sequences from picr_117
# 	Extracting 44 sequences from picr_118
# 	Extracting 161 sequences from picr_119
# 	Extracting 151 sequences from picr_120
# 	Extracting 32 sequences from picr_121
# 	Extracting 60 sequences from picr_122
# 	Extracting 46 sequences from picr_123
# 	Extracting 46 sequences from picr_124
# 	Extracting 31 sequences from picr_125
# 	Extracting 27 sequences from picr_126
# 	Extracting 96 sequences from picr_127
# 	Extracting 25 sequences from picr_128
# 	Extracting 9 sequences from picr_129
# 	Extracting 159 sequences from picr_130
# 	Extracting 37 sequences from picr_131
# 	Extracting 168 sequences from picr_132
# 	Extracting 92 sequences from picr_133
# 	Extracting 18 sequences from picr_134
# 	Extracting 38 sequences from picr_135
# 	Extracting 83 sequences from picr_136
# 	Extracting 40 sequences from picr_137
# 	Extracting 84 sequences from picr_138
# 	Extracting 99 sequences from picr_139
# 	Extracting 25 sequences from picr_140
# 	Extracting 20 sequences from picr_141
# 	Extracting 14 sequences from picr_142
# 	Extracting 14 sequences from picr_143
# 	Extracting 22 sequences from picr_144
# 	Extracting 17 sequences from picr_145
# 	Extracting 22 sequences from picr_146
# 	Extracting 32 sequences from picr_148
# 	Extracting 22 sequences from picr_149
# 	Extracting 19 sequences from picr_151
# 	Extracting 28 sequences from picr_152
# 	Extracting 33 sequences from picr_153
# 	Extracting 94 sequences from picr_154
# 	Extracting 31 sequences from picr_155
# 	Extracting 77 sequences from picr_157
# 	Extracting 90 sequences from picr_158
# 	Extracting 15 sequences from picr_159
# 	Extracting 6 sequences from picr_160
# 	Extracting 55 sequences from picr_161
# 	Extracting 22 sequences from picr_162
# 	Extracting 26 sequences from picr_163
# 	Extracting 9 sequences from picr_164
# 	Extracting 49 sequences from picr_166
# 	Extracting 55 sequences from picr_167
# 	Extracting 11 sequences from picr_168
# 	Extracting 19 sequences from picr_169
# 	Extracting 6 sequences from picr_170
# 	Extracting 15 sequences from picr_171
# 	Extracting 12 sequences from picr_172
# 	Extracting 26 sequences from picr_173
# 	Extracting 30 sequences from picr_174
# 	Extracting 2 sequences from picr_176
# 	Extracting 15 sequences from picr_178
# 	Extracting 2 sequences from picr_182
# 	Extracting 21 sequences from picr_183
# 	Extracting 23 sequences from picr_185
# 	Extracting 25 sequences from picr_186
# 	Extracting 13 sequences from picr_187
# 	Extracting 13 sequences from picr_188
# 	Extracting 20 sequences from picr_191
# 	Extracting 19 sequences from picr_192
# 	Extracting 8 sequences from picr_193
# 	Extracting 27 sequences from picr_195
# 	Extracting 3 sequences from picr_198
# 	Extracting 8 sequences from picr_199
# 	Extracting 18 sequences from picr_200
# 	Extracting 1 sequences from picr_201
# 	Extracting 13 sequences from picr_209
# 	Extracting 2 sequences from picr_211
# 	Extracting 1 sequences from picr_222
# 	Extracting 4 sequences from picr_231
# 	Extracting 3 sequences from picr_232
# 	Extracting 1 sequences from picr_234
# 	Extracting 8 sequences from picr_235
# 	Extracting 2 sequences from picr_244
# 	Extracting 2 sequences from picr_245
# 	Extracting 1 sequences from picr_248
# 	Extracting 2 sequences from picr_250
# 	Extracting 6 sequences from picr_253
# 	Extracting 1 sequences from picr_263
# 	Extracting 3 sequences from picr_265
# 	Extracting 1 sequences from picr_268
# 	Extracting 2 sequences from picr_269
# 	Extracting 1 sequences from picr_274
# 	Extracting 3 sequences from picr_276
# 	Extracting 1 sequences from picr_289
# 	Extracting 2 sequences from picr_296
# 	Extracting 2 sequences from picr_298
# 	Extracting 1 sequences from picr_310
# 	Extracting 8 sequences from picr_312
# 	Extracting 2 sequences from picr_316
# 	Extracting 1 sequences from picr_317
# 	Extracting 3 sequences from picr_323
# 	Extracting 2 sequences from picr_328
# 	Extracting 1 sequences from picr_329
# 	Extracting 1 sequences from picr_331
# 	Extracting 1 sequences from picr_332
# 	Extracting 1 sequences from picr_342
# 	Extracting 1 sequences from picr_348
# 	Extracting 1 sequences from picr_355
# 	Extracting 1 sequences from picr_358
# 	Extracting 1 sequences from picr_374
# 	Extracting 6 sequences from picr_378
# 	Extracting 2 sequences from picr_380
# 	Extracting 2 sequences from picr_400
# 	Extracting 1 sequences from picr_415
# 	Extracting 1 sequences from picr_432
# 	Extracting 1 sequences from picr_433
# 	Extracting 1 sequences from picr_434
# 	Extracting 2 sequences from picr_435
# 	Extracting 1 sequences from picr_456
# 	Extracting 2 sequences from picr_477
# 	Extracting 1 sequences from picr_478
# 	Extracting 1 sequences from picr_493
# 	Extracting 3 sequences from picr_512
# 	Extracting 1 sequences from picr_517
# 	Extracting 1 sequences from picr_534
# 	Extracting 1 sequences from picr_566
# 	Extracting 7 sequences from picr_591
# 	Extracting 1 sequences from picr_603
# 	Extracting 1 sequences from picr_606
# 	Extracting 1 sequences from picr_653
# 	Extracting 1 sequences from picr_654
# 	Extracting 3 sequences from picr_709
# 	Extracting 1 sequences from picr_721
# 	Extracting 1 sequences from picr_738
# 	Extracting 2 sequences from picr_776
# 	Extracting 1 sequences from picr_778
# 	Extracting 1 sequences from picr_817
# 	Extracting 1 sequences from picr_824
# 	Extracting 1 sequences from picr_843
# 	Extracting 1 sequences from picr_853
# 	Extracting 1 sequences from picr_911
# 	Extracting 1 sequences from picr_954
# 	Extracting 1 sequences from picr_964
# 	Extracting 1 sequences from picr_1034
# 	Extracting 1 sequences from picr_1059
# 	Extracting 1 sequences from picr_1097
# 	Extracting 2 sequences from picr_1137
# 	Extracting 2 sequences from picr_1165
# 	Extracting 1 sequences from picr_1410
# 	Extracting 1 sequences from picr_1503
# 	Extracting 1 sequences from picr_1628
# 	Extracting 1 sequences from picr_1669
# 	Extracting 2 sequences from picr_1757
