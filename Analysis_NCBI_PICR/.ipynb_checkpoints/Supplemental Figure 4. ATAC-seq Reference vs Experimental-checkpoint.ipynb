# %%
tissues_with_atac = ['CHO','Brain','Liver','Lung','Kidney','Spleen','BMDMwt','BMDM1hKLA']

# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])
ref_fa = doc['ref_fa']
annotation=doc['annotation']
mRNA_peak_file = doc["mRNA_peak_file"]

# %%
tss_annotation = doc['tss_annotation']

# %%
import os
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm
### notebook specific configuration ###
from os.path import basename
#mpl.style.use('ggplot')
mpl.style.use('fivethirtyeight')
from cycler import cycler
mpl.rcParams['axes.prop_cycle'] = cycler(color='bgrcmyk')

from Homer import *

print('Number of tissues: ',len(tissues))
# Out:
# ('Number of tissues: ', 13)

# %%
from ATAC_helper import *

# %%
import create_output

# %%
if not os.path.exists("Results/Figures/SuppFigure4/Data"):
    os.makedirs("Results/Figures/SuppFigure4/Data")

# %%
cmd = "cp Results/output/TSS1.exp.bed Results/Figures/SuppFigure4/Data/"
# !{cmd}

# %%
cmd = "cp Results/output/TSS1.ref.bed Results/Figures/SuppFigure4/Data/"
# !{cmd}

# %%
bed_df = pd.read_csv("Results/Figures/SuppFigure4/Data/TSS1.exp.bed",sep="\t",header=None)
bed_df[3] = bed_df.index #bed_df[3].str.replace("@","")
bed_df.to_csv("Results/Figures/SuppFigure4/Data/TSS1.exp.bed_mod",sep="\t",header=None,index=False)
bed_df.head()

# %%
cmd = "computeMatrix reference-point -S /data/isshamie/TSS/1015_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/peak_groups/CHO/confident_promoters.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/exp_all --numberOfProcessors 6"
# !{cmd}

# %%
cmd = "computeMatrix reference-point -S /data/isshamie/TSS/1015_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.exp.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/exp_all --numberOfProcessors 6"
# !{cmd}
# Out:
# Skipping p1@IGHV3-6_gene_3015_asmbl_8943, due to being absent in the computeMatrix output.
# Skipping p1@APOE_gene_5058_asmbl_14749, due to being absent in the computeMatrix output.
# Skipping p1@IGHV3-74_gene_7002_asmbl_20945, due to being absent in the computeMatrix output.
# Skipping p1@GM5629_gene_21760_asmbl_61263, due to being absent in the computeMatrix output.
# Skipping p2@GM5629_gene_21760_asmbl_61263, due to being absent in the computeMatrix output.
# Skipping p1@IGHV3-6_gene_21761_asmbl_61264, due to being absent in the computeMatrix output.
# Skipping p2@IGHV3-6_gene_21761_asmbl_61264, due to being absent in the computeMatrix output.

# %% [markdown]
# ## 1. Using final bed file vs the refseq genes CHO peaks and ATAC

# %%
meta_df = pd.read_csv("Results/output/TSS1.meta",sep="\t",na_filter=None,index_col=0)
bed_df = pd.read_csv("Results/output/TSS1.bed",sep="\t",header=None)

# %% [markdown]
# ## 1.1
# ## +/-1 1kb CHO experimental and refseq not in experimental

# %%
outfile = "Results/Figures/SuppFigure4/exp_all"
tss_bed = "Results/Figures/SuppFigure4/Data/TSS1.exp.bed" 
t = "CHO"

bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/*.fc.signal.bigwig'))[0]

run_heatmap(tss_bed, bigwig, outfile, dist=1000, numProc=6, dispImage=True)
# Out:
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.exp.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/exp_all --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/exp_all     -out Results/Figures/SuppFigure4/exp_all.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %%
outfile = "Results/Figures/SuppFigure4/ref_nonexp"
tss_bed = "Results/output/TSS1.ref.bed" 
t = "CHO"

bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/*.fc.signal.bigwig'))[0]

run_heatmap(tss_bed, bigwig, outfile, dist=1000, numProc=6, dispImage=True)
# Out:
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/output/TSS1.ref.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/ref_nonexp --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/ref_nonexp     -out Results/Figures/SuppFigure4/ref_nonexp.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %% [markdown]
# ## Peaks seen only in CHO

# %%
cho_meta_df = meta_df[meta_df["Tissues"].str.contains("CHO")]
cho_bed_df = bed_df[bed_df[3].isin(cho_meta_df.index)]

print(cho_bed_df.shape)

print(cho_meta_df.shape)


cho_bed_df.to_csv("Results/Figures/SuppFigure4/Data/TSS1.CHO.bed",sep="\t",header=None,index=None)
# Out:
# (24200, 6)
# (24200, 9)

# %%
outfile = "Results/Figures/SuppFigure4/TSS1.CHO"
tss_bed = "Results/Figures/SuppFigure4/Data/TSS1.CHO.bed" 
t = "CHO"

bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/*.fc.signal.bigwig'))[0]

run_heatmap(tss_bed, bigwig, outfile, dist=1000, numProc=6, dispImage=True)
# Out:
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/TSS1.CHO --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/TSS1.CHO     -out Results/Figures/SuppFigure4/TSS1.CHO.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %%
cho_meta_df = meta_df[meta_df["Tissues"].str.contains("CHO")]
print("CHO ATAC", (cho_meta_df["CHO ATAC Region"] == "").sum())
print("has any ATAC:",cho_meta_df["has ATAC"].sum())
# Out:
# ('CHO ATAC', 13175)
# ('has any ATAC:', 10009)

# %% [markdown]
# ## Tissues with ATAC

# %% [markdown]
# ## 2. Create for bed for each tissue with an atac

# %%
for t in tissues_with_atac:
    print(t)

    if os.path.exists(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/')):
        bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/*.fc.signal.bigwig'))[0]
    else:
        bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/rep1/*.fc.signal.bigwig'))[0]

    curr_meta_df = meta_df[meta_df["Tissues"].str.contains(t)]
    curr_bed_df = bed_df[bed_df[3].isin(curr_meta_df.index)]
    
    print(curr_bed_df.shape)
    print(curr_meta_df.shape)

    curr_tss_bed = "Results/Figures/SuppFigure4/Data/TSS1.%s.bed" % (t)
    curr_bed_df.to_csv(curr_tss_bed,sep="\t",header=None,index=None)
    
    curr_tss_meta = "Results/Figures/SuppFigure4/Data/TSS1.%s.meta" % (t)
    curr_meta_df.to_csv(curr_tss_meta,sep="\t")
    curr_tss_out = curr_tss_bed.strip(".bed")
    print(curr_tss_bed,curr_tss_out)
    c = run_heatmap(curr_tss_bed, bigwig, curr_tss_out, dist=1000, numProc=6, dispImage=True)
    

    ## Create the refseq version
    
    save_f = curr_tss_bed.strip(".bed") + "_refseq_centered.bed"
    _ = create_output.exp_bed_to_refseq(curr_tss_bed, curr_tss_meta, save_f = save_f,
                  refseq_f=mRNA_peak_file)
    
    curr_tss_out = save_f.strip(".bed")
    c = run_heatmap(save_f, bigwig, curr_tss_out, dist=1000, numProc=6, dispImage=True)
# Out:
# CHO
# (24200, 6)
# (24200, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.CHO.bed', 'Results/Figures/SuppFigure4/Data/TSS1.CHO')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO     -out Results/Figures/SuppFigure4/Data/TSS1.CHO.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Brain
# (31501, 6)
# (31501, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Brain.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Brain')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Brain/ATAC/out/signal/macs2/rep1/Brain_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Brain.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Brain --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Brain     -out Results/Figures/SuppFigure4/Data/TSS1.Brain.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Brain/ATAC/out/signal/macs2/rep1/Brain_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Brain_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Brain_refseq_center --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Brain_refseq_center     -out Results/Figures/SuppFigure4/Data/TSS1.Brain_refseq_center.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Liver
# (24370, 6)
# (24370, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Liver.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Liver')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Liver/ATAC/out/signal/macs2/rep1/Liver_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Liver.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Liver --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Liver     -out Results/Figures/SuppFigure4/Data/TSS1.Liver.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Liver/ATAC/out/signal/macs2/rep1/Liver_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Liver_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Liver_refseq_center --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Liver_refseq_center     -out Results/Figures/SuppFigure4/Data/TSS1.Liver_refseq_center.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Lung
# (29256, 6)
# (29256, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Lung.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Lung')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Lung/ATAC/out/signal/macs2/rep1/Lung_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Lung.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Lung --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Lung     -out Results/Figures/SuppFigure4/Data/TSS1.Lung.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Lung/ATAC/out/signal/macs2/rep1/Lung_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Lung_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Lung_refseq_center --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Lung_refseq_center     -out Results/Figures/SuppFigure4/Data/TSS1.Lung_refseq_center.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Kidney
# (28123, 6)
# (28123, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Kidney.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Kidney')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Kidney/ATAC/out/signal/macs2/rep1/Kidney_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Kidney.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Kidney --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Kidney     -out Results/Figures/SuppFigure4/Data/TSS1.Kidney.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Kidney/ATAC/out/signal/macs2/rep1/Kidney_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Kidney_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Kidney_refseq_center --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Kidney_refseq_center     -out Results/Figures/SuppFigure4/Data/TSS1.Kidney_refseq_center.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Spleen
# (26140, 6)
# (26140, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Spleen.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Spleen')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Spleen/ATAC/out/signal/macs2/rep1/Spleen_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Spleen.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Spleen --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Spleen     -out Results/Figures/SuppFigure4/Data/TSS1.Spleen.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Spleen/ATAC/out/signal/macs2/rep1/Spleen_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Spleen_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.Spleen_refseq_center --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Spleen_refseq_center     -out Results/Figures/SuppFigure4/Data/TSS1.Spleen_refseq_center.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# BMDMwt
# (21031, 6)
# (21031, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.BMDMwt.bed', 'Results/Figures/SuppFigure4/Data/TSS1.BMDMwt')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/BMDMwt/ATAC/out/signal/macs2/pooled_rep/BMDMwt_ATAC1.trim.nodup.tn5_BMDMwt_ATAC2.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.BMDMwt.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.BMDMwt --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.BMDMwt     -out Results/Figures/SuppFigure4/Data/TSS1.BMDMwt.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/BMDMwt/ATAC/out/signal/macs2/pooled_rep/BMDMwt_ATAC1.trim.nodup.tn5_BMDMwt_ATAC2.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_refseq_center --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_refseq_center     -out Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_refseq_center.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# BMDM1hKLA
# (20275, 6)
# (20275, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA.bed', 'Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/BMDM1hKLA/ATAC/out/signal/macs2/pooled_rep/BMDM1hKLA_ATAC2.trim.nodup.tn5_BMDM1hKLA_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA     -out Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/BMDM1hKLA/ATAC/out/signal/macs2/pooled_rep/BMDM1hKLA_ATAC2.trim.nodup.tn5_BMDM1hKLA_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_refseq_center --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_refseq_center     -out Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_refseq_center.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %%
bed_f, meta_f  = curr_tss_bed, curr_tss_meta
save_f = save_f,
refseq_f = mRNA_peak_file
    
tss = pd.read_csv(refseq_f, sep="\t", index_col=0)
meta_df = pd.read_csv(meta_f, sep="\t", index_col=0)
bed_df = pd.read_csv(bed_f, sep="\t", header=None)

out_meta = meta_df[meta_df["Transcript"].isin(tss.index)]
out_bed = bed_df[bed_df[3].isin(out_meta.index)]

out_bed = out_bed.copy()
out_bed = out_bed.set_index(3)

#out_bed[0] = np.array(tss.loc[out_meta["Transcript"], "Chr"])
# Out:
# [autoreload of create_output failed: Traceback (most recent call last):
#   File "/home/isshamie/software/anaconda2/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "/data/isshamie/TSS/Analysis/src/create_output.py", line 356
#     tss.
#        ^
# SyntaxError: invalid syntax
# ]

# %% [markdown]
# ## 200 bps

# %%
dist = 250

for t in tissues_with_atac:
    print(t)
    if os.path.exists(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/')):
        bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/*.fc.signal.bigwig'))[0]
    else:
        bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/rep1/*.fc.signal.bigwig'))[0]

    curr_meta_df = meta_df[meta_df["Tissues"].str.contains(t)]
    curr_bed_df = bed_df[bed_df[3].isin(curr_meta_df.index)]
    
    print(curr_bed_df.shape)
    print(curr_meta_df.shape)

    curr_tss_bed = "Results/Figures/SuppFigure4/Data/TSS1.%s.bed" % (t)
    curr_bed_df.to_csv(curr_tss_bed,sep="\t",header=None,index=None)
    
    curr_tss_meta = "Results/Figures/SuppFigure4/Data/TSS1.%s.meta" % (t)
    curr_meta_df.to_csv(curr_tss_meta,sep="\t")
    curr_tss_out = curr_tss_bed.strip(".bed") + "_" + str(dist)
    print(curr_tss_bed,curr_tss_out)
    c = run_heatmap(curr_tss_bed, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)
    

    ## Create the refseq version
    save_f = curr_tss_bed.strip(".bed") + "_refseq_centered.bed"
    curr_tss_out = save_f.strip(".bed") + "_" + str(dist)
    c = run_heatmap(save_f, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)
# Out:
# CHO
# (24200, 6)
# (24200, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.CHO.bed', 'Results/Figures/SuppFigure4/Data/TSS1.CHO_250')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_250     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_250     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Brain
# (31501, 6)
# (31501, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Brain.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Brain_250')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Brain/ATAC/out/signal/macs2/rep1/Brain_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Brain.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Brain_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Brain_250     -out Results/Figures/SuppFigure4/Data/TSS1.Brain_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Brain/ATAC/out/signal/macs2/rep1/Brain_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Brain_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Brain_refseq_center_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Brain_refseq_center_250     -out Results/Figures/SuppFigure4/Data/TSS1.Brain_refseq_center_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Liver
# (24370, 6)
# (24370, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Liver.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Liver_250')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Liver/ATAC/out/signal/macs2/rep1/Liver_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Liver.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Liver_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Liver_250     -out Results/Figures/SuppFigure4/Data/TSS1.Liver_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Liver/ATAC/out/signal/macs2/rep1/Liver_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Liver_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Liver_refseq_center_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Liver_refseq_center_250     -out Results/Figures/SuppFigure4/Data/TSS1.Liver_refseq_center_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Lung
# (29256, 6)
# (29256, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Lung.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Lung_250')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Lung/ATAC/out/signal/macs2/rep1/Lung_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Lung.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Lung_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Lung_250     -out Results/Figures/SuppFigure4/Data/TSS1.Lung_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Lung/ATAC/out/signal/macs2/rep1/Lung_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Lung_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Lung_refseq_center_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Lung_refseq_center_250     -out Results/Figures/SuppFigure4/Data/TSS1.Lung_refseq_center_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Kidney
# (28123, 6)
# (28123, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Kidney.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Kidney_250')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Kidney/ATAC/out/signal/macs2/rep1/Kidney_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Kidney.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Kidney_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Kidney_250     -out Results/Figures/SuppFigure4/Data/TSS1.Kidney_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Kidney/ATAC/out/signal/macs2/rep1/Kidney_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Kidney_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Kidney_refseq_center_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Kidney_refseq_center_250     -out Results/Figures/SuppFigure4/Data/TSS1.Kidney_refseq_center_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# Spleen
# (26140, 6)
# (26140, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.Spleen.bed', 'Results/Figures/SuppFigure4/Data/TSS1.Spleen_250')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Spleen/ATAC/out/signal/macs2/rep1/Spleen_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Spleen.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Spleen_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Spleen_250     -out Results/Figures/SuppFigure4/Data/TSS1.Spleen_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/Spleen/ATAC/out/signal/macs2/rep1/Spleen_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.Spleen_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.Spleen_refseq_center_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.Spleen_refseq_center_250     -out Results/Figures/SuppFigure4/Data/TSS1.Spleen_refseq_center_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# BMDMwt
# (21031, 6)
# (21031, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.BMDMwt.bed', 'Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_250')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/BMDMwt/ATAC/out/signal/macs2/pooled_rep/BMDMwt_ATAC1.trim.nodup.tn5_BMDMwt_ATAC2.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.BMDMwt.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_250     -out Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/BMDMwt/ATAC/out/signal/macs2/pooled_rep/BMDMwt_ATAC1.trim.nodup.tn5_BMDMwt_ATAC2.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_refseq_center_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_refseq_center_250     -out Results/Figures/SuppFigure4/Data/TSS1.BMDMwt_refseq_center_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# BMDM1hKLA
# (20275, 6)
# (20275, 9)
# ('Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA.bed', 'Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_250')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/BMDM1hKLA/ATAC/out/signal/macs2/pooled_rep/BMDM1hKLA_ATAC2.trim.nodup.tn5_BMDM1hKLA_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_250     -out Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/BMDM1hKLA/ATAC/out/signal/macs2/pooled_rep/BMDM1hKLA_ATAC2.trim.nodup.tn5_BMDM1hKLA_ATAC1.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_refseq_center_250 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_refseq_center_250     -out Results/Figures/SuppFigure4/Data/TSS1.BMDM1hKLA_refseq_center_250.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %% [markdown]
# ## Homer

# %%
dist = 250
t = "CHO"
print(t)
bigwig = "/data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/Homer_Process/tags/CHO_ATAC1.bigwig"

curr_meta_df = meta_df[meta_df["Tissues"].str.contains(t)]
curr_bed_df = bed_df[bed_df[3].isin(curr_meta_df.index)]

curr_tss_bed = "Results/Figures/SuppFigure4/Data/TSS1.%s.bed" % (t)
curr_tss_meta = "Results/Figures/SuppFigure4/Data/TSS1.%s.meta" % (t)
curr_tss_out = curr_tss_bed.strip(".bed") + "_" + str(dist) + '_Homer'
print(curr_tss_bed,curr_tss_out)

c = run_heatmap(curr_tss_bed, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)


## Create the refseq version
save_f = curr_tss_bed.strip(".bed") + "_refseq_centered.bed"
curr_tss_out = save_f.strip(".bed") + "_" + str(dist) + "_Homer"
c = run_heatmap(save_f, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)
# Out:
# CHO
# ('Results/Figures/SuppFigure4/Data/TSS1.CHO.bed', 'Results/Figures/SuppFigure4/Data/TSS1.CHO_250_Homer')
# computeMatrix reference-point -S /data/isshamie/TSS/1015_Processed/CHO/ATAC/Homer_Process/tags/CHO_ATAC1.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_250_Homer --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_250_Homer     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_250_Homer.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/1015_Processed/CHO/ATAC/Homer_Process/tags/CHO_ATAC1.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_centered.bed -a 250 -b 250 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_250_Homer --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_250_Homer     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_250_Homer.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %%
dist = 1000
t = "CHO"
print(t)
bigwig = "/data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/Homer_Process/tags/CHO_ATAC1.bigwig"

curr_meta_df = meta_df[meta_df["Tissues"].str.contains(t)]
curr_bed_df = bed_df[bed_df[3].isin(curr_meta_df.index)]

curr_tss_bed = "Results/Figures/SuppFigure4/Data/TSS1.%s.bed" % (t)
curr_tss_meta = "Results/Figures/SuppFigure4/Data/TSS1.%s.meta" % (t)
curr_tss_out = curr_tss_bed.strip(".bed") + "_" + str(dist) + '_Homer'
print(curr_tss_bed,curr_tss_out)

c = run_heatmap(curr_tss_bed, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)


## Create the refseq version
save_f = curr_tss_bed.strip(".bed") + "_refseq_centered.bed"
curr_tss_out = save_f.strip(".bed") + "_" + str(dist) + "_Homer"
c = run_heatmap(save_f, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)
# Out:
# CHO
# ('Results/Figures/SuppFigure4/Data/TSS1.CHO.bed', 'Results/Figures/SuppFigure4/Data/TSS1.CHO_1000_Homer')
# computeMatrix reference-point -S /data/isshamie/TSS/1015_Processed/CHO/ATAC/Homer_Process/tags/CHO_ATAC1.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_1000_Homer --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_1000_Homer     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_1000_Homer.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/1015_Processed/CHO/ATAC/Homer_Process/tags/CHO_ATAC1.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_centered.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_1000_Homer --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_1000_Homer     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_refseq_center_1000_Homer.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %% [markdown]
# ## Only peak1 bed file

# %%
dist = 1000
t = "CHO"
print(t)
#bigwig = "/data/isshamie/TSS/1015_Processed/CHO/ATAC/Homer_Process/tags/CHO_ATAC1.bigwig"
if os.path.exists(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/')):
    bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/*.fc.signal.bigwig'))[0]
else:
    bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/rep1/*.fc.signal.bigwig'))[0]

    
curr_meta_df = meta_df[meta_df["Tissues"].str.contains(t)]
curr_meta_df = curr_meta_df[curr_meta_df.index.str.contains("p1")]
curr_bed_df = bed_df[bed_df[3].isin(curr_meta_df.index)]

curr_tss_bed = "Results/Figures/SuppFigure4/Data/TSS1.%s_p1.bed" % (t)
curr_bed_df.to_csv(curr_tss_bed,sep="\t",header=None,index=None)

curr_tss_meta = "Results/Figures/SuppFigure4/Data/TSS1.%s_p1.meta" % (t)
curr_meta_df.to_csv(curr_tss_meta,sep="\t")
curr_tss_out = curr_tss_bed.strip(".bed")
print(curr_tss_bed,curr_tss_out)
c = run_heatmap(curr_tss_bed, bigwig, curr_tss_out, dist=1000, numProc=6, dispImage=True)


## Create the refseq version

save_f = curr_tss_bed.strip(".bed") + "_refseq_centered_p1.bed"
_ = create_output.exp_bed_to_refseq(curr_tss_bed, curr_tss_meta, save_f = save_f,
              refseq_f=mRNA_peak_file)

curr_tss_out = save_f.strip(".bed") + "_" + str(dist) + "_p1"
c = run_heatmap(save_f, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)
# Out:
# CHO
# ('Results/Figures/SuppFigure4/Data/TSS1.CHO_p1.bed', 'Results/Figures/SuppFigure4/Data/TSS1.CHO_p1')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_p1.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_p1 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_p1     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_p1.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_p1_refseq_centered_p1.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_p1_refseq_centered_p1_1000_p1 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_p1_refseq_centered_p1_1000_p1     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_p1_refseq_centered_p1_1000_p1.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %%
curr_tss_out = save_f.strip(".bed") + "_" + str(dist) + "_p1"
c = run_heatmap(save_f, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)
# Out:
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_p1_refseq_centered_p1.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_p1_refseq_centered_p1_1000_p1 --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_p1_refseq_centered_p1_1000_p1     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_p1_refseq_centered_p1_1000_p1.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %% [markdown]
# ## 3. Leftmost peak vs others

# %%
cols = ["Chr","Start","End","ID","Stat","Strand"]
bed_df.columns = cols
out_tss_df = pd.concat((bed_df.set_index("ID"),meta_df),axis=1)

# %%
def return_most_downstream_peak(tss_df):
    ## Need to separate pos and neg strand b/c want leftmost
    out_tss = tss_df.sort_values(["Chr","Strand"])
    out_tss_pos = out_tss_df[out_tss_df["Strand"] == "+"]
    out_tss_neg = out_tss_df[out_tss_df["Strand"] == "-"]
    out_tss_pos = out_tss_pos.sort_values(["Start","End"],ascending=False)
    out_tss_pos = out_tss_pos[~out_tss_pos["Transcript"].duplicated()]
    out_tss_neg = out_tss_neg.sort_values(["Start","End"])

    out_tss = pd.concat((out_tss_pos,out_tss_neg),axis=0)
    out_tss = out_tss.sort_values(["Chr","Strand","Start","End"])
    out_tss = out_tss[~out_tss.sort_values(["Chr","Strand","Start","End"])["Transcript"].duplicated()]

    out_tss = out_tss.sort_values(["Chr","Start","End","Strand"])
    return out_tss

# %%
dist = 1000
t = "CHO"
print(t)
#bigwig = "/data/isshamie/TSS/1015_Processed/CHO/ATAC/Homer_Process/tags/CHO_ATAC1.bigwig"
if os.path.exists(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/')):
    bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/pooled_rep/*.fc.signal.bigwig'))[0]
else:
    bigwig = glob.glob(os.path.join(data_folder,t, 'ATAC/out/signal/macs2/rep1/*.fc.signal.bigwig'))[0]

curr_meta_df = meta_df[meta_df["Tissues"].str.contains(t)]
curr_bed_df = bed_df[bed_df["ID"].isin(curr_meta_df.index)]

# Merge the two and find the most downstream peaks of a transcript
out_tss_df = pd.concat((curr_bed_df.set_index("ID"),curr_meta_df),axis=1)
out_tss_df = return_most_downstream_peak(out_tss_df)

curr_bed_df = out_tss_df[["Chr","Start","End","ID","Stat","Strand"]]
curr_tss_bed = "Results/Figures/SuppFigure4/Data/TSS1.%s_downstream.bed" % (t)
curr_bed_df.to_csv(curr_tss_bed,sep="\t",header=None,index=None)

# Make the full meta 
curr_meta_df = out_tss_df
curr_tss_meta = "Results/Figures/SuppFigure4/Data/TSS1.%s_downstream.meta" % (t)
curr_meta_df.to_csv(curr_tss_meta,sep="\t")
curr_tss_out = curr_tss_bed.strip(".bed")
print(curr_tss_bed,curr_tss_out)
c = run_heatmap(curr_tss_bed, bigwig, curr_tss_out, dist=1000, numProc=6, dispImage=True)


## Create the refseq version

save_f = curr_tss_bed.strip(".bed") + "_refseq_centered_downstream.bed"
_ = create_output.exp_bed_to_refseq(curr_tss_bed, curr_tss_meta, save_f = save_f,
              refseq_f=mRNA_peak_file)

curr_tss_out = save_f.strip(".bed") + "_" + str(dist) + "_downstream"
c = run_heatmap(save_f, bigwig, curr_tss_out, dist=dist, numProc=6, dispImage=True)
# Out:
# CHO
# ('Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream.bed', 'Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream')
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'
# computeMatrix reference-point -S /data/isshamie/TSS/NCBI_PICR_103_Processed/CHO/ATAC/out/signal/macs2/pooled_rep/CHO_ATAC1.trim.nodup.tn5_CHO_ATAC3.trim.nodup.tn5.pf.fc.signal.bigwig -R Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream_refseq_centered_downstream.bed -a 1000 -b 1000 -out Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream_refseq_centered_downstream_1000_downstream --numberOfProcessors 6
# plotHeatmap     -m Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream_refseq_centered_downstream_1000_downstream     -out Results/Figures/SuppFigure4/Data/TSS1.CHO_downstream_refseq_centered_downstream_1000_downstream.png      --heatmapHeight 15       --refPointLabel TSS.center      --regionsLabel TSS      --plotTitle 'ATAC signal'

# %% [markdown]
# ## Panel B
# ## silenced genes in refseq

# %% [markdown]
# ## 3. Peak 1 vs others
