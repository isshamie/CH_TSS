# %% [markdown]
# ## Motif using logos in python using matplotlib
#
# This is a proof of concept for plotting motif logos using matplotlib.
# The coordinates for bases were picked of from [seqLogo](http://bioconductor.org/packages/release/bioc/html/seqLogo.html) package.
#
# `seqLogo` is LGPL(v2.1) licensed and hence so is this notebook.
#
# See [LICENCE](LICENSE)

# %%
# %matplotlib inline
from __future__ import division
from Bio import motifs
import seaborn
import matplotlib.pyplot as plt
plt.style.use('seaborn-ticks')
import numpy as np
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection
from matplotlib import transforms

 

colors_scheme = {'G': 'orange', 'A': 'red', 'C': 'blue', 'T': 'darkgreen'}

# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])


import os

import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm

from os.path import basename
##mpl.use('Agg')
#mpl.style.use('ggplot')
#mpl.style.use('fivethirtyeight')
from Homer import *
import motif_analysis
import helper
import create_output
print('Number of tissues: ',len(tissues))
# Out:
# ('Number of tissues: ', 13)

# %%
if not os.path.exists("Results/Figures/Figure3/alt2/"):
    os.mkdir("Results/Figures/Figure3/alt2/")

# %%
import pandas as pd
import motif_analysis

# %%
#ACGT
def setup_as_motif(f_in, f_save,ind_range=(-10, 10) , is_bg= True, is_info = True):
    #n is number of sequences used
    m = pd.read_csv(f_in, sep="\t", index_col=0)
    m = m[["A frequency", "C frequency","G frequency","T frequency"]]
    
    # Generate background file
    nucs = m.sum()
    tot = nucs.sum()
    bg = {"A": nucs["A frequency"]/tot, "C": nucs["C frequency"]/tot, "G":nucs["G frequency"]/tot, "T":nucs["T frequency"]/tot }
    bg = pd.Series(bg)
    bg.index = bg.index.rename("#\torder 0")
    bg.to_csv("tmp_motif.bg",sep="\t",header=True)
    
    #Restrict m to the index range
    m = m.loc[ind_range[0]:ind_range[1]].transpose()  

    # tmp files for storing motifs
    tmp_pfm = "tmp_motif.pfm"
    tmp = "tmp_motif.meme" 
    
    # normalize m to the background frequencies
    if is_bg:
        m.loc["A frequency"] = m.loc["A frequency"]/bg["A"]
        m.loc["C frequency"] = m.loc["C frequency"]/bg["C"]
        m.loc["G frequency"] = m.loc["G frequency"]/bg["G"]
        m.loc["T frequency"] = m.loc["T frequency"]/bg["T"]
        # Re-normalize
        m = m/m.sum() 
        cmd = "jaspar2meme -bg tmp_motif.bg -pfm . > %s" % tmp #-logodds
    else:
        cmd = "jaspar2meme -pfm . > %s" % tmp 
        
    m.to_csv(tmp_pfm,sep="\t",header=None,index=None)
    # !{cmd}
    
    
    # Generate seq logo    
    cmd_png = "ceqlogo -i %s -m 1 -p 0 -c 0.25 -o %s -f PNG" % (tmp, f_save + ".png")
    cmd_eps = "ceqlogo -i %s -m 1 -p 0 -c 0.25 -o %s -f EPS" % (tmp, f_save + ".eps")

    #This scales each position to 1
    if not is_info:
        cmd_png = cmd_png + " -F"
        cmd_eps = cmd_eps + " -F"
        
    # !{cmd_png}
    # !{cmd_eps}
    
    cmd = "rm %s %s" % (tmp, tmp_pfm)
    # !{cmd}
    
    return m, bg

# %%
f_in = "Results/Figures/Figure3/alt/C_i_exp.nuc_freq_1000.txt"
f_save = "Results/Figures/Figure3/alt2/C_exp_m10_10_bg"
ind_range=(-10, 10)
is_bg=True
is_info=False

# %%
bg
# Out:
# #\torder 0
# A    0.211923
# C    0.275432
# G    0.291265
# T    0.221380
# dtype: float64

# %%
np.mean(m.loc["G frequency"])
# Out:
# 0.3021155714285715

# %%
m
# Out:
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -10  \
# A frequency                                                                                                                                                                 0.226253
# C frequency                                                                                                                                                                 0.271618
# G frequency                                                                                                                                                                 0.267368
# T frequency                                                                                                                                                                 0.234761
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -9   \
# A frequency                                                                                                                                                                 0.223050
# C frequency                                                                                                                                                                 0.269462
# G frequency                                                                                                                                                                 0.270071
# T frequency                                                                                                                                                                 0.237417
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -8   \
# A frequency                                                                                                                                                                 0.229913
# C frequency                                                                                                                                                                 0.259100
# G frequency                                                                                                                                                                 0.271752
# T frequency                                                                                                                                                                 0.239235
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -7   \
# A frequency                                                                                                                                                                 0.221632
# C frequency                                                                                                                                                                 0.264515
# G frequency                                                                                                                                                                 0.267648
# T frequency                                                                                                                                                                 0.246205
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -6   \
# A frequency                                                                                                                                                                 0.203356
# C frequency                                                                                                                                                                 0.302107
# G frequency                                                                                                                                                                 0.252428
# T frequency                                                                                                                                                                 0.242109
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -5   \
# A frequency                                                                                                                                                                 0.297976
# C frequency                                                                                                                                                                 0.241036
# G frequency                                                                                                                                                                 0.236017
# T frequency                                                                                                                                                                 0.224971
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -4   \
# A frequency                                                                                                                                                                 0.248350
# C frequency                                                                                                                                                                 0.283825
# G frequency                                                                                                                                                                 0.243962
# T frequency                                                                                                                                                                 0.223863
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -3   \
# A frequency                                                                                                                                                                 0.230129
# C frequency                                                                                                                                                                 0.219899
# G frequency                                                                                                                                                                 0.280393
# T frequency                                                                                                                                                                 0.269578
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -2   \
# A frequency                                                                                                                                                                 0.167826
# C frequency                                                                                                                                                                 0.253111
# G frequency                                                                                                                                                                 0.267263
# T frequency                                                                                                                                                                 0.311801
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -1   \
# A frequency                                                                                                                                                                 0.097779
# C frequency                                                                                                                                                                 0.469571
# G frequency                                                                                                                                                                 0.124339
# T frequency                                                                                                                                                                 0.308310
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)  ...  \
# A frequency                                                                                                                                                                 ...
# C frequency                                                                                                                                                                 ...
# G frequency                                                                                                                                                                 ...
# T frequency                                                                                                                                                                 ...
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        1   \
# A frequency                                                                                                                                                                 0.233866
# C frequency                                                                                                                                                                 0.177404
# G frequency                                                                                                                                                                 0.305635
# T frequency                                                                                                                                                                 0.283095
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        2   \
# A frequency                                                                                                                                                                 0.293738
# C frequency                                                                                                                                                                 0.151004
# G frequency                                                                                                                                                                 0.207559
# T frequency                                                                                                                                                                 0.347699
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        3   \
# A frequency                                                                                                                                                                 0.232248
# C frequency                                                                                                                                                                 0.216652
# G frequency                                                                                                                                                                 0.250883
# T frequency                                                                                                                                                                 0.300217
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        4   \
# A frequency                                                                                                                                                                 0.223559
# C frequency                                                                                                                                                                 0.231240
# G frequency                                                                                                                                                                 0.252338
# T frequency                                                                                                                                                                 0.292862
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        5   \
# A frequency                                                                                                                                                                 0.207887
# C frequency                                                                                                                                                                 0.249651
# G frequency                                                                                                                                                                 0.273249
# T frequency                                                                                                                                                                 0.269214
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)
#  477                                                    0.052317
#  478                                                    0.051992
#  479                                                    0.049813
#  480                                                    0.052447
#  481                                                    0.054203
#  482                                                    0.053422
#  483                                                    0.049746
#  484                                                    0.053518
#  485                                                    0.053453
#  486                                                    0.052705
#  487                                                    0.053713
#  488                                                    0.052868
#  489                                                    0.052608
#  490                                                    0.054786
#  491                                                    0.054656
#  492                                                    0.052705
#  493                                                    0.053323
#  494                                                    0.050104
#  495                                                    0.051014
#  496                                                    0.050332
#  497                                                    0.052022
#  498                                                    0.053616
#  499                                                    0.052803
#  500                                                    0.000000
#
#                                                     AC frequency  ...  \
# Distance from Center (cmd=annotatePeaks.pl Resu...                ...
# -500                                                    0.051661  ...
# -499                                                    0.052051  ...
# -498                                                    0.054719  ...
# -497                                                    0.051531  ...
# -496                                                    0.053287  ...
# -495                                                    0.051205  ...
# -494                                                    0.051433  ...
# -493                                                    0.051075  ...
# -492                                                    0.050815  ...
# -491                                                    0.051173  ...
# -490                                                    0.053905  ...
# -489                                                    0.052864  ...
# -488                                                    0.051628  ...
# -487                                                    0.052637  ...
# -486                                                    0.051823  ...
# -485                                                    0.052149  ...
# -484                                                    0.052474  ...
# -483                                                    0.052604  ...
# -482                                                    0.051075  ...
# -481                                                    0.053222  ...
# -480                                                    0.050652  ...
# -479                                                    0.051726  ...
# -478                                                    0.050327  ...
# -477                                                    0.052019  ...
# -476                                                    0.050880  ...
# -475                                                    0.051986  ...
# -474                                                    0.049937  ...
# -473                                                    0.052637  ...
# -472                                                    0.051140  ...
# -471                                                    0.051335  ...
# ...                                                          ...  ...
#  471                                                    0.043895  ...
#  472                                                    0.045684  ...
#  473                                                    0.044351  ...
#  474                                                    0.044513  ...
#  475                                                    0.045944  ...
#  476                                                    0.043765  ...
#  477                                                    0.046204  ...
#  478                                                    0.044708  ...
#  479                                                    0.045651  ...
#  480                                                    0.044188  ...
#  481                                                    0.043863  ...
#  482                                                    0.046497  ...
#  483                                                    0.045292  ...
#  484                                                    0.043114  ...
#  485                                                    0.046430  ...
#  486                                                    0.044219  ...
#  487                                                    0.045259  ...
#  488                                                    0.045455  ...
#  489                                                    0.043211  ...
#  490                                                    0.044609  ...
#  491                                                    0.046462  ...
#  492                                                    0.043504  ...
#  493                                                    0.044999  ...
#  494                                                    0.045617  ...
#  495                                                    0.044089  ...
#  496                                                    0.044739  ...
#  497                                                    0.045877  ...
#  498                                                    0.043959  ...
#  499                                                    0.044902  ...
#  500                                                    0.000000  ...
#
#                                                     CG frequency  \
# Distance from Center (cmd=annotatePeaks.pl Resu...
# -500                                                    0.032695
# -499                                                    0.033020
# -498                                                    0.032174
# -497                                                    0.032239
# -496                                                    0.033898
# -495                                                    0.033606
# -494                                                    0.033638
# -493                                                    0.032630
# -492                                                    0.031654
# -491                                                    0.032011
# -490                                                    0.030548
# -489                                                    0.034939
# -488                                                    0.031881
# -487                                                    0.032825
# -486                                                    0.033052
# -485                                                    0.032499
# -484                                                    0.033345
# -483                                                    0.033052
# -482                                                    0.031881
# -481                                                    0.033280
# -480                                                    0.034321
#  492                                                    0.072864      0.063500
#  493                                                    0.072474      0.062362
#  494                                                    0.072636      0.063207
#  495                                                    0.073709      0.065548
#  496                                                    0.071433      0.062232
#  497                                                    0.070230      0.065256
#  498                                                    0.071888      0.064540
#  499                                                    0.072669      0.064410
#  500                                                    0.000000      0.000000
#
# [1001 rows x 24 columns]

# %%
m.sum().sum()
# Out:
# 1000.9999939999998

# %%
bg = {"A": nucs["A frequency"]/tot, "C": nucs["C frequency"]/tot, "G":nucs["G frequency"]/tot, "T":nucs["T frequency"]/tot }

# %%
bg
# Out:
# {'A': 0.21192332494659336,
#  'C': 0.27543223841417908,
#  'G': 0.29126466708050752,
#  'T': 0.22137976955872002}

# %%
m = pd.read_csv(f_in, sep="\t", index_col=0)
m = m[["A frequency", "C frequency","G frequency","T frequency"]]

# Generate background file
nucs = m.sum()
tot = nucs.sum()
bg = {"A": nucs["A frequency"]/tot, "C": nucs["C frequency"]/tot, "G":nucs["G frequency"]/tot, "T":nucs["T frequency"]/tot }
bg = pd.Series(bg)
bg.index = bg.index.rename("#\torder 0")
bg.to_csv("tmp_motif.bg",sep="\t",header=True)

#Restrict m to the index range
m = m.loc[ind_range[0]:ind_range[1]].transpose()  

# tmp files for storing motifs
tmp_pfm = "tmp_motif.pfm"
tmp = "tmp_motif.meme"

# # normalize m to the background frequencies
# if is_bg:
#     m.loc["A frequency"] = m.loc["A frequency"]/bg["A"]
#     m.loc["C frequency"] = m.loc["C frequency"]/bg["C"]
#     m.loc["G frequency"] = m.loc["G frequency"]/bg["G"]
#     m.loc["T frequency"] = m.loc["T frequency"]/bg["T"]
#     # Re-normalize
#     m = m/m.sum() 
#     cmd = "jaspar2meme -bg tmp_motif.bg -pfm . > %s" % tmp #-logodds
# else:
#     cmd = "jaspar2meme -pfm . > %s" % tmp

# %%
m.loc["A frequency"] = m.loc["A frequency"]/bg["A"]
m.loc["C frequency"] = m.loc["C frequency"]/bg["C"]
m.loc["G frequency"] = m.loc["G frequency"]/bg["G"]
m.loc["T frequency"] = m.loc["T frequency"]/bg["T"]

# %%
m
# Out:
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -10  \
# A frequency                                                                                                                                                                 0.226253
# C frequency                                                                                                                                                                 0.271618
# G frequency                                                                                                                                                                 0.267368
# T frequency                                                                                                                                                                 0.234761
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -9   \
# A frequency                                                                                                                                                                 0.223050
# C frequency                                                                                                                                                                 0.269462
# G frequency                                                                                                                                                                 0.270071
# T frequency                                                                                                                                                                 0.237417
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -8   \
# A frequency                                                                                                                                                                 0.229913
# C frequency                                                                                                                                                                 0.259100
# G frequency                                                                                                                                                                 0.271752
# T frequency                                                                                                                                                                 0.239235
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -7   \
# A frequency                                                                                                                                                                 0.221632
# C frequency                                                                                                                                                                 0.264515
# G frequency                                                                                                                                                                 0.267648
# T frequency                                                                                                                                                                 0.246205
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -6   \
# A frequency                                                                                                                                                                 0.203356
# C frequency                                                                                                                                                                 0.302107
# G frequency                                                                                                                                                                 0.252428
# T frequency                                                                                                                                                                 0.242109
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -5   \
# A frequency                                                                                                                                                                 0.297976
# C frequency                                                                                                                                                                 0.241036
# G frequency                                                                                                                                                                 0.236017
# T frequency                                                                                                                                                                 0.224971
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -4   \
# A frequency                                                                                                                                                                 0.248350
# C frequency                                                                                                                                                                 0.283825
# G frequency                                                                                                                                                                 0.243962
# T frequency                                                                                                                                                                 0.223863
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -3   \
# A frequency                                                                                                                                                                 0.230129
# C frequency                                                                                                                                                                 0.219899
# G frequency                                                                                                                                                                 0.280393
# T frequency                                                                                                                                                                 0.269578
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -2   \
# A frequency                                                                                                                                                                 0.167826
# C frequency                                                                                                                                                                 0.253111
# G frequency                                                                                                                                                                 0.267263
# T frequency                                                                                                                                                                 0.311801
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)       -1   \
# A frequency                                                                                                                                                                 0.097779
# C frequency                                                                                                                                                                 0.469571
# G frequency                                                                                                                                                                 0.124339
# T frequency                                                                                                                                                                 0.308310
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)  ...  \
# A frequency                                                                                                                                                                 ...
# C frequency                                                                                                                                                                 ...
# G frequency                                                                                                                                                                 ...
# T frequency                                                                                                                                                                 ...
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        1   \
# A frequency                                                                                                                                                                 0.233866
# C frequency                                                                                                                                                                 0.177404
# G frequency                                                                                                                                                                 0.305635
# T frequency                                                                                                                                                                 0.283095
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        2   \
# A frequency                                                                                                                                                                 0.293738
# C frequency                                                                                                                                                                 0.151004
# G frequency                                                                                                                                                                 0.207559
# T frequency                                                                                                                                                                 0.347699
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        3   \
# A frequency                                                                                                                                                                 0.232248
# C frequency                                                                                                                                                                 0.216652
# G frequency                                                                                                                                                                 0.250883
# T frequency                                                                                                                                                                 0.300217
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        4   \
# A frequency                                                                                                                                                                 0.223559
# C frequency                                                                                                                                                                 0.231240
# G frequency                                                                                                                                                                 0.252338
# T frequency                                                                                                                                                                 0.292862
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        5   \
# A frequency                                                                                                                                                                 0.207887
# C frequency                                                                                                                                                                 0.249651
# G frequency                                                                                                                                                                 0.273249
# T frequency                                                                                                                                                                 0.269214
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        6   \
# A frequency                                                                                                                                                                 0.212041
# C frequency                                                                                                                                                                 0.245682
# G frequency                                                                                                                                                                 0.305698
# T frequency                                                                                                                                                                 0.236578
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        7   \
# A frequency                                                                                                                                                                 0.226690
# C frequency                                                                                                                                                                 0.234816
# G frequency                                                                                                                                                                 0.298740
# T frequency                                                                                                                                                                 0.239753
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        8   \
# A frequency                                                                                                                                                                 0.214614
# C frequency                                                                                                                                                                 0.255117
# G frequency                                                                                                                                                                 0.294952
# T frequency                                                                                                                                                                 0.235318
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        9   \
# A frequency                                                                                                                                                                 0.216950
# C frequency                                                                                                                                                                 0.245220
# G frequency                                                                                                                                                                 0.295138
# T frequency                                                                                                                                                                 0.242692
#
# Distance from Center (cmd=annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 1000 -hist 1 -di)        10
# A frequency                                                                                                                                                                 0.221133
# C frequency                                                                                                                                                                 0.235582
# G frequency                                                                                                                                                                 0.299189
# T frequency                                                                                                                                                                 0.244097
#
# [4 rows x 21 columns]

# %% [markdown]
# ## with bg, without info_content

# %%
#Inr region
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = setup_as_motif(
    f_in,
    f_save="Results/Figures/Figure3/alt2/C_exp_m10_10_bg",
    ind_range=(-10, 10),
    is_bg=True,
    is_info=False)

# #tata region
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = setup_as_motif(
    f_in,
    f_save="Results/Figures/Figure3/alt2/C_exp_m40_m15_bg",
    ind_range=(-40, -15),    
    is_bg=True,
    is_info=False)

# %% [markdown]
# ## without bg, without info_content

# %%
#Inr region
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = setup_as_motif(
    f_in,
    f_save="Results/Figures/Figure3/alt2/C_exp_m10_10_nobg",
    ind_range=(-10, 10), 
    is_info=False,
    is_bg=False)

#tata region
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = setup_as_motif(
    f_in,
    f_save="Results/Figures/Figure3/alt2/C_exp_m40_m15_nobg",
    ind_range=(-40, -15),
    is_info=False,
    is_bg=False)

# %% [markdown]
# ## without bg, with info_content

# %%
#Inr region
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = setup_as_motif(
    f_in,
    f_save="Results/Figures/Figure3/alt2/C_exp_m10_10_nobg_info",
    ind_range=(-10, 10),
    is_info=True,
    is_bg=False)

#tata region
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = setup_as_motif(
    f_in,
    f_save="Results/Figures/Figure3/alt2/C_exp_m40_m15_nobg_info",
    ind_range=(-40, -15),
    is_info=True,
    is_bg=False)

# %% [markdown]
# ## with bg, with info_content

# %%
#Inr region
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = setup_as_motif(
    f_in,
    f_save="Results/Figures/Figure3/alt2/C_exp_m10_10_info",
    ind_range=(-10, 10),
    is_info=True,
    is_bg=True)

#tata region
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = setup_as_motif(
    f_in,
    f_save="Results/Figures/Figure3/alt2/C_exp_m40_m15_info",
    ind_range=(-40, -15),
    is_info=True,
    is_bg=True)

# %% [markdown]
# ### Height calculation near tata

# %%
# A and T freq change 0.23/0.2 

#G and C freq change 0.27/0.3

# total for renorm: 2*0.9+ 1.15*2

p = np.array([0.23/0.2,0.23/0.2,0.27/0.3,0.27/0.3])/(2*0.9+ 1.15*2)
print("Normed probability vector", p)

from scipy.stats import entropy
print("IC", 2 - entropy(p,base=2))
# Out:
# ('Normed probability vector', array([ 0.2804878,  0.2804878,  0.2195122,  0.2195122]))
# ('IC', 0.010754703071499838)

# %% [markdown]
# ### Calculate pointwise entropy calculation

# %%
f_in = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_1000.txt"
m = pd.read_csv(f_in, sep="\t", index_col=0)
m = m[["A frequency", "C frequency","G frequency","T frequency"]]
m =(m.apply(lambda x: x/x.sum(),axis=1))
m
# Out:
#                                                     A frequency  C frequency  \
# Distance from Center (cmd=annotatePeaks.pl Resu...
# -500                                                   0.241843     0.254367
# -499                                                   0.243925     0.258629
# -498                                                   0.247568     0.252058
# -497                                                   0.243697     0.255311
# -496                                                   0.242135     0.253619
# -495                                                   0.243567     0.257100
# -494                                                   0.243957     0.254400
# -493                                                   0.243990     0.251440
# -492                                                   0.243957     0.251797
# -491                                                   0.245226     0.253229
# -490                                                   0.249423     0.251928
# -489                                                   0.247731     0.253424
# -488                                                   0.246039     0.253522
# -487                                                   0.246202     0.249845
# -486                                                   0.245063     0.255148
# -485                                                   0.243111     0.254563
# -484                                                   0.243176     0.255474
# -483                                                   0.244217     0.253717
# -482                                                   0.245714     0.251667
# -481                                                   0.243502     0.254205
# -480                                                   0.243144     0.254530
# -479                                                   0.241973     0.253522
# -478                                                   0.243502     0.251862
# -477                                                   0.242786     0.252415
# -476                                                   0.242005     0.256905
# -475                                                   0.244315     0.254270
# -474                                                   0.240574     0.255441
# -473                                                   0.244543     0.248837
# -472                                                   0.243827     0.255213
# -471                                                   0.247861     0.257003
# ...                                                         ...          ...
#  471                                                   0.209104     0.278491
#  472                                                   0.207869     0.272541
#  473                                                   0.205788     0.267436
#  474                                                   0.209007     0.269647
#  500                                                   0.295194     0.230199
#
# [1001 rows x 4 columns]

# %%
m["IC"] = m.apply(lambda x: 2 -  entropy(x),axis=1)
plt.plot(m["IC"])

# %%
    m = pd.read_csv(f_in2, sep="\t", index_col=0)
    m = m[["A frequency", "C frequency","G frequency","T frequency"]]
    m = m.apply(lambda x: x/x.sum(),axis=1)
    m["IC"] = m.apply(lambda x: 2 -  entropy(x),axis=1)

# %%
import plot_tss_results

# %%
def plot_entropy(f_in1, f_in2, f_save=None,ind_range=(-10, 10), is_bg= True):
    #n is number of sequences used
    m = pd.read_csv(f_in1, sep="\t", index_col=0)
    m = m[["A frequency", "C frequency","G frequency","T frequency"]]
    m = m.apply(lambda x: x/x.sum(),axis=1)
    m["IC"] = m.apply(lambda x: 2 -  entropy(x),axis=1)
    
    m2 = pd.read_csv(f_in2, sep="\t", index_col=0)
    m2 = m2[["A frequency", "C frequency","G frequency","T frequency"]]
    m2 = m2.apply(lambda x: x/x.sum(),axis=1)
    m2["IC"] = m2.apply(lambda x: 2 -  entropy(x),axis=1)
        
    # Plot
    f = plt.figure()
    plt.plot(m["IC"])
    plt.plot(m2["IC"],c='g')
    plt.ylabel("Information Content (2-entropy)")
    plt.xlabel("Nucleotide position relative to TSS")

    helper_save(f_save)
    
    
#     #--------
#     # Generate background file
#     nucs = m.sum()
#     tot = nucs.sum()
#     bg = {"A": nucs["A frequency"]/tot, "C": nucs["C frequency"]/tot, "G":nucs["G frequency"]/tot, "T":nucs["T frequency"]/tot }
#     bg = pd.Series(bg)
#     bg.index = bg.index.rename("#\torder 0")
#     bg.to_csv("tmp_motif.bg",sep="\t",header=True)
    
#     #Restrict m to the index range
#     m = m.loc[ind_range[0]:ind_range[1]].transpose()  
    return m,m2

# %%
f_in1 = "Results/Figures/Figure3/alt2/C_i_exp.nuc_freq_200.txt"
f_in2 = "Results/Figures/Figure3/alt2/C_i_refseq.nuc_freq_200.txt"
_ = plot_entropy(f_in1, f_in2,f_save="Results/Figures/Figure3/alt2/C_entropy",)

# %%
pwm = m.counts.normalize(pseudocounts=0.5)
## Get pssm with backgroud
pssm = pwm.log_odds(background=bg)

# %%
with open("tmp_motif.pfm") as handle:
    m = motifs.read(handle, "pfm")

m.counts
# Out:
# {'A': [0.203855,
#   0.212143,
#   0.224624,
#   0.234374,
#   0.241655,
#   0.218253,
#   0.201092,
#   0.189391,
#   0.181461,
#   0.182663,
#   0.183768],
#  'C': [0.275165,
#   0.273117,
#   0.271135,
#   0.264309,
#   0.261969,
#   0.281568,
#   0.283063,
#   0.295381,
#   0.303475,
#   0.30874,
#   0.299314],
#  'G': [0.295056,
#   0.286313,
#   0.279033,
#   0.266552,
#   0.275978,
#   0.294374,
#   0.320961,
#   0.322911,
#   0.327006,
#   0.321741,
#   0.323918],
#  'T': [0.225924,
#   0.228427,
#   0.225209,
#   0.234765,
#   0.220398,
#   0.205805,
#   0.194884,
#   0.192316,
#   0.188059,
#   0.186856,
#   0.192999]}
