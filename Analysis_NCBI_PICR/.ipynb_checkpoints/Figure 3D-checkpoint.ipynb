# %% [markdown]
# ## Distance to Annotation

# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys
import scipy.stats as stats
with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])
ref_fa = doc['ref_fa']
anno_gff=doc['annotation']
mRNA_peak_file = doc["mRNA_peak_file"]

tss_annotation = doc['tss_annotation']


import os
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm

from os.path import basename
##mpl.use('Agg')
#mpl.style.use('ggplot')
#mpl.style.use('fivethirtyeight')
from Homer import *
from plot_tss_results import helper_save
print('Number of tissues: ',len(tissues))
# Out:
# ('Number of tissues: ', 13)

# %% [markdown]
# ## Plotting attributes

# %%
sns.set_style("whitegrid", {'axes.grid' : False})

# %%
tss = pd.read_csv(tss_annotation,sep='\t',index_col=0)

# %% [markdown]
# # i.
# Same strand, merged samples

# %%
anno_peaks = pd.read_csv('Results/merged/peaks_with_tss_distances.tsv',sep='\t',index_col=0)
anno_peaks = anno_peaks[(~(anno_peaks['Distance to TSS']==np.infty))]
anno_peaks = anno_peaks[np.abs(anno_peaks['Distance to TSS'])< 1000]

sns.distplot(anno_peaks[anno_peaks['isSameStrand']]['Distance to TSS'])

plt.ylabel('Frequency')
plt.xlabel('TSS Position relative to previous annotation')

helper_save("Results/Figures/Figure3/Distance_to_Anno/i.png")
#plt.savefig("Results/Figures/Figure3/Distance_to_Anno/i.png",bbox_inches='tight')

print("Mean: %s" % (np.mean(anno_peaks["Distance to TSS"])))
print("Std: %s" % (np.std(anno_peaks["Distance to TSS"])))

print("Absolute Mean: %s" % (np.mean(np.abs(anno_peaks["Distance to TSS"]))))
print("Absolute Std: %s" % (np.std(np.abs(anno_peaks["Distance to TSS"]))))
# Out:
# Mean: 69.4869015238
# Std: 465.506138083
# Absolute Mean: 366.875340006
# Absolute Std: 294.833646269

# %% [markdown]
# # ii.
# Using Output TSS1.exp.bed

# %%
import annotation

# %%
peaks_file = "Results/output/TSS1.exp.bed"

peaks_with_dist = annotation.wrap_distance_to_landmarks(peaks_file, landmark_file=tss_annotation,
                          main_landmark = 'transcript_id',landmark_cols=[],is_bed=True,
                          output_f='Results/Figures/Figure3/Distance_to_Anno/ii.tsv',is_parallel=True,num_par=12)
# Out:
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])

# %%
anno_peaks = pd.read_csv('Results/Figures/Figure3/Distance_to_Anno/ii.tsv',sep='\t',index_col=0)
anno_peaks = anno_peaks[(~(anno_peaks['Distance to TSS']==np.infty))]

# %%
anno_peaks
# Out:
#                                            Chr    Start      End Strand  \
# ID
# p1@Bmp4_XM_027386529.1          NW_020822366.1   722208   722359      -
# p2@Bmp4_XM_027386529.1          NW_020822366.1   721599   721750      -
# p3@Bmp4_XM_027386529.1          NW_020822366.1   721832   721983      -
# p1@Bmp4_XM_027386528.1          NW_020822366.1   724533   724684      -
# p1@Cdkn3_XM_027386531.1         NW_020822366.1  1085431  1085582      +
# p1@Cnih1_XM_027386534.1         NW_020822366.1  1114280  1114431      -
# p1@Cgrrf1_XM_027386536.1        NW_020822366.1  1159823  1159974      +
# p1@Samd4a_XM_027386537.1        NW_020822366.1  1214762  1214913      +
# p1@Samd4a_XM_027386539.1        NW_020822366.1  1332776  1332927      +
# p2@Samd4a_XM_027386539.1        NW_020822366.1  1332950  1333101      +
# p1@Gch1_XM_027386540.1          NW_020822366.1  1513701  1513852      -
# p1@Wdhd1_XM_027386542.1         NW_020822366.1  1605015  1605166      -
# p1@Socs4_XM_027386543.1         NW_020822366.1  1605281  1605432      +
# p1@Mapk1ip1l_XM_027386545.1     NW_020822366.1  1634508  1634659      +
# p1@Lgals3_XM_027386548.1        NW_020822366.1  1718825  1718976      +
# p1@Dlgap5_XM_027386547.1        NW_020822366.1  1758877  1759028      -
# p1@Dlgap5_XM_027386546.1        NW_020822366.1  1765390  1765541      -
# p2@Dlgap5_XM_027386546.1        NW_020822366.1  1766334  1766485      -
# p1@Atg14_XM_027386553.1         NW_020822366.1  1915106  1915257      -
# p1@Ktn1_XM_027386554.1          NW_020822366.1  1980624  1980775      +
# p2@Ktn1_XM_027386554.1          NW_020822366.1  1981584  1981735      +
# p3@Ktn1_XM_027386554.1          NW_020822366.1  1981020  1981171      +
# p1@LOC100768260_XM_027386564.1  NW_020822366.1  2439644  2439795      +
# p1@LOC100768260_XM_027386567.1  NW_020822366.1  2440093  2440244      +
# p1@Tmem260_XM_027386568.1       NW_020822366.1  2801497  2801648      +
# p2@Tmem260_XM_027386568.1       NW_020822366.1  2800512  2800663      +
# p1@Exoc5_XM_027386571.1         NW_020822366.1  3417678  3417829      -
# p1@Ap5m1_XM_027386573.1         NW_020822366.1  3417855  3418006      +
# p1@Naa30_XM_027386575.1         NW_020822366.1  3518106  3518257      +
# p2@Naa30_XM_027386575.1         NW_020822366.1  3517344  3517495      +
# ...                                        ...      ...      ...    ...
# p2@LOC113838541_XM_027434168.1  NW_020823627.1    44308    44459      -
# p1@LOC113838538_XM_027434165.1  NW_020823627.1    44891    45042      +
# p1@LOC113838538_XM_027434162.1  NW_020823627.1    45199    45350      +
# p1@LOC113838537_XM_027434161.1  NW_020823627.1    62453    62604      -
# p2@LOC113838537_XM_027434161.1  NW_020823627.1    61906    62057      -
# p1@LOC113838542_XM_027434169.1  NW_020823627.1    65462    65500      -
# p1@LOC100769620_XM_027434174.1  NW_020823629.1    62290    62441      -
# p1@LOC100769912_XM_027434173.1  NW_020823629.1    71714    71824      -
# p1@LOC113831691_XM_027434189.1  NW_020823639.1     7292     7443      +
# p1@LOC100757478_XM_027434222.1  NW_020823676.1    29535    29686      -
# p1@LOC113831730_XM_027434333.1  NW_020823792.1    24701    24852      -
# p1@LOC113838852_XM_027434360.1  NW_020823819.1    10260    10411      +
# p2@LOC113838852_XM_027434360.1  NW_020823819.1     9776     9927      +
# p1@LOC113838855_XM_027434367.1  NW_020823819.1    38071    38222      +
# p2@LOC113838855_XM_027434367.1  NW_020823819.1    36928    37079      +
# p1@LOC113838897_XM_027434403.1  NW_020823856.1    10737    10775      +
# p1@LOC107977194_XM_027434428.1  NW_020823876.1    33369    33437      +
# p1@LOC100751996_XM_027434444.1  NW_020823898.1    36819    36857      +
# p1@LOC113838952_XM_027434451.1  NW_020823908.1     4162     4313      +
# p1@LOC113838972_XM_027434460.1  NW_020823928.1    19882    20033      -
# p1@LOC113838971_XM_027434459.1  NW_020823928.1    20647    20685      +
# p1@LOC113839006_XM_027434479.1  NW_020823970.1     3396     3455      -
# p1@LOC113839031_XM_027434493.1  NW_020824001.1    37861    38012      -
# p1@LOC113839047_XM_027434508.1  NW_020824030.1    40701    40852      -
# p1@LOC113839066_XM_027434527.1  NW_020824056.1     5306     5457      +
# p1@LOC113839076_XM_027434536.1  NW_020824066.1    29450    29601      +
# p1@LOC113839076_XM_027434535.1  NW_020824066.1    29879    30030      +
# p1@LOC113839111_XM_027434561.1  NW_020824120.1    10402    10553      +
# p2@LOC113839111_XM_027434561.1  NW_020824120.1     9878    10029      +
# p1@LOC113839113_XM_027434564.1  NW_020824123.1      675      713      +
#
#                                     Stat     Nearest TSS  Distance to TSS  \
# ID
# p1@Bmp4_XM_027386529.1          1.779596  XM_027386529.1             25.0
# p2@Bmp4_XM_027386529.1          0.506505  XM_027386529.1            634.0
# p3@Bmp4_XM_027386529.1          0.580925  XM_027386529.1            401.0
# p1@Bmp4_XM_027386528.1          4.074290  XM_027386528.1              2.0
# p1@Cdkn3_XM_027386531.1         1.212188  XM_027386531.1             71.0
# p1@Cnih1_XM_027386534.1         1.527630  XM_027386534.1             58.0
# p1@Cgrrf1_XM_027386536.1        1.748963  XM_027386536.1             15.0
# p1@Samd4a_XM_027386537.1        1.346353  XM_027386537.1             -4.0
# p1@Samd4a_XM_027386539.1        1.198657  XM_027386539.1           -305.0
# p2@Samd4a_XM_027386539.1        0.394452  XM_027386539.1           -131.0
# p1@Gch1_XM_027386540.1          1.654177  XM_027386540.1             19.0
# p1@Wdhd1_XM_027386542.1         1.665581  XM_027386542.1             13.0
# p1@Socs4_XM_027386543.1         1.623249  XM_027386543.1             64.0
# p1@Mapk1ip1l_XM_027386545.1     1.332438  XM_027386545.1             13.0
# p1@Lgals3_XM_027386548.1        2.523876  XM_027386548.1             65.0
# p1@Dlgap5_XM_027386547.1        0.784617  XM_027386547.1            975.0
# p1@Dlgap5_XM_027386546.1        1.139879  XM_027386546.1             36.0
# p2@Dlgap5_XM_027386546.1        0.418301  XM_027386546.1           -908.0
# p1@Atg14_XM_027386553.1         1.103804  XM_027386553.1             29.0
# p1@Ktn1_XM_027386554.1          1.158362  XM_027386554.1           -902.0
# p2@Ktn1_XM_027386554.1          1.771587  XM_027386554.1             58.0
# p3@Ktn1_XM_027386554.1          0.880814  XM_027386554.1           -506.0
# p1@LOC100768260_XM_027386564.1  0.179264  XM_027386564.1           -353.0
# p1@LOC100768260_XM_027386567.1  1.294466  XM_027386567.1             93.0
# p1@Tmem260_XM_027386568.1       1.307496  XM_027386568.1             39.0
# p2@Tmem260_XM_027386568.1       0.332438  XM_027386568.1           -946.0
# p1@Exoc5_XM_027386571.1         1.678518  XM_027386571.1            -28.0
# p1@Ap5m1_XM_027386573.1         1.378398  XM_027386573.1           -169.0
# p1@Naa30_XM_027386575.1         0.350248  XM_027386575.1           -168.0
# p2@Naa30_XM_027386575.1         0.342423  XM_027386575.1           -930.0
# ...                                  ...             ...              ...
# p2@LOC113838541_XM_027434168.1  0.695482  XM_027434168.1           -232.0
# p1@LOC113838538_XM_027434165.1  0.183839  XM_027434165.1           -151.0
# p1@LOC113838538_XM_027434162.1  0.831870  XM_027434162.1              5.0
# p1@LOC113838537_XM_027434161.1  0.242293  XM_027434161.1              2.0
# p2@LOC113838537_XM_027434161.1  0.332438  XM_027434161.1            549.0
# p1@LOC113838542_XM_027434169.1  0.281488  XM_027434169.1           -854.0
# p1@LOC100769620_XM_027434174.1  1.631444  XM_027434174.1            422.0
# p1@LOC100769912_XM_027434173.1  1.222716  XM_027434173.1             41.0
# p1@LOC113831691_XM_027434189.1  1.703291  XM_027434189.1            -14.0
# p1@LOC100757478_XM_027434222.1  0.203577  XM_027434222.1           -104.0
# p1@LOC113831730_XM_027434333.1  0.389166  XM_027434333.1            -23.0
# p1@LOC113838852_XM_027434360.1  0.403121  XM_027434360.1            266.0
# p2@LOC113838852_XM_027434360.1  0.289143  XM_027434360.1           -218.0
# p1@LOC113838855_XM_027434367.1  0.160769  XM_027434367.1            811.0
# p2@LOC113838855_XM_027434367.1  0.646404  XM_027434367.1           -332.0
# p1@LOC113838897_XM_027434403.1  0.511883  XM_027434403.1           -512.0
# p1@LOC107977194_XM_027434428.1  0.378398  XM_027434428.1             -4.0
# p1@LOC100751996_XM_027434444.1  0.442480  XM_027434444.1           -599.0
# p1@LOC113838952_XM_027434451.1  0.528917  XM_027434451.1           -228.0
# p1@LOC113838972_XM_027434460.1  0.305351  XM_027434460.1            -65.0
# p1@LOC113838971_XM_027434459.1  0.861534  XM_027434459.1           -230.0
# p1@LOC113839006_XM_027434479.1  1.161368  XM_027434479.1             -7.0
# p1@LOC113839031_XM_027434493.1  0.418301  XM_027434493.1            266.0
# p1@LOC113839047_XM_027434508.1  0.634477  XM_027434508.1            238.0
# p1@LOC113839066_XM_027434527.1  0.824776  XM_027434527.1            167.0
# p1@LOC113839076_XM_027434536.1  0.667453  XM_027434536.1           -120.0
# p1@LOC113839076_XM_027434535.1  0.229426  XM_027434535.1            308.0
# p1@LOC113839111_XM_027434561.1  1.600973  XM_027434561.1             16.0
# p2@LOC113839111_XM_027434561.1  0.574031  XM_027434561.1           -508.0
# p1@LOC113839113_XM_027434564.1  0.604226  XM_027434564.1           -859.0
#
#                                 isSameStrand
# ID
# p1@Bmp4_XM_027386529.1                  True
# p2@Bmp4_XM_027386529.1                  True
# p3@Bmp4_XM_027386529.1                  True
# p1@Bmp4_XM_027386528.1                  True
# p1@Cdkn3_XM_027386531.1                 True
# p1@Cnih1_XM_027386534.1                 True
# p1@Cgrrf1_XM_027386536.1                True
# p1@Samd4a_XM_027386537.1                True
# p1@Samd4a_XM_027386539.1                True
# p2@Samd4a_XM_027386539.1                True
# p1@Gch1_XM_027386540.1                  True
# p1@Wdhd1_XM_027386542.1                 True
# p1@Socs4_XM_027386543.1                 True
# p1@Mapk1ip1l_XM_027386545.1             True
# p1@Lgals3_XM_027386548.1                True
# p1@Dlgap5_XM_027386547.1                True
# p1@Dlgap5_XM_027386546.1                True
# p2@Dlgap5_XM_027386546.1                True
# p1@Atg14_XM_027386553.1                 True
# p1@Ktn1_XM_027386554.1                  True
# p2@Ktn1_XM_027386554.1                  True
# p3@Ktn1_XM_027386554.1                  True
# p1@LOC100768260_XM_027386564.1          True
# p1@LOC100768260_XM_027386567.1          True
# p1@Tmem260_XM_027386568.1               True
# p2@Tmem260_XM_027386568.1               True
# p1@Exoc5_XM_027386571.1                 True
# p1@Ap5m1_XM_027386573.1                 True
# p1@Naa30_XM_027386575.1                 True
# p2@Naa30_XM_027386575.1                 True
# ...                                      ...
# p2@LOC113838541_XM_027434168.1          True
# p1@LOC113838538_XM_027434165.1          True
# p1@LOC113838538_XM_027434162.1          True
# p1@LOC113838537_XM_027434161.1          True
# p2@LOC113838537_XM_027434161.1          True
# p1@LOC113838542_XM_027434169.1          True
# p1@LOC100769620_XM_027434174.1          True
# p1@LOC100769912_XM_027434173.1          True
# p1@LOC113831691_XM_027434189.1          True
# p1@LOC100757478_XM_027434222.1          True
# p1@LOC113831730_XM_027434333.1          True
# p1@LOC113838852_XM_027434360.1          True
# p2@LOC113838852_XM_027434360.1          True
# p1@LOC113838855_XM_027434367.1          True
# p2@LOC113838855_XM_027434367.1          True
# p1@LOC113838897_XM_027434403.1          True
# p1@LOC107977194_XM_027434428.1          True
# p1@LOC100751996_XM_027434444.1          True
# p1@LOC113838952_XM_027434451.1          True
# p1@LOC113838972_XM_027434460.1          True
# p1@LOC113838971_XM_027434459.1          True
# p1@LOC113839006_XM_027434479.1          True
# p1@LOC113839031_XM_027434493.1          True
# p1@LOC113839047_XM_027434508.1          True
# p1@LOC113839066_XM_027434527.1          True
# p1@LOC113839076_XM_027434536.1          True
# p1@LOC113839076_XM_027434535.1          True
# p1@LOC113839111_XM_027434561.1          True
# p2@LOC113839111_XM_027434561.1          True
# p1@LOC113839113_XM_027434564.1          True
#
# [30775 rows x 8 columns]

# %%
anno_peaks = pd.read_csv('Results/Figures/Figure3/Distance_to_Anno/ii.tsv',sep='\t',index_col=0)
#anno_peaks = anno_peaks[np.abs(anno_peaks['Distance to TSS'])< 1000]

sns.distplot(anno_peaks[anno_peaks['isSameStrand']]['Distance to TSS'])

plt.ylabel('Frequency')
plt.xlabel('TSS Position relative to previous annotation')

helper_save("Results/Figures/Figure3/Distance_to_Anno/ii.png")
#plt.savefig("Results/Figures/Figure3/Distance_to_Anno/ii.png",bbox_inches='tight')

print("Mean: %s" % (np.mean(anno_peaks["Distance to TSS"])))
print("Std: %s" % (np.std(anno_peaks["Distance to TSS"])))
print("Mode: %s" % (stats.mode(anno_peaks["Distance to TSS"])[0][0]))

print("Number of TSSs in concordance with Reference", (anno_peaks["Distance to TSS"]==0).sum())
print("Number of TSSs less than 10nts from Reference", np.abs((anno_peaks["Distance to TSS"])<10).sum())
print("Total number of TSSs", len(anno_peaks))
print("Absolute Mean: %s" % (np.mean(np.abs(anno_peaks["Distance to TSS"]))))
print("Absolute Std: %s" % (np.std(np.abs(anno_peaks["Distance to TSS"]))))

# %%
curr = anno_peaks[np.abs(anno_peaks['Distance to TSS'])< 100]

sns.distplot(curr[curr["Strand"] == "-"]['Distance to TSS'])
print(stats.mode(curr[curr["Strand"] == "-"]['Distance to TSS']))
# Out:
# ModeResult(mode=array([ 27.]), count=array([95]))

# %%
curr = anno_peaks[np.abs(anno_peaks['Distance to TSS'])< 100]

sns.distplot(curr[curr["Strand"] == "+"]['Distance to TSS'])
print(stats.mode(curr[curr["Strand"] == "+"]['Distance to TSS']))
# Out:
# ModeResult(mode=array([ 16.]), count=array([98]))

# %% [markdown]
# # iii.
# ## With only peak1

# %%
import Homer

# %%
peaks_file = "Results/output/TSS1.exp.bed"
df = Homer.read_bed_file(peaks_file)
df = df[df.index.str.contains("p1@")]
out = "TSS1_only_peak1.exp.bed"
df["ID"] = df.index
df = df[["Chr", "Start","End","ID","Stat","Strand"]]
df.to_csv(out,sep="\t",header=None,index=None)


peaks_with_dist = annotation.wrap_distance_to_landmarks(out, landmark_file=tss_annotation,
                          main_landmark = 'transcript_id',landmark_cols=[],is_bed=True,
                          output_f='Results/Figures/Figure3/Distance_to_Anno/iii.tsv',is_parallel=True,num_par=12)
# Out:
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])
# /data/isshamie/TSS/Analysis/src/annotation.py:114: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   filt2 = np.abs(filt['actual_start'] - peak_start).argmin()
# /data/isshamie/TSS/Analysis/src/annotation.py:124: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', peak_start - landmark_df.loc[filt2, 'actual_start'])
# /data/isshamie/TSS/Analysis/src/annotation.py:115: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Nearest TSS', landmark_df.loc[filt2, main_landmark])
# /data/isshamie/TSS/Analysis/src/annotation.py:126: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'Distance to TSS', landmark_df.loc[filt2, 'actual_start'] - peak_start)
# /data/isshamie/TSS/Analysis/src/annotation.py:127: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   anno_peaks.set_value(ind, 'isSameStrand', val['Strand'] == landmark_df.loc[filt2, 'Strand'])

# %%
anno_peaks = pd.read_csv('Results/Figures/Figure3/Distance_to_Anno/iii.tsv',sep='\t',index_col=0)
anno_peaks = anno_peaks[(~(anno_peaks['Distance to TSS']==np.infty))]
anno_peaks = anno_peaks[np.abs(anno_peaks['Distance to TSS'])< 1000]

sns.distplot(anno_peaks[anno_peaks['isSameStrand']]['Distance to TSS'])

plt.ylabel('Frequency')
plt.xlabel('TSS Position relative to previous annotation')

helper_save("Results/Figures/Figure3/Distance_to_Anno/iii.png")
#plt.savefig("Results/Figures/Figure3/Distance_to_Anno/iii.png",bbox_inches='tight')

print("Mean: %s" % (np.mean(anno_peaks["Distance to TSS"])))
print("Std: %s" % (np.std(anno_peaks["Distance to TSS"])))

print("Absolute Mean: %s" % (np.mean(np.abs(anno_peaks["Distance to TSS"]))))
print("Absolute Std: %s" % (np.std(np.abs(anno_peaks["Distance to TSS"]))))
# Out:
# Mean: -35.1474884737
# Std: 297.891757667
# Absolute Mean: 180.158699345
# Absolute Std: 239.828455947

# %% [markdown]
# # iv. Remove genes that are back-to-back with another gene
