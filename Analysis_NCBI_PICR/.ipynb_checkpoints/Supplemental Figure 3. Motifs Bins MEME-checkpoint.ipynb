# %% [markdown]
# # 1. Environment Setup

# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])
ref_fa = doc['ref_fa']
anno_gff=doc['annotation']
mRNA_peak_file = doc["mRNA_peak_file"]
mRNA_peak_150_file = doc["mRNA_peak_150_file"]
supplemental = doc["supplemental"]
tss_annotation = doc['tss_annotation']

import os
os.chdir
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm
import time

from os.path import basename
##mpl.use('Agg')
#mpl.style.use('ggplot')
#mpl.style.use('fivethirtyeight')
from Homer import *

print('Number of tissues: ',len(tissues))
# Out:
# ('Number of tissues: ', 13)

# %%
from create_output import *

# %%
sys.path.append("/home/isshamie/software/homebrew/parallel_functions/")
import parallel_functions as pf

# %%
import motif_analysis

# %% [markdown]
# ## Create directory

# %%
out_dir = "Results/Figures/SuppFigure3/"
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

# %%
out_dir = "Results/Figures/SuppFigure3/fasta_files"
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ## Create fasta for CHO GRO

# %%
peak_f = "f04_peaks/CHO_GROCap1_and_CHO_GRO1"
seq_f = "Results/Figures/SuppFigure3/fasta_files/CHO_GROCap1_and_CHO_GRO1.fa" 
cmd = "homerTools extract {peak_f} {ref_fa} -fa > {seq_f}".format(peak_f=peak_f,seq_f=seq_f,ref_fa=ref_fa)
print cmd
# !{cmd}
# Out:
# homerTools extract f04_peaks/CHO_GROCap1_and_CHO_GRO1 /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -fa > Results/Figures/SuppFigure3/fasta_files/CHO_GROCap1_and_CHO_GRO1.fa
#
# 	Extracting sequences from file: /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna
# 	Looking for peak sequences in a single file (/data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna)
# 	Extracting 211 sequences from NW_020822366.1
# 	Extracting 1094 sequences from NW_020822370.1
# 	Extracting 242 sequences from NW_020822372.1
# 	Extracting 153 sequences from NW_020822373.1
# 	Extracting 83 sequences from NW_020822374.1
# 	Extracting 862 sequences from NW_020822375.1
# 	Extracting 183 sequences from NW_020822376.1
# 	Extracting 166 sequences from NW_020822377.1
# 	Extracting 209 sequences from NW_020822379.1
# 	Extracting 332 sequences from NW_020822381.1
# 	Extracting 85 sequences from NW_020822382.1
# 	Extracting 63 sequences from NW_020822385.1
# 	Extracting 2 sequences from NW_020824157.1
# 	Extracting 1 sequences from NW_020824181.1

# %% [markdown]
# ## 3. Motif Generation
#
# ### Using FIMO

# %% [markdown]
# ## First do the TSSs used in the final output

# %% [markdown]
# ### Experimental

# %%
t = time.time()
seq_f = os.path.join("Results/Figures/SuppFigure3/TSS1.exp.fa")
meme_motifs_dir = '/data/isshamie/TSS/Analysis/supplemental/homer_motifs/MEME_motifs.txt'
out_dir = "Results/Figures/SuppFigure3/TSS1.exp_meme"
cmd = "fimo --o {out_dir} {motif_f} {seq_f} ".format(motif_f=meme_motifs_dir,seq_f=seq_f,out_dir=out_dir)
print(cmd)
# !{cmd}
print(t - time.time())
# Out:
# fimo --o Results/Figures/SuppFigure3/TSS1.exp_meme /data/isshamie/TSS/Analysis/supplemental/homer_motifs/MEME_motifs.txt Results/Figures/SuppFigure3/TSS1.exp.fa
# Using motif +ap1.motif of width 10.
# Using motif -ap1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +ap2.motif of width 12.
# Using motif -ap2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.724037
# Using motif +ap2gamma.motif of width 12.
# Using motif -ap2gamma.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.710693
# Using motif +ap4.motif of width 10.
# Using motif -ap4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.913621
# Using motif +ar-half.motif of width 10.
# Using motif -ar-half.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.907238
# Using motif +are-fox.motif of width 20.
# Using motif -are-fox.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +are.motif of width 16.
# Using motif -are.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.98191
# Using motif +arnt.motif of width 10.
# Using motif -arnt.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.898095
# Using motif +ascl1.motif of width 12.
# Using motif -ascl1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.851858
# Using motif +atf1.motif of width 10.
# Using motif -atf1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +atf2.motif of width 12.
# Using motif -atf2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.975556
# Using motif +atf3.motif of width 12.
# Using motif -atf3.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +atf4.motif of width 10.
# Using motif -atf4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +atf7.motif of width 12.
# Using motif -atf7.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.93982
# Using motif +atoh1.motif of width 12.
# Using motif -atoh1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.864779
# Using motif +bach1.motif of width 15.
# Using motif -bach1.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +bach2.motif of width 10.
# Using motif -bach2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.987975
# Using motif +bapx1.motif of width 10.
# Using motif -bapx1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +barx1.motif of width 10.
# Using motif -barx1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +batf.motif of width 10.
# Using motif -batf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +batf3-irf8.motif of width 15.
# Using motif -batf3-irf8.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +bcl6.motif of width 15.
# Using motif -bcl6.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.997487
# Using motif +bhlhe40.motif of width 10.
# Using motif -bhlhe40.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.897333
# Using motif +bmal.motif of width 8.
# Using motif -bmal.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.89
# Using motif +bmyb.motif of width 10.
# Using motif -bmyb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999899
# Using motif +boris.motif of width 20.
# Using motif -boris.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.663178
# Using motif +brachyury.motif of width 21.
# Using motif -brachyury.motif of width 21.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.940696
# Using motif +brn1.motif of width 12.
# Using motif -brn1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +brn2.motif of width 10.
# Using motif -brn2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +bzip-irf.motif of width 18.
# Using motif -bzip-irf.motif of width 18.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cdx2.motif of width 10.
# Using motif -cdx2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cdx4.motif of width 12.
# Using motif -cdx4.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cebp-ap1.motif of width 10.
# Using motif -cebp-ap1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cebp-cebp.motif of width 20.
# Using motif -cebp-cebp.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +cebp.motif of width 10.
# Using motif -cebp.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +chop.motif of width 10.
# Using motif -chop.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +chr.motif of width 10.
# Using motif -chr.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +clock.motif of width 8.
# Using motif -clock.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.874128
# Using motif +cMyc.lncap.motif of width 8.
# Using motif -cMyc.lncap.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7894
# Using motif +cmyc.motif of width 10.
# Using motif -cmyc.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.796346
# Using motif +couptf1.motif of width 12.
# Using motif -couptf1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.905042
# Using motif +couptf2.motif of width 8.
# Using motif -couptf2.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.887037
# Using motif +cre.motif of width 12.
# Using motif -cre.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.739216
# Using motif +crx.motif of width 8.
# Using motif -crx.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +ctcf-mys.motif of width 20.
# Using motif -ctcf-mys.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.979773
# Using motif +ctcf.motif of width 20.
# Using motif -ctcf.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.786038
# Using motif +cux2.motif of width 10.
# Using motif -cux2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +dmc1.motif of width 20.
# Using motif -dmc1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998794
# Using motif +dmrt1.motif of width 15.
# Using motif -dmrt1.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +dmrt6.motif of width 15.
# Using motif -dmrt6.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +dr0.motif of width 12.
# Using motif -dr0.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.910756
# Using motif +dr5.motif of width 18.
# Using motif -dr5.motif of width 18.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.854609
# Using motif +dux4.motif of width 15.
# Using motif -dux4.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +e2a.motif of width 10.
# Using motif -e2a.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.772477
# Using motif +e2f.motif of width 12.
# Using motif -e2f.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.669903
# Using motif +e2f1.motif of width 10.
# Using motif -e2f1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7538
# Using motif +e2f3.motif of width 12.
# Using motif -e2f3.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7144
# Using motif +e2f4.motif of width 10.
# Using motif -e2f4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.696667
# Using motif +e2f6.motif of width 10.
# Using motif -e2f6.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.731456
# Using motif +e2f7.motif of width 12.
# Using motif -e2f7.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.735619
# Using motif +e47.motif of width 10.
# Using motif -e47.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.809
# Using motif +ebf-old.motif of width 12.
# Using motif -ebf-old.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.861417
# Using motif +ebf.motif of width 12.
# Using motif -ebf.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.813091
# Using motif +ebna1.motif of width 20.
# Using motif -ebna1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.903459
# Using motif +ebox.motif of width 12.
# Using motif -ebox.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.765385
# Using motif +egr1.motif of width 10.
# Using motif -egr1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.83254
# Using motif +egr2.motif of width 12.
# Using motif -egr2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.802075
# Using motif +ehf.motif of width 10.
# Using motif -ehf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.99171
# Using motif +eklf.motif of width 12.
# Using motif -eklf.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.862364
# Using motif +elf1.motif of width 10.
# Using motif -elf1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.86713
# Using motif +elf3.motif of width 10.
# Using motif -elf3.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.996548
# Using motif +elf5.motif of width 10.
# Using motif -elf5.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.965203
# Using motif +elk1.motif of width 10.
# Using motif -elk1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.862157
# Using motif +elk4.motif of width 10.
# Using motif -elk4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.942615
# Using motif +eomes.motif of width 10.
# Using motif -eomes.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +ere.motif of width 15.
# Using motif -ere.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.92336
# Using motif +erg.motif of width 10.
# Using motif -erg.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.955362
# Using motif +erra.motif of width 10.
# Using motif -erra.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.861333
# Using motif +es.motif of width 12.
# Using motif -es.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.903649
# Using motif +esrrb.motif of width 10.
# Using motif -esrrb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.903333
# Using motif +ets-distal.motif of width 10.
# Using motif -ets-distal.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.995736
# Using motif +ets-ebox.motif of width 12.
# Using motif -ets-ebox.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.975249
# Using motif +ets-runx.motif of width 12.
# Using motif -ets-runx.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.903652
# Using motif +ets.motif of width 10.
# Using motif -ets.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.867965
# Using motif +ets1.motif of width 10.
# Using motif -ets1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.948923
# Using motif +etv1.motif of width 10.
# Using motif -etv1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.913704
# Using motif +etv2.motif of width 12.
# Using motif -etv2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.944179
# Using motif +etv4.motif of width 10.
# Using motif -etv4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.8292
# Using motif +ews-erg.motif of width 10.
# Using motif -ews-erg.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +ews-fli1.motif of width 10.
# Using motif -ews-fli1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.991538
# Using motif +fli.motif of width 10.
# Using motif -fli.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.915504
# Using motif +fosl2.motif of width 12.
# Using motif -fosl2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +fox-ebox.motif of width 17.
# Using motif -fox-ebox.motif of width 17.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxa1.lncap.motif of width 10.
# Using motif -foxa1.lncap.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxa1.mcf7.motif of width 10.
# Using motif -foxa1.mcf7.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxa2.motif of width 12.
# Using motif -foxa2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxa3.motif of width 15.
# Using motif -foxa3.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxf1.motif of width 12.
# Using motif -foxf1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxh1.motif of width 12.
# Using motif -foxh1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxk1.motif of width 10.
# Using motif -foxk1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxk2.motif of width 12.
# Using motif -foxk2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxl2.motif of width 12.
# Using motif -foxl2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxm1.motif of width 10.
# Using motif -foxm1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxo1.motif of width 8.
# Using motif -foxo1.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxo3.motif of width 8.
# Using motif -foxo3.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +foxp1.motif of width 12.
# Using motif -foxp1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +fra1.motif of width 12.
# Using motif -fra1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +fra2.motif of width 12.
# Using motif -fra2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +fxr.motif of width 14.
# Using motif -fxr.motif of width 14.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.837477
# Using motif +gabp.motif of width 10.
# Using motif -gabp.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.856481
# Using motif +gata-scl.motif of width 20.
# Using motif -gata-scl.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.932897
# Using motif +gata.motif of width 10.
# Using motif -gata.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata2.motif of width 10.
# Using motif -gata2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.dr4.motif of width 15.
# Using motif -gata3.dr4.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.dr8.motif of width 20.
# Using motif -gata3.dr8.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.ir3.motif of width 20.
# Using motif -gata3.ir3.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.ir4.motif of width 15.
# Using motif -gata3.ir4.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata3.motif of width 8.
# Using motif -gata3.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata4.motif of width 10.
# Using motif -gata4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gata6.motif of width 10.
# Using motif -gata6.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gfi1b.motif of width 10.
# Using motif -gfi1b.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gfx.motif of width 12.
# Using motif -gfx.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.859619
# Using motif +gfy-staf.motif of width 20.
# Using motif -gfy-staf.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.97913
# Using motif +gfy.motif of width 12.
# Using motif -gfy.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.917612
# Using motif +gli.motif of width 12.
# Using motif -gli.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.788039
# Using motif +gre-raw.motif of width 15.
# Using motif -gre-raw.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gre.motif of width 16.
# Using motif -gre.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.961699
# Using motif +grhl2.motif of width 20.
# Using motif -grhl2.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +gsc.motif of width 8.
# Using motif -gsc.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hand2.motif of width 15.
# Using motif -hand2.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.950563
# Using motif +heb.motif of width 10.
# Using motif -heb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.7146
# Using motif +hif1a.motif of width 8.
# Using motif -hif1a.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.852308
# Using motif +hif1b.motif of width 8.
# Using motif -hif1b.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.945641
# Using motif +hif2a.motif of width 10.
# Using motif -hif2a.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.881154
# Using motif +hinfp.motif of width 10.
# Using motif -hinfp.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.689109
# Using motif +hlf.motif of width 10.
# Using motif -hlf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hnf1.motif of width 13.
# Using motif -hnf1.motif of width 13.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hnf1b.motif of width 12.
# Using motif -hnf1b.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hnf4.motif of width 16.
# Using motif -hnf4.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.983911
# Using motif +hnf6.motif of width 10.
# Using motif -hnf6.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa10.motif of width 10.
# Using motif -hoxa10.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa11.motif of width 10.
# Using motif -hoxa11.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa13.motif of width 10.
# Using motif -hoxa13.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa2.motif of width 12.
# Using motif -hoxa2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxa9.motif of width 10.
# Using motif -hoxa9.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxb13.motif of width 10.
# Using motif -hoxb13.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxb4.motif of width 12.
# Using motif -hoxb4.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxc9.motif of width 12.
# Using motif -hoxc9.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxd10.motif of width 10.
# Using motif -hoxd10.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxd11.motif of width 10.
# Using motif -hoxd11.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxd12.motif of width 12.
# Using motif -hoxd12.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hoxd13.motif of width 10.
# Using motif -hoxd13.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +hsf.motif of width 15.
# Using motif -hsf.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999799
# Using motif +hsf1.motif of width 20.
# Using motif -hsf1.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.841165
# Using motif +inr.motif of width 8.
# Using motif -inr.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.956608
# Using motif +irf1.motif of width 12.
# Using motif -irf1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998291
# Using motif +irf2.motif of width 12.
# Using motif -irf2.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.922545
# Using motif +irf3.motif of width 12.
# Using motif -irf3.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998593
# Using motif +irf4.motif of width 10.
# Using motif -irf4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +irf8.motif of width 12.
# Using motif -irf8.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998291
# Using motif +isl1.motif of width 8.
# Using motif -isl1.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +isre.motif of width 12.
# Using motif -isre.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.999397
# Using motif +jun-ap1.motif of width 12.
# Using motif -jun-ap1.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +jun-cre.motif of width 12.
# Using motif -jun-cre.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.981667
# Using motif +junb.motif of width 10.
# Using motif -junb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +jund.motif of width 12.
# Using motif -jund.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +klf10.motif of width 12.
# Using motif -klf10.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.830517
# Using motif +klf14.motif of width 12.
# Using motif -klf14.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.791532
# Using motif +klf3.motif of width 15.
# Using motif -klf3.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.778667
# Using motif +klf4.motif of width 10.
# Using motif -klf4.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.808713
# Using motif +klf5.motif of width 10.
# Using motif -klf5.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.826964
# Using motif +klf6.motif of width 12.
# Using motif -klf6.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.771852
# Using motif +klf9.motif of width 12.
# Using motif -klf9.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.780556
# Using motif +lef1.motif of width 10.
# Using motif -lef1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +lhx1.motif of width 10.
# Using motif -lhx1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +lhx2.motif of width 8.
# Using motif -lhx2.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +lhx3.motif of width 10.
# Using motif -lhx3.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +limb.motif of width 10.
# Using motif -limb.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +lrf.motif of width 10.
# Using motif -lrf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.756814
# Using motif +lrh1.motif of width 10.
# Using motif -lrh1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.950069
# Using motif +lxre.motif of width 16.
# Using motif -lxre.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.985625
# Using motif +mafa.motif of width 10.
# Using motif -mafa.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.931095
# Using motif +mafb.motif of width 20.
# Using motif -mafb.motif of width 20.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.998995
# Using motif +mafF.motif of width 15.
# Using motif -mafF.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mafk.motif of width 12.
# Using motif -mafk.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.981739
# Using motif +max.motif of width 12.
# Using motif -max.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.891071
# Using motif +maz.motif of width 8.
# Using motif -maz.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.723571
# Using motif +mef2a.motif of width 10.
# Using motif -mef2a.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mef2b.motif of width 12.
# Using motif -mef2b.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mef2c.motif of width 12.
# Using motif -mef2c.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +mef2d.motif of width 12.
# Using motif -mef2d.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +meis1.motif of width 10.
# Using motif -meis1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.884182
# Using motif +mitf.motif of width 10.
# Using motif -mitf.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.879048
# Using motif +mnt.motif of width 10.
# Using motif -mnt.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.892475
# Using motif +myb.motif of width 8.
# Using motif -myb.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.913
# Using motif +myba.motif of width 10.
# Using motif -myba.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.96438
# Using motif +myf5.motif of width 10.
# Using motif -myf5.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.883697
# Using motif +mynn.motif of width 15.
# Using motif -mynn.motif of width 15.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +myod.motif of width 12.
# Using motif -myod.motif of width 12.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.875252
# Using motif +myog.motif of width 8.
# Using motif -myog.motif of width 8.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.877431
# Using motif +nanog.motif of width 10.
# Using motif -nanog.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +neurod1.motif of width 10.
# Using motif -neurod1.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.891724
# Using motif +neurog2.motif of width 10.
# Using motif -neurog2.motif of width 10.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=0.93875
# Using motif +nf1-fox.motif of width 16.
# Using motif -nf1-fox.motif of width 16.
# Computing q-values.
# Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# Estimating pi_0.
# Estimated pi_0=1
# Using motif +nf1-half.motif of width 8.
# Using motif -nf1-half.motif of width 8.

# %% [markdown]
# ### Refseq

# %%
t = time.time()
seq_f = os.path.join("Results/Figures/SuppFigure3/TSS1.exp_refseq_centered.fa")
meme_motifs_dir = '/data/isshamie/TSS/Analysis/supplemental/homer_motifs/MEME_motifs.txt'
out_dir = "Results/Figures/SuppFigure3/TSS1.exp_refseq_centered_meme"
#f_save = 'Results/Figures/SuppFigure3/TSS1.exp_refseq_centered_instance_meme'
cmd = "fimo --o {out_dir} {motif_f} {seq_f} ".format(motif_f=meme_motifs_f,seq_f=seq_f,out_dir=out_dir)
print(cmd)
# !{cmd}
print(time.time()-t)

# %% [markdown]
# ## All peak files

# %%
for peak_f in glob.glob("f04_peaks/*"):
    seq_f = "Results/Figures/SuppFigure3/fasta_files/{sample}.fa".format(sample=os.path.basename(peak_f))
    cmd = "homerTools extract {peak_f} {ref_fa} -fa > {seq_f}".format(peak_f=peak_f,seq_f=seq_f,ref_fa=ref_fa)
    # !{cmd}
    print(cmd)
    meme_motifs_dir = '/data/isshamie/TSS/Analysis/supplemental/homer_motifs/MEME_motifs.txt'
    out_dir = "Results/Figures/SuppFigure3/" + os.path.basename(peak_f)
    #f_save = 'Results/Figures/SuppFigure3/TSS1.exp_refseq_centered_instance_meme'
    cmd = "fimo --o {out_dir} {motif_f} {seq_f} ".format(motif_f=meme_motifs_f,seq_f=seq_f,out_dir=out_dir)
    # !{cmd}
    print(cmd)

# %% [markdown]
# # 4. Plotting

# %%
from motif_analysis import *

# %%
motifs_df = pd.read_csv("Results/Figures/SuppFigure3/CHO_motifs/fimo.tsv",sep="\t",comment="#")
motifs_df
# Out:
#         motif_id  motif_alt_id        sequence_name  start  stop strand  \
# 0      sp1.motif           NaN    NW_020822393.1-84      1    12      +
# 1      sp1.motif           NaN   NW_020822611.1-676      1    12      +
# 2      sp1.motif           NaN   NW_020822438.1-976      2    13      +
# 3      sp1.motif           NaN   NW_020822657.1-161      3    14      +
# 4      sp1.motif           NaN    NW_020822503.1-65      4    15      +
# 5      sp1.motif           NaN   NW_020822452.1-515      4    15      +
# 6      sp1.motif           NaN    NW_020822531.1-12      5    16      +
# 7      sp1.motif           NaN   NW_020822487.1-318      5    16      +
# 8      sp1.motif           NaN   NW_020822468.1-367      6    17      +
# 9      sp1.motif           NaN   NW_020822507.1-209      6    17      +
# 10     sp1.motif           NaN   NW_020822658.1-818      6    17      +
# 11     sp1.motif           NaN   NW_020822474.1-116      7    18      +
# 12     sp1.motif           NaN   NW_020822468.1-198      7    18      +
# 13     sp1.motif           NaN   NW_020822567.1-648      7    18      +
# 14     sp1.motif           NaN    NW_020822531.1-96      8    19      +
# 15     sp1.motif           NaN     NW_020822393.1-8      8    19      +
# 16     sp1.motif           NaN    NW_020822398.1-66      9    20      +
# 17     sp1.motif           NaN   NW_020822616.1-181      9    20      +
# 18     sp1.motif           NaN   NW_020822643.1-110      9    20      +
# 19     sp1.motif           NaN    NW_020822611.1-20     11    22      +
# 20     sp1.motif           NaN    NW_020822465.1-19     11    22      +
# 21     sp1.motif           NaN   NW_020822423.1-420      1    12      -
# 22     sp1.motif           NaN    NW_020822632.1-26     12    23      +
# 23     sp1.motif           NaN    NW_020822638.1-83      1    12      -
# 24     sp1.motif           NaN    NW_020822503.1-76      2    13      -
# 25     sp1.motif           NaN    NW_020822629.1-16      2    13      -
# 26     sp1.motif           NaN   NW_020822470.1-411     13    24      +
# 27     sp1.motif           NaN    NW_020822366.1-44     13    24      +
# 28     sp1.motif           NaN   NW_020822439.1-519     13    24      +
# 29     sp1.motif           NaN    NW_020822643.1-49     14    25      +
# ...          ...           ...                  ...    ...   ...    ...
# 42570  sp1.motif           NaN   NW_020822539.1-126     59    70      -
# 42571  sp1.motif           NaN     NW_020822483.1-9     61    72      -
# 42572  sp1.motif           NaN    NW_020822458.1-62     61    72      -
# 42573  sp1.motif           NaN   NW_020822420.1-392     62    73      -
# 42574  sp1.motif           NaN  NW_020822505.1-1905     63    74      -
# 42575  sp1.motif           NaN  NW_020822375.1-1017     66    77      -
# 42576  sp1.motif           NaN   NW_020822567.1-242     66    77      -
# 42577  sp1.motif           NaN   NW_020822458.1-357     70    81      -
# 42578  sp1.motif           NaN   NW_020822538.1-396     85    96      +
# 42579  sp1.motif           NaN   NW_020822499.1-398     87    98      +
# 23     21.60610  1.720000e-08  0.000847     GGCCCCGCCCCC
# 24     21.60610  1.720000e-08  0.000847     GGCCCCGCCCCC
# 25     21.60610  1.720000e-08  0.000847     GGCCCCGCCCCC
# 26     21.60610  1.720000e-08  0.000847     GGCCCCGCCCCC
# 27     21.60610  1.720000e-08  0.000847     GGCCCCGCCCCC
# 28     21.60610  1.720000e-08  0.000847     GGCCCCGCCCCC
# 29     21.60610  1.720000e-08  0.000847     GGCCCCGCCCCC
# ...         ...           ...       ...              ...
# 42570   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42571   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42572   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42573   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42574   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42575   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42576   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42577   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42578   9.59394  9.990000e-05  0.047200     GGTCTCGCCTCC
# 42579   9.59394  9.990000e-05  0.047200     GGTCTCGCCTCC
# 42580   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42581   9.59394  9.990000e-05  0.047200     GGTCTCGCCTCC
# 42582   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42583   9.59394  9.990000e-05  0.047200     GGCCCCTCCGCT
# 42584   9.59394  9.990000e-05  0.047200     GTTCCCGCCTCC
# 42585   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42586   9.59394  9.990000e-05  0.047200     GGCCCCTCCGCT
# 42587   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42588   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42589   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42590   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42591   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42592   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42593   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42594   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42595   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42596   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42597   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
# 42598   9.59394  9.990000e-05  0.047200     GGCCCCTCCGCT
# 42599   9.59394  9.990000e-05  0.047200     CTCCCCTCCCCC
#
# [42600 rows x 10 columns]

# %%
inr = motifs_df[motifs_df["motif_id"] == "inr.motif"]
# Out:
#         motif_id  motif_alt_id        sequence_name  start  stop strand  \
# 13330  inr.motif           NaN   NW_020822468.1-412      1     8      +
# 13331  inr.motif           NaN   NW_020822570.1-262      1     8      +
# 39932  inr.motif           NaN     NW_020823524.1-2    140   147      -
# 39933  inr.motif           NaN   NW_020822370.1-286    140   147      -
# 39934  inr.motif           NaN   NW_020822415.1-386    140   147      -
# 39935  inr.motif           NaN  NW_020822570.1-1203    141   148      -
# 39936  inr.motif           NaN   NW_020822406.1-900    141   148      -
# 39937  inr.motif           NaN  NW_020822439.1-2217    141   148      -
# 39938  inr.motif           NaN   NW_020822406.1-827    142   149      -
# 39939  inr.motif           NaN   NW_020822533.1-429    142   149      -
# 39940  inr.motif           NaN     NW_020822668.1-8    142   149      -
# 39941  inr.motif           NaN  NW_020822519.1-1037    143   150      -
# 39942  inr.motif           NaN  NW_020822439.1-2612    144   151      -
# 39943  inr.motif           NaN   NW_020822425.1-175    144   151      -
#
#          score   p-value  q-value matched_sequence
# 13330  7.20000  0.000012    0.337         TCAGTCCC
# 13331  7.20000  0.000012    0.337         TCAGTCCC
# 13332  7.20000  0.000012    0.337         TCAGTCCC
# 13333  7.20000  0.000012    0.337         TCAGTCCC
# 13334  7.20000  0.000012    0.337         TCAGTCCC
# 13335  7.20000  0.000012    0.337         TCAGTCCC
# 13336  7.20000  0.000012    0.337         TCAGTCCC
# 13337  7.20000  0.000012    0.337         TCAGTCCC
# 13338  7.20000  0.000012    0.337         TCAGTCCC
# 13339  7.20000  0.000012    0.337         TCAGTCCC
# 13340  7.20000  0.000012    0.337         TCAGTCCC
# 13341  7.20000  0.000012    0.337         TCAGTCCC
# 13342  7.20000  0.000012    0.337         TCAGTCCC
# 13343  7.20000  0.000012    0.337         TCAGTCCC
# 13344  7.20000  0.000012    0.337         TCAGTCCC
# 13345  7.20000  0.000012    0.337         TCAGTCCC
# 13346  7.20000  0.000012    0.337         TCAGTCCC
# 13347  7.20000  0.000012    0.337         TCAGTCCC
# 13348  7.20000  0.000012    0.337         TCAGTCCC
# 13349  7.20000  0.000012    0.337         TCAGTCCC
# 13350  7.20000  0.000012    0.337         TCAGTCCC
# 13351  7.20000  0.000012    0.337         TCAGTCCC
# 13352  7.20000  0.000012    0.337         TCAGTCCC
# 13353  7.20000  0.000012    0.337         TCAGTCCC
# 13354  7.20000  0.000012    0.337         TCAGTCCC
# 13355  7.20000  0.000012    0.337         TCAGTCCC
# 13356  7.20000  0.000012    0.337         TCAGTCCC
# 13357  7.20000  0.000012    0.337         TCAGTCCC
# 13358  7.20000  0.000012    0.337         TCAGTCCC
# 13359  7.20000  0.000012    0.337         TCAGTCCC
# ...        ...       ...      ...              ...
# 39914  6.95152  0.000093    0.405         TCAGTCTT
# 39915  6.95152  0.000093    0.405         TCAGTCTT
# 39916  6.95152  0.000093    0.405         TCAGTCTT
# 39917  6.95152  0.000093    0.405         TCAGTCTT
# 39918  6.95152  0.000093    0.405         TCAGTCTT
# 39919  6.95152  0.000093    0.405         TCAGTCTT
# 39920  6.95152  0.000093    0.405         TCAGTCTT
# 39921  6.95152  0.000093    0.405         TCAGTCTT
# 39922  6.95152  0.000093    0.405         TCAGTCTT
# 39923  6.95152  0.000093    0.405         TCAGTCTT
# 39924  6.95152  0.000093    0.405         TCAGTCTT
# 39925  6.95152  0.000093    0.405         TCAGTCTT
# 39926  6.95152  0.000093    0.405         TCAGTCTT
# 39927  6.95152  0.000093    0.405         TCAGTCTT
# 39928  6.95152  0.000093    0.405         TCAGTCTT
# 39929  6.95152  0.000093    0.405         TCAGTCTT
# 39930  6.95152  0.000093    0.405         TCAGTCTT
# 39931  6.95152  0.000093    0.405         TCAGTCTT
# 39932  6.95152  0.000093    0.405         TCAGTCTT
# 39933  6.95152  0.000093    0.405         TCAGTCTT
# 39934  6.95152  0.000093    0.405         TCAGTCTT
# 39935  6.95152  0.000093    0.405         TCAGTCTT
# 39936  6.95152  0.000093    0.405         TCAGTCTT
# 39937  6.95152  0.000093    0.405         TCAGTCTT
# 39938  6.95152  0.000093    0.405         TCAGTCTT
# 39939  6.95152  0.000093    0.405         TCAGTCTT
# 39940  6.95152  0.000093    0.405         TCAGTCTT
# 39941  6.95152  0.000093    0.405         TCAGTCTT
# 39942  6.95152  0.000093    0.405         TCAGTCTT
# 39943  6.95152  0.000093    0.405         TCAGTCTT
#
# [4686 rows x 10 columns]

# %%
for motif,curr in motifs_df.groupby("motif_id"):
    peaks_df = read_peak_file(peak_f)

    num_nts = np.max(curr["stop"])#np.max(curr["stop"] - (curr["start"])+1)

    curr_out_pos = motif_analysis.initialize_motif_df(peaks_df.index,seq_len=num_nts)
    curr_out_neg = motif_analysis.initialize_motif_df(peaks_df.index,seq_len=num_nts)
    first_seq = curr_out.columns.values[0]


    for ind,val in tqdm.tqdm_notebook(curr.iterrows()):
        if val["strand"] == "+":
            curr_out_pos.at[val["sequence_name"],first_seq + val["start"] - 1] = True
        else:
            curr_out_neg.at[val["sequence_name"],first_seq + val["start"] - 1] = True
    curr_out_pos
    #curr_out = pd.DataFrame(index= peaks_df.index,columns=np.arange(-num_nts/2,num_nts/2),dtype=bool)

# %% [markdown]
# ### Create sequence-by-|basepairs| matrix , fill in with the start of the motif where present.
# fimo output is 1-based indexing

# %%
peaks_df = read_peak_file("f04_peaks/CHO_GROCap1_and_CHO_GRO1")

num_nts = np.max(inr["stop"])#np.max(inr["stop"] - (inr["start"])+1)

inr_out_pos = motif_analysis.initialize_motif_df(peaks_df.index,seq_len=num_nts)
inr_out_neg = motif_analysis.initialize_motif_df(peaks_df.index,seq_len=num_nts)
first_seq = inr_out.columns.values[0]


for ind,val in tqdm.tqdm_notebook(inr.iterrows()):
    if val["strand"] == "+":
        inr_out_pos.at[val["sequence_name"],first_seq + val["start"] - 1] = True
    else:
        inr_out_neg.at[val["sequence_name"],first_seq + val["start"] - 1] = True
inr_out_pos
#inr_out = pd.DataFrame(index= peaks_df.index,columns=np.arange(-num_nts/2,num_nts/2),dtype=bool)

# %%
motif_analysis.plot_count([inr_out_pos, inr_out_neg], "Initiator CHO GROCap peaks", out_dir="")
