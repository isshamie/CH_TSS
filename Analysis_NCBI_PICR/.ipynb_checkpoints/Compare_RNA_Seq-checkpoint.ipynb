# %% [markdown]
# ## Compare results from TSS to RNA-seq results

# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])
ref_fa = doc['ref_fa']
anno_gff=doc['annotation']


tss_annotation = doc['tss_annotation']


import os
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm

from os.path import basename
##mpl.use('Agg')
#mpl.style.use('ggplot')
#mpl.style.use('fivethirtyeight')
from Homer import *

print('Number of tissues: ',len(tissues))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ('Number of tissues: ', 15)

# %%
outdir = "RNAseq_Compare"

# %% [markdown]
# ## Load
# ### 1. CHO rna matrix
# ### 2. TSS DataFrame
# ### 3. CHO filtered peak file

# %% [markdown]
# ### 1.

# %%
cho_rna_file = doc["cho_rna_file"]
cho_rna = pd.read_csv(cho_rna_file,sep="\t",index_col=0)
cho_rna = cho_rna.iloc[:,1:]
cho_rna = np.log10(cho_rna+1)
cho_rna
# Out:
#                          1         2         3         4         5         6  \
# gid
# gene_10           1.206581  1.190397  1.266534  1.299687  1.250293  1.241380
# gene_100          0.095228  0.109453  0.048500  0.111266  0.114090  0.070754
# gene_10000_1      0.428575  0.401795  0.524840  0.444983  0.526040  0.476838
# gene_10000_10     0.000000  0.000000  0.208872  0.250192  0.079810  0.000000
# gene_10000_11     0.540125  0.554644  0.441339  0.523375  0.592315  0.641386
# gene_10000_12     1.677752  1.671340  1.714967  1.775541  1.746701  1.733816
# gene_10000_2      0.200030  0.181347  0.215802  0.243011  0.269654  0.268938
# gene_10000_3      0.071477  0.029705  0.082297  0.068219  0.202137  0.074280
# gene_10000_4      0.040378  0.055501  0.046175  0.028485  0.065582  0.016580
# gene_10000_5      0.000000  0.051350  0.087116  0.055830  0.123715  0.205456
# gene_10000_6      0.001883  0.022362  0.000003  0.012562  0.010695  0.010791
# gene_10000_7      0.215060  0.143860  0.000000  0.000000  0.000000  0.000000
# gene_10000_8      0.007543  0.000000  0.044100  0.000000  0.021458  0.010828
# gene_10000_9      0.376098  0.364988  0.237205  0.503114  0.472587  0.449879
# gene_10001_1      0.653466  0.574171  0.638531  0.725039  0.705156  0.675321
# gene_10001_2      0.350295  0.256903  0.281022  0.255020  0.289375  0.287709
# gene_10001_3      0.803377  0.816067  0.730715  0.735520  0.908902  0.961292
# gene_10002_1      0.174080  0.170730  0.208431  0.138748  0.206587  0.265144
# gene_10002_2      0.099822  0.104724  0.139415  0.036834  0.084899  0.145667
# gene_10003        0.116806  0.000000  0.158665  0.096406  0.351060  0.275342
# gene_10004        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_10005        0.274713  0.294799  0.131362  0.160175  0.172109  0.169520
# gene_10006        1.555129  1.572211  1.537122  1.560894  1.632699  1.624196
# gene_10007_1      1.445185  1.439800  1.409026  1.447648  1.450007  1.422757
# gene_10007_2      0.841447  1.025242  0.709949  0.809717  0.859016  0.919171
# gene_10008_1      0.560777  0.687718  0.463766  0.559940  0.653282  0.633393
# gene_10008_2      0.547523  0.428562  0.519858  0.447167  0.106299  0.495732
# gene_10009        0.078828  0.058410  0.078274  0.043395  0.070817  0.101645
# gene_1000_1       1.724224  1.733920  1.764929  1.694119  1.652631  1.651344
# gene_1000_2       0.591841  0.507151  0.469121  0.375819  0.290219  0.322922
# ...                    ...       ...       ...       ...       ...       ...
# gene_asmbl_31305  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_32007  0.848535  0.820792  0.941206  0.983669  0.752166  0.675365
# gene_asmbl_32008  1.411277  1.397164  1.137178  0.811052  0.568147  0.523431
# gene_asmbl_32009  0.848514  0.820763  0.941152  0.983637  0.752148  0.675345
# gene_asmbl_32011  0.848506  0.820741  0.941104  0.983944  0.752140  0.675330
# gene_asmbl_37912  2.052677  2.082519  2.088659  2.074916  1.948511  1.949209
# gene_asmbl_39654  2.401319  2.409104  2.342583  2.364849  2.393081  2.389354
# gene_asmbl_39659  0.356369  0.043146  0.366307  0.000007  0.626170  1.133749
# gene_asmbl_39660  2.401305  2.409134  2.342571  2.364813  2.393088  2.389330
# gene_asmbl_40822  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_40823  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_48289  0.799521  0.783318  0.037505  0.798671  0.000000  0.000000
# gene_asmbl_48305  1.032970  1.103095  1.097461  1.057066  1.328869  1.353246
# gene_asmbl_60477  1.712856  1.712184  1.570252  1.564467  1.308694  1.332137
# gene_asmbl_65837  0.998562  0.982833  1.059871  1.077328  1.037672  1.073552
# gene_asmbl_65842  0.998620  0.982816  1.060002  1.077303  1.037650  1.073584
# gene_asmbl_65843  0.998585  0.982790  1.060023  1.077254  1.037647  1.073555
# gene_asmbl_65844  0.998560  0.982915  1.059976  1.077291  1.037614  1.073544
# gene_asmbl_65845  0.454364  0.000000  0.308066  0.000000  0.000000  0.000000
# gene_asmbl_65846  0.998544  0.982870  1.059912  1.077255  1.037560  1.073597
# gene_asmbl_65847  0.998591  0.982852  1.059878  1.077233  1.037592  1.073580
# gene_asmbl_65848  0.998617  0.982837  1.060006  1.077203  1.037707  1.073559
# gene_asmbl_65850  0.000050  0.000000  0.170939  0.000000  0.000000  0.000000
# gene_asmbl_65854  0.998608  0.982925  1.059977  1.077202  1.037710  1.073538
# gene_asmbl_68438  2.091235  2.103059  2.023950  2.023052  1.993933  2.134518
# gene_asmbl_81468  1.873364  1.690947  1.715005  1.847480  1.856667  2.004068
# gene_asmbl_81469  2.544658  2.506472  2.572638  2.563541  2.517807  2.578007
# gene_asmbl_83539  2.086368  2.099745  2.098504  2.156615  2.110697  2.123099
# gene_asmbl_83541  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_84694  1.608408  1.518812  1.513093  1.407568  1.217180  1.153341
#
#                          7         8         9        10    ...         1604  \
# gid                                                         ...
# gene_10           1.216064  1.228527  1.158073  1.248399    ...     1.210053
# gene_100          0.164908  0.189990  0.164238  0.199324    ...     0.000000
# gene_10000_1      0.334874  0.137845  0.206931  0.208200    ...     0.675063
# gene_10000_10     0.583274  0.000000  0.807168  0.525297    ...     0.000000
# gene_10000_11     0.711139  0.619822  0.713691  0.878432    ...     0.149086
# gene_10000_12     1.447307  1.477983  1.496814  1.513296    ...     1.723614
# gene_10000_2      0.253915  0.364867  0.371840  0.364880    ...     0.233700
# gene_10000_3      0.099487  0.066516  0.079761  0.075437    ...     0.111822
# gene_10000_4      0.043009  0.114510  0.099225  0.000000    ...     0.035970
# gene_10000_5      0.251770  0.298608  0.000000  0.121489    ...     0.109355
# gene_10000_6      0.058837  0.000000  0.000000  0.000000    ...     0.000000
# gene_10000_7      0.368204  0.403116  0.000000  0.000000    ...     0.133661
# gene_10000_8      0.000000  0.000000  0.000000  0.000000    ...     0.000000
# gene_10000_9      0.000000  0.564237  0.601019  0.547636    ...     0.000000
# gene_10001_1      0.889553  0.987232  0.914519  0.961136    ...     0.829812
# gene_10001_2      0.243185  0.141767  0.253710  0.115242    ...     0.553267
# gene_10001_3      0.633217  0.452760  0.763433  0.694203    ...     1.403932
# gene_10002_1      0.233215  0.381047  0.308195  0.283533    ...     0.033075
# gene_10002_2      0.000000  0.115312  0.158060  0.069796    ...     0.000000
# gene_10003        0.186008  0.000000  0.000000  0.315691    ...     0.273749
# gene_10004        0.000000  0.000000  0.000000  0.000000    ...     0.000000
# gene_10005        0.154110  0.150198  0.168630  0.135539    ...     0.020174
# gene_10006        1.427040  1.384091  1.440256  1.449124    ...     1.492310
# gene_10007_1      1.587093  1.619416  1.647266  1.607043    ...     1.189736
# gene_10007_2      0.961012  0.796205  0.000000  0.614013    ...     0.000000
# gene_10008_1      0.283208  0.507724  0.367964  0.383351    ...     0.301676
# gene_10008_2      0.662329  0.409462  0.361723  0.000000    ...     0.365846
# gene_10009        0.000000  0.000000  0.000000  0.000000    ...     0.000000
# gene_1000_1       1.522005  1.550123  1.479581  1.591393    ...     1.253353
# gene_1000_2       0.989508  0.944083  0.787873  1.154648    ...     0.467393
# ...                    ...       ...       ...       ...    ...          ...
# gene_asmbl_31305  0.527843  0.000000  0.000000  0.000000    ...     0.000000
# gene_asmbl_32007  0.987623  1.075048  0.932109  1.124167    ...     0.816284
# gene_asmbl_32008  1.380494  1.264610  1.400547  1.277678    ...     1.508230
# gene_asmbl_32009  0.987678  1.074983  0.932034  1.124118    ...     0.816204
# gene_asmbl_32011  0.987608  1.074972  0.931974  1.124052    ...     0.816123
# gene_asmbl_37912  2.622509  2.604630  2.635928  2.603777    ...     2.406462
# gene_asmbl_39654  2.189783  2.210653  2.221913  2.232431    ...     2.152140
# gene_asmbl_39659  0.076434  0.867034  0.625443  0.000000    ...     2.610054
# gene_asmbl_39660  2.189763  2.210602  2.222048  2.232351    ...     2.152098
# gene_asmbl_40822  0.000000  0.000000  0.000000  0.000000    ...     0.000000
# gene_asmbl_40823  0.000000  0.000000  0.000000  0.000000    ...     0.000000
# gene_asmbl_48289  1.335491  1.249297  1.223565  0.938746    ...     0.859858
# gene_asmbl_48305  1.042801  1.017946  1.243001  1.145366    ...     0.916696
# gene_asmbl_60477  1.901414  1.916146  1.753232  1.882418    ...     2.102307
# gene_asmbl_65837  0.966854  0.975644  0.979794  0.980150    ...     0.702771
# gene_asmbl_65842  0.966842  0.975603  0.979737  0.980094    ...     0.702764
# gene_asmbl_65843  0.966951  0.975626  0.979673  0.979998    ...     0.703321
# gene_asmbl_65844  0.967023  0.975554  0.979650  0.979962    ...     0.703223
# gene_asmbl_65845  0.730054  0.486363  0.398692  0.879367    ...     0.550192
# gene_asmbl_65846  0.966990  0.975492  0.979576  0.979835    ...     0.703248
# gene_asmbl_65847  0.967038  0.975460  0.979529  0.979818    ...     0.703455
# gene_asmbl_65848  0.966973  0.975028  0.979477  0.979906    ...     0.703381
# gene_asmbl_65850  0.000006  0.000494  0.000000  0.020068    ...     0.000000
# gene_asmbl_65854  0.967005  0.975121  0.979729  0.979836    ...     0.703323
# gene_asmbl_68438  2.410167  2.265613  2.442474  2.329366    ...     1.959504
# gene_asmbl_81468  1.888966  1.929242  1.667026  1.570933    ...     1.545943
# gene_asmbl_81469  2.462115  2.376672  2.514545  2.494184    ...     2.243233
# gene_asmbl_83539  1.970186  1.959555  1.976175  1.909213    ...     1.811818
# gene_asmbl_83541  0.000000  0.000000  0.000000  0.000000    ...     0.000000
# gene_asmbl_84694  1.477426  1.370174  1.477695  1.452694    ...     1.484693
#
#                       1605      1606      1607      1608      1609      1610  \
# gid
# gene_10           1.257118  1.286452  1.277479  1.263934  1.317704  1.265916
# gene_100          0.084812  0.124246  0.032041  0.041590  0.102458  0.085185
# gene_10000_1      0.453194  0.758460  0.694144  0.638614  0.835254  0.703149
# gene_10000_10     0.000000  0.000000  0.000000  0.000000  0.000000  0.350713
# gene_10000_11     0.067567  0.337029  0.191921  0.168180  0.199981  0.282501
# gene_10000_12     1.726460  1.692061  1.676079  1.715650  1.748177  1.732927
# gene_10000_2      0.193712  0.116671  0.232673  0.167558  0.145945  0.257988
# gene_10000_3      0.000000  0.220356  0.107115  0.000000  0.156499  0.000000
# gene_10000_4      0.000000  0.080451  0.094930  0.056833  0.028444  0.000000
# gene_10000_5      0.000000  0.000000  0.000000  0.000000  0.094884  0.000000
# gene_10000_6      0.000000  0.000000  0.000000  0.000000  0.000000  0.000110
# gene_10000_7      0.183087  0.278345  0.000000  0.175211  0.000000  0.000000
# gene_10000_8      0.000000  0.000000  0.000000  0.066557  0.040350  0.036434
# gene_10000_9      0.115482  0.000000  0.180311  0.311944  0.000000  0.417994
# gene_10001_1      0.890797  0.973610  0.907907  0.967447  0.936771  0.990060
# gene_10001_2      0.488799  0.494809  0.558385  0.643646  0.533287  0.540557
# gene_10001_3      1.369521  1.320251  1.371121  1.311074  1.287901  1.341233
# gene_10002_1      0.108365  0.031931  0.122950  0.127143  0.064147  0.176200
# gene_10002_2      0.000000  0.000000  0.000000  0.000000  0.076058  0.000000
# gene_10003        0.000000  0.250553  0.255783  0.253497  0.411085  0.000000
# gene_10004        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_10005        0.036172  0.050932  0.052175  0.082934  0.067277  0.034722
# gene_10006        1.523391  1.505441  1.477237  1.500450  1.468021  1.452796
# gene_10007_1      1.113200  1.347344  1.218896  1.393047  1.258238  1.205769
# gene_10007_2      0.000000  0.000000  0.000000  0.000000  0.000000  0.625589
# gene_10008_1      0.124902  0.272769  0.203499  0.308457  0.274777  0.064206
# gene_10008_2      0.474742  0.314243  0.044680  0.313711  0.342392  0.491189
# gene_10009        0.000000  0.093133  0.173465  0.000000  0.093969  0.000000
# gene_1000_1       1.326880  1.281125  1.253950  1.296987  1.275421  1.334081
# gene_1000_2       0.306239  0.277337  0.580735  0.294545  0.000000  0.000000
# ...                    ...       ...       ...       ...       ...       ...
# gene_asmbl_31305  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_32007  0.993406  0.696884  0.852950  0.830473  0.995517  0.971014
# gene_asmbl_32008  1.420194  1.412006  1.409771  1.470701  1.250891  1.336577
# gene_asmbl_32009  0.993257  0.696839  0.853306  0.830491  0.995449  0.970898
# gene_asmbl_32011  0.993176  0.697129  0.853340  0.831420  0.995348  0.970868
# gene_asmbl_37912  2.346159  2.439137  2.436620  2.391483  2.368337  2.257899
# gene_asmbl_39654  2.210187  2.136679  2.123769  2.228608  2.149124  2.222272
# gene_asmbl_39659  2.566379  2.526135  2.552369  2.468391  2.594092  2.360258
# gene_asmbl_39660  2.210151  2.136644  2.123725  2.228553  2.149061  2.222257
# gene_asmbl_40822  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_40823  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_48289  0.857608  0.797778  0.858101  1.253342  0.863144  1.103523
# gene_asmbl_48305  0.795570  0.748553  0.001572  0.661936  0.914632  0.769028
# gene_asmbl_60477  2.072729  2.103935  2.257220  2.207352  2.212878  1.963276
# gene_asmbl_65837  0.655612  0.698210  0.525776  0.625119  0.534142  0.660539
# gene_asmbl_65842  0.655640  0.698849  0.525737  0.625473  0.534103  0.660486
# gene_asmbl_65843  0.655687  0.698751  0.525679  0.625399  0.534040  0.660386
# gene_asmbl_65844  0.655625  0.698688  0.525631  0.625340  0.534000  0.660306
# gene_asmbl_65845  1.023357  0.574914  1.139704  0.624064  1.197912  1.138429
# gene_asmbl_65846  0.655514  0.698565  0.525572  0.625241  0.534042  0.660184
# gene_asmbl_65847  0.655445  0.698511  0.525536  0.625206  0.533993  0.660141
# gene_asmbl_65848  0.655392  0.698684  0.525489  0.625218  0.533942  0.660082
# gene_asmbl_65850  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_65854  0.655347  0.698614  0.525660  0.625433  0.534277  0.660062
# gene_asmbl_68438  2.042534  1.807766  1.769442  1.880588  1.775078  2.022403
# gene_asmbl_81468  1.311051  1.535451  1.210984  1.591229  1.566775  1.561633
# gene_asmbl_81469  2.308496  2.462237  2.298276  2.351798  2.369609  2.402095
# gene_asmbl_83539  1.825898  1.784339  1.806630  1.803969  1.790830  1.873850
# gene_asmbl_83541  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# gene_asmbl_84694  1.399339  1.239909  1.354024  1.441741  1.060933  1.457894
#
#                       1611      1612      1613
# gid
# gene_10           1.279162  1.281020  1.322098
# gene_100          0.077236  0.110746  0.000000
# gene_10000_1      0.745164  0.742015  0.760027
# gene_10000_10     0.000000  0.000000  0.000000
# gene_10000_11     0.268678  0.115582  0.353714
# gene_10000_12     1.738739  1.740801  1.670787
# gene_10000_2      0.178229  0.170312  0.173281
# gene_10000_3      0.000000  0.000000  0.000000
# gene_10000_4      0.000000  0.042305  0.000000
# gene_10000_5      0.217945  0.312387  0.136620
# gene_10000_6      0.033242  0.000000  0.000000
# gene_10000_7      0.181730  0.234020  0.392846
# gene_10000_8      0.000000  0.000000  0.000000
# gene_10000_9      0.403396  0.163052  0.000000
# gene_10001_1      0.876174  0.860838  0.872135
# gene_10001_2      0.481504  0.464391  0.570973
# gene_10001_3      1.346533  1.369308  1.314727
# gene_10002_1      0.091464  0.146504  0.137092
# gene_10002_2      0.049107  0.000000  0.113223
# gene_10003        0.273275  0.271609  0.436053
# gene_10004        0.000000  0.000000  0.000000
# gene_10005        0.038555  0.098047  0.055917
# gene_10006        1.563995  1.500345  1.508188
# gene_10007_1      1.334290  1.372100  1.277140
# gene_10007_2      0.000000  0.000000  0.422407
# gene_10008_1      0.258862  0.328582  0.254467
# gene_10008_2      0.237433  0.335168  0.000000
# gene_10009        0.000000  0.000000  0.000000
# gene_1000_1       1.325987  1.349111  1.289260
# gene_1000_2       0.393935  0.000000  0.000000
# ...                    ...       ...       ...
# gene_asmbl_31305  0.000000  0.000000  0.000000
# gene_asmbl_32007  0.935990  0.935430  0.893140
# gene_asmbl_32008  1.403697  1.473505  1.562306
# gene_asmbl_32009  0.935879  0.935316  0.893023
# gene_asmbl_32011  0.935802  0.935240  0.892928
# gene_asmbl_37912  2.306879  2.283921  2.356124
# gene_asmbl_39654  2.256452  2.316012  2.231108
# gene_asmbl_39659  2.386574  2.232561  2.336485
# gene_asmbl_39660  2.256539  2.315931  2.231126
# gene_asmbl_40822  0.000000  0.000000  0.000000
# gene_asmbl_40823  0.000000  0.000000  0.000000
# gene_asmbl_48289  0.973747  1.022044  1.223613
# gene_asmbl_48305  1.155641  0.869803  0.436897
# gene_asmbl_60477  1.980160  2.103709  2.027425
# gene_asmbl_65837  0.674369  0.746431  0.681068
# gene_asmbl_65842  0.674286  0.746373  0.681025
# gene_asmbl_65843  0.674156  0.746291  0.681230
# gene_asmbl_65844  0.674347  0.746249  0.681148
# gene_asmbl_65845  1.098385  0.924301  0.739543
# gene_asmbl_65846  0.674248  0.746184  0.681146
# gene_asmbl_65847  0.674197  0.746185  0.681084
# gene_asmbl_65848  0.674245  0.746140  0.681008
# gene_asmbl_65850  0.000000  0.000000  0.000000
# gene_asmbl_65854  0.674180  0.746085  0.680941
# gene_asmbl_68438  2.008340  2.029651  1.929706
# gene_asmbl_81468  1.650151  1.479762  1.394728
# gene_asmbl_81469  2.444319  2.373541  2.397784
# gene_asmbl_83539  1.779749  1.853380  1.863946
# gene_asmbl_83541  0.000000  0.000000  0.000000
# gene_asmbl_84694  1.341212  1.337588  1.447978
#
# [38554 rows x 1517 columns]

# %% [markdown]
# ### 2.

# %%
geneID_df = pickle.load(open("Results/tss_annotation/geneID_df_02.p","rb"))
geneID_df
# Out:
#                                                           peaks  \
# gene_1_2                                                     []
# gene_2        [104402, 138452, 215685, 222350, 227617, 24916...
# gene_1_4                                [55675, 163581, 239267]
# gene_3_1      [10516, 35365, 56536, 67616, 72210, 122731, 14...
# gene_3_2      [3383, 12381, 82328, 85156, 110522, 132949, 15...
# gene_4_1                                               [162676]
# gene_4_3      [7861, 14511, 22244, 46573, 46858, 47181, 6782...
# gene_5_1      [16352, 21039, 28166, 34718, 50596, 79729, 135...
# gene_6        [22262, 33162, 46179, 55029, 56153, 58506, 665...
# gene_7        [25758, 94565, 106544, 188053, 217007, 239323,...
# gene_11       [80290, 81311, 140381, 203807, 218548, 233664,...
# gene_10       [81049, 92690, 222772, 223341, 233757, 311565,...
# gene_8        [927, 60452, 105416, 189784, 192646, 212161, 2...
# gene_9        [15278, 38152, 181036, 212539, 236946, 243770,...
# gene_12       [33116, 117077, 120579, 135409, 135410, 190525...
# gene_14       [9742, 9839, 62515, 69923, 104178, 106154, 233...
# gene_16       [57932, 196404, 226165, 228076, 236971, 249193...
# gene_17                                 [78586, 284264, 429002]
# gene_18           [11030, 44709, 45814, 169022, 247400, 332488]
# gene_19_1                                [22263, 41472, 334651]
# gene_19_2        [41473, 83169, 195127, 249114, 311940, 455155]
# gene_19_3     [90834, 126856, 181928, 192648, 224519, 229811...
# gene_19_4     [3338, 10968, 11028, 11309, 11892, 41734, 4584...
# gene_20       [487, 3339, 11305, 18673, 28387, 41474, 44176,...
# gene_23       [44710, 56780, 56792, 68215, 82197, 99218, 151...
# gene_26       [8721, 22190, 61834, 65399, 73919, 93849, 9424...
# gene_27_1     [32126, 53347, 54286, 79458, 94850, 151822, 16...
# gene_27_3     [22264, 22265, 41475, 99647, 131627, 132976, 1...
# gene_28_1     [54795, 68817, 79835, 115331, 126857, 190526, ...
# gene_29                [212544, 241376, 249115, 293402, 463058]
# ...                                                         ...
# gene_30638                        [765, 113753, 236132, 395271]
# gene_30637    [14078, 236264, 293401, 315023, 366620, 370573...
# gene_30633_2                    [16816, 234372, 237912, 476595]
# gene_30633_4                                           [228213]
# gene_30632    [38947, 51478, 55896, 57629, 293819, 385754, 4...
# gene_30636                                     [171260, 234234]
# gene_30639_1                                                 []
# gene_30639_2                                                 []
# gene_30640                                                   []
# gene_30642_2                                                 []
# gene_30642_4                                                 []
# gene_30646    [3019, 29325, 34218, 68623, 69406, 92992, 9573...
# gene_30652    [3018, 3020, 3026, 14805, 40197, 45553, 95738,...
# gene_30653    [15185, 19821, 45546, 45557, 104281, 143661, 1...
# gene_30655    [9502, 88797, 172970, 189043, 214478, 214498, ...
# gene_30659_2  [69416, 69419, 69422, 95567, 114761, 114762, 1...
# gene_30660    [77736, 114710, 189059, 214489, 284157, 299224...
# gene_30661    [3021, 3023, 7527, 9003, 22024, 29154, 45547, ...
# gene_30662    [45554, 45556, 45558, 63839, 143629, 143641, 1...
# gene_30663    [19911, 29155, 244022, 244063, 284153, 284159,...
# gene_30665    [3016, 9501, 91116, 95741, 166238, 189009, 189...
# gene_30666    [8283, 21877, 22021, 172973, 243990, 244090, 2...
# gene_30667    [14457, 15001, 55753, 67639, 69407, 69424, 827...
# gene_30671    [45551, 50805, 95744, 143658, 189051, 289920, ...
# gene_30672    [45555, 69401, 77742, 83207, 88642, 88796, 887...
# gene_30674    [3017, 3022, 22022, 22025, 22026, 29326, 29327...
# gene_30675                                             [375690]
# gene_30676                                                   []
# gene_30677                                                   []
# gene_30678                              [31243, 377756, 377757]
#
#               closest_to_X_numberOfPeaks  \
# gene_1_2                               0
# gene_2                                 9
# gene_1_4                               3
# gene_3_1                              42
# gene_3_2                              17
# gene_4_1                               1
# gene_4_3                              44
# gene_5_1                              32
# gene_6                                73
# gene_7                                 8
# gene_11                               15
# gene_10                               10
# gene_8                                17
# gene_9                                 8
# gene_12                               16
# gene_14                               15
# gene_16                               12
# gene_17                                3
# gene_18                                6
# gene_19_1                              3
# gene_19_2                              6
# gene_19_3                             11
# gene_19_4                             59
# gene_20                               63
# gene_23                               33
# gene_26                               34
# gene_27_1                             10
# gene_27_3                             21
# gene_28_1                             30
# gene_29                                5
# ...                                  ...
# gene_30638                             4
# gene_30637                             8
# gene_30633_2                           4
# gene_30633_4                           1
# gene_30632                             7
# gene_30636                             2
# gene_30639_1                           0
# gene_30639_2                           0
# gene_30640                             0
# gene_30642_2                           0
# gene_30642_4                           0
# gene_30646                            26
# gene_30652                            35
# gene_30653                            33
# gene_30655                            21
# gene_30659_2                          27
# gene_30660                            13
# gene_30661                            53
# gene_30662                            31
# gene_30663                            15
# gene_30665                            36
# gene_30666                            14
# gene_30667                            42
# gene_30671                            15
# gene_30672                            29
# gene_30674                           102
# gene_30675                             1
# gene_30676                             0
# gene_30677                             0
# gene_30678                             3
#
#                                                  bin_-1000_1000  \
# gene_1_2                                                     []
# gene_2                 [104402, 138452, 215685, 222350, 227617]
# gene_1_4                                        [55675, 163581]
# gene_3_1        [10516, 159928, 166008, 236944, 337166, 435205]
# gene_3_2                          [3383, 82328, 250779, 475428]
# gene_4_1                                               [162676]
# gene_4_3                               [208250, 233594, 339761]
# gene_5_1      [21039, 28166, 34718, 50596, 162395, 180754, 2...
# gene_6        [33162, 66695, 94224, 118239, 306136, 334894, ...
# gene_7                                          [25758, 106544]
# gene_11          [80290, 81311, 385031, 452793, 457095, 463055]
# gene_10                 [81049, 222772, 223341, 233757, 311565]
# gene_8                                    [927, 105416, 249172]
# gene_9                                  [38152, 236946, 482476]
# gene_12                 [33116, 307223, 381895, 392622, 399041]
# gene_14                           [9742, 62515, 106154, 284235]
# gene_16                                                [228076]
# gene_17                                         [78586, 429002]
# gene_18                                        [169022, 247400]
# gene_19_1                                                    []
# gene_19_2                               [83169, 311940, 455155]
# gene_19_3                      [224519, 296245, 330889, 433369]
# gene_19_4     [53813, 76270, 90968, 228660, 257116, 279687, ...
# gene_20                                [165306, 173238, 211636]
# gene_23                                  [44710, 99218, 426511]
# gene_26       [8721, 73919, 94242, 94876, 105086, 113339, 17...
# gene_27_1                                               [54286]
# gene_27_3     [41475, 99647, 190172, 289513, 320335, 333864,...
# gene_28_1      [243830, 309757, 331155, 339225, 363888, 431186]
# gene_29                                                [293402]
# ...                                                         ...
# gene_30638                                [765, 236132, 395271]
# gene_30637                                                   []
# gene_30633_2                                                 []
# gene_30633_4                                           [228213]
# gene_30632        [51478, 55896, 57629, 293819, 385754, 425798]
# gene_30636                                             [171260]
# gene_30639_1                                                 []
# gene_30639_2                                                 []
# gene_30640                                                   []
# gene_30642_2                                                 []
# gene_30642_4                                                 []
# gene_30646                                                   []
# gene_30652                                                   []
# gene_30653    [15185, 19821, 45546, 104281, 189012, 224883, ...
# gene_30655                                                   []
# gene_30659_2                                   [214496, 443811]
# gene_30660                                                   []
# gene_30661                       [9003, 244062, 337050, 428250]
# gene_30662                                                   []
# gene_30663                                                   []
# gene_30665                        [9501, 91116, 166238, 284163]
# gene_30666                       [8283, 299216, 332008, 396338]
# gene_30667    [15001, 55753, 95743, 101834, 209199, 243957, ...
# gene_30671                                                   []
# gene_30672                                                   []
# gene_30674    [84876, 299239, 306449, 382376, 396283, 396302...
# gene_30675                                                   []
# gene_30676                                                   []
# gene_30677                                                   []
# gene_30678                                     [377756, 377757]
#
#                                       sameStrand_bin_-1000_1000  \
# gene_1_2                                                     []
# gene_2                                         [138452, 215685]
# gene_1_4                                                [55675]
# gene_3_1                       [159928, 166008, 236944, 435205]
# gene_3_2                                 [3383, 250779, 475428]
# gene_4_1                                                     []
# gene_4_3                               [208250, 233594, 339761]
# gene_5_1                 [21039, 28166, 162395, 250812, 428140]
# gene_6          [94224, 306136, 334894, 354590, 368539, 465287]
# gene_7                                                 [106544]
# gene_11                         [81311, 385031, 457095, 463055]
# gene_10                                        [222772, 311565]
# gene_8                                            [927, 249172]
# gene_9                                          [38152, 236946]
# gene_12                                [307223, 381895, 399041]
# gene_14                           [9742, 62515, 106154, 284235]
# gene_16                                                [228076]
# gene_17                                                [429002]
# gene_18                                        [169022, 247400]
# gene_19_1                                                    []
# gene_19_2                                              [455155]
# gene_19_3                              [224519, 296245, 330889]
# gene_19_4     [90968, 228660, 257116, 279687, 335512, 366813...
# gene_20                                        [165306, 211636]
# gene_23                                                 [99218]
# gene_26          [8721, 105086, 113339, 178960, 314394, 398886]
# gene_27_1                                                    []
# gene_27_3        [41475, 99647, 190172, 289513, 335031, 457557]
# gene_28_1                              [243830, 331155, 339225]
# gene_29                                                [293402]
# ...                                                         ...
# gene_30638                                             [236132]
# gene_30637                                                   []
# gene_30633_2                                                 []
# gene_30633_4                                                 []
# gene_30632                              [51478, 293819, 425798]
# gene_30636                                                   []
# gene_30639_1                                                 []
# gene_30639_2                                                 []
# gene_30640                                                   []
# gene_30642_2                                                 []
# gene_30642_4                                                 []
# gene_30646                                                   []
# gene_30652                                                   []
# gene_30653        [15185, 19821, 45546, 341722, 436934, 444245]
# gene_30655                                                   []
# gene_30659_2                                           [214496]
# gene_30660                                                   []
# gene_30661                               [9003, 244062, 337050]
# gene_30662                                                   []
# gene_30663                                                   []
# gene_30665                                       [9501, 166238]
# gene_30666                             [299216, 332008, 396338]
# gene_30667                              [55753, 299223, 382156]
# gene_30671                                                   []
# gene_30672                                                   []
# gene_30674              [84876, 299239, 306449, 382376, 396302]
# gene_30675                                                   []
# gene_30676                                                   []
# gene_30677                                                   []
# gene_30678                                             [377756]
#
#                                                         samples  minDistance  \
# gene_1_2                                                     []          inf
# gene_2        [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    24.000000
# gene_1_4      [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    31.000000
# gene_3_1      [Brain_START2_and_Brain_STARTinput1, Brain_GRO...   -24.000000
# gene_3_2      [FemaleReproductive_START1_and_FemaleReproduct...     0.000000
# gene_4_1                                                     []          inf
# gene_4_3      [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     5.000000
# gene_5_1      [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    28.000000
# gene_6        [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    24.000000
# gene_7        [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    25.000000
# gene_11       [Brain_START2_and_Brain_STARTinput1, Lung_GROC...    -2.000000
# gene_10       [Brain_GROCap1_and_Brain_GRO1, Muscle_START2_a...    23.000000
# gene_8        [Brain_START2_and_Brain_STARTinput1, Brain_GRO...   -51.000000
# gene_9        [Brain_START2_and_Brain_STARTinput1, FemaleRep...     7.000000
# gene_12       [Brain_START2_and_Brain_STARTinput1, Brain_GRO...   -10.000000
# gene_14       [Brain_GROCap1_and_Brain_GRO1, Heart_START1_an...    59.000000
# gene_16       [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    62.000000
# gene_17       [Brain_GROCap1_and_Brain_GRO1, Brain_START3_an...    31.000000
# gene_18       [Brain_GROCap1_and_Brain_GRO1, Brain_START1_an...     1.000000
# gene_19_1                                                    []          inf
# gene_19_2     [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    47.000000
# gene_19_3     [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    49.000000
# gene_19_4     [Brain_GROCap1_and_Brain_GRO1, FemaleReproduct...   -67.000000
# gene_20       [Brain_START2_and_Brain_STARTinput1, FemaleRep...   -39.000000
# gene_23       [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    10.000000
# gene_26       [Brain_START2_and_Brain_STARTinput1, Kidney_ST...     3.000000
# gene_27_1                                                    []          inf
# gene_27_3     [Brain_START2_and_Brain_STARTinput1, Kidney_ST...    24.000000
# gene_28_1     [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    24.000000
# gene_29       [Spleen_START1_and_Spleen_STARTinput1, CHO_STA...     5.000000
# ...                                                         ...          ...
# gene_30638                     [BMDMwt_GROCap1_and_BMDMwt_GRO1]    47.000000
# gene_30637                                                   []          inf
# gene_30633_2                                                 []          inf
# gene_30633_4                                                 []          inf
# gene_30632    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...   -32.000000
# gene_30636                                                   []          inf
# gene_30639_1                                                 []          inf
# gene_30639_2                                                 []          inf
# gene_30640                                                   []          inf
# gene_30642_2                                                 []          inf
# gene_30642_4                                                 []          inf
# gene_30646                                                   []          inf
# gene_30652                                                   []          inf
# gene_30653    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    10.000000
# gene_30655                                                   []          inf
# gene_30659_2                   [CHO_START1_and_CHO_STARTinput1]   363.000000
# gene_30660                                                   []          inf
# gene_30661    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     0.000000
# gene_30662                                                   []          inf
# gene_30663                                                   []          inf
# gene_30665    [Brain_GROCap1_and_Brain_GRO1, Kidney_START1_a...    -4.000000
# gene_30666    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    96.000000
# gene_30667    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...   142.000000
# gene_30671                                                   []          inf
# gene_30672                                                   []          inf
# gene_30674    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...    25.000000
# gene_30675                                                   []          inf
# gene_30676                                                   []          inf
# gene_30677                                                   []          inf
# gene_30678               [Spleen_START2_and_Spleen_STARTinput1]   110.000000
#
#              minDistancePeak maxValue maxPeakId maxSample       Chr    Start  \
# gene_1_2                 NaN      NaN       NaN       NaN       NaN      NaN
# gene_2                138452     17.4    138452       NaN    picr_0    44409
# gene_1_4               55675    150.9     55675       NaN    picr_0    20879
# gene_3_1              159928    210.1    435205       NaN    picr_0    98719
# gene_3_2              250779     4.51    250779       NaN    picr_0    92125
# gene_4_1                 NaN      NaN       NaN       NaN       NaN      NaN
# gene_4_3              339761     43.4    208250       NaN    picr_0   185649
# gene_5_1              428140    307.9    428140       NaN    picr_0   298116
# gene_6                306136   2256.8    334894       NaN    picr_0   398728
# gene_7                106544    158.3    106544       NaN    picr_0   440836
# gene_11               385031     19.5    385031       NaN    picr_0   470516
# gene_10               222772     13.2    222772       NaN    picr_0   491388
# gene_8                   927     26.6       927       NaN    picr_0   519434
# gene_9                236946     38.4     38152       NaN    picr_0   491031
# gene_12               381895     5.73    381895       NaN    picr_0   648245
# gene_14                62515     31.5    106154       NaN    picr_0   705865
# gene_16               228076     3.13    228076       NaN    picr_0   973132
# gene_17               429002     16.8    429002       NaN    picr_0  1011173
# gene_18               247400     2.82    247400       NaN    picr_0  1027017
# gene_19_1                NaN      NaN       NaN       NaN       NaN      NaN
# gene_19_2             455155    100.7    455155       NaN    picr_0  1058558
# gene_19_3             330889     39.3    330889       NaN    picr_0  1081236
# gene_19_4              90968       34    335512       NaN    picr_0  1125683
# gene_20               165306       43    211636       NaN    picr_0  1224391
# gene_23                99218     18.7     99218       NaN    picr_0  1450980
# gene_26                 8721     16.1    314394       NaN    picr_0  1562508
# gene_27_1                NaN      NaN       NaN       NaN       NaN      NaN
# gene_27_3             335031     43.7    335031       NaN    picr_0  1599121
# gene_28_1             339225     20.5    339225       NaN    picr_0  1726318
# gene_29               293402     11.7    293402       NaN    picr_0  1792810
# ...                      ...      ...       ...       ...       ...      ...
# gene_30638            236132     3.95    236132       NaN   picr_98  7189530
# gene_30637               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30633_2             NaN      NaN       NaN       NaN       NaN      NaN
# gene_30633_4             NaN      NaN       NaN       NaN       NaN      NaN
# gene_30632             51478     45.5     51478       NaN   picr_98  7214807
# gene_30636               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30639_1             NaN      NaN       NaN       NaN       NaN      NaN
# gene_30639_2             NaN      NaN       NaN       NaN       NaN      NaN
# gene_30640               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30642_2             NaN      NaN       NaN       NaN       NaN      NaN
# gene_30642_4             NaN      NaN       NaN       NaN       NaN      NaN
# gene_30646               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30652               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30653             15185     14.1     19821       NaN   picr_99  1817989
# gene_30655               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30659_2          214496    0.897    214496       NaN   picr_99  2900101
# gene_30660               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30661              9003     27.1    337050       NaN   picr_99  3428474
# gene_30662               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30663               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30665            166238    274.9    166238       NaN   picr_99  4062633
# gene_30666            299216     54.2    332008       NaN   picr_99  4130459
# gene_30667             55753    154.3     55753       NaN   picr_99  4149224
# gene_30671               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30672               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30674            306449    201.9    306449       NaN   picr_99  6824813
# gene_30675               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30676               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30677               NaN      NaN       NaN       NaN       NaN      NaN
# gene_30678            377756     2.06    377756       NaN  picr_997    30046
#
#                   End Strand       gene_id         gene   transcript  \
# gene_1_2          NaN    NaN           NaN          NaN          NaN
# gene_2          44569      -        gene_2        RRP7A     asmbl_10
# gene_1_4        21067      +      gene_1_4        SERHL     asmbl_14
# gene_3_1        98916      -      gene_3_1      POLDIP3     asmbl_17
# gene_3_2        92275      -      gene_3_2       CYB5R3     asmbl_20
# gene_4_1          NaN    NaN           NaN          NaN          NaN
# gene_4_3       185806      -      gene_4_3       A4GALT     asmbl_30
# gene_5_1       298311      -      gene_5_1      ARFGAP3     asmbl_31
# gene_6         398918      -        gene_6      PACSIN2     asmbl_43
# gene_7         440998      -        gene_7        TTLL1     asmbl_49
# gene_11        470680      +       gene_11          BIK     asmbl_63
# gene_10        491602      -       gene_10         MCAT     asmbl_57
# gene_8         519617      -        gene_8       TTLL12     asmbl_59
# gene_9         491208      +        gene_9         TSPO     asmbl_60
# gene_12        648405      -       gene_12       SCUBE1     asmbl_66
# gene_14        706127      +       gene_14       MPPED1     asmbl_72
# gene_16        973350      -       gene_16       EFCAB6     asmbl_77
# gene_17       1011328      -       gene_17      SULT4A1     asmbl_79
# gene_18       1027167      -       gene_18       PNPLA5     asmbl_81
# gene_19_1         NaN    NaN           NaN          NaN          NaN
# gene_19_2     1058809      +     gene_19_2       PNPLA3     asmbl_82
# gene_19_3     1081439      +     gene_19_3       SAMM50     asmbl_83
# gene_19_4     1125910      +     gene_19_4        PARVB     asmbl_84
# gene_20       1224588      +       gene_20        PARVG     asmbl_92
# gene_23       1451209      -       gene_23         RTL6     asmbl_99
# gene_26       1562693      +       gene_26         PRR5    asmbl_110
# gene_27_1         NaN    NaN           NaN          NaN          NaN
# gene_27_3     1599335      +     gene_27_3      ARHGAP8    asmbl_118
# gene_28_1     1726479      -     gene_28_1       PHF21B    asmbl_123
# gene_29       1792960      +       gene_29        RPL10    asmbl_128
# ...               ...    ...           ...          ...          ...
# gene_30638    7189680      +    gene_30638    CG061_RAT  asmbl_86687
# gene_30637        NaN    NaN           NaN          NaN          NaN
# gene_30633_2      NaN    NaN           NaN          NaN          NaN
# gene_30633_4      NaN    NaN           NaN          NaN          NaN
# gene_30632    7215087      +    gene_30632       ZCWPW1  asmbl_86681
# gene_30636        NaN    NaN           NaN          NaN          NaN
# gene_30639_1      NaN    NaN           NaN          NaN          NaN
# gene_30639_2      NaN    NaN           NaN          NaN          NaN
# gene_30640        NaN    NaN           NaN          NaN          NaN
# gene_30642_2      NaN    NaN           NaN          NaN          NaN
# gene_30642_4      NaN    NaN           NaN          NaN          NaN
# gene_30646        NaN    NaN           NaN          NaN          NaN
# gene_30652        NaN    NaN           NaN          NaN          NaN
# gene_30653    1818270      +    gene_30653        NOVA1  asmbl_86720
# gene_30655        NaN    NaN           NaN          NaN          NaN
# gene_30659_2  2900251      -  gene_30659_2        ALG12  asmbl_86745
# gene_30660        NaN    NaN           NaN          NaN          NaN
# gene_30661    3428808      +    gene_30661       STXBP6  asmbl_86747
# gene_30662        NaN    NaN           NaN          NaN          NaN
# gene_30663        NaN    NaN           NaN          NaN          NaN
# gene_30665    4062797      -    gene_30665        NRCAM  asmbl_86753
# gene_30666    4130753      -    gene_30666       PNPLA8  asmbl_86764
# gene_30667    4149475      +    gene_30667       DNAJB9  asmbl_86767
# gene_30671        NaN    NaN           NaN          NaN          NaN
# gene_30672        NaN    NaN           NaN          NaN          NaN
# gene_30674    6824967      +    gene_30674        LRRN3  asmbl_86779
# gene_30675        NaN    NaN           NaN          NaN          NaN
# gene_30676        NaN    NaN           NaN          NaN          NaN
# gene_30677        NaN    NaN           NaN          NaN          NaN
# gene_30678      30196      +    gene_30678  KV3A9_MOUSE  asmbl_86789
#
#                                                      maxSamples  hasGene  \
# gene_1_2                                                     []    False
# gene_2        [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_1_4      [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_3_1      [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_3_2                       [BMDMwt_GROCap1_and_BMDMwt_GRO1]     True
# gene_4_1                                                     []    False
# gene_4_3      [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_5_1      [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_6        [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_7        [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_11       [CHO_GROCap2_and_CHO_GRO1, CHO_GROCap1_and_CHO...     True
# gene_10       [Brain_GROCap1_and_Brain_GRO1, Muscle_START2_a...     True
# gene_8        [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_9        [Brain_START2_and_Brain_STARTinput1, FemaleRep...     True
# gene_12       [Brain_START2_and_Brain_STARTinput1, Heart_STA...     True
# gene_14       [Brain_GROCap1_and_Brain_GRO1, Heart_START1_an...     True
# gene_16       [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_17       [Brain_GROCap1_and_Brain_GRO1, Brain_START3_an...     True
# gene_18                        [BMDMwt_GROCap1_and_BMDMwt_GRO1]     True
# gene_19_1                                                    []    False
# gene_19_2     [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_19_3     [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_19_4     [Brain_GROCap1_and_Brain_GRO1, FemaleReproduct...     True
# gene_20       [Brain_START2_and_Brain_STARTinput1, FemaleRep...     True
# gene_23       [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_26       [Brain_START2_and_Brain_STARTinput1, MiscOrgan...     True
# gene_27_1                                                    []    False
# gene_27_3     [Brain_START2_and_Brain_STARTinput1, Kidney_ST...     True
# gene_28_1     [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_29       [Spleen_START1_and_Spleen_STARTinput1, CHO_STA...     True
# ...                                                         ...      ...
# gene_30638                     [BMDMwt_GROCap1_and_BMDMwt_GRO1]     True
# gene_30637                                                   []    False
# gene_30633_2                                                 []    False
# gene_30633_4                                                 []    False
# gene_30632    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_30636                                                   []    False
# gene_30639_1                                                 []    False
# gene_30639_2                                                 []    False
# gene_30640                                                   []    False
# gene_30642_2                                                 []    False
# gene_30642_4                                                 []    False
# gene_30646                                                   []    False
# gene_30652                                                   []    False
# gene_30653    [Brain_GROCap1_and_Brain_GRO1, FemaleReproduct...     True
# gene_30655                                                   []    False
# gene_30659_2                   [CHO_START1_and_CHO_STARTinput1]     True
# gene_30660                                                   []    False
# gene_30661    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_30662                                                   []    False
# gene_30663                                                   []    False
# gene_30665    [Brain_GROCap1_and_Brain_GRO1, Kidney_START1_a...     True
# gene_30666    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_30667    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_30671                                                   []    False
# gene_30672                                                   []    False
# gene_30674    [Brain_START2_and_Brain_STARTinput1, Brain_GRO...     True
# gene_30675                                                   []    False
# gene_30676                                                   []    False
# gene_30677                                                   []    False
# gene_30678               [Spleen_START2_and_Spleen_STARTinput1]     True
#
#               Number of SS
# gene_1_2                 0
# gene_2                   2
# gene_1_4                 1
# gene_3_1                 4
# gene_3_2                 3
# gene_4_1                 0
# gene_4_3                 3
# gene_5_1                 5
# gene_6                   6
# gene_7                   1
# gene_11                  4
# gene_10                  2
# gene_8                   2
# gene_9                   2
# gene_12                  3
# gene_14                  4
# gene_16                  1
# gene_17                  1
# gene_18                  2
# gene_19_1                0
# gene_19_2                1
# gene_19_3                3
# gene_19_4                7
# gene_20                  2
# gene_23                  1
# gene_26                  6
# gene_27_1                0
# gene_27_3                6
# gene_28_1                3
# gene_29                  1
# ...                    ...
# gene_30638               1
# gene_30637               0
# gene_30633_2             0
# gene_30633_4             0
# gene_30632               3
# gene_30636               0
# gene_30639_1             0
# gene_30639_2             0
# gene_30640               0
# gene_30642_2             0
# gene_30642_4             0
# gene_30646               0
# gene_30652               0
# gene_30653               6
# gene_30655               0
# gene_30659_2             1
# gene_30660               0
# gene_30661               3
# gene_30662               0
# gene_30663               0
# gene_30665               2
# gene_30666               3
# gene_30667               3
# gene_30671               0
# gene_30672               0
# gene_30674               5
# gene_30675               0
# gene_30676               0
# gene_30677               0
# gene_30678               1
#
# [24562 rows x 20 columns]

# %% [markdown]
# ### 3.

# %%
peaks_folder = "Results/tss_annotation_peaks/"
all_peaks_file = "Results/merged/samples.merge"

# %%
tissue="CHO"
curr_inds = set()
for i in glob.glob(os.path.join(peaks_folder,"merged*"+tissue+"*")):
    curr_inds = curr_inds | (set(pd.read_csv(i,sep='\t',index_col=0).index))

tissue_peaks = pd.read_csv(all_peaks_file,index_col=0,sep="\t")
tissue_peaks = tissue_peaks.loc[curr_inds]
tissue_peaks
# Out:
#              Chr     Start       End Strand        Stat  \
# ID
# 338604   picr_64   7894013   7894257      -    8.131177
# 65551   picr_123   3329039   3329211      -   25.398275
# 65552   picr_130   1192373   1192585      +   11.122069
# 65554   picr_144   2561199   2561421      -   27.114483
# 65555    picr_27   2496609   2496777      +  148.115524
# 65556    picr_36  13730430  13730608      -   18.562069
# 32789   picr_102   1258121   1258354      -   12.700000
# 22       picr_74   3049292   3049442      +    3.415188
# 65560    picr_90   3481187   3481446      +    1.276667
# 27       picr_93   6194584   6194969      +    6.499091
# 294941   picr_55   9121850   9122101      +    8.351666
# 32803    picr_45   1034589   1034818      -    3.301666
# 36        picr_3  27828657  27828846      +   10.826207
# 38        picr_0  64021607  64021823      -   23.846128
# 32807    picr_41  17773166  17773474      +    2.724615
# 32820    picr_90   3481614   3481833      +    4.635833
# 32821    picr_31  12775554  12775823      +    7.750000
# 294966   picr_20  20756230  20756456      +   14.065000
# 294972  picr_209    278145    278335      -    3.406154
# 294974    picr_2  41473934  41474145      -    3.618824
# 426047   picr_77   4600149   4600299      -    0.758000
# 294978   picr_95   5973302   5973555      -   18.020384
# 294979    picr_0  59448436  59448714      +    6.593846
# 294981   picr_15  26393076  26393399      -   14.484445
# 65609     picr_2  16007644  16007868      -    1.866667
# 426067   picr_22  17272935  17273158      -    1.447667
# 65631    picr_59   9401877   9402035      +    1.363333
# 32784    picr_74   4712429   4712918      -    7.148375
# 65636    picr_27  21552969  21553164      -    1.126667
# 426089    picr_8  29020678  29020867      +    0.677333
# ...          ...       ...       ...    ...         ...
# 32659    picr_35  17324540  17324785      +   21.578259
# 32660    picr_62   2105591   2105830      +    7.574815
# 425878   picr_34    703372    703522      -    1.198333
# 64373    picr_35    592917    593080      -   13.323810
# 38212   picr_103   3776759   3776934      +    2.652500
# 479003    picr_0  15920460  15920690      -    2.838143
# 369890   picr_18  21693501  21693651      -    0.325000
# 32686    picr_22  11090796  11091040      -    1.963333
# 65458     picr_1  73439039  73439305      +    7.332400
# 365897   picr_83    303518    303750      +   21.702896
# 65469     picr_8  12158231  12158438      -    3.107000
# 32705    picr_47  11539977  11540265      -    6.159200
# 32706   picr_174    209847    210043      -   12.233929
# 102564    picr_4  26599608  26600047      -    6.771111
# 65476   picr_170   1041357   1041620      -    7.350136
# 65482     picr_3  44075409  44075643      -   39.959629
# 65483    picr_75   3207846   3208163      +    6.278214
# 32719    picr_57   7480400   7480857      +    5.629524
# 294867  picr_131    519794    520068      -    4.788000
# 294869   picr_48   4106352   4106634      -   14.946154
# 65494   picr_200    191100    191345      -    2.446500
# 280419   picr_50   6888508   6888658      +    4.736667
# 32736   picr_138    331313    331510      -    7.915625
# 229349   picr_64   2499262   2499524      +    0.420000
# 65512   picr_158    305236    305404      -   15.950833
# 65513    picr_54   8468046   8468242      -    6.288518
# 32756   picr_127   3009311   3009463      +    7.174000
# 57013     picr_0  19406915  19407219      +    5.705833
# 425975   picr_12  35637217  35637367      +    2.066667
# 65535    picr_16  20814641  20814893      +    2.679400
#
#                                              Parent files  Total subpeaks  \
# ID
# 338604  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              17
# 65551   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              29
# 65552   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              29
# 65554   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              29
# 65555   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              29
# 65556   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              29
# 32789   f04_peaks/FemaleReproductive_START1_and_Female...              10
# 22      f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              16
# 65560   f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...               3
# 27      f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              22
# 294941  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              24
# 32803   f04_peaks/Lung_GROCap1_and_Lung_GRO1|f04_peaks...               6
# 36      f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              29
# 38      f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              31
# 32807   f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...              13
# 32820   f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...              12
# 32821   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              13
# 294966  f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...               8
# 294972  f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...              13
# 294974  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              17
# 426047  f04_peaks/CHO_GROCap2_and_CHO_GRO1|f04_peaks/C...               3
# 294978  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              26
# 294979  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              26
# 294981  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              27
# 65609   f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...               3
# 426067  f04_peaks/CHO_GROCap2_and_CHO_GRO1|f04_peaks/C...               3
# 65631   f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...               3
# 32784   f04_peaks/Lung_GROCap1_and_Lung_GRO1|f04_peaks...               8
# 65636   f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...               3
# 426089  f04_peaks/CHO_GROCap2_and_CHO_GRO1|f04_peaks/C...               3
# ...                                                   ...             ...
# 32659   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              27
# 32660   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              27
# 425878  f04_peaks/CHO_GROCap2_and_CHO_GRO1|f04_peaks/C...               3
# 64373   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              21
# 38212   f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...               8
# 479003  f04_peaks/CHO_GROCap2_and_CHO_GRO1|f04_peaks/C...               7
# 369890                 f04_peaks/CHO_GROCap2_and_CHO_GRO1               1
# 32686   f04_peaks/MiscOrgans_START1_and_MiscOrgans_STA...               3
# 65458   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              25
# 365897  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              29
# 65469   f04_peaks/Muscle_START2_and_Muscle_STARTinput1...              10
# 32705   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              25
# 32706   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              28
# 102564  f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...              18
# 65476   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              22
# 65482   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              27
# 65483   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              28
# 32719   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              21
# 294867  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              15
# 294869  f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              26
# 65494   f04_peaks/Brain_GROCap1_and_Brain_GRO1|f04_pea...               4
# 280419  f04_peaks/CHO_GROCap1_and_CHO_GRO2|f04_peaks/C...               3
# 32736   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              16
# 229349  f04_peaks/CHO_GROCap2_and_CHO_GRO1|f04_peaks/C...               2
# 65512   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              24
# 65513   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              27
# 32756   f04_peaks/Muscle_START2_and_Muscle_STARTinput1...               5
# 57013   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...              12
# 425975  f04_peaks/CHO_GROCap2_and_CHO_GRO1|f04_peaks/C...               3
# 65535   f04_peaks/Brain_START2_and_Brain_STARTinput1|f...               5
#
#        f04_peaks/Brain_START2_and_Brain_STARTinput1  \
# ID
# 338604                                   picr_64-63
# 65551                                   picr_123-11
# 65552                                   picr_130-73
# 65554                                    picr_144-5
# 65555                                     picr_27-7
# 65556                                   picr_36-106
# 32789                                           NaN
# 22                                      picr_74-291
# 65560                                           NaN
# 27                                      picr_93-105
# 294941                                   picr_55-35
# 32803                                           NaN
# 36                                       picr_3-211
# 38                                       picr_0-724
# 32807                                           NaN
# 32820                                           NaN
# 32821                                   picr_31-113
# 294966                                          NaN
# 294972                                          NaN
# 294974                                   picr_2-735
# 426047                                          NaN
# 294978                                    picr_95-4
# 294979                                   picr_0-601
# 294981                                  picr_15-323
# 65609                                           NaN
# 426067                                          NaN
# 65631                                           NaN
# 32784                                           NaN
# 65636                                           NaN
# 426089                                          NaN
# ...                                             ...
# 32659                                   picr_35-125
# 32660                                    picr_62-91
# 425878                                          NaN
# 64373                                   picr_35-147
# 38212                                           NaN
# 479003                                          NaN
# 369890                                          NaN
# 32686                                           NaN
# 65458                                    picr_1-229
# 365897                                   picr_83-43
# 65469                                           NaN
# 32705                                   picr_47-126
# 32706                                   picr_174-14
# 102564                                          NaN
# 65476                                    picr_170-4
# 65482                                     picr_3-26
# 65483                                    picr_75-94
# 32719                                    picr_57-80
# 294867                                  picr_131-10
# 294869                                   picr_48-67
# 65494                                           NaN
# 280419                                          NaN
# 32736                                   picr_138-76
# 229349                                          NaN
# 65512                                    picr_158-7
# 65513                                   picr_54-134
# 32756                                           NaN
# 57013                                    picr_0-647
# 425975                                          NaN
# 65535                                   picr_16-258
#
#        f04_peaks/Brain_GROCap1_and_Brain_GRO1  \
# ID
# 338604                             picr_64-53
# 65551                             picr_123-18
# 65552                             picr_130-44
# 65554                              picr_144-6
# 65555                             picr_27-189
# 65556                              picr_36-70
# 32789                                     NaN
# 22                                picr_74-515
# 65560                             picr_90-151
# 27                                picr_93-506
# 294941                                    NaN
# 32803                                     NaN
# 36                                 picr_3-141
# 38                                 picr_0-198
# 32807                             picr_41-175
# 32820                              picr_90-61
# 32821                                     NaN
# 294966                            picr_20-477
# 294972                             picr_209-9
# 294974                             picr_2-551
# 426047                                    NaN
# 294978                             picr_95-22
# 294979                             picr_0-336
# 294981                             picr_15-99
# 65609                             picr_2-1253
# 426067                                    NaN
# 65631                             picr_59-497
# 32784                                     NaN
# 65636                             picr_27-701
# 426089                                    NaN
# ...                                       ...
# 32659                             picr_35-332
# 32660                             picr_62-163
# 425878                                    NaN
# 64373                             picr_35-272
# 38212                            picr_103-209
# 479003                                    NaN
# 369890                                    NaN
# 32686                                     NaN
# 65458                             picr_1-1883
# 365897                            picr_83-121
# 65469                                     NaN
# 32705                             picr_47-254
# 32706                              picr_174-4
# 102564                             picr_4-601
# 65476                                     NaN
# 65482                              picr_3-132
# 65483                             picr_75-196
# 32719                             picr_57-420
# 294867                                    NaN
# 294869                             picr_48-50
# 65494                             picr_200-83
# 280419                                    NaN
# 32736                             picr_138-55
# 229349                                    NaN
# 65512                            picr_158-108
# 65513                             picr_54-145
# 32756                                     NaN
# 57013                                     NaN
# 425975                                    NaN
# 65535                                     NaN
#
#        f04_peaks/FemaleReproductive_START1_and_FemaleReproductive_STARTinput1  \
# ID
# 338604                                                NaN
# 65551                                                 NaN
# 65552                                                 NaN
# 65554                                                 NaN
# 65555                                                 NaN
# 65556                                                 NaN
# 32789                                         picr_102-15
# 22                                                    NaN
# 65560                                                 NaN
# 27                                            picr_93-166
# 294941                                         picr_55-55
# 32803                                                 NaN
# 36                                              picr_3-82
# 38                                             picr_0-616
# 32807                                         picr_41-108
# 32820                                                 NaN
# 32821                                                 NaN
# 294966                                                NaN
# 294972                                                NaN
# 294974                                                NaN
# 426047                                                NaN
# 294978                                         picr_95-35
# 294979                                         picr_0-687
# 294981                                                NaN
# 65609                                                 NaN
# 426067                                                NaN
# 65631                                                 NaN
# 32784                                                 NaN
# 65636                                                 NaN
# 426089                                                NaN
# ...                                                   ...
# 32659                                                 NaN
# 32660                                                 NaN
# 425878                                                NaN
# 64373                                                 NaN
# 38212                                                 NaN
# 479003                                                NaN
# 369890                                                NaN
# 32686                                                 NaN
# 65458                                          picr_1-466
# 365897                                         picr_83-52
# 65469                                                 NaN
# 32705                                         picr_47-116
# 32706                                                 NaN
# 102564                                                NaN
# 65476                                          picr_170-4
# 65482                                           picr_3-34
# 65483                                                 NaN
# 32719                                                 NaN
# 294867                                                NaN
# 294869                                                NaN
# 65494                                                 NaN
# 280419                                                NaN
# 32736                                                 NaN
# 229349                                                NaN
# 65512                                          picr_158-5
# 65513                                         picr_54-185
# 32756                                                 NaN
# 57013                                         picr_0-1839
# 425975                                                NaN
# 65535                                         picr_16-191
#
#                           ...                      \
# ID                        ...
# 338604                    ...
# 65551                     ...
# 65552                     ...
# 65554                     ...
# 65555                     ...
# 65556                     ...
# 32789                     ...
# 22                        ...
# 65560                     ...
# 27                        ...
# 294941                    ...
# 32803                     ...
# 36                        ...
# 38                        ...
# 32807                     ...
# 32820                     ...
# 32821                     ...
# 294966                    ...
# 294972                    ...
# 294974                    ...
# 426047                    ...
# 294978                    ...
# 294979                    ...
# 294981                    ...
# 65609                     ...
# 426067                    ...
# 65631                     ...
# 32784                     ...
# 65636                     ...
# 426089                    ...
# ...                       ...
# 32659                     ...
# 32660                     ...
# 425878                    ...
# 64373                     ...
# 38212                     ...
# 479003                    ...
# 369890                    ...
# 32686                     ...
# 65458                     ...
# 365897                    ...
# 65469                     ...
# 32705                     ...
# 32706                     ...
# 102564                    ...
# 65476                     ...
# 65482                     ...
# 65483                     ...
# 32719                     ...
# 294867                    ...
# 294869                    ...
# 65494                     ...
# 280419                    ...
# 32736                     ...
# 229349                    ...
# 65512                     ...
# 65513                     ...
# 32756                     ...
# 57013                     ...
# 425975                    ...
# 65535                     ...
#
#        f04_peaks/Brain_START1_and_Brain_STARTinput2  \
# ID
# 338604                                   picr_64-12
# 65551                                    picr_123-3
# 65552                                   picr_130-68
# 65554                                    picr_144-6
# 65555                                     picr_27-2
# 65556                                    picr_36-34
# 32789                                           NaN
# 22                                      picr_74-339
# 65560                                           NaN
# 27                                      picr_93-149
# 294941                                  picr_55-102
# 32803                                           NaN
# 36                                       picr_3-276
# 38                                       picr_0-109
# 32807                                           NaN
# 32820                                           NaN
# 32821                                   picr_31-117
# 294966                                          NaN
# 294972                                  picr_209-21
# 294974                                   picr_2-707
# 426047                                          NaN
# 294978                                    picr_95-9
# 294979                                   picr_0-613
# 294981                                  picr_15-240
# 65609                                           NaN
# 426067                                          NaN
# 65631                                           NaN
# 32784                                           NaN
# 65636                                           NaN
# 426089                                          NaN
# ...                                             ...
# 32659                                    picr_35-52
# 32660                                    picr_62-63
# 425878                                          NaN
# 64373                                   picr_35-354
# 38212                                           NaN
# 479003                                          NaN
# 369890                                          NaN
# 32686                                           NaN
# 65458                                    picr_1-340
# 365897                                   picr_83-20
# 65469                                   picr_8-1091
# 32705                                   picr_47-127
# 32706                                   picr_174-16
# 102564                                   picr_4-296
# 65476                                           NaN
# 65482                                    picr_3-227
# 65483                                    picr_75-73
# 32719                                   picr_57-143
# 294867                                          NaN
# 294869                                   picr_48-96
# 65494                                   picr_200-13
# 280419                                          NaN
# 32736                                           NaN
# 229349                                          NaN
# 65512                                   picr_158-26
# 65513                                   picr_54-143
# 32756                                           NaN
# 57013                                           NaN
# 425975                                          NaN
# 65535                                           NaN
#
#        f04_peaks/FemaleReproductive_START2_and_FemaleReproductive_STARTinput1  \
# ID
# 338604                                         picr_64-61
# 65551                                         picr_123-10
# 65552                                         picr_130-73
# 65554                                          picr_144-5
# 65555                                           picr_27-4
# 65556                                          picr_36-96
# 32789                                                 NaN
# 22                                            picr_74-239
# 65560                                                 NaN
# 27                                            picr_93-120
# 294941                                         picr_55-49
# 32803                                         picr_45-133
# 36                                             picr_3-268
# 38                                             picr_0-694
# 32807                                                 NaN
# 32820                                          picr_90-70
# 32821                                         picr_31-143
# 294966                                        picr_20-399
# 294972                                                NaN
# 294974                                         picr_2-872
# 426047                                                NaN
# 294978                                          picr_95-8
# 294979                                         picr_0-658
# 294981                                        picr_15-321
# 65609                                                 NaN
# 426067                                                NaN
# 65631                                                 NaN
# 32784                                                 NaN
# 65636                                                 NaN
# 426089                                                NaN
# ...                                                   ...
# 32659                                         picr_35-100
# 32660                                          picr_62-93
# 425878                                                NaN
# 64373                                         picr_35-121
# 38212                                        picr_103-303
# 479003                                                NaN
# 369890                                                NaN
# 32686                                                 NaN
# 65458                                          picr_1-271
# 365897                                         picr_83-31
# 65469                                                 NaN
# 32705                                         picr_47-121
# 32706                                         picr_174-15
# 102564                                                NaN
# 65476                                          picr_170-5
# 65482                                           picr_3-47
# 65483                                         picr_75-102
# 32719                                          picr_57-91
# 294867                                        picr_131-19
# 294869                                        picr_48-112
# 65494                                                 NaN
# 280419                                                NaN
# 32736                                        picr_138-109
# 229349                                                NaN
# 65512                                         picr_158-16
# 65513                                         picr_54-139
# 32756                                                 NaN
# 57013                                          picr_0-457
# 425975                                                NaN
# 65535                                         picr_16-542
#
#        f04_peaks/Pancreas_START2_and_Pancreas_STARTinput1  \
# ID
# 338604                                         picr_64-24
# 65551                                          picr_123-6
# 65552                                         picr_130-92
# 65554                                          picr_144-6
# 65555                                           picr_27-3
# 65556                                          picr_36-67
# 32789                                                 NaN
# 22                                            picr_74-179
# 65560                                                 NaN
# 27                                                    NaN
# 294941                                         picr_55-79
# 32803                                                 NaN
# 36                                             picr_3-132
# 38                                             picr_0-200
# 32807                                                 NaN
# 32820                                                 NaN
# 32821                                                 NaN
# 294966                                                NaN
# 294972                                                NaN
# 294974                                                NaN
# 426047                                                NaN
# 294978                                         picr_95-15
# 294979                                         picr_0-932
# 294981                                         picr_15-79
# 65609                                                 NaN
# 426067                                                NaN
# 65631                                                 NaN
# 32784                                                 NaN
# 65636                                                 NaN
# 426089                                                NaN
# ...                                                   ...
# 32659                                         picr_35-101
# 32660                                          picr_62-86
# 425878                                                NaN
# 64373                                                 NaN
# 38212                                                 NaN
# 479003                                                NaN
# 369890                                                NaN
# 32686                                                 NaN
# 65458                                          picr_1-292
# 365897                                         picr_83-29
# 65469                                                 NaN
# 32705                                                 NaN
# 32706                                         picr_174-24
# 102564                                                NaN
# 65476                                                 NaN
# 65482                                          picr_3-125
# 65483                                          picr_75-81
# 32719                                         picr_57-112
# 294867                                                NaN
# 294869                                        picr_48-129
# 65494                                                 NaN
# 280419                                                NaN
# 32736                                                 NaN
# 229349                                                NaN
# 65512                                         picr_158-26
# 65513                                                 NaN
# 32756                                                 NaN
# 57013                                                 NaN
# 425975                                                NaN
# 65535                                                 NaN
#
#        f04_peaks/Brain_START3_and_Brain_STARTinput1  \
# ID
# 338604                                   picr_64-24
# 65551                                    picr_123-5
# 65552                                   picr_130-45
# 65554                                    picr_144-6
# 65555                                    picr_27-27
# 65556                                    picr_36-24
# 32789                                           NaN
# 22                                              NaN
# 65560                                           NaN
# 27                                              NaN
# 294941                                   picr_55-69
# 32803                                           NaN
# 36                                       picr_3-151
# 38                                        picr_0-90
# 32807                                   picr_41-106
# 32820                                           NaN
# 32821                                           NaN
# 294966                                          NaN
# 294972                                          NaN
# 294974                                          NaN
# 426047                                          NaN
# 294978                                    picr_95-5
# 294979                                   picr_0-506
# 294981                                  picr_15-160
# 65609                                           NaN
# 426067                                          NaN
# 65631                                           NaN
# 32784                                           NaN
# 65636                                           NaN
# 426089                                          NaN
# ...                                             ...
# 32659                                    picr_35-77
# 32660                                   picr_62-112
# 425878                                          NaN
# 64373                                           NaN
# 38212                                           NaN
# 479003                                          NaN
# 369890                                          NaN
# 32686                                           NaN
# 65458                                    picr_1-189
# 365897                                   picr_83-12
# 65469                                           NaN
# 32705                                           NaN
# 32706                                   picr_174-13
# 102564                                   picr_4-179
# 65476                                           NaN
# 65482                                    picr_3-113
# 65483                                    picr_75-78
# 32719                                    picr_57-89
# 294867                                          NaN
# 294869                                  picr_48-134
# 65494                                           NaN
# 280419                                          NaN
# 32736                                   picr_138-57
# 229349                                          NaN
# 65512                                           NaN
# 65513                                   picr_54-115
# 32756                                           NaN
# 57013                                           NaN
# 425975                                          NaN
# 65535                                           NaN
#
#        f04_peaks/Kidney_GROCap1_and_Kidney_GRO1  \
# ID
# 338604                                      NaN
# 65551                               picr_123-59
# 65552                              picr_130-136
# 65554                               picr_144-11
# 65555                               picr_27-180
# 65556                               picr_36-155
# 32789                                       NaN
# 22                                  picr_74-432
# 65560                                       NaN
# 27                                          NaN
# 294941                                      NaN
# 32803                                       NaN
# 36                                   picr_3-512
# 38                                   picr_0-312
# 32807                                       NaN
# 32820                                       NaN
# 32821                               picr_31-285
# 294966                              picr_20-434
# 294972                               picr_209-9
# 294974                              picr_2-1672
# 426047                                      NaN
# 294978                               picr_95-25
# 294979                               picr_0-320
# 294981                              picr_15-133
# 65609                                       NaN
# 426067                                      NaN
# 65631                                       NaN
# 32784                               picr_74-887
# 65636                                       NaN
# 426089                                      NaN
# ...                                         ...
# 32659                              picr_35-1971
# 32660                               picr_62-248
# 425878                                      NaN
# 64373                               picr_35-137
# 38212                              picr_103-173
# 479003                                      NaN
# 369890                                      NaN
# 32686                                       NaN
# 65458                               picr_1-1202
# 365897                              picr_83-100
# 65469                                       NaN
# 32705                               picr_47-415
# 32706                                picr_174-5
# 102564                                      NaN
# 65476                               picr_170-14
# 65482                                picr_3-228
# 65483                               picr_75-204
# 32719                                       NaN
# 294867                                      NaN
# 294869                               picr_48-66
# 65494                                       NaN
# 280419                                      NaN
# 32736                                       NaN
# 229349                                      NaN
# 65512                               picr_158-55
# 65513                               picr_54-161
# 32756                                       NaN
# 57013                                picr_0-516
# 425975                                      NaN
# 65535                                       NaN
#
#        f04_peaks/Brain_START1_and_Brain_STARTinput1  \
# ID
# 338604                                   picr_64-12
# 65551                                    picr_123-3
# 65552                                   picr_130-68
# 65554                                    picr_144-6
# 65555                                     picr_27-2
# 65556                                    picr_36-34
# 32789                                           NaN
# 22                                      picr_74-339
# 65560                                           NaN
# 27                                      picr_93-149
# 294941                                  picr_55-102
# 32803                                           NaN
# 36                                       picr_3-276
# 38                                       picr_0-109
# 32807                                   picr_41-233
# 32820                                    picr_90-50
# 32821                                   picr_31-117
# 294966                                          NaN
# 294972                                          NaN
# 294974                                   picr_2-707
# 426047                                          NaN
# 294978                                    picr_95-9
# 294979                                   picr_0-613
# 294981                                  picr_15-240
# 65609                                           NaN
# 426067                                          NaN
# 65631                                           NaN
# 32784                                           NaN
# 65636                                           NaN
# 426089                                          NaN
# ...                                             ...
# 32659                                    picr_35-52
# 32660                                    picr_62-63
# 425878                                          NaN
# 64373                                   picr_35-354
# 38212                                           NaN
# 479003                                          NaN
# 369890                                          NaN
# 32686                                           NaN
# 65458                                    picr_1-340
# 365897                                   picr_83-20
# 65469                                           NaN
# 32705                                   picr_47-127
# 32706                                   picr_174-16
# 102564                                   picr_4-296
# 65476                                           NaN
# 65482                                           NaN
# 65483                                    picr_75-73
# 32719                                           NaN
# 294867                                          NaN
# 294869                                   picr_48-96
# 65494                                   picr_200-13
# 280419                                          NaN
# 32736                                   picr_138-79
# 229349                                          NaN
# 65512                                           NaN
# 65513                                   picr_54-143
# 32756                                           NaN
# 57013                                           NaN
# 425975                                          NaN
# 65535                                           NaN
#
#        f04_peaks/CHO_GROCap1_and_CHO_GRO1  \
# ID
# 338604                        picr_64-126
# 65551                          picr_123-6
# 65552                         picr_130-64
# 65554                          picr_144-4
# 65555                          picr_27-48
# 65556                         picr_36-107
# 32789                          picr_102-6
# 22                                    NaN
# 65560                                 NaN
# 27                                    NaN
# 294941                        picr_55-142
# 32803                          picr_45-88
# 36                                    NaN
# 38                              picr_0-65
# 32807                         picr_41-134
# 32820                                 NaN
# 32821                                 NaN
# 294966                         picr_20-72
# 294972                        picr_209-22
# 294974                                NaN
# 426047                                NaN
# 294978                                NaN
# 294979                                NaN
# 294981                         picr_15-35
# 65609                                 NaN
# 426067                                NaN
# 65631                                 NaN
# 32784                         picr_74-500
# 65636                                 NaN
# 426089                                NaN
# ...                                   ...
# 32659                         picr_35-283
# 32660                         picr_62-216
# 425878                                NaN
# 64373                         picr_35-287
# 38212                        picr_103-302
# 479003                        picr_0-1416
# 369890                                NaN
# 32686                        picr_22-1042
# 65458                                 NaN
# 365897                        picr_83-357
# 65469                         picr_8-1043
# 32705                                 NaN
# 32706                         picr_174-24
# 102564                         picr_4-428
# 65476                          picr_170-2
# 65482                                 NaN
# 65483                          picr_75-53
# 32719                         picr_57-404
# 294867                        picr_131-28
# 294869                         picr_48-13
# 65494                         picr_200-57
# 280419                        picr_50-386
# 32736                          picr_138-9
# 229349                        picr_64-432
# 65512                                 NaN
# 65513                         picr_54-160
# 32756                        picr_127-120
# 57013                                 NaN
# 425975                                NaN
# 65535                                 NaN
#
#        f04_peaks/BMDMwt_GROCap1_and_BMDMwt_GRO1  \
# ID
# 338604                                      NaN
# 65551                               picr_123-24
# 65552                               picr_130-72
# 65554                                picr_144-2
# 65555                               picr_27-164
# 65556                                picr_36-65
# 32789                               picr_102-31
# 22                                          NaN
# 65560                                       NaN
# 27                                  picr_93-389
# 294941                                      NaN
# 32803                                       NaN
# 36                                   picr_3-110
# 38                                   picr_0-165
# 32807                                       NaN
# 32820                               picr_90-104
# 32821                                       NaN
# 294966                                      NaN
# 294972                              picr_209-12
# 294974                                      NaN
# 426047                                      NaN
# 294978                               picr_95-11
# 294979                               picr_0-784
# 294981                               picr_15-86
# 65609                                       NaN
# 426067                                      NaN
# 65631                                       NaN
# 32784                                       NaN
# 65636                                       NaN
# 426089                                      NaN
# ...                                         ...
# 32659                               picr_35-398
# 32660                               picr_62-311
# 425878                                      NaN
# 64373                               picr_35-328
# 38212                                       NaN
# 479003                              picr_0-2102
# 369890                                      NaN
# 32686                                       NaN
# 65458                               picr_1-1610
# 365897                               picr_83-75
# 65469                                       NaN
# 32705                                       NaN
# 32706                               picr_174-14
# 102564                              picr_4-1707
# 65476                                       NaN
# 65482                               picr_3-2209
# 65483                               picr_75-204
# 32719                                picr_57-83
# 294867                                      NaN
# 294869                              picr_48-143
# 65494                                       NaN
# 280419                                      NaN
# 32736                                       NaN
# 229349                                      NaN
# 65512                                       NaN
# 65513                                       NaN
# 32756                               picr_127-14
# 57013                                       NaN
# 425975                                      NaN
# 65535                                       NaN
#
#        f04_peaks/Heart_START2_and_Heart_STARTinput1  \
# ID
# 338604                                          NaN
# 65551                                   picr_123-24
# 65552                                   picr_130-94
# 65554                                   picr_144-15
# 65555                                    picr_27-85
# 65556                                   picr_36-213
# 32789                                           NaN
# 22                                              NaN
# 65560                                           NaN
# 27                                       picr_93-58
# 294941                                  picr_55-220
# 32803                                           NaN
# 36                                        picr_3-56
# 38                                        picr_0-51
# 32807                                           NaN
# 32820                                           NaN
# 32821                                           NaN
# 294966                                          NaN
# 294972                                          NaN
# 294974                                   picr_2-968
# 426047                                          NaN
# 294978                                          NaN
# 294979                                          NaN
# 294981                                   picr_15-97
# 65609                                           NaN
# 426067                                          NaN
# 65631                                           NaN
# 32784                                           NaN
# 65636                                           NaN
# 426089                                          NaN
# ...                                             ...
# 32659                                           NaN
# 32660                                   picr_62-110
# 425878                                          NaN
# 64373                                           NaN
# 38212                                           NaN
# 479003                                          NaN
# 369890                                          NaN
# 32686                                           NaN
# 65458                                    picr_1-910
# 365897                                  picr_83-233
# 65469                                           NaN
# 32705                                    picr_47-88
# 32706                                   picr_174-38
# 102564                                          NaN
# 65476                                    picr_170-2
# 65482                                     picr_3-57
# 65483                                           NaN
# 32719                                   picr_57-112
# 294867                                          NaN
# 294869                                   picr_48-88
# 65494                                           NaN
# 280419                                          NaN
# 32736                                           NaN
# 229349                                          NaN
# 65512                                   picr_158-30
# 65513                                   picr_54-199
# 32756                                           NaN
# 57013                                           NaN
# 425975                                          NaN
# 65535                                           NaN
#
#        f04_peaks/Lung_START1_and_Lung_STARTinput1
# ID
# 338604                                 picr_64-81
# 65551                                 picr_123-13
# 65552                                picr_130-104
# 65554                                  picr_144-4
# 65555                                   picr_27-8
# 65556                                  picr_36-84
# 32789                                         NaN
# 22                                    picr_74-363
# 65560                                         NaN
# 27                                    picr_93-104
# 294941                                 picr_55-36
# 32803                                         NaN
# 36                                     picr_3-282
# 38                                     picr_0-713
# 32807                                         NaN
# 32820                                  picr_90-42
# 32821                                         NaN
# 294966                                        NaN
# 294972                                        NaN
# 294974                                 picr_2-882
# 426047                                        NaN
# 294978                                  picr_95-9
# 294979                                 picr_0-397
# 294981                                picr_15-248
# 65609                                         NaN
# 426067                                        NaN
# 65631                                         NaN
# 32784                                         NaN
# 65636                                         NaN
# 426089                                        NaN
# ...                                           ...
# 32659                                 picr_35-168
# 32660                                 picr_62-105
# 425878                                        NaN
# 64373                                 picr_35-298
# 38212                                         NaN
# 479003                                picr_0-1591
# 369890                                        NaN
# 32686                                         NaN
# 65458                                  picr_1-183
# 365897                                 picr_83-42
# 65469                                         NaN
# 32705                                  picr_47-53
# 32706                                 picr_174-14
# 102564                                 picr_4-549
# 65476                                  picr_170-8
# 65482                                   picr_3-43
# 65483                                  picr_75-74
# 32719                                  picr_57-99
# 294867                                picr_131-48
# 294869                                        NaN
# 65494                                         NaN
# 280419                                        NaN
# 32736                                 picr_138-74
# 229349                                        NaN
# 65512                                  picr_158-7
# 65513                                  picr_54-77
# 32756                                         NaN
# 57013                                         NaN
# 425975                                        NaN
# 65535                                         NaN
#
# [10511 rows x 41 columns]

# %%
has_peak = cho_rna.index.isin(geneID_df)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Chart comparing RNA-seq in genes that have TSS and those that dont

# %%
in_cho = geneID_df[geneID_df['samples'].apply(lambda x: tissue in ' '.join(x))].index
not_in_cho = geneID_df[geneID_df['samples'].apply(lambda x: tissue not in ' '.join(x))].index
in_any_sample_but_cho = geneID_df[geneID_df['hasGene']].index.difference(in_cho)
in_no_sample = geneID_df[~geneID_df['hasGene']].index

# %%
len(in_any_sample_but_cho)+len(in_no_sample)
# Out:
# 14382

# %%
gene_stats = cho_rna.transpose().describe()

# %%
gene_stats
# Out:
# gid        gene_10     gene_100  gene_10000_1  gene_10000_10  gene_10000_11  \
# count  1517.000000  1517.000000   1517.000000    1517.000000    1517.000000
# mean      1.097176     0.146771      0.509780       0.144823       0.278449
# std       0.224042     0.163835      0.255440       0.232104       0.249070
# min       0.000000     0.000000      0.000000       0.000000       0.000000
# 25%       0.978662     0.064244      0.324645       0.000000       0.000008
# 50%       1.155310     0.111266      0.493800       0.000000       0.265157
# 75%       1.236137     0.176848      0.711477       0.255474       0.468772
# max       2.620247     1.351577      1.691837       2.249839       1.728426
#
# gid    gene_10000_12  gene_10000_2  gene_10000_3  gene_10000_4  gene_10000_5  \
# count    1517.000000   1517.000000   1517.000000   1517.000000   1517.000000
# mean        1.501172      0.226841      0.110681      0.045838      0.151907
# std         0.269154      0.106550      0.147533      0.068392      0.171461
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         1.439064      0.160584      0.000000      0.000000      0.000000
# 50%         1.552245      0.224287      0.073660      0.022167      0.106643
# 75%         1.643104      0.284092      0.169356      0.068453      0.259319
# max         2.071840      0.814705      2.004899      0.571510      0.845466
#
# gid          ...         gene_asmbl_65847  gene_asmbl_65848  gene_asmbl_65850  \
# count        ...              1517.000000       1517.000000       1517.000000
# mean         ...                 0.706679          0.706681          0.061523
# std          ...                 0.231232          0.231232          0.187157
# min          ...                 0.000000          0.000000          0.000000
# 25%          ...                 0.524352          0.524352          0.000000
# 50%          ...                 0.754014          0.753877          0.000000
# 75%          ...                 0.892131          0.892022          0.000000
# max          ...                 1.131536          1.131536          1.791509
#
# gid    gene_asmbl_65854  gene_asmbl_68438  gene_asmbl_81468  gene_asmbl_81469  \
# count       1517.000000       1517.000000       1517.000000       1517.000000
# mean           0.706694          2.033522          1.497033          2.411188
# std            0.231233          0.374472          0.544635          0.427635
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.524352          1.943424          1.377883          2.348387
# 50%            0.753760          2.093237          1.624275          2.488662
# 75%            0.892258          2.218510          1.820309          2.603607
# max            1.131536          2.719708          2.599238          3.224860
#
# gid    gene_asmbl_83539  gene_asmbl_83541  gene_asmbl_84694
# count       1517.000000       1517.000000       1517.000000
# mean           1.654598          0.203555          1.024675
# std            0.431776          0.412223          0.496574
# min            0.000000          0.000000          0.000000
# 25%            1.454876          0.000000          0.748097
# 50%            1.804392          0.000000          1.195932
# 75%            1.943983          0.000000          1.393852
# max            2.439222          3.088941          1.861202
#
# [8 rows x 38554 columns]

# %%
import pylab

# %%
def suplabel(axis,label,label_prop=None,
             labelpad=5,
             ha='center',va='center'):
    ''' Add super ylabel or xlabel to the figure
    Similar to matplotlib.suptitle
    axis       - string: "x" or "y"
    label      - string
    label_prop - keyword dictionary for Text
    labelpad   - padding from the axis (default: 5)
    ha         - horizontal alignment (default: "center")
    va         - vertical alignment (default: "center")
    '''
    fig = pylab.gcf()
    xmin = []
    ymin = []
    for ax in fig.axes:
        xmin.append(ax.get_position().xmin)
        ymin.append(ax.get_position().ymin)
    xmin,ymin = min(xmin),min(ymin)
    dpi = fig.dpi
    if axis.lower() == "y":
        rotation=90.
        x = xmin-float(labelpad)/dpi
        y = 0.5
    elif axis.lower() == 'x':
        rotation = 0.
        x = 0.5
        y = ymin - float(labelpad)/dpi
    else:
        raise Exception("Unexpected axis: x or y")
    if label_prop is None: 
        label_prop = dict()
    pylab.text(x,y,label,rotation=rotation,
               transform=fig.transFigure,
               ha=ha,va=va,
               **label_prop)

# %%
#f,axes = plt.subplots(2,2,sharex=True, sharey=True)
f = plt.figure()
plt.subplot(2,2,1)
sns.violinplot(gene_stats.loc["50%",in_cho],orient='vertical')
plt.title("Genes with TSS in CHO")
#plt.gca().get_yaxis().set_visible(False)
plt.ylabel("")
plt.subplot(2,2,2)
sns.violinplot(gene_stats.loc["50%",not_in_cho],orient='vertical')
plt.title("Genes with no TSS in CHO")
#plt.gca().get_yaxis().set_visible(False)
plt.ylabel("")
plt.subplot(2,2,3)
sns.violinplot(gene_stats.loc["50%",in_any_sample_but_cho],orient='vertical')
plt.title("Genes with a TSS but not in CHO")
#plt.gca().get_yaxis().set_visible(False)
plt.ylabel("")

plt.subplot(2,2,4)
sns.violinplot(gene_stats.loc["50%",in_no_sample],orient='vertical')
plt.title("Genes with no TSS in any sample")
#plt.gca().get_yaxis().set_visible(False)
plt.ylabel("")

suplabel("y","Median log2(TPM+1)",label_prop={"fontsize":18})

plt.suptitle("Median expression across RNA-seq experiments",fontsize=18)
# if not os.path.exists("Results/RNAseq_Compare"):
#     os.mkdir(outdir)
    
plt.savefig(os.path.join(outdir,"RNAseq_CHO_with_TSS.png"))

# %% [markdown]
# ## Load RNA tissue matrix and compare

# %%
#tissue_f = "/data/isshamie/TSS/Processed/RNA_Total/"
