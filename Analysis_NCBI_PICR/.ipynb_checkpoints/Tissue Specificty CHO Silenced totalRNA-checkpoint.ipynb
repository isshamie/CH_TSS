# %% [markdown]
# # 1. Library

# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])
ref_fa = doc['ref_fa']
anno_gff=doc['annotation']
mRNA_peak_file = doc["mRNA_peak_file"]

tss_annotation = doc['tss_annotation']


import os
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm

from os.path import basename
##mpl.use('Agg')
#mpl.style.use('ggplot')
#mpl.style.use('fivethirtyeight')
from Homer import *
import plot_tss_results
print('Number of tissues: ',len(tissues))

from scipy.stats import zscore
from scipy.stats import iqr
# Out:
# ('Number of tissues: ', 13)

# %%
save_dir = "Results/Figures/Silenced_CHO"
if not os.path.exists(save_dir):
    os.mkdir(save_dir)

# %% [markdown]
# # 2. Load and Preprocessing

# %% [markdown]
# ## Read in expression matrix

# %%
tissues_expr = pd.read_csv("Results/merged/tissues.merge.peaksexpression.log10",sep="\t",index_col=0)
tissues_expr.head()
# Out:
#       Heart    Spleen  MiscOrgans  FemaleReproductive       CHO  BMDM1hKLA  \
# 0  0.213256  0.000000    0.191009            0.177054  1.379905    1.93044
# 1  0.000000  0.569562    0.658306            0.704879  0.000000    0.00000
# 2  0.000000  0.272654    0.191009            0.650337  1.269450    0.00000
# 3  0.213256  0.583265    0.592983            0.556972  0.347363    0.00000
# 4  0.858835  1.743575    1.998797            1.218955  0.698374    0.00000
#
#       Brain      Lung     Liver    BMDMwt    Muscle    Kidney  Pancreas
# 0  0.192445  0.292457  0.000000  0.000000  0.192803  0.289548  0.000000
# 1  0.365353  0.875756  0.211156  0.000000  0.160073  0.206016  0.000000
# 2  0.285237  0.440272  0.000000  0.823474  0.252575  0.377071  0.299942
# 3  0.633209  0.256951  0.000000  0.537819  0.300486  0.216445  0.380588
# 4  1.707621  0.729080  0.945703  0.642465  1.198361  0.838893  1.141651

# %% [markdown]
# ### Read in promoter output

# %%
tss_meta = pd.read_csv("Results/output/TSS1.exp.meta",sep="\t",index_col=0)
tss_meta["Name"] = tss_meta.index
tss_meta.set_index("ID",inplace=True)
tss_meta.head()
# Out:
#                                                   Tissues    cs  \
# ID
# 348823  Spleen,MiscOrgans,FemaleReproductive,Brain,Lun...  0b11
# 90264   Spleen,MiscOrgans,FemaleReproductive,Brain,Lun...  0b00
# 181215  Spleen,MiscOrgans,FemaleReproductive,Brain,Lun...  0b00
# 308710  Heart,Spleen,MiscOrgans,FemaleReproductive,Bra...  0b11
# 237253  BMDMwt,Spleen,MiscOrgans,FemaleReproductive,CH...  0b11
#
#         CHO ATAC Region   Gene  Gene ID      Transcript  Is Experimental  \
# ID
# 348823              NaN   Bmp4      NaN  XM_027386529.1              1.0
# 90264               NaN   Bmp4      NaN  XM_027386529.1              1.0
# 181215              NaN   Bmp4      NaN  XM_027386529.1              1.0
# 308710              NaN   Bmp4      NaN  XM_027386528.1              1.0
# 237253              NaN  Cdkn3      NaN  XM_027386531.1              1.0
#
#                            Name
# ID
# 348823   p1@Bmp4_XM_027386529.1
# 90264    p2@Bmp4_XM_027386529.1
# 181215   p3@Bmp4_XM_027386529.1
# 308710   p1@Bmp4_XM_027386528.1
# 237253  p1@Cdkn3_XM_027386531.1

# %% [markdown]
# ## Extract promoter peaks

# %%
prom_tissue = tissues_expr.loc[tissues_expr.index.isin(tss_meta.index)]
prom_tissue.head()
# Out:
#        Heart    Spleen  MiscOrgans  FemaleReproductive       CHO  BMDM1hKLA  \
# 4   0.858835  1.743575    1.998797            1.218955  0.698374   0.000000
# 5   0.401729  1.308001    1.395354            0.648333  0.000000   0.000000
# 6   0.815153  0.519195    1.187007            0.253253  0.418561   0.000000
# 8   0.700905  0.681902    0.877857            0.600699  0.213637   0.849419
# 12  0.000000  0.128118    0.000000            0.000000  0.000000   0.000000
#
#        Brain      Lung     Liver    BMDMwt    Muscle    Kidney  Pancreas
# 4   1.707621  0.729080  0.945703  0.642465  1.198361  0.838893  1.141651
# 5   0.934077  0.962747  0.864244  0.328380  1.110788  0.902202  1.001847
# 6   0.285242  0.256951  1.480135  0.561101  0.964390  0.899657  0.826164
# 8   0.858705  0.749040  0.442105  1.089905  0.633441  0.483976  0.623310
# 12  0.000000  0.241971  0.774026  0.000000  0.151598  0.000000  0.000000

# %% [markdown]
# ## Create median and max values

# %% [markdown]
# ## Take the max transcript for the Gene (sum across tissues)
# (Also should test the median)

# %%
tss_meta["Median"] = prom_tissue.median(axis=1)
tss_meta["Max"] = prom_tissue.max(axis=1)
tss_meta.head()
# Out:
#                                                   Tissues    cs  \
# ID
# 348823  Spleen,MiscOrgans,FemaleReproductive,Brain,Lun...  0b11
# 90264   Spleen,MiscOrgans,FemaleReproductive,Brain,Lun...  0b00
# 181215  Spleen,MiscOrgans,FemaleReproductive,Brain,Lun...  0b00
# 308710  Heart,Spleen,MiscOrgans,FemaleReproductive,Bra...  0b11
# 237253  BMDMwt,Spleen,MiscOrgans,FemaleReproductive,CH...  0b11
#
#         CHO ATAC Region   Gene  Gene ID      Transcript  Is Experimental  \
# ID
# 348823              NaN   Bmp4      NaN  XM_027386529.1              1.0
# 90264               NaN   Bmp4      NaN  XM_027386529.1              1.0
# 181215              NaN   Bmp4      NaN  XM_027386529.1              1.0
# 308710              NaN   Bmp4      NaN  XM_027386528.1              1.0
# 237253              NaN  Cdkn3      NaN  XM_027386531.1              1.0
#
#                            Name    Median       Max
# ID
# 348823   p1@Bmp4_XM_027386529.1  0.260824  0.949261
# 90264    p2@Bmp4_XM_027386529.1  0.000000  0.253253
# 181215   p3@Bmp4_XM_027386529.1  0.000000  0.193642
# 308710   p1@Bmp4_XM_027386528.1  1.045548  2.262918
# 237253  p1@Cdkn3_XM_027386531.1  0.207487  0.658520

# %%
gene_tissue = pd.DataFrame(index=tss_meta["Gene"].unique(), columns=prom_tissue.columns, dtype=float)
for ind, val in tqdm.tqdm_notebook(tss_meta.groupby("Gene")):
    gene_tissue.loc[ind] = prom_tissue.loc[prom_tissue.loc[val.index].sum(axis=1).idxmax()]
    
    
gene_tissue
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
#                  Heart    Spleen  MiscOrgans  FemaleReproductive       CHO  \
# Bmp4          1.741928  1.221935    0.754393            1.058231  0.000000
# Cdkn3         0.000000  0.430767    0.467970            0.395136  0.658520
# Cnih1         1.026731  1.081789    0.687066            1.082934  0.305526
# Cgrrf1        0.702417  1.216486    1.273049            0.666219  1.633526
# Samd4a        0.339714  0.651102    0.826606            0.546711  0.749829
# Gch1          0.319245  0.594936    0.694496            0.325639  0.906732
# Wdhd1         0.000000  0.615134    0.829673            0.450184  1.609751
# Socs4         1.013885  1.024802    0.766068            0.881669  1.480592
# Mapk1ip1l     0.633421  0.887599    0.692100            0.486101  0.266488
# LOC100769620  0.493814  0.000000
# LOC100769912  0.166104  0.552632
# LOC113831691  0.000000  0.000000
# LOC100757478  0.000000  0.000000
# LOC113838852  0.000000  0.000000
# LOC113838855  0.000000  0.000000
# LOC113838897  0.000000  0.000000
# LOC107977194  0.000000  0.000000
# LOC100751996  0.000000  0.221240
# LOC113838952  0.000000  0.000000
# LOC113838972  0.000000  0.000000
# LOC113838971  0.287178  0.000000
# LOC113839006  0.000000  0.330433
# LOC113839031  0.139434  0.000000
# LOC113839047  0.682243  0.402070
# LOC113839066  0.099981  0.000000
# LOC113839076  0.792775  0.380588
# LOC113839111  0.103918  0.000000
# LOC113839113  0.000000  0.000000
#
# [15317 rows x 13 columns]

# %% [markdown]
# # 3. Filter to genes of interest: DNA repair genes

# %%
with open("../supplemental/dna_repair_genes/03_DNA_repair_genes.hamster.final.txt","r") as f:
    repair_genes = [line.rstrip() for line in f]
    
#repair_genes = list(map(lambda x: x.upper(),repair_genes))
repair_genes
# Out:
# ['Abl1',
#  'Abr',
#  'Actr8',
#  'Alkbh2',
#  'Alkbh3',
#  'Anapc1',
#  'Anapc10',
#  'Anapc11',
#  'Anapc13',
#  'Anapc2',
#  'Anapc4',
#  'Anapc5',
#  'Anapc5',
#  'Anapc7',
#  'Apex1',
#  'Apex2',
#  'Aplf',
#  'Aptx',
#  'Asf1a',
#  'Asf1b',
#  'Atad5',
#  'Atm',
#  'Atr',
#  'Atrip',
#  'Atrx',
#  'Atxn3',
#  'Bcr',
#  'Blm',
#  'Brca1',
#  'Brca2',
#  'Brip1',
#  'Brip1',
#  'Brsk1',
#  'Brsk2',
#  'Bub1',
#  'Bub1b',
#  'Bub3',
#  'Camkk1',
#  'Camkk2',
#  'Ccna1',
#  'Ccna2',
#  'Ccnb1',
#  'Ccnb2',
#  'Ccnb3',
#  'Ccnd1',
#  'Ccnd2',
#  'Ccnd3',
#  'Ccne1',
#  'Ccne2',
#  'Ccnh',
#  'Ccnk',
#  'Ccno',
#  'Ccnt1',
#  'Ccnt2',
#  'Ccs',
#  'Cdc14a',
#  'Cdc14b',
#  'Cdc16',
#  'Cdc20',
#  'Cdc20b',
#  'Cdc23',
#  'Cdc25a',
#  'Cdc25b',
#  'Cdc25c',
#  'Cdc26',
#  'Cdc27',
#  'Cdc45',
#  'Cdc6',
#  'Cdc7',
#  'Cdc73',
#  'Cdk1',
#  'Cdk2',
#  'Cdk4',
#  'Cdk7',
#  'Cdkn1a',
#  'Cdkn1b',
#  'Cdkn2c',
#  'Cetn2',
#  'Chaf1a',
#  'Chaf1b',
#  'Chek1',
#  'Chek2',
#  'Chmp6',
#  'Chtf18',
#  'Clk2',
#  'Clspn',
#  'Crebbp',
#  'Cry1',
#  'Cry2',
#  'Csnk2b',
#  'Cstf2',
#  'Cstf2t',
#  'Cul1',
#  'Cul3',
#  'Dbf4',
#  'Dclre1a',
#  'Dclre1b',
#  'Dclre1c',
#  'Ddb1',
#  'Ddb2',
#  'Ddx11',
#  'Ddx58',
#  'Dhx58',
#  'Dld',
#  'Dmc1',
#  'Dna2',
#  'Dnaja2',
#  'Dnaja4',
#  'Dot1l',
#  'Dut',
#  'E2f1',
#  'E2f2',
#  'E2f3',
#  'E2f4',
#  'Eme1',
#  'Eme2',
#  'Endov',
#  'Ep300',
#  'Ercc1',
#  'Ercc2',
#  'Ercc3',
#  'Ercc4',
#  'Ercc5',
#  'Ercc8',
#  'Espl1',
#  'Exo1',
#  'Fan1',
#  'Fanca',
#  'Fancb',
#  'Fancc',
#  'Fancd2',
#  'Fance',
#  'Fancf',
#  'Fancg',
#  'Fanci',
#  'Fancl',
#  'Fancm',
#  'Fbxo18',
#  'Fen1',
#  'Fzr1',
#  'Gadd45b',
#  'Gadd45g',
#  'Gen1',
#  'Gsk3b',
#  'Gtf2h1',
#  'Gtf2h3',
#  'Gtf2h4',
#  'Gtf2h5',
#  'Hdac1',
#  'Hdac2',
#  'Hdac3',
#  'Helq',
#  'Hltf',
#  'Hspa14',
#  'Hus1',
#  'Hus1b',
#  'Ifih1',
#  'Ighmbp2',
#  'Lig1',
#  'Lig3',
#  'Lig4',
#  'Mad1l1',
#  'Mad2l1',
#  'Mad2l2',
#  'Mbd4',
#  'Mcm2',
#  'Mcm3',
#  'Mcm3ap',
#  'Mcm4',
#  'Mcm5',
#  'Mcm6',
#  'Mcm7',
#  'Mdc1',
#  'Mdm2',
#  'Mgmt',
#  'Mlh1',
#  'Mlh1',
#  'Mlh3',
#  'Mms19',
#  'Mnat1',
#  'Mpg',
#  'Mre11a',
#  'Mrpl2',
#  'Msh2',
#  'Msh3',
#  'Msh4',
#  'Msh5',
#  'Msh6',
#  'Mus81',
#  'Mutyh',
#  'Myc',
#  'Myc',
#  'Nbn',
#  'Neil1',
#  'Neil2',
#  'Neil3',
#  'Nfatc2ip',
#  'Nhej1',
#  'Nprl3',
#  'Nthl1',
#  'Nudt1',
#  'Nup107',
#  'Nup133',
#  'Nup153',
#  'Ogg1',
#  'Orc1',
#  'Orc2',
#  'Orc3',
#  'Orc4',
#  'Orc5',
#  'Orc6',
#  'Palb2',
#  'Parp1',
#  'Parp2',
#  'Parp3',
#  'Pbrm1',
#  'Pcna',
#  'Per1',
#  'Pfdn4',
#  'Pias1',
#  'Pias2',
#  'Pias3',
#  'Pias4',
#  'Pif1',
#  'Pkmyt1',
#  'Plk1',
#  'Pms1',
#  'Pms2',
#  'Pnkp',
#  'Polb',
#  'Pold1',
#  'Pold3',
#  'Pole',
#  'Pole3',
#  'Polg',
#  'Polh',
#  'Poli',
#  'Polk',
#  'Poll',
#  'Polm',
#  'Polq',
#  'Pomp',
#  'Ppp2r5a',
#  'Ppp2r5b',
#  'Ppp2r5c',
#  'Ppp2r5d',
#  'Ppp2r5e',
#  'Prdx1',
#  'Prdx2',
#  'Prdx3',
#  'Prdx4',
#  'Prdx5',
#  'Prdx6',
#  'Prkd1',
#  'Prkd1',
#  'Prkd2',
#  'Prkd3',
#  'Prkdc',
#  'Prpf19',
#  'Prrc2a',
#  'Prrc2c',
#  'Psmd4',
#  'Pttg1',
#  'Rad1',
#  'Rad17',
#  'Rad18',
#  'Rad21',
#  'Rad23a',
#  'Rad23b',
#  'Rad50',
#  'Rad51',
#  'Rad51b',
#  'Rad51c',
#  'Rad51d',
#  'Rad52',
#  'Rad54b',
#  'Rad54b',
#  'Rad54l',
#  'Rad54l2',
#  'Rad9a',
#  'Rad9b',
#  'Rb1',
#  'Rbbp4',
#  'Rbbp7',
#  'Rbbp8',
#  'Rbl1',
#  'Rbl2',
#  'Rbx1',
#  'Recql',
#  'Recql4',
#  'Rev1',
#  'Rev3l',
#  'Rev3l',
#  'Rfc1',
#  'Rfc5',
#  'Rif1',
#  'Rmi1',
#  'Rmnd5a',
#  'Rmnd5b',
#  'Rnaseh2a',
#  'Rnaseh2b',
#  'Rnaseh2c',
#  'Rnf10',
#  'Rnf168',
#  'Rnf4',
#  'Rnf8',
#  'Rpa1',
#  'Rpa2',
#  'Rpa3',
#  'Rrm1',
#  'Rrm2b',
#  'Sac3d1',
#  'Sfn',
#  'Shfm1',
#  'Shprh',
#  'Sirt1',
#  'Sirt5',
#  'Skp1',
#  'Skp2',
#  'Slc25a39',
#  'Slc25a40',
#  'Slk',
#  'Slx1a',
#  'Smad2',
#  'Smad3',
#  'Smad4',
#  'Smarca1',
#  'Smarca5',
#  'Smc1a',
#  'Smc1b',
#  'Smc3',
#  'Smc6',
#  'Smg5',
#  'Smg6',
#  'Smg7',
#  'Smug1',
#  'Spo11',
#  'Sprtn',
#  'Stag1',
#  'Stag2',
#  'Supt3h',
#  'Swsap1',
#  'Tcea2',
#  'Tdg',
#  'Tdp1',
#  'Tdp2',
#  'Tert',
#  'Tfdp1',
#  'Tfdp2',
#  'Tgfb1',
#  'Tgfb2',
#  'Tgfb3',
#  'Timeless',
#  'Tipin',
#  'Tmem30a',
#  'Tmem30b',
#  'Top3a',
#  'Top3b',
#  'Top3b',
#  'Topbp1',
#  'Tp53',
#  'Tp53bp1',
#  'Trex1',
#  'Trex2',
#  'Ttk',
#  'Ube2a',
#  'Ube2b',
#  'Ube2n',
#  'Ube2v1',
#  'Ube2v2',
#  'Ubr1',
#  'Ubr2',
#  'Ung',
#  'Uvssa',
#  'Vps53',
#  'Wapal',
#  'Wdhd1',
#  'Wdr73',
#  'Wee1',
#  'Wee2',
#  'Wrn',
#  'Xab2',
#  'Xpa',
#  'Xpc',
#  'Xrcc1',
#  'Xrcc2',
#  'Xrcc3',
#  'Xrcc4',
#  'Xrcc5',
#  'Xrcc6',
#  'Xrcc6bp1',
#  'Ywhab',
#  'Ywhah',
#  'Ywhaq',
#  'Ywhaz',
#  'Zbtb17',
#  'Zmiz1',
#  'Zswim7']

# %%
tss_meta_dna_repair = tss_meta[tss_meta["Gene"].isin(repair_genes)]["Gene"].unique()

print("Number of repair genes in annotation", len(tss_meta[tss_meta["Gene"].isin(repair_genes)]["Gene"].unique()))
print("Number of overall repair genes", len(np.unique(np.array(repair_genes))))

not_found_in_anno = []
for i in repair_genes:
    if i not in tss_meta["Gene"].values:
        not_found_in_anno.append(i)

print("Number of repair genes not found in annotation", len(not_found_in_anno))
# Out:
# ('Number of repair genes in annotation', 345)
# ('Number of overall repair genes', 390)
# ('Number of repair genes not found in annotation', 45)

# %%
gene_tissue = gene_tissue[gene_tissue.index.isin(repair_genes)]

# %% [markdown]
# # 4. Extract silenced Genes

# %% [markdown]
# ## Calculate Z-score over tissues

# %%
gene_tissue_z = gene_tissue.apply(zscore,axis=1,result_type='broadcast') #gene_tissue.apply(lambda x) zscore(gene_tissue, axis=1)
gene_tissue_z.sum(axis=1)
# Out:
# Wdhd1      1.776357e-15
# Parp2      2.220446e-16
# Apex1      6.661338e-15
# Rev1      -6.661338e-16
# Anapc4    -6.661338e-15
# Rnf4       5.329071e-15
# Uvssa     -2.220446e-16
# Ywhah     -2.886580e-15
# Supt3h     5.329071e-15
# Cdc16      3.774758e-15
# Tfdp1      2.220446e-16
# Lig4       1.110223e-14
# Fancl     -6.661338e-16
# Hus1       6.661338e-16
# Polm      -1.998401e-15
# Helq      -2.664535e-15
# Gtf2h4     1.887379e-15
# Mdc1      -2.220446e-16
# Msh5      -4.996004e-15
# Csnk2b    -5.107026e-15
# Prrc2a    -8.992806e-15
# Fance      1.110223e-16
# Zmiz1      6.661338e-16
# Ccnd3     -7.327472e-15
# Ubr2       4.440892e-16
# Ppp2r5d   -1.332268e-15
# Mrpl2      4.884981e-15
# Polh      -1.332268e-15
# Pbrm1      1.901257e-15
# Actr8     -2.220446e-16
#                ...
# Xpc       -3.108624e-15
# Rad18     -5.512951e-15
# Ogg1      -2.442491e-15
# Fancd2    -1.554312e-15
# Mbd4      -3.885781e-15
# Rmnd5a    -2.220446e-15
# Cdkn1b     6.661338e-16
# Recql     -3.608225e-16
# Mad2l1    -1.748601e-15
# Ccne1     -2.220446e-16
# Tgfb1     -2.220446e-15
# Brsk1     -2.220446e-16
# Ercc2      3.441691e-15
# Ercc1      2.886580e-15
# Xrcc1      1.554312e-15
# Lig1       1.110223e-15
# Prkd2     -1.998401e-15
# Rad21      4.773959e-15
# Rrm2b      4.218847e-15
# Ywhaz     -8.073403e-15
# Myc        1.776357e-15
# Ube2a      1.887379e-15
# Apex2      1.554312e-15
# Smc1a     -4.884981e-15
# Prdx4     -6.217249e-15
# Rbbp7      1.043610e-14
# Fancb      3.330669e-16
# Atrx       1.693090e-15
# Smarca1   -6.661338e-16
# Stag2     -2.886580e-15
# Length: 345, dtype: float64

# %% [markdown]
# ## A. See CHO Genes 2SD below mean

# %%
silenced_cho_2sd = gene_tissue_z[gene_tissue_z["CHO"] < -2]
silenced_cho_2sd
# Out:
#            Heart    Spleen  MiscOrgans  FemaleReproductive       CHO  \
# Prrc2a  0.142615  0.809610   -0.067562           -0.160047 -2.543412
# Aptx   -1.165640  0.799105    0.527244            0.567990 -2.080754
# Pomp   -0.328886  1.169433    1.140963            0.087856 -2.190493
# Gtf2h3 -0.521364  0.764295    0.808280            0.755724 -2.669438
# Mcm7    0.576105 -0.104511   -0.192918            0.377744 -2.361452
# Pcna   -0.860434  1.270653    0.329114            0.206598 -2.585405
# Alkbh3 -0.639802  1.122544    0.943527           -0.633188 -2.116548
# Ddb2   -0.849821  0.905645    0.691191           -0.451245 -2.223172
# Ywhab   0.632674  0.454766    0.453910            0.419403 -2.516078
# Rpa1    0.355682  1.529676    0.690457           -0.253755 -2.187229
# Per1    0.504219  0.028667    0.616569            0.062387 -2.258017
# Mad2l1 -0.178371  1.203453    0.272332            0.370368 -2.108300
# Prkd2   0.734484  1.207136    0.968430            1.287272 -2.047030
# Ywhaz   0.167786  0.657237    0.612402            1.061941 -2.773008
# Rbbp7   1.313438 -0.116244   -0.292284            0.260916 -2.811164
#
#         BMDM1hKLA     Brain      Lung     Liver    BMDMwt    Muscle    Kidney  \
# Prrc2a   1.036469  0.621093 -0.245030 -0.467734  1.651365  0.619398 -0.691651
# Aptx     0.271866  0.928740 -0.460283 -0.090155  0.825900  1.183193  0.341302
# Pomp    -0.893668  1.325398 -0.973606  0.527874 -0.537980  0.942431  0.323999
# Gtf2h3   0.282959  0.355763 -0.819969  0.245485 -0.975494  1.344220  0.257708
# Mcm7     0.657590  0.238287  0.254940 -0.619519  1.796228  0.657849  0.221215
# Pcna     0.475329  0.500616 -0.582229  0.808077  0.790118  0.896277 -0.365513
# Alkbh3  -0.807402  1.158290  0.258076 -0.502706 -0.802950  0.888245 -0.199689
# Ddb2    -0.893424  0.005333  0.250062  0.648682  0.942372  0.265196  1.647327
# Ywhab    0.245032  1.728964  0.028546 -1.295634  0.664350  0.162691 -0.538350
# Rpa1    -0.870390  0.886749 -0.926909 -0.513564  1.143749  0.829863 -0.736305
# Per1    -1.188645  0.334717  1.348865  0.531228 -1.362700  1.049422  0.724283
# Mad2l1   1.183700  0.155558 -0.748872 -0.468948  1.880034 -0.479636 -0.933310
# Prkd2   -0.596932 -0.084726  0.333112 -1.270878  0.483213  0.131349  0.208867
# Ywhaz   -0.590961  1.490343 -0.298658 -0.635333 -0.040182  0.510013 -0.149997
# Rbbp7    0.339190 -0.240805  1.408574 -0.116971  0.816278  0.213826 -0.281863
#
#         Pancreas
# Prrc2a -0.705115
# Aptx   -1.648508
# Pomp   -0.593319
# Gtf2h3  0.171829
# Mcm7   -1.501558
# Pcna   -0.883202
# Alkbh3  1.331604
# Ddb2   -0.938145
# Ywhab  -0.440275
# Rpa1    0.051974
# Per1   -0.390993
# Mad2l1 -0.148007
# Prkd2  -1.354299
# Ywhaz  -0.011584
# Rbbp7  -0.492891

# %% [markdown]
# ## Get CHO less than 1 TPM

# %%
pseudocount = 1 # This is b/c 1 was added to TPM in log when taking the average
silenced_cho_1tpm = gene_tissue.loc[gene_tissue["CHO"] < np.log10(1+pseudocount)].index
print("Number of CHO genes less than 1TPM:", len(silenced_cho_1tpm))
silenced_cho_1tpm
# Out:
# ('Number of CHO genes less than 1TPM:', 72)
# Index([u'Parp2', u'Ywhah', u'Cdc16', u'Tfdp1', u'Hus1', u'Mdc1', u'Pbrm1',
#        u'Cul1', u'Neil2', u'Rnaseh2b', u'Wee2', u'Timeless', u'Mcm3', u'Clk2',
#        u'Bcr', u'Mcm3ap', u'Cdkn1a', u'Ccna1', u'Dna2', u'Msh4', u'Polb',
#        u'Smad2', u'Pias2', u'Rbbp4', u'Hdac1', u'E2f2', u'Ccno', u'Rbbp8',
#        u'Rad23a', u'Dnaja2', u'Brsk2', u'Mgmt', u'Cdc14b', u'Rmi1', u'Gadd45g',
#        u'Mcm5', u'Ttk', u'Gsk3b', u'Gtf2h3', u'Rad9b', u'Anapc13', u'Rad54l2',
#        u'Mlh1', u'Dnaja4', u'Mcm7', u'Chaf1b', u'Xab2', u'Chek2', u'Smg7',
#        u'Tmem30b', u'Tgfb3', u'Ppp2r5a', u'Tgfb2', u'Pias4', u'Pold1',
#        u'Tp53bp1', u'Ddb2', u'Ube2v1', u'Ywhab', u'Eme1', u'Ercc4', u'Chmp6',
#        u'Prkd3', u'Camkk1', u'Tp53', u'Dhx58', u'Ccne1', u'Tgfb1', u'Brsk1',
#        u'Ercc2', u'Ercc1', u'Prkd2'],
#       dtype='object')

# %% [markdown]
# ## B and C. More than 75% /100% of the other tissues are on

# %%
n_samples = len(gene_tissue.columns)-1 # Remove CHO
cutoffs = dict()
gene_tissue_silenced = gene_tissue.drop(["CHO"],axis=1) < np.log10(1+pseudocount)

num_tissues_silenced = gene_tissue_silenced.sum(axis=1)
cutoffs[75] = num_tissues_silenced[num_tissues_silenced < (1-0.75)*n_samples].index
cutoffs[90] = num_tissues_silenced[num_tissues_silenced < (1-0.9)*n_samples].index

cutoffs[100] = num_tissues_silenced[num_tissues_silenced ==0].index




cho_75 = set(silenced_cho_1tpm).intersection(cutoffs[75])
cho_90 = set(silenced_cho_1tpm).intersection(cutoffs[90])
cho_100 = set(silenced_cho_1tpm).intersection(cutoffs[100])

print("75th percentile number of silenced genes:", len(cho_75))
print("90th percentile number of silenced genes:", len(cho_90))
print("100th percentile number of silenced genes:", len(cho_100))
# Out:
# ('75th percentile number of silenced genes:', 24)
# ('90th percentile number of silenced genes:', 17)
# ('100th percentile number of silenced genes:', 8)

# %% [markdown]
# ## D. CHO IQR outlier

# %%
gene_iqr = iqr(gene_tissue,axis=1)
lower_quart = np.percentile(gene_tissue,25,axis=1)
iqr_outlier_thresh = lower_quart - gene_iqr*1.5

silenced_cho_1tpm_iqr_outlier = gene_tissue[gene_tissue["CHO"] < iqr_outlier_thresh].index
print("Number of genes: ", len(silenced_cho_1tpm_iqr_outlier))
silenced_cho_1tpm_iqr_outlier
# Out:
# ('Number of genes: ', 12)
# Index([u'Cdc16', u'Prrc2a', u'Rad1', u'Gtf2h3', u'Mcm7', u'Ywhab', u'Per1',
#        u'Skp1', u'Mad2l1', u'Rrm2b', u'Ywhaz', u'Rbbp7'],
#       dtype='object')

# %%
outlier_methods_df = pd.DataFrame(
    index=["Genes", "Number of Genes"],
    columns=[
        "IQR", "1TPM", "1TPM and 75 percent tissues on",
        "1TPM and 90 percent tissues on", "1TPM and 100 percent tissues on",
        "Zscore -2"
    ])

outlier_methods_df.loc["Number of Genes"] = [
    len(silenced_cho_1tpm_iqr_outlier),
    len(silenced_cho_1tpm),
    len(cho_75),
    len(cho_90),
    len(cho_100), 
    len(silenced_cho_2sd)
]
outlier_methods_df.loc["Genes"] = [
    set(silenced_cho_1tpm_iqr_outlier),
    set(silenced_cho_1tpm), cho_75, cho_90, cho_100, set(silenced_cho_2sd.index.values)
]
outlier_methods_df
# Out:
#                                                                IQR  \
# Genes            {Ywhaz, Mad2l1, Cdc16, Skp1, Gtf2h3, Prrc2a, R...
# Number of Genes                                                 12
#
#                                                               1TPM  \
# Genes            {Rbbp8, Brsk2, Prkd3, Mdc1, Msh4, Rbbp4, Pias2...
# Number of Genes                                                 72
#
#                                     1TPM and 75 percent tissues on  \
# Genes            {Rbbp4, Mcm7, Anapc13, Pias4, Pbrm1, Hdac1, Sm...
# Number of Genes                                                 24
#
#                                     1TPM and 90 percent tissues on  \
# Genes            {Hdac1, Smg7, Cdc16, Gtf2h3, Cdkn1a, Ppp2r5a, ...
# Number of Genes                                                 17
#
#                                    1TPM and 100 percent tissues on  \
# Genes            {Hdac1, Smg7, Gtf2h3, Rbbp4, Ywhab, Pias4, Ddb...
# Number of Genes                                                  8
#
#                                                          Zscore -2
# Genes            {Pcna, Ywhaz, Mad2l1, Pomp, Gtf2h3, Rbbp7, Prr...
# Number of Genes                                                 15

# %% [markdown]
# # 5. Plot silenced genes values

# %%
for col in outlier_methods_df.columns.values:
    curr_order = gene_tissue.loc[outlier_methods_df.loc["Genes",col]].apply(lambda x: x.sum(), axis=1).sort_values().index
    curr_genes = gene_tissue.loc[curr_order]
    zip(range(len(curr_genes)), curr_genes.index)

    # Construct scatter values
    cho_scatter_x = []
    cho_scatter_y = []
    tissue_scatter_x = []
    tissue_scatter_y = []
    n_tissues = curr_genes.shape[1] - 1
    for i in zip(range(len(curr_genes)), curr_genes.index):
        cho_scatter_y.append(i[0])
        cho_scatter_x.append(gene_tissue.loc[i[1],"CHO"])
        tissue_scatter_y += [i[0]] * n_tissues
        tissue_scatter_x += list(gene_tissue.drop("CHO",axis=1).loc[i[1]].values)


    f, ax = plt.subplots()
    ax.scatter(tissue_scatter_x,tissue_scatter_y)
    ax.scatter(cho_scatter_x,cho_scatter_y,color="g")
    plt.ylabel("Gene")
    plt.xlabel("Log10(TPM+1)")
    ax.set_yticks(range(len(cho_scatter_y)))
    ax.set_yticklabels(curr_genes.index.values);
    plt.title(col);
    
    name =os.path.join(save_dir,"repair_genes_method_" + col.replace(" ",""))
    plt.savefig(name+".png")
    #gene_tissue.loc[]
    curr_genes.to_csv(name + ".txt")
#     with open(name+".txt","w") as f:
        
#         f.write("\n".join(list(curr_genes.index.values)))

# %% [markdown]
# # 6. Overlap of genes across the different thresholding methods

# %% [markdown]
# ## Plot the two

# %% [raw]
# ### Without removing 0s
