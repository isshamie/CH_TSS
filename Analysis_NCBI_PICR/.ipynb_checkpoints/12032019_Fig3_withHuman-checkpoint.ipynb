# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys
import os

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
ref_fa = doc["ref_fa"]
sys.path.append(doc['pipeline_path'])



from Homer import *
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
savedir = "Results/Figures/12032019/Figure3"
if not os.path.exists(savedir):
    os.mkdir(savedir)
    
hum_ref_fa = '/data/isshamie/genome/hg38/GCF_000001405.38_GRCh38.p12_genomic.fna'

# %%
eTSS = "Results/output/TSS1.exp.bed"
eTSS_out = os.path.join(savedir, "eTSS_100")
homer_nucleotide(eTSS,
    eTSS_out,
    ref_fa,
    size=100)

rTSS = "Results/Figures/Figure3/alt/A.TSS1_mrna"
rTSS_out = os.path.join(savedir, "rTSS_100")
homer_nucleotide(rTSS,
    rTSS_out,
    ref_fa,
    size=100)

humTSS = "/data/isshamie/genome/hg38/mRNA_final.peak"
humTSS_out = os.path.join(savedir, "humTSS_100")

homer_nucleotide(humTSS,
    humTSS_out,
    hum_ref_fa,
    size=100)
# Out:
# annotatePeaks.pl Results/output/TSS1.exp.bed /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 100 -hist 1 -di > Results/Figures/12032019/Figure3/eTSS_100
# annotatePeaks.pl Results/Figures/Figure3/alt/A.TSS1_mrna /data/isshamie/genome/ncbi_anno_103/GCF_003668045.1_CriGri-PICR_genomic.fna -size 100 -hist 1 -di > Results/Figures/12032019/Figure3/rTSS_100
# annotatePeaks.pl /data/isshamie/genome/hg38/mRNA_final.peak /data/isshamie/genome/hg38/GCF_000001405.38_GRCh38.p12_genomic.fna -size 100 -hist 1 -di > Results/Figures/12032019/Figure3/humTSS_100

# %%
size = 100
f1 = "hg38_seq/hg38_nucfreq_100"
f2 = "Results/Figures/Figure3/alt/A.TSS1_mrna"
f3 = "Results/output/TSS1.exp.bed"


f = plt.figure()
#(0.05,0.65)
wrap_plots([humTSS_out,rTSS_out,eTSS_out],homer_nucleotide,os.path.join(savedir,"C.combine"),["Human RefSeq","Hamster RefSeq","expTSS"],None,size,(0.05,0.6),True)
