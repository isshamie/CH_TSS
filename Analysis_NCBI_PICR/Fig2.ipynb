# %%
## Parameters specific to where your folders are and your data
parameter_file = 'params/params.yaml'
import yaml
import sys

with open(parameter_file,'r') as f:
    doc = yaml.load(f)

#p = dic2obj(**doc)

data_folder = doc['data_folder']
tissues = doc['tissues'].split(',')
sys.path.append(doc['pipeline_path'])
ref_fa = doc['ref_fa']
anno_gff=doc['annotation']


tss_annotation = doc['tss_annotation']


import os
import sys
import pandas as pd
import seaborn as sns
import pickle
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from itertools import product
import glob
import re
from matplotlib_venn import venn2
from matplotlib import rcParams
import inspect
mpl.style.use('ggplot')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.setrecursionlimit(3000)
# %load_ext autoreload
# %autoreload 2
rcParams['figure.figsize'] = 8, 6
import tqdm

from os.path import basename


#mpl.use('nbagg')
##mpl.use('Agg')
#mpl.style.use('ggplot')
#mpl.style.use('fivethirtyeight')
from Homer import *

print('Number of tissues: ',len(tissues))
# Out:
# ('Number of tissues: ', 13)

# %%
import plot_tss_results

# %%
f_in = 'Results/tss_annotation/gene_df_02.p' 

df = pickle.load(open(f_in,'rb'))

# %%
landmark_name='genes'

# %% [markdown]
# ## peak bins -1kb:+1kb, no introns

# %%
if not os.path.exists("Results/Figures/Figure2"):
    os.makedirs("Results/Figures/Figure2")

# %%
f_in = 'Results/tss_annotation/gene_df_02_tissues.p' 
f_save = 'Results/Figures/Figure2/gene_df_02_tissues_frac_unique'
plot_tss_results.plot_tss_across_tissues_plus_unique(f_in, tissues, landmark_name='genes',f_save=f_save)

# %%
f_in = 'Results/tss_annotation/gene_df_02_tissues.p' 
f_save = 'Results/Figures/Figure2/gene_df_02_tissues_cho_venn'
plot_tss_results.find_unique_cho(f_in,f_save=f_save);

# f_save = 'Results/Figures/Figure2/gene_df_02_tissues_frac_unique'
# find_unique_cho(df,"Tissues")

# %%
f_in = 'Results/tss_annotation/txn_df_02_tissues.p'

f_save = 'Results/Figures/Figure2/txn_df_02_tissues_frac_unique'
plot_tss_results.plot_tss_across_tissues_plus_unique(f_in, tissues, landmark_name='Transcript',f_save=f_save)

# %%
f_in = 'Results/tss_annotation/txn_df_02_tissues.p' 
f_save = 'Results/Figures/Figure2/txn_df_02_tissues_cho_venn'
plot_tss_results.find_unique_cho(f_in,f_save=f_save);

# f_save = 'Results/Figures/Figure2/gene_df_02_tissues_frac_unique'
# find_unique_cho(df,"Tissues")
